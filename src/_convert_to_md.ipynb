# %% [markdown]
# # convert notebooks to markdown

# %%
from pandas_plots.cli import converter
import os

os.makedirs("./quality-reports/docs/clin", exist_ok=True)
os.makedirs("./quality-reports/docs/epi", exist_ok=True)
os.makedirs("./quality-analysis/01-colorectal/docs", exist_ok=True)
os.makedirs("./quality-analysis/02-date-periods/docs", exist_ok=True)
os.makedirs("./quality-analysis/03-fm/docs", exist_ok=True)
os.makedirs("./quality-analysis/04-relapse/docs", exist_ok=True)
os.makedirs("./quality-analysis/05-further-class/docs", exist_ok=True)
os.makedirs("./quality-analysis/06-triple-n/docs", exist_ok=True)
os.makedirs("./quality-analysis/07-c07/docs", exist_ok=True)
os.makedirs("./quality-analysis/08-c50-brain/docs", exist_ok=True)
os.makedirs("./quality-analysis/09-c61-gleason/docs", exist_ok=True)

converter.jupyter_to_md("./quality-reports/clin_2_analyze.ipynb",no_input=True, output_dir="./quality-reports/docs/clin")
# converter.jupyter_to_md("./quality-reports/epi_2_analyze.ipynb",no_input=True, output_dir="./quality-reports/docs/epi")

converter.jupyter_to_md("./quality-analysis/01-colorectal/colorectal.ipynb",no_input=True, output_dir="./quality-analysis/01-colorectal/docs")
converter.jupyter_to_md("./quality-analysis/02-date-periods/date_periods.ipynb",no_input=True, output_dir="./quality-analysis/02-date-periods/docs", execute=False)
converter.jupyter_to_md("./quality-analysis/03-fm/fm.ipynb",no_input=True, output_dir="./quality-analysis/03-fm/docs")
converter.jupyter_to_md("./quality-analysis/04-relapse/relapse.ipynb",no_input=True, output_dir="./quality-analysis/04-relapse/docs")
converter.jupyter_to_md("./quality-analysis/05-further-class/further_class.ipynb",no_input=True, output_dir="./quality-analysis/05-further-class/docs")
converter.jupyter_to_md("./quality-analysis/06-triple-n/triple_n.ipynb",no_input=True, output_dir="./quality-analysis/06-triple-n/docs")
converter.jupyter_to_md("./quality-analysis/07-c07/c07.ipynb",no_input=True, output_dir="./quality-analysis/07-c07/docs")
converter.jupyter_to_md("./quality-analysis/09-c61-gleason/c61_gleason.ipynb",no_input=True, output_dir="./quality-analysis/09-c61-gleason/docs")
# Out:
# Converting ./quality-reports/clin_2_analyze.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-reports/docs/clin/clin_2_analyze.md
# └ DEBUG: INSERTED after Line 470 in file clin_2_analyze.md
# └ ✅ SUCCESS: File successfully processed: ./quality-reports/docs/clin/clin_2_analyze.md. Missing <br> tags inserted.
# Converting ./quality-analysis/01-colorectal/colorectal.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-analysis/01-colorectal/docs/colorectal.md
# └ ℹ️ NO CHANGES: All target chunks already contained the line-separated <br> tag in: ./quality-analysis/01-colorectal/docs/colorectal.md or no targets found.
# Converting ./quality-analysis/02-date-periods/date_periods.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-analysis/02-date-periods/docs/date_periods.md
# └ ℹ️ NO CHANGES: All target chunks already contained the line-separated <br> tag in: ./quality-analysis/02-date-periods/docs/date_periods.md or no targets found.
# Converting ./quality-analysis/03-fm/fm.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-analysis/03-fm/docs/fm.md
# └ DEBUG: INSERTED after Line 11 in file fm.md
# └ ✅ SUCCESS: File successfully processed: ./quality-analysis/03-fm/docs/fm.md. Missing <br> tags inserted.
# Converting ./quality-analysis/04-relapse/relapse.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-analysis/04-relapse/docs/relapse.md
# └ ℹ️ NO CHANGES: All target chunks already contained the line-separated <br> tag in: ./quality-analysis/04-relapse/docs/relapse.md or no targets found.
# Converting ./quality-analysis/05-further-class/further_class.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-analysis/05-further-class/docs/further_class.md
# └ ℹ️ NO CHANGES: All target chunks already contained the line-separated <br> tag in: ./quality-analysis/05-further-class/docs/further_class.md or no targets found.
# Converting ./quality-analysis/06-triple-n/triple_n.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-analysis/06-triple-n/docs/triple_n.md
# └ DEBUG: INSERTED after Line 55 in file triple_n.md
# └ ✅ SUCCESS: File successfully processed: ./quality-analysis/06-triple-n/docs/triple_n.md. Missing <br> tags inserted.
# Converting ./quality-analysis/07-c07/c07.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-analysis/07-c07/docs/c07.md
# └ ℹ️ NO CHANGES: All target chunks already contained the line-separated <br> tag in: ./quality-analysis/07-c07/docs/c07.md or no targets found.
# Converting ./quality-analysis/09-c61-gleason/c61_gleason.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-analysis/09-c61-gleason/docs/c61_gleason.md
# └ DEBUG: INSERTED after Line 9 in file c61_gleason.md
# └ ✅ SUCCESS: File successfully processed: ./quality-analysis/09-c61-gleason/docs/c61_gleason.md. Missing <br> tags inserted.
