# %% [markdown]
# # convert notebooks to markdown

# %%
from pandas_plots.cli import converter
import os

os.makedirs("./quality-reports/docs/clin", exist_ok=True)
os.makedirs("./quality-reports/docs/epi", exist_ok=True)
os.makedirs("./quality-analysis/01-colorectal/docs", exist_ok=True)
os.makedirs("./quality-analysis/02-date-periods/docs", exist_ok=True)
os.makedirs("./quality-analysis/03-fm/docs", exist_ok=True)
os.makedirs("./quality-analysis/04-relapse/docs", exist_ok=True)
os.makedirs("./quality-analysis/05-further-class/docs", exist_ok=True)
os.makedirs("./quality-analysis/06-triple-n/docs", exist_ok=True)
os.makedirs("./quality-analysis/07-c07/docs", exist_ok=True)
os.makedirs("./quality-analysis/08-c50-brain/docs", exist_ok=True)
os.makedirs("./quality-analysis/09-c61-gleason/docs", exist_ok=True)
os.makedirs("./section-12-report/docs", exist_ok=True)

# converter.jupyter_to_md("./section-12-report/report.ipynb",no_input=True, output_dir="./section-12-report/docs")

converter.jupyter_to_md("./quality-reports/clin_analyze.ipynb",no_input=True, output_dir="./quality-reports/docs/clin",)
# converter.jupyter_to_md("./quality-reports/clin_tech.ipynb",no_input=True, output_dir="./quality-reports/docs/clin")
# converter.jupyter_to_md("./quality-reports/epi.ipynb",no_input=True, output_dir="./quality-reports/docs/epi")

# converter.jupyter_to_md("./quality-analysis/01-colorectal/colorectal.ipynb",no_input=True, output_dir="./quality-analysis/01-colorectal/docs")
# converter.jupyter_to_md("./quality-analysis/02-date-periods/date_periods.ipynb",no_input=True, output_dir="./quality-analysis/02-date-periods/docs", execute=False)
# converter.jupyter_to_md("./quality-analysis/03-fm/fm.ipynb",no_input=True, output_dir="./quality-analysis/03-fm/docs")
# converter.jupyter_to_md("./quality-analysis/04-relapse/relapse.ipynb",no_input=True, output_dir="./quality-analysis/04-relapse/docs")
# converter.jupyter_to_md("./quality-analysis/05-further-class/further_class.ipynb",no_input=True, output_dir="./quality-analysis/05-further-class/docs")
# converter.jupyter_to_md("./quality-analysis/06-triple-n/triple_n.ipynb",no_input=True, output_dir="./quality-analysis/06-triple-n/docs")
# converter.jupyter_to_md("./quality-analysis/07-c07/c07.ipynb",no_input=True, output_dir="./quality-analysis/07-c07/docs")
# converter.jupyter_to_md("./quality-analysis/09-c61-gleason/c61_gleason.ipynb",no_input=True, output_dir="./quality-analysis/09-c61-gleason/docs")
# Out:
# Converting ./quality-reports/clin_analyze.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-reports/docs/clin/clin_analyze.md
# └ ✅ SUCCESS: File successfully processed: ./quality-reports/docs/clin/clin_analyze.md. Missing <br> tags inserted.
# └ ℹ️ NO CHANGES: No block found between '<!-- START_TOKEN_PYTHON -->' and '<!-- END_TOKEN_PYTHON -->' in: ./quality-reports/docs/clin/clin_analyze.md or block already enclosed.
# └ ✅ SUCCESS: Block enclosed from line 2430 to 2440. Tokens were removed.
# └ ✅ SUCCESS: Block enclosed from line 1226 to 1231. Tokens were included.
# └ ✅ SUCCESS: Image scaling applied to: ./quality-reports/docs/clin/clin_analyze.md
# Converting ./quality-reports/clin_tech.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-reports/docs/clin/clin_tech.md
# └ ✅ SUCCESS: File successfully processed: ./quality-reports/docs/clin/clin_tech.md. Missing <br> tags inserted.
# └ ℹ️ NO CHANGES: No block found between '<!-- START_TOKEN_PYTHON -->' and '<!-- END_TOKEN_PYTHON -->' in: ./quality-reports/docs/clin/clin_tech.md or block already enclosed.
# └ ✅ SUCCESS: Block enclosed from line 696 to 698. Tokens were removed.
# └ ✅ SUCCESS: Block enclosed from line 700 to 709. Tokens were included.
# └ ℹ️ NO CHANGES: No scalable images found in: ./quality-reports/docs/clin/clin_tech.md
# Converting ./quality-reports/epi.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-reports/docs/epi/epi.md
# └ ✅ SUCCESS: File successfully processed: ./quality-reports/docs/epi/epi.md. Missing <br> tags inserted.
# └ ℹ️ NO CHANGES: No block found between '<!-- START_TOKEN_PYTHON -->' and '<!-- END_TOKEN_PYTHON -->' in: ./quality-reports/docs/epi/epi.md or block already enclosed.
# └ ✅ SUCCESS: Block enclosed from line 906 to 915. Tokens were removed.
# └ ℹ️ NO CHANGES: No block found between '┌──────' and '└─────────' in: ./quality-reports/docs/epi/epi.md or block already enclosed.
# └ ✅ SUCCESS: Image scaling applied to: ./quality-reports/docs/epi/epi.md
