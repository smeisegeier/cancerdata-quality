# %% [markdown]
# # convert notebooks to markdown

# %%
from pandas_plots.cli import converter
from pandas_plots import hlp

hlp.show_package_version()

# converter.jupyter_to_md("./section-12-report/report.ipynb",no_input=True, output_dir="./section-12-report/docs", theme="system", to_pdf=False, is_german=True)
# converter.jupyter_to_html("./section-12-report/report.ipynb",no_input=True, output_dir="./section-12-report/docs", use_base64=False, is_german=True)
# converter.jupyter_to_md("./section-12-report/report.ipynb",no_input=True, output_dir="./section-12-report/docs", theme="light", to_pdf=True, is_german=True)

converter.jupyter_to_md("./quality-reports/clin.ipynb",no_input=True, output_dir="./quality-reports/docs/clin",theme="system",is_german=True)
converter.jupyter_to_html("./quality-reports/clin.ipynb",no_input=True, output_dir="./quality-reports/docs/clin",use_base64=False,is_german=True)
# converter.jupyter_to_md("./quality-reports/clin.ipynb",no_input=True, output_dir="./quality-reports/docs/clin",theme="light",is_german=True, to_pdf=True)  # ! set to pdf before

converter.jupyter_to_md("./quality-reports/epi.ipynb",no_input=True, output_dir="./quality-reports/docs/epi", theme="system", is_german=True)
converter.jupyter_to_html("./quality-reports/epi.ipynb",no_input=True, output_dir="./quality-reports/docs/epi", use_base64=False, is_german=True)
# converter.jupyter_to_md("./quality-reports/epi.ipynb",no_input=True, output_dir="./quality-reports/docs/epi")

converter.jupyter_to_md("./quality-reports/tech.ipynb",no_input=True, output_dir="./quality-reports/docs/tech", theme="system", is_german=True)
converter.jupyter_to_html("./quality-reports/tech.ipynb",no_input=True, output_dir="./quality-reports/docs/tech", use_base64=False, is_german=True)

converter.jupyter_to_md("./quality-reports/internal.ipynb",no_input=True, output_dir="./quality-reports/docs/tech", theme="system", is_german=True)

# converter.jupyter_to_md("./quality-analysis/01-colorectal/colorectal.ipynb",no_input=True, output_dir="./quality-analysis/01-colorectal/docs")
# converter.jupyter_to_html("./quality-analysis/01-colorectal/colorectal.ipynb",no_input=True, output_dir="./quality-analysis/01-colorectal/docs")
# converter.jupyter_to_md("./quality-analysis/02-date-periods/date_periods.ipynb",no_input=True, output_dir="./quality-analysis/02-date-periods/docs", execute=False)
# converter.jupyter_to_md("./quality-analysis/03-fm/fm.ipynb",no_input=True, output_dir="./quality-analysis/03-fm/docs")
# converter.jupyter_to_md("./quality-analysis/04-relapse/relapse.ipynb",no_input=True, output_dir="./quality-analysis/04-relapse/docs")
# converter.jupyter_to_md("./quality-analysis/05-further-class/further_class.ipynb",no_input=True, output_dir="./quality-analysis/05-further-class/docs")
# converter.jupyter_to_md("./quality-analysis/06-triple-n/triple_n.ipynb",no_input=True, output_dir="./quality-analysis/06-triple-n/docs")
# converter.jupyter_to_md("./quality-analysis/07-c07/c07.ipynb",no_input=True, output_dir="./quality-analysis/07-c07/docs")
# converter.jupyter_to_md("./quality-analysis/09-c61-gleason/c61_gleason.ipynb",no_input=True, output_dir="./quality-analysis/09-c61-gleason/docs")
# Out:
# 🐍 3.12.8 | 📦 pandas: 2.3.3 | 📦 numpy: 1.26.4 | 📦 duckdb: 1.5.0 | 📦 pandas-plots: 2.0.3
# [theme: system]
# [1/2] dark theme ..
# Pre-executing ./quality-reports/clin.ipynb ..
# Converting ./quality-reports/clin.ipynb to Markdown using dataframe-image python API ..
# [2/2] light theme ..
# Pre-executing ./quality-reports/clin.ipynb ..
# Converting ./quality-reports/clin.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-reports/docs/clin/clin.md
# └ ✅ SUCCESS: File successfully processed: ./quality-reports/docs/clin/clin.md. Missing <br> tags inserted.
# └ ℹ️ NO CHANGES: No block found between '<!-- START_TOKEN_PYTHON -->' and '<!-- END_TOKEN_PYTHON -->' in: ./quality-reports/docs/clin/clin.md or block already enclosed.
# └ ✅ SUCCESS: Block enclosed from line 2775 to 2786. Tokens were removed.
# └ ✅ SUCCESS: Block enclosed from line 634 to 641. Tokens were included.
# └ ✅ SUCCESS: MD images normalized to <img> in: ./quality-reports/docs/clin/clin.md
# └ ✅ SUCCESS: Image scaling applied to: ./quality-reports/docs/clin/clin.md
# └ ✅ SUCCESS: Alt text injected in: ./quality-reports/docs/clin/clin.md
# └ ✅ SUCCESS: GitHub theming applied to: ./quality-reports/docs/clin/clin.md
# └ ✅ SUCCESS: German translations applied to: ./quality-reports/docs/clin/clin.md
# Converting ./quality-reports/clin.ipynb to HTML ..
# └ ✅ SUCCESS: ./quality-reports/docs/clin/clin.html
# └ ✅ SUCCESS: German translations applied to: ./quality-reports/docs/clin/clin.html
# [theme: system]
# [1/2] dark theme ..
# Pre-executing ./quality-reports/epi.ipynb ..
# Converting ./quality-reports/epi.ipynb to Markdown using dataframe-image python API ..
# [2/2] light theme ..
# Pre-executing ./quality-reports/epi.ipynb ..
# Converting ./quality-reports/epi.ipynb to Markdown using dataframe-image python API ..
# └ ✅ reconciled dark filename: output_48_7.png → output_48_8.png
# └ ✅ reconciled dark filename: output_50_9.svg → output_50_8.svg
# └ ✅ reconciled dark filename: output_40_5.svg → output_40_6.svg
# └ ✅ reconciled dark filename: output_22_5.png → output_22_6.png
# └ ✅ Successfully removed CSS rules and updated: ./quality-reports/docs/epi/epi.md
# └ ✅ SUCCESS: File successfully processed: ./quality-reports/docs/epi/epi.md. Missing <br> tags inserted.
# └ ℹ️ NO CHANGES: No block found between '<!-- START_TOKEN_PYTHON -->' and '<!-- END_TOKEN_PYTHON -->' in: ./quality-reports/docs/epi/epi.md or block already enclosed.
# └ ✅ SUCCESS: Block enclosed from line 778 to 794. Tokens were removed.
# └ ℹ️ NO CHANGES: No block found between '┌──────' and '└─────────' in: ./quality-reports/docs/epi/epi.md or block already enclosed.
# └ ✅ SUCCESS: MD images normalized to <img> in: ./quality-reports/docs/epi/epi.md
# └ ✅ SUCCESS: Image scaling applied to: ./quality-reports/docs/epi/epi.md
# └ ℹ️ NO CHANGES: No ALT_TEXT tokens found in: ./quality-reports/docs/epi/epi.md
# └ ✅ SUCCESS: GitHub theming applied to: ./quality-reports/docs/epi/epi.md
# └ ✅ SUCCESS: German translations applied to: ./quality-reports/docs/epi/epi.md
# Converting ./quality-reports/epi.ipynb to HTML ..
# └ ✅ SUCCESS: ./quality-reports/docs/epi/epi.html
# └ ✅ SUCCESS: German translations applied to: ./quality-reports/docs/epi/epi.html
# [theme: system]
# [1/2] dark theme ..
# Pre-executing ./quality-reports/tech.ipynb ..
# Converting ./quality-reports/tech.ipynb to Markdown using dataframe-image python API ..
# [2/2] light theme ..
# Pre-executing ./quality-reports/tech.ipynb ..
# Converting ./quality-reports/tech.ipynb to Markdown using dataframe-image python API ..
# └ ✅ reconciled dark filename: output_89_72.svg → output_89_71.svg
# └ ✅ reconciled dark filename: output_89_73.png → output_89_72.png
# └ ✅ reconciled dark filename: output_50_1.png → output_50_2.png
# └ ✅ Successfully removed CSS rules and updated: ./quality-reports/docs/tech/tech.md
# └ ✅ SUCCESS: File successfully processed: ./quality-reports/docs/tech/tech.md. Missing <br> tags inserted.
# └ ℹ️ NO CHANGES: No block found between '<!-- START_TOKEN_PYTHON -->' and '<!-- END_TOKEN_PYTHON -->' in: ./quality-reports/docs/tech/tech.md or block already enclosed.
# └ ✅ SUCCESS: Block enclosed from line 1337 to 1339. Tokens were removed.
# └ ✅ SUCCESS: Block enclosed from line 1335 to 1342. Tokens were included.
# └ ✅ SUCCESS: MD images normalized to <img> in: ./quality-reports/docs/tech/tech.md
# └ ✅ SUCCESS: Image scaling applied to: ./quality-reports/docs/tech/tech.md
# └ ℹ️ NO CHANGES: No ALT_TEXT tokens found in: ./quality-reports/docs/tech/tech.md
# └ ✅ SUCCESS: GitHub theming applied to: ./quality-reports/docs/tech/tech.md
# └ ✅ SUCCESS: German translations applied to: ./quality-reports/docs/tech/tech.md
# Converting ./quality-reports/tech.ipynb to HTML ..
# └ ✅ SUCCESS: ./quality-reports/docs/tech/tech.html
# └ ✅ SUCCESS: German translations applied to: ./quality-reports/docs/tech/tech.html
# [theme: system]
# [1/2] dark theme ..
# Pre-executing ./quality-reports/internal.ipynb ..
# Converting ./quality-reports/internal.ipynb to Markdown using dataframe-image python API ..
# [2/2] light theme ..
# Pre-executing ./quality-reports/internal.ipynb ..
# Converting ./quality-reports/internal.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./quality-reports/docs/tech/internal.md
# └ ℹ️ NO CHANGES: All target chunks already contained the line-separated <br> tag in: ./quality-reports/docs/tech/internal.md or no targets found.
# └ ℹ️ NO CHANGES: No block found between '<!-- START_TOKEN_PYTHON -->' and '<!-- END_TOKEN_PYTHON -->' in: ./quality-reports/docs/tech/internal.md or block already enclosed.
# └ ✅ SUCCESS: Block enclosed from line 75 to 77. Tokens were removed.
# └ ✅ SUCCESS: Block enclosed from line 79 to 94. Tokens were included.
# └ ✅ SUCCESS: MD images normalized to <img> in: ./quality-reports/docs/tech/internal.md
# └ ℹ️ NO CHANGES: No scalable images found in: ./quality-reports/docs/tech/internal.md
# └ ℹ️ NO CHANGES: No ALT_TEXT tokens found in: ./quality-reports/docs/tech/internal.md
# └ ✅ SUCCESS: GitHub theming applied to: ./quality-reports/docs/tech/internal.md
# └ ✅ SUCCESS: German translations applied to: ./quality-reports/docs/tech/internal.md
