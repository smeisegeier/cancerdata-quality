# %% [markdown]
# # convert notebooks to markdown

# %%
from pandas_plots.cli import converter
converter.jupyter_to_md(
    "./clin_2_analyze.ipynb",
    no_input=True,
)
# Out:
# Successfully removed CSS rules and updated: ./docs/clin_2_analyze.md
