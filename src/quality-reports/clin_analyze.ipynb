# %% [markdown]
# # <a id='toc1_'></a>[Bericht zur Datenqualität (klin) 📉](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Bericht zur Datenqualität (klin) 📉](#toc1_)
#   - [♻️ Änderungen seit der letzten Version](#toc1_1_)
#   - [⏱️ Datenstand](#toc1_2_)
#   - [📆 Lieferdatum](#toc1_3_)
#   - [Fallzahlen](#toc1_4_)
#     - [absolut](#toc1_4_1_)
#     - [relativ](#toc1_4_2_)
#       - [nach KKR](#toc1_4_2_1_)
#       - [nach System](#toc1_4_2_2_)
#   - [Fehlende Therapieangaben](#toc1_5_)
#     - [alle Therapien](#toc1_5_1_)
#     - [OP](#toc1_5_2_)
#       - [OP wenn OP erwartet](#toc1_5_2_1_)
#         - [C50](#toc1_5_2_1_1_)
#         - [C18-C20](#toc1_5_2_1_2_)
#     - [ST](#toc1_5_3_)
#     - [SYST](#toc1_5_4_)
#   - [Fallzahlen epi vs clin](#toc1_6_)
#   - [Verteilung von Variablen](#toc1_7_)
#     - [UICC (p)](#toc1_7_1_)
#     - [Diagnosesicherung](#toc1_7_2_)
#     - [DCO](#toc1_7_3_)
#     - [DCN](#toc1_7_4_)
#     - [Geschlecht](#toc1_7_5_)
#     - [Grading](#toc1_7_6_)
#       - [Verteilung](#toc1_7_6_1_)
#       - [Anteile Unbekannt](#toc1_7_6_2_)
#     - [Diagnosejahr mit Altdaten](#toc1_7_7_)
#     - [Diagnosejahr ohne Altdaten](#toc1_7_8_)
#     - [Inzidenzort vs Lieferregister](#toc1_7_9_)
#     - [ICD10 Gruppen](#toc1_7_10_)
#     - [Altersgruppen Kinder und Heranwachsende](#toc1_7_11_)
#     - [Verstorben](#toc1_7_12_)
#     - [TNM-T (p)](#toc1_7_13_)
#     - [TNM-N (p)](#toc1_7_14_)
#     - [TNM-M (p)](#toc1_7_15_)
#   - [Todesursachen (TU)](#toc1_8_)
#     - [nach ICD10 Einstellern](#toc1_8_1_)
#     - [nach Sterbejahr und Todesursachen](#toc1_8_2_)
#     - [nach ICD10 Dreistellern (TOP 5)](#toc1_8_3_)
#     - [nach IsGrundleiden](#toc1_8_4_)
#   - [Therapien](#toc1_9_)
#     - [OP](#toc1_9_1_)
#       - [nach ICD10](#toc1_9_1_1_)
#       - [nach Intention](#toc1_9_1_2_)
#     - [OPS](#toc1_9_2_)
#       - [nach OPS ICD Kapitel (Top 10)](#toc1_9_2_1_)
#     - [SYST](#toc1_9_3_)
#       - [nach Stellung_OP](#toc1_9_3_1_)
#   - [Missings- und Unbekannt-Kodierungen](#toc1_10_)
#     - [Verpflichtende Tumorvariablen](#toc1_10_1_)
#     - [Weitere Tumorangaben](#toc1_10_2_)
#     - [Tumorstadien](#toc1_10_3_)
#     - [Therapieangaben](#toc1_10_4_)
#       - [OP](#toc1_10_4_1_)
#       - [ST](#toc1_10_4_2_)
#       - [SYST](#toc1_10_4_3_)
#     - [Folgeereignisse](#toc1_10_5_)
#     - [Freitexte](#toc1_10_6_)
#     - [Organspezifische Variablen](#toc1_10_7_)
#       - [Mamma](#toc1_10_7_1_)
#       - [Prostata](#toc1_10_7_2_)
#       - [Darm](#toc1_10_7_3_)
#       - [Melanom](#toc1_10_7_4_)
#   - [🆕 Weitere Klassifikationen](#toc1_11_)
#     - [nach Quelle](#toc1_11_1_)
#     - [nach Jahren](#toc1_11_2_)
#     - [PSA](#toc1_11_3_)
#       - [Angabe zu Diagnose vs Weitere Klassifikationen](#toc1_11_3_1_)
#       - [Weitere Klassifikationen: Diagnose vs Folgeereignis](#toc1_11_3_2_)
#     - [UICC](#toc1_11_4_)
#   - [🆕 Freitexte](#toc1_12_)
#   - [Datum_Vitalstatus](#toc1_13_)
#     - [Verteilung Monat](#toc1_13_1_)
#     - [Vitalstatus Jahr](#toc1_13_2_)
#   - [🔢 Numerische Variablen](#toc1_14_)
#     - [Diagnosealter](#toc1_14_1_)
#     - [Anzahl Tage zwischen Diagnose und Tod](#toc1_14_2_)
#     - [Tumordicke](#toc1_14_3_)
#     - [PSA](#toc1_14_4_)
#     - [LK_befallen](#toc1_14_5_)
#     - [LK_untersucht](#toc1_14_6_)
#     - [RektumAbstandAnokutanlinie](#toc1_14_7_)
#     - [LDH](#toc1_14_8_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_1_'></a>[♻️ Änderungen seit der letzten Version](#toc0_)
# - Neulieferung für Daten mit max DJ=2024

# %% [markdown]
# <br>
#
# ## <a id='toc1_2_'></a>[⏱️ Datenstand](#toc0_)

# %%
import os
from pathlib import Path
import pandas as pd
import duckdb as ddb
from connection_helper import sql
from pandas_plots import tbl, pls, hlp, const
from enum import Enum

os.environ["DY_MAX"] = "2024"  # set before import
from mod.filters import *

os.environ["RENDERER"] = "svg"
os.environ['THEME']='light'

hlp.show_package_version()

dir_db=Path("C://temp") if hlp.get_os(hlp.OperatingSystem.WINDOWS) else Path(os.path.expanduser("~/tmp"))
file_db_clin = dir_db/'2026-03-04_data_clin.duckdb'
file_db_intern = dir_db/'2026-03-04_internal_clin.duckdb'
file_db_epi = dir_db/'2026-03-03_data_epi.duckdb'
URL_V2 = 'https://gitlab.opencode.de/robert-koch-institut/zentrum-fuer-krebsregisterdaten/cancerdata-references/-/raw/main/data/v2/'

if not file_db_clin.exists() or not file_db_epi.exists() or not file_db_intern.exists():
    raise FileNotFoundError()

hlp.setup_rendering(True)
# Out:
# 🐍 3.12.8 | 📦 pandas: 2.3.3 | 📦 numpy: 1.26.4 | 📦 duckdb: 1.5.0 | 📦 pandas-plots: 1.4.5

# %%
# # ! settings
class grouper_reg(Enum):
    KKR = "kkr"
    SYSTEM = "system"
    TOTAL = "Total"

class kpi(Enum):
    MISSINGS = "kpi_missing"
    UNKNOWN = "kpi_unknown"
    
class grouper_table(Enum):
    TABLECOL = "tablecolumn"
    TABLES = "tables"

# %%
print()
sql.print_meta(file_db_clin)
# Out:
# database file:           2026-03-04_data_clin.duckdb
# data tag:                v2.4
# last kkr data import:    2026-02-26
# sql table created:       2026-03-04 10:17:13
# doi:                     -
# document created:        2026-04-15 08:04:19

# %%
con = ddb.connect()
_=con.execute("PRAGMA disable_progress_bar;")
_=con.execute(f"ATTACH DATABASE '{file_db_epi}' AS epi (READ_ONLY);")
_=con.execute(f"ATTACH DATABASE '{file_db_intern}' AS intern (READ_ONLY);")
_=con.execute(f"ATTACH DATABASE '{file_db_clin}' AS clin (READ_ONLY); SET SCHEMA 'clin';")
_=con.execute("ATTACH DATABASE ':memory:' AS mem; SET SCHEMA 'clin';")

# %%
# load from web
dim_icd10_3d = sql.load_file_to_duckdb(con, URL_V2 + "Aggregationen/icd10_3d.csv", sep=";")
# dim_syst_op_stellung = sql.load_file_to_duckdb(con, URL_V2 + "Klassifikationen/syst_op_stellung.csv", sep=";")

# %%
Applikationsart = con.sql("select * from clin.Applikationsart")
Bestrahlung = con.sql("select * from clin.Bestrahlung")
Diagnose_Fernmetastase = con.sql("select * from clin.Diagnose_Fernmetastase")
Diagnose_WeitereKlassifikation = con.sql("select * from clin.Diagnose_WeitereKlassifikation")
Folgeereignis = con.sql("select * from clin.Folgeereignis")
Folgeereignis_Fernmetastase = con.sql("select * from clin.Folgeereignis_Fernmetastase")
Folgeereignis_TNM = con.sql("select * from clin.Folgeereignis_TNM")
Folgeereignis_WeitereKlassifikation = con.sql("select * from clin.Folgeereignis_WeitereKlassifikation")
Lieferung = con.sql("select * from clin.Lieferung")
OP = con.sql("select * from clin.OP")
OPS = con.sql("select * from clin.OPS")
Protokoll = con.sql("select * from clin.Protokoll")
ST = con.sql("select * from clin.ST")
SYST= con.sql("select * from clin.SYST")
Substanz = con.sql("select * from clin.Substanz")
Todesursache = con.sql("select * from clin.Todesursache")
_meta = con.sql("select * from clin._meta")
Tumor = con.sql("select * from clin.Tumor")
Patient = con.sql("select * from clin.Patient")

dim_lieferregister = con.sql("select * from clin.dim_lieferregister")
dim_tnm_t = con.sql("select * from clin.dim_tnm_t")
dim_tnm_uicc = con.sql("select * from clin.dim_tnm_uicc")
dim_grading_clin = con.sql("select * from clin.dim_grading_clin")

# ! eg: 7.2 -> 72
dim_dsich_clin = con.sql("""--sql
    select
        replace(printf('%g', code),'.','') as code,
        name,
    from clin.dim_diagnosesicherung_clin
""")
dim_op_intention = con.sql("select * from clin.dim_op_intention")

dim_tree = sql.load_file_to_duckdb(con, "../quality-reports/data/dim_tree.csv", sep=";")

# ! depr
# _treecompletion = con.sql("select * from intern._treecompletion").project('*, Diagnose_ICD10_Code_DREI as icd10_3d').project('* exclude (Diagnose_ICD10_Code_DREI)')

# * epi (Fallzahlen)
Tumor4 = (con
    .sql("select * from epi.Tumor4")
    .project("""--sql
        *,
        left(ICDGM10,3) as z_icd10_3d,
        DJ as z_dy,
        case
            when DCO = 1 then true
            when DCO = 2 then false
            else null
        end as z_is_dco
    """)
    # .project("*, case when IARC like '%A_%' then cast(1 as int16) else cast(0 as int16) end as is_deleted")
)

# %% [markdown]
# <br>
#
# ## <a id='toc1_3_'></a>[📆 Lieferdatum](#toc0_)
# - `kkr` = Klinisches Krebsregister
# - `Lieferdatum` = Datum der letzten Übermittlung durch die KKR
# - `Diagnosemonat` = letzter Diagnosemonat in den Daten

# %%
_tu_latest = Tumor.filter(f"z_dy = {DY_MAX}").aggregate("z_kkr_label, count(*) as cnt")  # noqa: F405

_tu=(Tumor.set_alias("t")
    .join(Lieferung.set_alias("l"), "l.Lieferregister::int = t.z_kkr::int", "inner")
    .aggregate("t.z_kkr_label, left(cast(max(Diagnosedatum) as varchar),7) as Diagnosemonat, max(Lieferdatum) as Lieferdatum")
    .join(_tu_latest.set_alias("latest"), "z_kkr_label", "left")
    # .project("z_kkr_label, Diagnosemonat")
    .order("z_kkr_label")
    .to_df().set_index("z_kkr_label")
    .astype({"Lieferdatum":str})
    .assign(Tumorfälle_2024 = lambda x: x["cnt"].apply(lambda y: f"{y:_.0f}"))
    .drop(columns=["cnt"])
    .T
)
display(_tu)

_late_kkr = con.from_df(_tu.T.reset_index(names="z_kkr_label")).filter("year(Lieferdatum::date) < 2026").z_kkr_label.fetchall()
print("kkr ohne aktuelle Daten: ", _late_kkr)

# * print as img, looks better for wide tables
# con.from_df(_tu
#     .reset_index(names="z_kkr_label")
# ).show()
# Out:
# z_kkr_label           01-SH       02-HH       03-NI       04-HB       05-NW  \
# Diagnosemonat       2024-12     2024-12     2024-12     2024-12     2024-12
# Lieferdatum      2026-02-10  2026-01-22  2026-02-15  2026-02-11  2026-01-22
# Tumorfälle_2024      37_898      13_977      48_119       4_879     191_865
#
# z_kkr_label           06-HE       07-RP       08-BW       09-BY       10-SL  \
# Diagnosemonat       2025-12     2024-12     2024-12     2026-01     2024-12
# Lieferdatum      2026-01-26  2026-01-29  2026-01-26  2026-01-25  2026-02-26
# Tumorfälle_2024      29_713      30_244      90_465      95_762      12_831
#
# z_kkr_label           11-BE       12-BB       13-MV       14-SN       15-ST  \
# Diagnosemonat       2025-10     2025-10     2025-01     2025-09     2025-12
# Lieferdatum      2026-01-05  2026-01-06  2025-01-21  2026-02-24  2026-01-30
# Tumorfälle_2024      27_792      22_456       2_837      41_076      27_291
#
# z_kkr_label           16-TH
# Diagnosemonat       2024-12
# Lieferdatum      2026-01-28
# Tumorfälle_2024      14_043
# kkr ohne aktuelle Daten:  [('13-MV',)]

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_4_'></a>[Fallzahlen](#toc0_)
# - in den Darstellungen sind keine Filter angewendet, solange nicht explizit angegeben

# %% [markdown]
# <br>
#
# ### <a id='toc1_4_1_'></a>[absolut](#toc0_)
# - aufgespannt sind die Fallzahlen für Lieferregister und Elementknoten
# - für jedes Register ist hier insbesondere einsehbar, wie viele Tumore/Patienten aus der aktuellsten Lieferung verarbeitet wurden
# - kein Filter, "Altfälle" (DJ < 2020) sind also enthalten
# - aufgeteilt auf 2 Tabellen zur besseren Übersicht
# - die `%` Werte sowie die farbigen Datenbalken zeigen das relative Gewicht jedes KKR an "D gesamt" (`Total` Zeile)
# - Erklärung für einige Elementknoten: (`_cnt` = count/Fallzahl)
#   - **Diagnose**
#     - `diag_weitere_cnt` = Weitere Klassifikation im Elementknoten "Diagnose"
#     - `diag_fm_cnt` = Fernmetastasen im Elementknoten "Diagnose"
#   - **Folge**
#     - `folge_fm_cnt`= Fernmetastasen im Elementknoten "Folgeereignis"
#     - `folge_weitere_cnt` = Weitere Klassifikation im Elementknoten "Folgeereignis"
#     - `folge_tnm_cnt` = TNM im Elementknoten "Folgeereignis"
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - inzwischen liegen die meisten Elemente flächendeckend vor, bis auf `Applikationsart` und `Folgeereignis_WeitereKlassifikation`
# > - einige Elemente sind überproportional zur Verteilung der Tumore vorhanden, z.B. Weitere Klassifikationen bei Folgeereignissen aus `05-NW`

# %%
with open("../sql/clin_data.sql") as f:
    sql_clin_data = f.read()
db_clin_all = con.sql(sql_clin_data)

# tbl.descr_db(db_clin_all, "db_clin_all", width=1000)

# %%
col_count_str = [
    f"sum({col}) as {col}" for col in db_clin_all.columns if (col.endswith("_cnt"))
]
col_missing_str = [
    f"sum({col}) as {col}" for col in db_clin_all.columns if col.endswith("_missing")
]

def get_absolute_cases(
    db_all,
    cols: list[str],
    group=grouper_reg.KKR.value,
    filter: str = "",
    total_include: bool = False,
):
    # * empty filter must be neutral in the query
    if not filter:
        filter = "True"

    # * is executed twice
    def get_db(group: str):
        _project = "'Total' as Total, *" if group == grouper_reg.TOTAL.value else "*"
        return (
            db_all.filter(filter)
            .project(_project)
            .aggregate(
                f"""--sql
                    {group},
                    count(*) as tum_cnt, 
                    count(distinct z_pat_id) as pat_cnt,
                    {','.join(cols)},
                    """
            )
            .order(group)
        )

    db = get_db(group)
    if group != grouper_reg.TOTAL.value and total_include:
        db = db.union(get_db(grouper_reg.TOTAL.value))
    return db


def get_relative_cases(
    db_all, group=grouper_reg.KKR.value, filter: str = "", total_include: bool = False
):
    db_abs = get_absolute_cases(
        db_clin_all,
        cols=col_count_str,
        group=group,
        filter=filter,
        total_include=total_include,
    )
    db_rel = db_abs.aggregate(
        f"""--sql
            {group},
            sum(tum_cnt)/sum(pat_cnt) as tum_per_pat,
            sum(op_cnt)/sum(tum_cnt) as op_per_tum,
            sum(ops_cnt)/sum(tum_cnt) as ops_per_tum,
            sum(st_cnt)/sum(tum_cnt) as st_per_tum,
            sum(syst_cnt)/sum(tum_cnt) as syst_per_tum,
            sum(folge_cnt)/sum(tum_cnt) as folge_per_tum,
            """
    ).order(group)
    df = db_rel.to_df().set_index(group)
    return df


def get_missing_cases(db_all, group=grouper_reg.KKR.value, filter: str = "", total_include: bool = False):
    db_abs = get_absolute_cases(
        db_clin_all, cols=col_missing_str, group=group, filter=filter, total_include=total_include
    )
    db_miss = db_abs.aggregate(
        f"""--sql
            {group},
            sum(op_missing)/sum(tum_cnt) as op_missing_per_tum,
            sum(st_missing)/sum(tum_cnt) as st_missing_per_tum,
            sum(syst_missing)/sum(tum_cnt) as syst_missing_per_tum,
            sum(folge_missing)/sum(tum_cnt) as folge_missings_per_tum,
            sum(thera_missing)/sum(tum_cnt) as treat_missing_per_tum,
            """
    ).order(group)
    df = db_miss.to_df().set_index(group)
    return df

# %%
db_cases_abs = get_absolute_cases(
    db_clin_all, group=grouper_reg.KKR.value, cols=col_count_str, total_include=False
)
_tu = db_cases_abs.to_df().set_index("kkr")[
    [
        "tum_cnt",
        "pat_cnt",
        "op_cnt",
        "ops_cnt",
        "syst_cnt",
        "st_cnt",
        "bestr_cnt",
        "app_cnt",

        "diag_weitere_cnt",
        "diag_fm_cnt",
        "folge_cnt",
        "folge_weitere_cnt",
        "folge_fm_cnt",
        "folge_tnm_cnt",
        "proto_cnt",
        "subst_cnt",
    ]
]
tbl.show_num_df(
    _tu.iloc[:, :8],
    data_bar_axis="x",
    total_axis="x",
    pct_axis="x",
    font_size_th=13,
    font_size_td=11,
    # kpi_mode="max_min_x",
)
# Out:
# <style type="text/css">
# #T_25b51 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_25b51 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_25b51_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.8%, transparent 4.8%);
#   font-family: Courier;
# }
# #T_25b51_row0_col1, #T_25b51_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.1%, transparent 5.1%);
#   font-family: Courier;
# }
# #T_25b51_row0_col2, #T_25b51_row0_col3, #T_25b51_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.7%, transparent 2.7%);
#   font-family: Courier;
# }
# #T_25b51_row0_col4, #T_25b51_row10_col4, #T_25b51_row10_col5, #T_25b51_row10_col6, #T_25b51_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.1%, transparent 4.1%);
#   font-family: Courier;
# }
# #T_25b51_row0_col5, #T_25b51_row11_col4, #T_25b51_row11_col5, #T_25b51_row14_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.9%, transparent 3.9%);
#   font-family: Courier;
# }
# #T_25b51_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.2%, transparent 3.2%);
#   font-family: Courier;
# }
# #T_25b51_row0_col7, #T_25b51_row2_col7, #T_25b51_row3_col7, #T_25b51_row9_col7 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_25b51_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.7%, transparent 1.7%);
#   font-family: Courier;
# }
# #T_25b51_row1_col1, #T_25b51_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_25b51_row1_col2, #T_25b51_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.0%, transparent 2.0%);
#   font-family: Courier;
# }
# #T_25b51_row1_col4, #T_25b51_row1_col5, #T_25b51_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.4%, transparent 2.4%);
#   font-family: Courier;
# }
# #T_25b51_row1_col6, #T_25b51_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_25b51_row1_col7, #T_25b51_row6_col4, #T_25b51_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.9%, transparent 2.9%);
#   font-family: Courier;
# }
# #T_25b51_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.9%, transparent 6.9%);
#   font-family: Courier;
# }
# #T_25b51_row2_col1, #T_25b51_row13_col2, #T_25b51_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.5%, transparent 7.5%);
#   font-family: Courier;
# }
# #T_25b51_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.0%, transparent 6.0%);
#   font-family: Courier;
# }
# #T_25b51_row2_col3, #T_25b51_row5_col6, #T_25b51_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.4%, transparent 6.4%);
#   font-family: Courier;
# }
# #T_25b51_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.8%, transparent 9.8%);
#   font-family: Courier;
# }
# #T_25b51_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.0%, transparent 8.0%);
#   font-family: Courier;
# }
# #T_25b51_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.5%, transparent 6.5%);
#   font-family: Courier;
# }
# #T_25b51_row3_col0, #T_25b51_row3_col1, #T_25b51_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.8%, transparent 0.8%);
#   font-family: Courier;
# }
# #T_25b51_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.6%, transparent 0.6%);
#   font-family: Courier;
# }
# #T_25b51_row3_col3, #T_25b51_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_25b51_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_25b51_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.3%, transparent 25.3%);
#   font-family: Courier;
# }
# #T_25b51_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.3%, transparent 27.3%);
#   font-family: Courier;
# }
# #T_25b51_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.8%, transparent 21.8%);
#   font-family: Courier;
# }
# #T_25b51_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.7%, transparent 22.7%);
#   font-family: Courier;
# }
# #T_25b51_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 18.7%, transparent 18.7%);
#   font-family: Courier;
# }
# #T_25b51_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.0%, transparent 15.0%);
#   font-family: Courier;
# }
# #T_25b51_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 16.8%, transparent 16.8%);
#   font-family: Courier;
# }
# #T_25b51_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 19.1%, transparent 19.1%);
#   font-family: Courier;
# }
# #T_25b51_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.2%, transparent 5.2%);
#   font-family: Courier;
# }
# #T_25b51_row5_col1, #T_25b51_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.3%, transparent 5.3%);
#   font-family: Courier;
# }
# #T_25b51_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.9%, transparent 5.9%);
#   font-family: Courier;
# }
# #T_25b51_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.8%, transparent 5.8%);
#   font-family: Courier;
# }
# #T_25b51_row5_col5, #T_25b51_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.5%, transparent 5.5%);
#   font-family: Courier;
# }
# #T_25b51_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.3%, transparent 7.3%);
#   font-family: Courier;
# }
# #T_25b51_row6_col0, #T_25b51_row11_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.0%, transparent 4.0%);
#   font-family: Courier;
# }
# #T_25b51_row6_col1, #T_25b51_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.3%, transparent 4.3%);
#   font-family: Courier;
# }
# #T_25b51_row6_col2, #T_25b51_row14_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.4%, transparent 4.4%);
#   font-family: Courier;
# }
# #T_25b51_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.3%, transparent 10.3%);
#   font-family: Courier;
# }
# #T_25b51_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.4%, transparent 8.4%);
#   font-family: Courier;
# }
# #T_25b51_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.1%, transparent 9.1%);
#   font-family: Courier;
# }
# #T_25b51_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.4%, transparent 11.4%);
#   font-family: Courier;
# }
# #T_25b51_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.8%, transparent 11.8%);
#   font-family: Courier;
# }
# #T_25b51_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 13.7%, transparent 13.7%);
#   font-family: Courier;
# }
# #T_25b51_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.3%, transparent 14.3%);
#   font-family: Courier;
# }
# #T_25b51_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.2%, transparent 15.2%);
#   font-family: Courier;
# }
# #T_25b51_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.4%, transparent 14.4%);
#   font-family: Courier;
# }
# #T_25b51_row7_col6, #T_25b51_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.2%, transparent 14.2%);
#   font-family: Courier;
# }
# #T_25b51_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 16.1%, transparent 16.1%);
#   font-family: Courier;
# }
# #T_25b51_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 13.3%, transparent 13.3%);
#   font-family: Courier;
# }
# #T_25b51_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.7%, transparent 14.7%);
#   font-family: Courier;
# }
# #T_25b51_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.6%, t

# %%
tbl.show_num_df(
    _tu.iloc[:, 8:],
    data_bar_axis="x",
    total_axis="x",
    pct_axis="x",
    font_size_th=13,
    font_size_td=11,
    # kpi_mode="max_min_x",
)
# Out:
# <style type="text/css">
# #T_5ea8d th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_5ea8d td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_5ea8d_row0_col0, #T_5ea8d_row12_col0, #T_5ea8d_row12_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_5ea8d_row0_col1, #T_5ea8d_row10_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.3%, transparent 4.3%);
#   font-family: Courier;
# }
# #T_5ea8d_row0_col2, #T_5ea8d_row0_col5, #T_5ea8d_row1_col2, #T_5ea8d_row1_col5, #T_5ea8d_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_5ea8d_row0_col3, #T_5ea8d_row1_col3, #T_5ea8d_row2_col3, #T_5ea8d_row3_col3, #T_5ea8d_row9_col3 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_5ea8d_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_5ea8d_row0_col6, #T_5ea8d_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.8%, transparent 0.8%);
#   font-family: Courier;
# }
# #T_5ea8d_row0_col7, #T_5ea8d_row11_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.9%, transparent 3.9%);
#   font-family: Courier;
# }
# #T_5ea8d_row1_col0, #T_5ea8d_row9_col0, #T_5ea8d_row11_col2, #T_5ea8d_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_5ea8d_row1_col1, #T_5ea8d_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.7%, transparent 3.7%);
#   font-family: Courier;
# }
# #T_5ea8d_row1_col4, #T_5ea8d_row2_col6, #T_5ea8d_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.6%, transparent 1.6%);
#   font-family: Courier;
# }
# #T_5ea8d_row1_col6, #T_5ea8d_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.1%, transparent 3.1%);
#   font-family: Courier;
# }
# #T_5ea8d_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.7%, transparent 2.7%);
#   font-family: Courier;
# }
# #T_5ea8d_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.7%, transparent 6.7%);
#   font-family: Courier;
# }
# #T_5ea8d_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.8%, transparent 9.8%);
#   font-family: Courier;
# }
# #T_5ea8d_row2_col2, #T_5ea8d_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_5ea8d_row2_col4, #T_5ea8d_row11_col4, #T_5ea8d_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.3%, transparent 3.3%);
#   font-family: Courier;
# }
# #T_5ea8d_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.9%, transparent 8.9%);
#   font-family: Courier;
# }
# #T_5ea8d_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.6%, transparent 0.6%);
#   font-family: Courier;
# }
# #T_5ea8d_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.2%, transparent 1.2%);
#   font-family: Courier;
# }
# #T_5ea8d_row3_col2, #T_5ea8d_row3_col5, #T_5ea8d_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_5ea8d_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.4%, transparent 14.4%);
#   font-family: Courier;
# }
# #T_5ea8d_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.5%, transparent 15.5%);
#   font-family: Courier;
# }
# #T_5ea8d_row4_col2, #T_5ea8d_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.9%, transparent 22.9%);
#   font-family: Courier;
# }
# #T_5ea8d_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.7%, transparent 77.7%);
#   font-family: Courier;
# }
# #T_5ea8d_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 13.6%, transparent 13.6%);
#   font-family: Courier;
# }
# #T_5ea8d_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.5%, transparent 5.5%);
#   font-family: Courier;
# }
# #T_5ea8d_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.5%, transparent 20.5%);
#   font-family: Courier;
# }
# #T_5ea8d_row5_col0, #T_5ea8d_row13_col2, #T_5ea8d_row13_col5, #T_5ea8d_row14_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.0%, transparent 6.0%);
#   font-family: Courier;
# }
# #T_5ea8d_row5_col1, #T_5ea8d_row10_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.4%, transparent 6.4%);
#   font-family: Courier;
# }
# #T_5ea8d_row5_col2, #T_5ea8d_row5_col5, #T_5ea8d_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.2%, transparent 7.2%);
#   font-family: Courier;
# }
# #T_5ea8d_row5_col3, #T_5ea8d_row10_col0, #T_5ea8d_row12_col2, #T_5ea8d_row12_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.4%, transparent 4.4%);
#   font-family: Courier;
# }
# #T_5ea8d_row5_col4, #T_5ea8d_row15_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.8%, transparent 4.8%);
#   font-family: Courier;
# }
# #T_5ea8d_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.1%, transparent 9.1%);
#   font-family: Courier;
# }
# #T_5ea8d_row5_col7, #T_5ea8d_row11_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.1%, transparent 6.1%);
#   font-family: Courier;
# }
# #T_5ea8d_row6_col0, #T_5ea8d_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.4%, transparent 1.4%);
#   font-family: Courier;
# }
# #T_5ea8d_row6_col1, #T_5ea8d_row12_col4, #T_5ea8d_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.3%, transparent 2.3%);
#   font-family: Courier;
# }
# #T_5ea8d_row6_col2, #T_5ea8d_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.3%, transparent 9.3%);
#   font-family: Courier;
# }
# #T_5ea8d_row6_col4, #T_5ea8d_row8_col2, #T_5ea8d_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.0%, transparent 9.0%);
#   font-family: Courier;
# }
# #T_5ea8d_row6_col6, #T_5ea8d_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.2%, transparent 2.2%);
#   font-family: Courier;
# }
# #T_5ea8d_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 33.4%, transparent 33.4%);
#   font-family: Courier;
# }
# #T_5ea8d_row7_col1, #T_5ea8d_row8_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 13.9%, transparent 13.9%);
#   font-family: Courier;
# }
# #T_5ea8d_row7_col2, #T_5ea8d_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.8%, transparent 25.8%);
#   font-family: Courier;
# }
# #T_5ea8d_row7_col3, #T_5ea8d_row15_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.8%, transparent 2.8%);
#   font-family: Courier;
# }
# #T_5ea8d_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.9%, transparent 26.9%);
#   font-family: Courier;
# }
# #T_5ea8d_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 16.3%, transparent 16.3%);
#   font-family: Courier;
# }
# #T_5ea8d_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 16.2%, transparent 16.2%);
#   font-family: Courier;
# }
# #T_5ea8d_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.4%, transparent 8.4%);
#   font-family: Courier;
# }
# #T_5ea8d_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.3%, transparent 14.3%);
#   font-family: Courier;
# }
# #T_5ea8d_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.0%, transparent 7.0%);
#   font-family: Courier;
# }
# #T_5ea8d_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.1%, transparent 15.1%);
#   font-family: Courier;
# }
# #T_5ea8d_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.0%, transparent 22.0%);
#   font-family: Courier;
# }
# #T_5ea8d_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.7%, transparent 1.7%);
#   font-family: Courier;
# }
# #T_5ea8d_row9_col2, #T_5ea8d_row9_col5 {
#   width: 10em;
#   background: linear

# %% [markdown]
# <br>
#
# ### <a id='toc1_4_2_'></a>[relativ](#toc0_)
# - **Filter: `DJ` = 2020-2024, `DCO` = N, `ICD10` != C44**
# - der Filter ist gewählt, um eine bessere Vergleichbarkeit der Werte zu gewährleisten
# - die Metriken sind **einfache Verhältiszahlen**, z.B: `op_per_tum` = alle OP / alle Tumore (pro kkr)
# - es sind jeweils die kumulierten Werte aufgespannt:
#   - nach einzelnen **Lieferregistern**
#   - nach verwendeten **Tumordokumentationssystemen** (um systemische Effekte darstellen zu können)
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - die Quote Tumor pro Patient ist verlässlich konstant
# > - bei den Therapien gibt es einige Auffälligkeiten, wie z.B. wenige Folgeereignisse aus den `tristan` Ländern, oder hohe ST pro Tumor Quote aus `07-RP`

# %% [markdown]
# #### <a id='toc1_4_2_1_'></a>[nach KKR](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)
_tu = get_relative_cases(db_clin_all, group=grouper_reg.KKR.value, filter=_filter, total_include=True)
tbl.show_num_df(
    _tu,
    data_bar_axis="xy",
    total_axis="",
    pct_axis="",
    precision=1,
    show_as_pct=True,
    # kpi_mode="min_max_x",
    # total_exclude=True,
    font_size_th=13,
    font_size_td=11,
    # font_size_th=8,
    # font_size_td=6,
    image_scale='800',
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_038_346  (75.7%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_0db63 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_0db63 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_0db63_row0_col0, #T_0db63_row3_col2, #T_0db63_row6_col2, #T_0db63_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.3%, transparent 54.3%);
#   font-family: Courier;
# }
# #T_0db63_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.9%, transparent 22.9%);
#   font-family: Courier;
# }
# #T_0db63_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.8%, transparent 44.8%);
#   font-family: Courier;
# }
# #T_0db63_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.1%, transparent 11.1%);
#   font-family: Courier;
# }
# #T_0db63_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.4%, transparent 26.4%);
#   font-family: Courier;
# }
# #T_0db63_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.7%, transparent 4.7%);
#   font-family: Courier;
# }
# #T_0db63_row1_col0, #T_0db63_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.2%, transparent 54.2%);
#   font-family: Courier;
# }
# #T_0db63_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.7%, transparent 31.7%);
#   font-family: Courier;
# }
# #T_0db63_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.4%, transparent 60.4%);
#   font-family: Courier;
# }
# #T_0db63_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.2%, transparent 12.2%);
#   font-family: Courier;
# }
# #T_0db63_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.7%, transparent 28.7%);
#   font-family: Courier;
# }
# #T_0db63_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.3%, transparent 10.3%);
#   font-family: Courier;
# }
# #T_0db63_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.5%, transparent 54.5%);
#   font-family: Courier;
# }
# #T_0db63_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.7%, transparent 22.7%);
#   font-family: Courier;
# }
# #T_0db63_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.0%, transparent 47.0%);
#   font-family: Courier;
# }
# #T_0db63_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.0%, transparent 10.0%);
#   font-family: Courier;
# }
# #T_0db63_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.1%, transparent 28.1%);
#   font-family: Courier;
# }
# #T_0db63_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.7%, transparent 5.7%);
#   font-family: Courier;
# }
# #T_0db63_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.6%, transparent 54.6%);
#   font-family: Courier;
# }
# #T_0db63_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 24.2%, transparent 24.2%);
#   font-family: Courier;
# }
# #T_0db63_row3_col3, #T_0db63_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.3%, transparent 11.3%);
#   font-family: Courier;
# }
# #T_0db63_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.0%, transparent 29.0%);
#   font-family: Courier;
# }
# #T_0db63_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.4%, transparent 6.4%);
#   font-family: Courier;
# }
# #T_0db63_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.2%, transparent 53.2%);
#   font-family: Courier;
# }
# #T_0db63_row4_col1, #T_0db63_row7_col1, #T_0db63_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.5%, transparent 31.5%);
#   font-family: Courier;
# }
# #T_0db63_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.8%, transparent 64.8%);
#   font-family: Courier;
# }
# #T_0db63_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.9%, transparent 7.9%);
#   font-family: Courier;
# }
# #T_0db63_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.5%, transparent 22.5%);
#   font-family: Courier;
# }
# #T_0db63_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.8%, transparent 50.8%);
#   font-family: Courier;
# }
# #T_0db63_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.5%, transparent 53.5%);
#   font-family: Courier;
# }
# #T_0db63_row5_col1, #T_0db63_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.3%, transparent 27.3%);
#   font-family: Courier;
# }
# #T_0db63_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.2%, transparent 59.2%);
#   font-family: Courier;
# }
# #T_0db63_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.5%, transparent 9.5%);
#   font-family: Courier;
# }
# #T_0db63_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 23.2%, transparent 23.2%);
#   font-family: Courier;
# }
# #T_0db63_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.3%, transparent 56.3%);
#   font-family: Courier;
# }
# #T_0db63_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.3%, transparent 55.3%);
#   font-family: Courier;
# }
# #T_0db63_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.3%, transparent 28.3%);
#   font-family: Courier;
# }
# #T_0db63_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.4%, transparent 22.4%);
#   font-family: Courier;
# }
# #T_0db63_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.7%, transparent 14.7%);
#   font-family: Courier;
# }
# #T_0db63_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 96.7%, transparent 96.7%);
#   font-family: Courier;
# }
# #T_0db63_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.1%, transparent 56.1%);
#   font-family: Courier;
# }
# #T_0db63_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.7%, transparent 65.7%);
#   font-family: Courier;
# }
# #T_0db63_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.9%, transparent 11.9%);
#   font-family: Courier;
# }
# #T_0db63_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.9%, transparent 28.9%);
#   font-family: Courier;
# }
# #T_0db63_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_0db63_row8_col0, #T_0db63_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.9%, transparent 53.9%);
#   font-family: Courier;
# }
# #T_0db63_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.0%, transparent 34.0%);
#   font-family: Courier;
# }
# #T_0db63_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.5%, transparent 65.5%);
#   font-family: Courier;
# }
# #T_0db63_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.0%, transparent 12.0%);
#   font-family: Courier;
# }
# #T_0db63_row8_col4, #T_0db63_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 24.9%, transparent 24.9%);
#   font-family: Courier;
# }
# #T_0db63_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.2%, transparent 32.2%);
#   font-family: Courier;
# }
# #T_0db63_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.2%, transparent 55.2%);
#   font-family: Courier;
# }
# #T_0db63_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.6%, transparent 22.6%);
#   font-family: Courier;
# }
# #T_0db63_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.5%, transparent 44.5%);
#   font-family: Courier;
# }
# #T_0db63_row9_col3, #T_0db63_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.9%, transparent 10.9%);
#   font-family: Courier;
# }
# #T_0db63_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.6%, transparent 6.6%);
#   font-family: Courier;
# }
# #T_0db63_row10_col0, #T_0db63_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.7%, transparent 53.7%);
#   font-family

# %% [markdown]
# #### <a id='toc1_4_2_2_'></a>[nach System](#toc0_)

# %%
_tu = get_relative_cases(db_clin_all, group=grouper_reg.SYSTEM.value, filter=_filter, total_include=True)
tbl.show_num_df(
    _tu,
    data_bar_axis="xy",
    total_axis="",
    pct_axis="",
    precision=1,
    show_as_pct=True,
    font_size_th=13,
    font_size_td=11,
    # font_size_th=8,
    # font_size_td=6,
    image_scale='800',
)
# Out:
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_726e5 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_726e5 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_726e5_row0_col0, #T_726e5_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.2%, transparent 54.2%);
#   font-family: Courier;
# }
# #T_726e5_row0_col1, #T_726e5_row2_col1, #T_726e5_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.5%, transparent 31.5%);
#   font-family: Courier;
# }
# #T_726e5_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 62.5%, transparent 62.5%);
#   font-family: Courier;
# }
# #T_726e5_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.3%, transparent 11.3%);
#   font-family: Courier;
# }
# #T_726e5_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.0%, transparent 26.0%);
#   font-family: Courier;
# }
# #T_726e5_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.9%, transparent 50.9%);
#   font-family: Courier;
# }
# #T_726e5_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.7%, transparent 53.7%);
#   font-family: Courier;
# }
# #T_726e5_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 35.1%, transparent 35.1%);
#   font-family: Courier;
# }
# #T_726e5_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 67.2%, transparent 67.2%);
#   font-family: Courier;
# }
# #T_726e5_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.8%, transparent 11.8%);
#   font-family: Courier;
# }
# #T_726e5_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.5%, transparent 27.5%);
#   font-family: Courier;
# }
# #T_726e5_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.0%, transparent 48.0%);
#   font-family: Courier;
# }
# #T_726e5_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.2%, transparent 53.2%);
#   font-family: Courier;
# }
# #T_726e5_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.8%, transparent 64.8%);
#   font-family: Courier;
# }
# #T_726e5_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.9%, transparent 7.9%);
#   font-family: Courier;
# }
# #T_726e5_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.5%, transparent 22.5%);
#   font-family: Courier;
# }
# #T_726e5_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.8%, transparent 50.8%);
#   font-family: Courier;
# }
# #T_726e5_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.3%, transparent 55.3%);
#   font-family: Courier;
# }
# #T_726e5_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.3%, transparent 28.3%);
#   font-family: Courier;
# }
# #T_726e5_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.3%, transparent 54.3%);
#   font-family: Courier;
# }
# #T_726e5_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.4%, transparent 22.4%);
#   font-family: Courier;
# }
# #T_726e5_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.7%, transparent 14.7%);
#   font-family: Courier;
# }
# #T_726e5_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 96.7%, transparent 96.7%);
#   font-family: Courier;
# }
# #T_726e5_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.5%, transparent 54.5%);
#   font-family: Courier;
# }
# #T_726e5_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.8%, transparent 22.8%);
#   font-family: Courier;
# }
# #T_726e5_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 46.6%, transparent 46.6%);
#   font-family: Courier;
# }
# #T_726e5_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.5%, transparent 10.5%);
#   font-family: Courier;
# }
# #T_726e5_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.6%, transparent 27.6%);
#   font-family: Courier;
# }
# #T_726e5_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.6%, transparent 5.6%);
#   font-family: Courier;
# }
# #T_726e5_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.1%, transparent 56.1%);
#   font-family: Courier;
# }
# #T_726e5_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.7%, transparent 65.7%);
#   font-family: Courier;
# }
# #T_726e5_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.9%, transparent 11.9%);
#   font-family: Courier;
# }
# #T_726e5_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.9%, transparent 28.9%);
#   font-family: Courier;
# }
# #T_726e5_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_726e5_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.7%, transparent 31.7%);
#   font-family: Courier;
# }
# #T_726e5_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.4%, transparent 60.4%);
#   font-family: Courier;
# }
# #T_726e5_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.2%, transparent 12.2%);
#   font-family: Courier;
# }
# #T_726e5_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.7%, transparent 28.7%);
#   font-family: Courier;
# }
# #T_726e5_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.3%, transparent 10.3%);
#   font-family: Courier;
# }
# </style>
# <table id="T_726e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_726e5_level0_col0" class="col_heading level0 col0" >tum_per_pat</th>
#       <th id="T_726e5_level0_col1" class="col_heading level0 col1" >op_per_tum</th>
#       <th id="T_726e5_level0_col2" class="col_heading level0 col2" >ops_per_tum</th>
#       <th id="T_726e5_level0_col3" class="col_heading level0 col3" >st_per_tum</th>
#       <th id="T_726e5_level0_col4" class="col_heading level0 col4" >syst_per_tum</th>
#       <th id="T_726e5_level0_col5" class="col_heading level0 col5" >folge_per_tum</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >system</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_726e5_level0_row0" class="row_heading level0 row0" >Total</th>
#       <td id="T_726e5_row0_col0" class="data row0 col0" >107.6% </td>
#       <td id="T_726e5_row0_col1" class="data row0 col1" >62.6% </td>
#       <td id="T_726e5_row0_col2" class="data row0 col2" >124.1% </td>
#       <td id="T_726e5_row0_col3" class="data row0 col3" >22.5% </td>
#       <td id="T_726e5_row0_col4" class="data row0 col4" >51.6% </td>
#       <td id="T_726e5_row0_col5" class="data row0 col5" >101.1% </td>
#     </tr>
#     <tr>
#       <th id="T_726e5_level0_row1" class="row_heading level0 row1" >gtds</th>
#       <td id="T_726e5_row1_col0" class="data row1 col0" >106.8% </td>
#       <td id="T_726e5_row1_col1" class="data row1 col1" >69.7% </td>
#       <td id="T_726e5_row1_col2" class="data row1 col2" >133.5% </td>
#       <td id="T_726e5_row1_col3" class="data row1 col3" >23.4% </td>
#       <td id="T_726e5_row1_col4" class="data row1 col4" >54.6% </td>
#       <td id="T_726e5_row1_col5" class="data row1 col5" >95.3% </td>
#     </tr>
#     <tr>
#       <th id="T_726e5_level0_row2" class="row_heading level0 row2" >nw</th>
#       <td id="T_726e5_row2_col0" class="data row2 col0" >105.8% </td>
#       <td id="T_726e5_row2_col1" class="data row2 col1" >62.6% </td>
#       <td id="T_726e5_row2_col2" class="data row2 col2" >128.8% </td>
#       <td id="T_726e5_row2_col3" class="data row2 col3" >15.6% </td>
#       <td id="T_726e5_row2_col4" class="data row2 col4" >44.7% </td>
#       <td id="T_726e5_row2_col5" class="data row2 col5" >101.0% </td>
#     </tr>
#     <tr>
#       <th id="T_726e5_level0_row3" class="row_heading level0 row3" >rp</th>

# %% [markdown]
# <br>
#
# ## <a id='toc1_5_'></a>[Fehlende Therapieangaben](#toc0_)
# - **Filter: `DJ` = 2020-2024, `DCO` = N, `ICD10` nur solide Tumoren** (_solide Tumoren_ schliesst folgende Diagnosen _aus_: C44, C76-C97, alle D)
# - ein Wert von bspw. 0.68 ist zu interpretieren als: _"68% aller Tumorfälle im KKR haben keine zugeordneten OP Angaben, die restlichen 32% mindestens eine."_
# - `treat_missing_per_tum` stellt den Anteil Fälle dar, bei denen keinerlei Therapieangabe (OP, ST, SYST) vorliegt
# - in der Darstellung sind die Max/Min Werte pro Kennzahl mit 🟥/🟩 markiert (kleiner ist besser)
#
# > [!NOTE]
# > 💡 `NI`: _"Die **Missings für Folgeereignis, Strahlentherapie und Systemische Therapie** sind Resultat der noch ausstehenden Implementierung in der Registersoftware Tristan zur Bildung der jeweiligen Best-Of-Informationen. Die Implementierung ist bereits beauftragt. Neben Niedersachsen nutzen die Bundesländer Schleswig-Holstein, Bremen und das Saarland dieselbe Tristan-Implementierung"_
# >
# > ---
# > 💡 `ZfKD`: _aus `st_missing_per_tum` lässt sich ablesen, dass ~24% der Tumoren deutschlandweit mind. eine ST zugeordnet ist (Total: 1 - 0.76 = 0.24). Das entspricht grob der Annahme von 30% Anteil von Strahlentherapien an primären Diagnosen_

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_SOLID,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_tu = get_missing_cases(
    db_clin_all,
    group=grouper_reg.KKR.value,
    filter=_filter,
    total_include=True,
)

tbl.show_num_df(
    _tu,
    data_bar_axis="xy",
    total_axis="",
    pct_axis="",
    precision=1,
    show_as_pct=True,
    kpi_mode="min_max_x",
    total_exclude=True,
    font_size_th=13,
    font_size_td=11,
    # font_size_th=7,
    # font_size_td=5,
    image_scale='800',
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                        (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:      n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:         n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur solide Tumore]: n = 2_270_570  (56.5%) ░░░░░░░░░░░░░░████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     z_icd10_3d not in ('C44')
#     and left(z_icd10_3d,1) = 'C'
#     and right(z_icd10_3d, 2)::int8 <= 75
#
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_5c08a th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_5c08a td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_5c08a_row0_col0, #T_5c08a_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.1%, transparent 55.1%);
#   font-family: Courier;
# }
# #T_5c08a_row0_col1, #T_5c08a_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.2%, transparent 81.2%);
#   font-family: Courier;
# }
# #T_5c08a_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.8%, transparent 74.8%);
#   font-family: Courier;
# }
# #T_5c08a_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_5c08a_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.5%, transparent 28.5%);
#   font-family: Courier;
# }
# #T_5c08a_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.9%, transparent 47.9%);
#   font-family: Courier;
# }
# #T_5c08a_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.3%, transparent 81.3%);
#   font-family: Courier;
# }
# #T_5c08a_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.7%, transparent 77.7%);
#   font-family: Courier;
# }
# #T_5c08a_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 92.4%, transparent 92.4%);
#   font-family: Courier;
# }
# #T_5c08a_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.1%, transparent 26.1%);
#   font-family: Courier;
# }
# #T_5c08a_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.6%, transparent 85.6%);
#   font-family: Courier;
# }
# #T_5c08a_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.1%, transparent 74.1%);
#   font-family: Courier;
# }
# #T_5c08a_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 97.7%, transparent 97.7%);
#   font-family: Courier;
# }
# #T_5c08a_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.4%, transparent 31.4%);
#   font-family: Courier;
# }
# #T_5c08a_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 49.4%, transparent 49.4%);
#   font-family: Courier;
# }
# #T_5c08a_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.4%, transparent 80.4%);
#   font-family: Courier;
# }
# #T_5c08a_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.1%, transparent 68.1%);
#   font-family: Courier;
# }
# #T_5c08a_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 95.0%, transparent 95.0%);
#   font-family: Courier;
# }
# #T_5c08a_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 24.3%, transparent 24.3%);
#   font-family: Courier;
# }
# #T_5c08a_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.3%, transparent 52.3%);
#   font-family: Courier;
# }
# #T_5c08a_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 92.6%, transparent 92.6%);
#   font-family: Courier;
# }
# #T_5c08a_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.4%, transparent 78.4%);
#   font-family: Courier;
# }
# #T_5c08a_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.7%, transparent 71.7%);
#   font-family: Courier;
# }
# #T_5c08a_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.2%, transparent 34.2%);
#   font-family: Courier;
# }
# #T_5c08a_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.4%, transparent 56.4%);
#   font-family: Courier;
# }
# #T_5c08a_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 88.6%, transparent 88.6%);
#   font-family: Courier;
# }
# #T_5c08a_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.1%, transparent 79.1%);
#   font-family: Courier;
# }
# #T_5c08a_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.5%, transparent 52.5%);
#   font-family: Courier;
# }
# #T_5c08a_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 36.5%, transparent 36.5%);
#   font-family: Courier;
# }
# #T_5c08a_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.7%, transparent 54.7%);
#   font-family: Courier;
# }
# #T_5c08a_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.6%, transparent 82.6%);
#   font-family: Courier;
# }
# #T_5c08a_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 83.5%, transparent 83.5%);
#   font-family: Courier;
# }
# #T_5c08a_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 40.8%, transparent 40.8%);
#   font-family: Courier;
# }
# #T_5c08a_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.6%, transparent 32.6%);
#   font-family: Courier;
# }
# #T_5c08a_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 51.7%, transparent 51.7%);
#   font-family: Courier;
# }
# #T_5c08a_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.8%, transparent 82.8%);
#   font-family: Courier;
# }
# #T_5c08a_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.1%, transparent 72.1%);
#   font-family: Courier;
# }
# #T_5c08a_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.8%, transparent 52.8%);
#   font-family: Courier;
# }
# #T_5c08a_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.4%, transparent 29.4%);
#   font-family: Courier;
# }
# #T_5c08a_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.9%, transparent 45.9%);
#   font-family: Courier;
# }
# #T_5c08a_row8_col1, #T_5c08a_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 83.6%, transparent 83.6%);
#   font-family: Courier;
# }
# #T_5c08a_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.0%, transparent 78.0%);
#   font-family: Courier;
# }
# #T_5c08a_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.2%, transparent 69.2%);
#   font-family: Courier;
# }
# #T_5c08a_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.9%, transparent 25.9%);
#   font-family: Courier;
# }
# #T_5c08a_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.4%, transparent 54.4%);
#   font-family: Courier;
# }
# #T_5c08a_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.8%, transparent 68.8%);
#   font-family: Courier;
# }
# #T_5c08a_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 94.7%, transparent 94.7%);
#   font-family: Courier;
# }
# #T_5c08a_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.2%, transparent 31.2%);
#   font-family: Courier;
# }
# #T_5c08a_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.4%, transparent 45.4%);
#   font-family: Courier;
# }
# #T_5c08a_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.9%, transparent 72.9%);
#   font-family: Courier;
# }
# #T_5c08a_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.5%, transparent 64.5%);
#   font-family: Courier;
# }
# #T_5c08a_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 23.6%, transparent 23.6%);
#   font-family: Courier;
# }
# #T_5c08a_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.5%, transparent 44.5%);
#   font-family: Courier;
# }
# #T_5c08a_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.2%, transparent 80.2%);
#   font-family: Courier;
# }
# #T_5c08a_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.6%, transparent 68.6%);
#   font-family: Courier;
# }
# #T_5c08a_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 62.1%, transparent 62.1%);
#   font-family: Courier;
# }
# #T_5c08a_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.2%, transparent 21.2%);
#   font-family: Courier;
# }
# #T_5c08a_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 41.4%, transparent 41.4%);
#   font-family: Courier;
# }
# #T_5c08a_row12_col1

# %% [markdown]
# ### <a id='toc1_5_1_'></a>[alle Therapien](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_C,
    FILTERS_NO_C44,
    FILTERS_NO_180D_DEAD,
    # FILTERS_SOLID,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        --z_tum_id,
        z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_treat,
        count(*) as cnt,
        cnt_no_treat / cnt as pct_no_treat
    from Tumor
    where {_filter}
    group by all
    union
    select
        --z_tum_id,
        'Total' as z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_treat,
        count(*) as cnt,
        cnt_no_treat / cnt as pct_no_treat
    from Tumor
    where {_filter}
    group by all
    union
    select
        --z_tum_id,
        z_kkr_label,
        'Total' as z_dy,
        sum(case when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_treat,
        count(*) as cnt,
        cnt_no_treat / cnt as pct_no_treat
    from Tumor
    where {_filter}
    group by all
    union
    select
        --z_tum_id,
        'Total' as z_kkr_label,
        'Total' as z_dy,
        sum(case when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_treat,
        count(*) as cnt,
        cnt_no_treat / cnt as pct_no_treat
    from Tumor
    where {_filter}
    group by all
    
""")
# _db.show()
tbl.pivot_df(
    _db.project("z_kkr_label, z_dy, pct_no_treat",).to_df(),
    # show_as_pct=True,
    total_axis="",
    precision=1,
    show_as_pct=True,
    pct_axis="",
    data_bar_axis="xy",
    # heatmap_axis="xy",
    kpi_mode="min_max_x",
    font_size_th=13,
    font_size_td=11,
    # font_size_th=7,
    # font_size_td=5,
    image_scale='800',
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_430_058  (85.4%) ░░░░░█████████████████████████
# └ [keine DCO]:                     n = 3_318_557  (82.6%) ░░░░░░████████████████████████
# └ [ICD10 nur C]:                   n = 2_773_478  (69.1%) ░░░░░░░░░░████████████████████
# └ [keine C44,D04]:                 n = 2_291_677  (57.1%) ░░░░░░░░░░░░░█████████████████
# └ [keine Verstorbenen < 180 Tage]: n = 1_959_965  (48.8%) ░░░░░░░░░░░░░░░░██████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and left(z_icd10_3d,1) = 'C'
# and z_icd10_3d not in ('C44','D04')
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_0f5db th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_0f5db td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_0f5db_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.8%, transparent 54.8%);
#   font-family: Courier;
# }
# #T_0f5db_row0_col1, #T_0f5db_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.6%, transparent 59.6%);
#   font-family: Courier;
# }
# #T_0f5db_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.6%, transparent 54.6%);
#   font-family: Courier;
# }
# #T_0f5db_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.0%, transparent 54.0%);
#   font-family: Courier;
# }
# #T_0f5db_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.9%, transparent 60.9%);
#   font-family: Courier;
# }
# #T_0f5db_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.4%, transparent 56.4%);
#   font-family: Courier;
# }
# #T_0f5db_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.7%, transparent 48.7%);
#   font-family: Courier;
# }
# #T_0f5db_row1_col1, #T_0f5db_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 49.8%, transparent 49.8%);
#   font-family: Courier;
# }
# #T_0f5db_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.6%, transparent 47.6%);
#   font-family: Courier;
# }
# #T_0f5db_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 51.2%, transparent 51.2%);
#   font-family: Courier;
# }
# #T_0f5db_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.2%, transparent 60.2%);
#   font-family: Courier;
# }
# #T_0f5db_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.6%, transparent 50.6%);
#   font-family: Courier;
# }
# #T_0f5db_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.0%, transparent 53.0%);
#   font-family: Courier;
# }
# #T_0f5db_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.4%, transparent 53.4%);
#   font-family: Courier;
# }
# #T_0f5db_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.3%, transparent 59.3%);
#   font-family: Courier;
# }
# #T_0f5db_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.5%, transparent 61.5%);
#   font-family: Courier;
# }
# #T_0f5db_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_0f5db_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.0%, transparent 61.0%);
#   font-family: Courier;
# }
# #T_0f5db_row3_col0, #T_0f5db_row14_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 40.8%, transparent 40.8%);
#   font-family: Courier;
# }
# #T_0f5db_row3_col1, #T_0f5db_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 39.8%, transparent 39.8%);
#   font-family: Courier;
# }
# #T_0f5db_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 43.0%, transparent 43.0%);
#   font-family: Courier;
# }
# #T_0f5db_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.5%, transparent 45.5%);
#   font-family: Courier;
# }
# #T_0f5db_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.3%, transparent 47.3%);
#   font-family: Courier;
# }
# #T_0f5db_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 42.9%, transparent 42.9%);
#   font-family: Courier;
# }
# #T_0f5db_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.9%, transparent 85.9%);
#   font-family: Courier;
# }
# #T_0f5db_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.4%, transparent 68.4%);
#   font-family: Courier;
# }
# #T_0f5db_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.6%, transparent 65.6%);
#   font-family: Courier;
# }
# #T_0f5db_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.9%, transparent 69.9%);
#   font-family: Courier;
# }
# #T_0f5db_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.1%, transparent 78.1%);
#   font-family: Courier;
# }
# #T_0f5db_row4_col5, #T_0f5db_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 73.1%, transparent 73.1%);
#   font-family: Courier;
# }
# #T_0f5db_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.0%, transparent 82.0%);
#   font-family: Courier;
# }
# #T_0f5db_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.4%, transparent 75.4%);
#   font-family: Courier;
# }
# #T_0f5db_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 84.3%, transparent 84.3%);
#   font-family: Courier;
# }
# #T_0f5db_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.2%, transparent 81.2%);
#   font-family: Courier;
# }
# #T_0f5db_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.0%, transparent 79.0%);
#   font-family: Courier;
# }
# #T_0f5db_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 67.4%, transparent 67.4%);
#   font-family: Courier;
# }
# #T_0f5db_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.5%, transparent 64.5%);
#   font-family: Courier;
# }
# #T_0f5db_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 67.5%, transparent 67.5%);
#   font-family: Courier;
# }
# #T_0f5db_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 76.6%, transparent 76.6%);
#   font-family: Courier;
# }
# #T_0f5db_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 84.2%, transparent 84.2%);
#   font-family: Courier;
# }
# #T_0f5db_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 70.7%, transparent 70.7%);
#   font-family: Courier;
# }
# #T_0f5db_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.3%, transparent 55.3%);
#   font-family: Courier;
# }
# #T_0f5db_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.3%, transparent 57.3%);
#   font-family: Courier;
# }
# #T_0f5db_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.4%, transparent 60.4%);
#   font-family: Courier;
# }
# #T_0f5db_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 70.3%, transparent 70.3%);
#   font-family: Courier;
# }
# #T_0f5db_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.5%, transparent 59.5%);
#   font-family: Courier;
# }
# #T_0f5db_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.2%, transparent 48.2%);
#   font-family: Courier;
# }
# #T_0f5db_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.7%, transparent 50.7%);
#   font-family: Courier;
# }
# #T_0f5db_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 51.8%, transparent 51.8%);
#   font-family: Courier;
# }
# #T_0f5db_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.7%, transparent 56.7%);
#   font-family: Courier;
# }
# #T_0f5db_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.1%, transparent 69.1%);
#   font-family: Courier;
# }
# #T_0f5db_row8_col5, #T_0f5db_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.9%, transparent 53.9%);
#   font-family: Courier;
# }
# #T_0f5db_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.3%, transparent 45.3%);
#   font-family: Courier;
# }
# #T_0f5db_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 46.0%, transparent 46.0%);
#   font-family: Courier;
# }
# #T_0f5db_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.5%, transparent 56.5%);
#   font-family: Courier;
# }
# #T_0f5db_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.3%, transparent 68.3%);
#   font-family: Courier;
# }
# #T_0f5db_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.5%, transparent 52.5%);
#   font-family: Courier;
# }
# #T_0f5db_row10_col0, #T_0f5db_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8e

# %% [markdown]
# ### <a id='toc1_5_2_'></a>[OP](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_SOLID,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_op_count = 0 then 1 else 0 end) as cnt_no_op,
        count(*) as cnt,
        cnt_no_op / cnt as pct_no_op,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        z_dy::text as z_dy,
        sum(case when z_tum_op_count = 0 then 1 else 0 end) as cnt_no_op,
        count(*) as cnt,
        cnt_no_op / cnt as pct_no_op,
    from Tumor
    where {_filter}
    group by all
    union
    select
        z_kkr_label,
        'Total',
        sum(case when z_tum_op_count = 0 then 1 else 0 end) as cnt_no_op,
        count(*) as cnt,
        cnt_no_op / cnt as pct_no_op,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        'Total',
        sum(case when z_tum_op_count = 0 then 1 else 0 end) as cnt_no_op,
        count(*) as cnt,
        cnt_no_op / cnt as pct_no_op,
    from Tumor
    where {_filter}
    group by all

""")
# _db.show()
tbl.pivot_df(
    _db.project("z_kkr_label, z_dy, pct_no_op",).to_df(),
    # show_as_pct=True,
    total_axis="",
    precision=1,
    show_as_pct=True,
    pct_axis="",
    data_bar_axis="xy",
    # heatmap_axis="xy",
    kpi_mode="min_max_x",
    font_size_th=13,
    font_size_td=11,
    image_scale='800',
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                                  (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]: n = 3_430_058  (85.4%) ░░░░░█████████████████████████
# └ [keine DCO]:                   n = 3_318_557  (82.6%) ░░░░░░████████████████████████
# └ [nur solide Tumore]:           n = 2_065_352  (51.4%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and
#     z_icd10_3d not in ('C44')
#     and left(z_icd10_3d,1) = 'C'
#     and right(z_icd10_3d, 2)::int8 <= 75
#
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_de650 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_de650 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_de650_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.3%, transparent 75.3%);
#   font-family: Courier;
# }
# #T_de650_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.7%, transparent 77.7%);
#   font-family: Courier;
# }
# #T_de650_row0_col2, #T_de650_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.4%, transparent 78.4%);
#   font-family: Courier;
# }
# #T_de650_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.8%, transparent 79.8%);
#   font-family: Courier;
# }
# #T_de650_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 87.7%, transparent 87.7%);
#   font-family: Courier;
# }
# #T_de650_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.0%, transparent 79.0%);
#   font-family: Courier;
# }
# #T_de650_row1_col0, #T_de650_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.6%, transparent 69.6%);
#   font-family: Courier;
# }
# #T_de650_row1_col1, #T_de650_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.3%, transparent 68.3%);
#   font-family: Courier;
# }
# #T_de650_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.8%, transparent 66.8%);
#   font-family: Courier;
# }
# #T_de650_row1_col3, #T_de650_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.3%, transparent 71.3%);
#   font-family: Courier;
# }
# #T_de650_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.5%, transparent 74.5%);
#   font-family: Courier;
# }
# #T_de650_row2_col0, #T_de650_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 73.7%, transparent 73.7%);
#   font-family: Courier;
# }
# #T_de650_row2_col1, #T_de650_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.9%, transparent 71.9%);
#   font-family: Courier;
# }
# #T_de650_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.0%, transparent 78.0%);
#   font-family: Courier;
# }
# #T_de650_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_de650_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.9%, transparent 77.9%);
#   font-family: Courier;
# }
# #T_de650_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 70.2%, transparent 70.2%);
#   font-family: Courier;
# }
# #T_de650_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.5%, transparent 68.5%);
#   font-family: Courier;
# }
# #T_de650_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.3%, transparent 74.3%);
#   font-family: Courier;
# }
# #T_de650_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.4%, transparent 72.4%);
#   font-family: Courier;
# }
# #T_de650_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.8%, transparent 72.8%);
#   font-family: Courier;
# }
# #T_de650_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.6%, transparent 71.6%);
#   font-family: Courier;
# }
# #T_de650_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.4%, transparent 80.4%);
#   font-family: Courier;
# }
# #T_de650_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.0%, transparent 72.0%);
#   font-family: Courier;
# }
# #T_de650_row4_col3, #T_de650_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.4%, transparent 75.4%);
#   font-family: Courier;
# }
# #T_de650_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.5%, transparent 81.5%);
#   font-family: Courier;
# }
# #T_de650_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.7%, transparent 75.7%);
#   font-family: Courier;
# }
# #T_de650_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.5%, transparent 77.5%);
#   font-family: Courier;
# }
# #T_de650_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 83.3%, transparent 83.3%);
#   font-family: Courier;
# }
# #T_de650_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.6%, transparent 80.6%);
#   font-family: Courier;
# }
# #T_de650_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.4%, transparent 85.4%);
#   font-family: Courier;
# }
# #T_de650_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 86.7%, transparent 86.7%);
#   font-family: Courier;
# }
# #T_de650_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.2%, transparent 82.2%);
#   font-family: Courier;
# }
# #T_de650_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.5%, transparent 79.5%);
#   font-family: Courier;
# }
# #T_de650_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 76.3%, transparent 76.3%);
#   font-family: Courier;
# }
# #T_de650_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.2%, transparent 77.2%);
#   font-family: Courier;
# }
# #T_de650_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.6%, transparent 79.6%);
#   font-family: Courier;
# }
# #T_de650_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.0%, transparent 82.0%);
#   font-family: Courier;
# }
# #T_de650_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.6%, transparent 78.6%);
#   font-family: Courier;
# }
# #T_de650_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.5%, transparent 71.5%);
#   font-family: Courier;
# }
# #T_de650_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.8%, transparent 75.8%);
#   font-family: Courier;
# }
# #T_de650_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.5%, transparent 82.5%);
#   font-family: Courier;
# }
# #T_de650_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.0%, transparent 75.0%);
#   font-family: Courier;
# }
# #T_de650_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.0%, transparent 59.0%);
#   font-family: Courier;
# }
# #T_de650_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.7%, transparent 64.7%);
#   font-family: Courier;
# }
# #T_de650_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.6%, transparent 65.6%);
#   font-family: Courier;
# }
# #T_de650_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.0%, transparent 68.0%);
#   font-family: Courier;
# }
# #T_de650_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.0%, transparent 74.0%);
#   font-family: Courier;
# }
# #T_de650_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.5%, transparent 65.5%);
#   font-family: Courier;
# }
# #T_de650_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.8%, transparent 71.8%);
#   font-family: Courier;
# }
# #T_de650_row9_col1, #T_de650_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 73.4%, transparent 73.4%);
#   font-family: Courier;
# }
# #T_de650_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.9%, transparent 78.9%);
#   font-family: Courier;
# }
# #T_de650_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.4%, transparent 77.4%);
#   font-family: Courier;
# }
# #T_de650_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 87.0%, transparent 87.0%);
#   font-family: Courier;
# }
# #T_de650_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 76.7%, transparent 76.7%);
#   font-family: Courier;
# }
# #T_de650_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.0%, transparent 65.0%);
#   font-family: Courier;
# }
# #T_de650_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.2%, transparent 65.2%);
#   font-family: Courier;
# }
# #T_de650_row10_col2 {
#   width: 10em;
#   background: linear-g

# %% [markdown]
# #### <a id='toc1_5_2_1_'></a>[OP wenn OP erwartet](#toc0_)
# - kategorien
#   - `1_op`: mind. eine OPS im definierten Bereich (3Steller, organspezifisch) ist dokumentiert
#   - `2_no_op_but_tp`: keine OPS, aber pT 1-4 ist dokumentiert
#   - `3_rest`: keine der zuvor genannten Merkmale trifft

# %% [markdown]
# ##### <a id='toc1_5_2_1_1_'></a>[C50](#toc0_)

# %%
FILTERS_C50 = ("z_icd10_3d = 'C50'", "ICD10 C50")
_filters = [
    FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_C50,
    FILTERS_M0,
    FILTERS_NO_180D_DEAD,
    # FILTERS_AGE_LT_80,
]
_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    # query="from Tumor tum left join OPS ops on ops.z_tum_id = tum.z_tum_id",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

db_op_c50 = con.sql(f"""--sql
    with t1 as (
        select
            tum.z_tum_id,
            z_kkr_label,
            op.Intention,
            z_tum_op_count,
            z_tum_st_count,
            z_tum_sy_count,
            case when {FILTERS_OPS_C50[0]} then true else false end as has_ops,
            case when z_t_p_1 in ('1','2','3','4') then true else false end as has_t_p,
            case when st.Stellung_OP = 'O' or sy.Stellung_OP = 'O' then true else false end as has_stell_op,
            sy.SYSTId
        from Tumor tum
        left join op on op.z_tum_id = tum.z_tum_id
        left join OPS ops on op.OPId = ops.OP_TypId
        left join ST st on tum.z_tum_id = st.z_tum_id
        left join SYST sy on tum.z_tum_id = sy.z_tum_id
        where {_filter}
    ),
    t2 as (
        select
            z_tum_id,
            any_value(z_kkr_label) as z_kkr_label,
            case
                when max(has_ops) then '1_op'
                when max(has_t_p) then '2_no_op_but_tp'
                --when max(has_stell_op) then '3_no_op_tp_but_other'
                when not(max(has_ops and has_t_p and has_stell_op)) then '3_rest'
                else 'U'
            end as categ_op,
            --Intention,
        from t1
        group by z_tum_id
    )
    select * from t2
""")
# tbl.descr_db(db_op_c50, "db_op_c50")
# db_op_c50.filter("z_tum_id = 'cdb36878-a43c-4413-9b56-14220b042323'").show()
# db_op_c50.filter("left(categ_op,1) = '4'").show()
# hlp.get_tum_details("c46d2307-ff1d-4dae-9725-d1e558dbd49f",con=con)

pls.plot_stacked_bars(
    db_op_c50.project("z_kkr_label, categ_op").to_df(),
    show_total=True,
    relative=True,
    normalize=True,
    orientation="h",
    show_pct_bar=True,
    caption="C50",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_430_058  (85.4%) ░░░░░█████████████████████████
# └ [ICD10 C50]:                       n = 362_653   (9.0%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# └ [nur M0]:                          n = 273_283   (6.8%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# └ [keine Verstorbenen < 180 Tage]:   n = 270_004   (6.7%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Diagnosedatum between '2020-01-01' and '2024-06-30'
# and z_icd10_3d = 'C50'
# and z_m_pc_1 = '0'
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>

# %% [markdown]
# ##### <a id='toc1_5_2_1_2_'></a>[C18-C20](#toc0_)

# %%
FILTER_C18C20 = ("z_icd10_3d in ('C18', 'C19', 'C20')", "ICD10 C18-C20")
_filters = [
    FILTERS_DY,
    FILTER_C18C20,
    FILTERS_M0,
    FILTERS_NO_180D_DEAD,
    # FILTERS_AGE_LT_80,
]
_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

db_op_c50 = con.sql(f"""--sql
    with t1 as (
        select
            tum.z_tum_id,
            z_kkr_label,
            op.Intention,
            z_tum_op_count,
            z_tum_st_count,
            z_tum_sy_count,
            case when {FILTERS_OPS_C18C20[0]} then true else false end as has_ops,
            case when z_t_p_1 in ('1','2','3','4') then true else false end as has_t_p,
            case when st.Stellung_OP = 'O' or sy.Stellung_OP = 'O' then true else false end as has_stell_op,
            sy.SYSTId
        from Tumor tum
        left join op on op.z_tum_id = tum.z_tum_id
        left join OPS ops on op.OPId = ops.OP_TypId
        left join ST st on tum.z_tum_id = st.z_tum_id
        left join SYST sy on tum.z_tum_id = sy.z_tum_id
        where {_filter}
    ),
    t2 as (
        select
            z_tum_id,
            any_value(z_kkr_label) as z_kkr_label,
            case
                when max(has_ops) then '1_op'
                when max(has_t_p) then '2_no_op_but_tp'
                --when max(has_stell_op) then '3_no_op_tp_but_other'
                when not(max(has_ops and has_t_p and has_stell_op)) then '3_rest'
                else 'U'
            end as categ_op,
            --Intention,
        from t1
        group by z_tum_id
    )
    select * from t2
""")
# tbl.descr_db(db_op_c50, "db_op_c50")
# db_op_c50.filter("z_tum_id = 'cdb36878-a43c-4413-9b56-14220b042323'").show()
# db_op_c50.filter("left(categ_op,1) = '4'").show()
# hlp.get_tum_details("c46d2307-ff1d-4dae-9725-d1e558dbd49f",con=con)

pls.plot_stacked_bars(
    db_op_c50.project("z_kkr_label, categ_op").to_df(),
    show_total=True,
    relative=True,
    normalize=True,
    orientation="h",
    show_pct_bar=True,
    caption="C18-C20",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [ICD10 C18-C20]:                   n = 284_931   (7.1%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# └ [nur M0]:                          n = 167_650   (4.2%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# └ [keine Verstorbenen < 180 Tage]:   n = 154_254   (3.8%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_icd10_3d in ('C18', 'C19', 'C20')
# and z_m_pc_1 = '0'
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>

# %% [markdown]
# ### <a id='toc1_5_3_'></a>[ST](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_SOLID,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_st_count = 0 then 1 else 0 end) as cnt_no_st,
        count(*) as cnt,
        cnt_no_st / cnt as pct_no_st,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        z_dy::text as z_dy,
        sum(case when z_tum_st_count = 0 then 1 else 0 end) as cnt_no_st,
        count(*) as cnt,
        cnt_no_st / cnt as pct_no_st,
    from Tumor
    where {_filter}
    group by all
    union
    select
        z_kkr_label,
        'Total',
        sum(case when z_tum_st_count = 0 then 1 else 0 end) as cnt_no_st,
        count(*) as cnt,
        cnt_no_st / cnt as pct_no_st,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        'Total',
        sum(case when z_tum_st_count = 0 then 1 else 0 end) as cnt_no_st,
        count(*) as cnt,
        cnt_no_st / cnt as pct_no_st,
    from Tumor
    where {_filter}
    group by all

""")
# _db.show()
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                                  (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]: n = 3_430_058  (85.4%) ░░░░░█████████████████████████
# └ [keine DCO]:                   n = 3_318_557  (82.6%) ░░░░░░████████████████████████
# └ [nur solide Tumore]:           n = 2_065_352  (51.4%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and
#     z_icd10_3d not in ('C44')
#     and left(z_icd10_3d,1) = 'C'
#     and right(z_icd10_3d, 2)::int8 <= 75
#
# ```
#
# </details>

# %%
tbl.pivot_df(
    _db.project("z_kkr_label, z_dy, pct_no_st",).to_df(),
    # show_as_pct=True,
    total_axis="",
    precision=1,
    show_as_pct=True,
    pct_axis="",
    data_bar_axis="",
    heatmap_axis="xy",
    kpi_mode="min_max_x",
    font_size_th=11,
    font_size_td=10,
    # swap=True,
    image_scale="550",
)
# Out:
# <!-- SCALE-550 -->
# <style type="text/css">
# #T_62985 th {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_62985 td {
#   text-align: right;
#   font-size: 10pt;
# }
# #T_62985_row0_col0 {
#   font-family: Courier;
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_62985_row0_col1, #T_62985_row9_col5 {
#   font-family: Courier;
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_62985_row0_col2, #T_62985_row10_col5, #T_62985_row15_col5 {
#   font-family: Courier;
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_62985_row0_col3 {
#   font-family: Courier;
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_62985_row0_col4, #T_62985_row10_col2, #T_62985_row15_col2 {
#   font-family: Courier;
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_62985_row0_col5, #T_62985_row1_col3 {
#   font-family: Courier;
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_62985_row1_col0, #T_62985_row7_col0 {
#   font-family: Courier;
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_62985_row1_col1 {
#   font-family: Courier;
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_62985_row1_col2, #T_62985_row7_col1 {
#   font-family: Courier;
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_62985_row1_col4 {
#   font-family: Courier;
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_62985_row1_col5 {
#   font-family: Courier;
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_62985_row2_col0 {
#   font-family: Courier;
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_62985_row2_col1, #T_62985_row7_col5 {
#   font-family: Courier;
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_62985_row2_col2 {
#   font-family: Courier;
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_62985_row2_col3 {
#   font-family: Courier;
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_62985_row2_col4 {
#   font-family: Courier;
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_62985_row2_col5 {
#   font-family: Courier;
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_62985_row3_col0 {
#   font-family: Courier;
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_62985_row3_col1 {
#   font-family: Courier;
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_62985_row3_col2, #T_62985_row10_col1, #T_62985_row12_col5, #T_62985_row14_col1, #T_62985_row15_col0 {
#   font-family: Courier;
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_62985_row3_col3 {
#   font-family: Courier;
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_62985_row3_col4 {
#   font-family: Courier;
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_62985_row3_col5 {
#   font-family: Courier;
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_62985_row4_col0 {
#   font-family: Courier;
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_62985_row4_col1 {
#   font-family: Courier;
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_62985_row4_col2 {
#   font-family: Courier;
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_62985_row4_col3, #T_62985_row4_col4 {
#   font-family: Courier;
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_62985_row4_col5 {
#   font-family: Courier;
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_62985_row5_col0, #T_62985_row16_col3 {
#   font-family: Courier;
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_62985_row5_col1 {
#   font-family: Courier;
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_62985_row5_col2 {
#   font-family: Courier;
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_62985_row5_col3 {
#   font-family: Courier;
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_62985_row5_col4 {
#   font-family: Courier;
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_62985_row5_col5, #T_62985_row15_col4 {
#   font-family: Courier;
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_62985_row6_col0, #T_62985_row13_col4 {
#   font-family: Courier;
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_62985_row6_col1 {
#   font-family: Courier;
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_62985_row6_col2 {
#   font-family: Courier;
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_62985_row6_col3 {
#   font-family: Courier;
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_62985_row6_col4 {
#   font-family: Courier;
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_62985_row6_col5 {
#   font-family: Courier;
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_62985_row7_col2, #T_62985_row14_col3 {
#   font-family: Courier;
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_62985_row7_col3 {
#   font-family: Courier;
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_62985_row7_col4 {
#   font-family: Courier;
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_62985_row8_col0, #T_62985_row9_col3, #T_62985_row14_col0 {
#   font-family: Courier;
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_62985_row8_col1, #T_62985_row14_col2 {
#   font-family: Courier;
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_62985_row8_col2 {
#   font-family: Courier;
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_62985_row8_col3 {
#   font-family: Courier;
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_62985_row8_col4 {
#   font-family: Courier;
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_62985_row8_col5 {
#   font-family: Courier;
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_62985_row9_col0, #T_62985_row11_col2 {
#   font-family: Courier;
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_62985_row9_col1 {
#   font-family: Courier;
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_62985_row9_col2 {
#   font-family: Courier;
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_62985_row9_col4 {
#   font-family: Courier;
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_62985_row10_col0, #T_62985_row11_col5 {
#   font-family: Courier;
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_62985_row10_col3 {
#   font-family: Courier;
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_62985_row10_col4 {
#   font-family: Courier;
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_62985_row11_col0 {
#   font-family: Courier;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_62985_row11_col1 {
#   font-family: Courier;
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_62985_row11_col3 {
#   font-family: Courier;
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_62985_row11_col4 {
#   font-family: Courier;
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_62985_row12_col0 {
#   font-family: Courier;
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_62985_row12_col1 {
#   font-family: Courier;
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_62985_row12_col2 {
#   font-family: Courier;
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_62985_row12_col3, #T_62985_row16_col0 {
#   font-family: Courier;
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_62985_row12_col4 {
#   font-family: Courier;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_62985_row13_col0 {
#   font-family: Courier;
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_62985_row13_col1 {
#   font-family: Courier;
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_62985_row13_col2 {
#   font-family: Courier;
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_62985_row13_col3 {
#   font-family: Courier;
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_62985_row13_col5 {
#   font-family: Courier;
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_62985_row14_col4 {
#   font-family: Courier;
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_62985_row14_col5 {
#   font-family: Courier;
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_62985_row15_col1 {
#   font-family: Courier;
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_62985_row15_col3 {
#   font-family: Courier;
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_62985_row16_col1 {
#   font-family: Courier;
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_62985_row16_col2, #T_62985_row16_col5 {
#   font-family: Courier;
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_62985_row16_col4 {
#   font-family: Courier;
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_62985">
#   <thead>
#     <tr>
#       <th class="index_name level0"

# %% [markdown]
# ### <a id='toc1_5_4_'></a>[SYST](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_NO_M1,
    # FILTERS_NO_SOLID,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_sy,
        count(*) as cnt,
        cnt_no_sy / cnt as pct_no_sy,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        z_dy::text as z_dy,
        sum(case when z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_sy,
        count(*) as cnt,
        cnt_no_sy / cnt as pct_no_sy,
    from Tumor
    where {_filter}
    group by all
    union
    select
        z_kkr_label,
        'Total',
        sum(case when z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_sy,
        count(*) as cnt,
        cnt_no_sy / cnt as pct_no_sy,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        'Total',
        sum(case when z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_sy,
        count(*) as cnt,
        cnt_no_sy / cnt as pct_no_sy,
    from Tumor
    where {_filter}
    group by all

""")
# _db.show()
tbl.pivot_df(
    _db.project("z_kkr_label, z_dy, pct_no_sy",).to_df(),
    # show_as_pct=True,
    total_axis="",
    precision=1,
    show_as_pct=True,
    pct_axis="",
    data_bar_axis="",
    heatmap_axis="xy",
    kpi_mode="min_max_x",
    font_size_th=11,
    font_size_td=10,
    # swap=True,
    image_scale="550",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                                  (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]: n = 3_430_058  (85.4%) ░░░░░█████████████████████████
# └ [keine DCO]:                   n = 3_318_557  (82.6%) ░░░░░░████████████████████████
# └ [kein M1]:                     n = 2_997_763  (74.6%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and ifnull(z_m_pc_1,'') <> '1'
# ```
#
# </details>
# <!-- SCALE-550 -->
# <style type="text/css">
# #T_9c8f2 th {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_9c8f2 td {
#   text-align: right;
#   font-size: 10pt;
# }
# #T_9c8f2_row0_col0, #T_9c8f2_row0_col2 {
#   font-family: Courier;
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_9c8f2_row0_col1 {
#   font-family: Courier;
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_9c8f2_row0_col3 {
#   font-family: Courier;
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_9c8f2_row0_col4 {
#   font-family: Courier;
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_9c8f2_row0_col5 {
#   font-family: Courier;
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_9c8f2_row1_col0, #T_9c8f2_row2_col4 {
#   font-family: Courier;
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_9c8f2_row1_col1 {
#   font-family: Courier;
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_9c8f2_row1_col2 {
#   font-family: Courier;
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_9c8f2_row1_col3 {
#   font-family: Courier;
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_9c8f2_row1_col4, #T_9c8f2_row6_col5, #T_9c8f2_row13_col0 {
#   font-family: Courier;
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_9c8f2_row1_col5, #T_9c8f2_row14_col0 {
#   font-family: Courier;
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_9c8f2_row2_col0, #T_9c8f2_row11_col1, #T_9c8f2_row11_col5 {
#   font-family: Courier;
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_9c8f2_row2_col1 {
#   font-family: Courier;
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_9c8f2_row2_col2, #T_9c8f2_row11_col3 {
#   font-family: Courier;
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_9c8f2_row2_col3, #T_9c8f2_row10_col1 {
#   font-family: Courier;
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_9c8f2_row2_col5 {
#   font-family: Courier;
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_9c8f2_row3_col0, #T_9c8f2_row3_col2 {
#   font-family: Courier;
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_9c8f2_row3_col1 {
#   font-family: Courier;
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_9c8f2_row3_col3 {
#   font-family: Courier;
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_9c8f2_row3_col4 {
#   font-family: Courier;
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_9c8f2_row3_col5 {
#   font-family: Courier;
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_9c8f2_row4_col0 {
#   font-family: Courier;
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_9c8f2_row4_col1, #T_9c8f2_row4_col5 {
#   font-family: Courier;
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_9c8f2_row4_col2 {
#   font-family: Courier;
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_9c8f2_row4_col3 {
#   font-family: Courier;
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_9c8f2_row4_col4 {
#   font-family: Courier;
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_9c8f2_row5_col0 {
#   font-family: Courier;
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_9c8f2_row5_col1 {
#   font-family: Courier;
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_9c8f2_row5_col2 {
#   font-family: Courier;
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_9c8f2_row5_col3, #T_9c8f2_row8_col3, #T_9c8f2_row14_col2, #T_9c8f2_row16_col1 {
#   font-family: Courier;
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_9c8f2_row5_col4, #T_9c8f2_row8_col2 {
#   font-family: Courier;
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_9c8f2_row5_col5, #T_9c8f2_row16_col0 {
#   font-family: Courier;
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_9c8f2_row6_col0 {
#   font-family: Courier;
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_9c8f2_row6_col1 {
#   font-family: Courier;
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_9c8f2_row6_col2 {
#   font-family: Courier;
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_9c8f2_row6_col3 {
#   font-family: Courier;
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_9c8f2_row6_col4 {
#   font-family: Courier;
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_9c8f2_row7_col0, #T_9c8f2_row10_col0, #T_9c8f2_row15_col3 {
#   font-family: Courier;
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_9c8f2_row7_col1 {
#   font-family: Courier;
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_9c8f2_row7_col2, #T_9c8f2_row7_col3 {
#   font-family: Courier;
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_9c8f2_row7_col4 {
#   font-family: Courier;
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_9c8f2_row7_col5 {
#   font-family: Courier;
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_9c8f2_row8_col0 {
#   font-family: Courier;
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_9c8f2_row8_col1 {
#   font-family: Courier;
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_9c8f2_row8_col4, #T_9c8f2_row14_col3 {
#   font-family: Courier;
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_9c8f2_row8_col5, #T_9c8f2_row12_col0 {
#   font-family: Courier;
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_9c8f2_row9_col0, #T_9c8f2_row9_col3 {
#   font-family: Courier;
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_9c8f2_row9_col1 {
#   font-family: Courier;
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_9c8f2_row9_col2 {
#   font-family: Courier;
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_9c8f2_row9_col4 {
#   font-family: Courier;
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_9c8f2_row9_col5, #T_9c8f2_row16_col3 {
#   font-family: Courier;
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_9c8f2_row10_col2 {
#   font-family: Courier;
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_9c8f2_row10_col3 {
#   font-family: Courier;
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_9c8f2_row10_col4 {
#   font-family: Courier;
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_9c8f2_row10_col5 {
#   font-family: Courier;
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_9c8f2_row11_col0 {
#   font-family: Courier;
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_9c8f2_row11_col2 {
#   font-family: Courier;
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_9c8f2_row11_col4 {
#   font-family: Courier;
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_9c8f2_row12_col1, #T_9c8f2_row14_col5 {
#   font-family: Courier;
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_9c8f2_row12_col2 {
#   font-family: Courier;
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_9c8f2_row12_col3 {
#   font-family: Courier;
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_9c8f2_row12_col4 {
#   font-family: Courier;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9c8f2_row12_col5, #T_9c8f2_row13_col1 {
#   font-family: Courier;
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_9c8f2_row13_col2 {
#   font-family: Courier;
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_9c8f2_row13_col3 {
#   font-family: Courier;
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_9c8f2_row13_col4, #T_9c8f2_row14_col1 {
#   font-family: Courier;
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_9c8f2_row13_col5, #T_9c8f2_row14_col4, #T_9c8f2_row16_col4 {
#   font-family: Courier;
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_9c8f2_row15_col0 {
#   font-family: Courier;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9c8f2_row15_col1 {
#   font-family: Courier;
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_9c8f2_row15_col2 {
#   font-family: Courier;
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_9c8f2_row15_col4 {
#   font-family: Courier;
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_9c8f2_row15_col5 {
#   font-family: Courier;
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_9c8f2_row16_col2 {
#   font-family: Courier;
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_9c8f2_row16_col5 {
#   font-family: Courier;
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c8f2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >z_dy</th>
#       <th id="T_9c8f2_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_9c8f2_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_9c8f2_level0_col2" class="col_heading

# %% [markdown]
# <br>
#
# ## <a id='toc1_6_'></a>[Fallzahlen epi vs clin](#toc0_)
# - Ziel der Darstellung: Abschätzung der Vollzähligkeit der klinischen Daten
# - dargestellt sind die gefilterten Fallzahlen jeweils aus den epi und den klinischen Daten, hier allerdings nur aus dem aktuellstem DJ
# - Hinweis: Die Auswertung Daten basiert auf `Inzidenzort` anstatt `Lieferregister`, da in den epi Daten bislang die einzelnen Länder des GKR nicht aufgeschlüsselt waren, und ein matching auf EKRNR somit fehlschlägt
#
# > [!NOTE]
# > 💡 **NI**: _"Die **höhere Fallzahl** des epidemiologischen Registers im Vergleich zum klinischen Register ist vermutlich auf unterschiedliche Filterkriterien in den beiden Registern zurückzuführen. Im KKN werden neben den Kriterien die das Lieferschema vorgibt auch noch weitere Plausibilitätsprüfungen angewandt. Tumoren, welche diese Prüfungen nicht bestehen, werden vom Export ausgeschlossen"_
# >
# > ---
# > 💡 **ZfKD**: Die quota in den anderen KKR entspricht der Erwartung, dass die Fallzahl bei klin. Daten höher sein sollte als bei epi Daten.

# %%
_filters = [
    (f"z_dy in ({DY_MAX})",f"DJ {DY_MAX}"),
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db2=(db_clin_all
    # .filter("left(kkr,2) = bl and bl::int between 1 and 16")  # * very few cases
    .filter(f"{_filter}")
    .aggregate("bl, count(*) as clin_cnt")
    .join(dim_lieferregister.set_alias("l"), "bl::int8 = l.code", "left")
    .project("bl,clin_cnt")
    )

_db1=(Tumor4
    # .project("*, case when left(GKZlk,2)::int > 10 then left(GKZlk,2) else EKRNR end as EKRNR_")
    # .filter("EKRNR_ = left(GKZlk,2) and left(GKZlk,2)::int between 1 and 16")
    # .filter(f"DJ in ({DY_MAX}) and not is_deleted")
    # .filter("left(ICDGM10,3) <> 'C44' and  DCO = 2")
    .filter("not is_deleted")
    .filter(_filter)
    .aggregate("left(GKZlk,2) as bl, count(*) as epi_cnt")
    )

_df12 = _db1.join(_db2, "bl", "right").to_df()


_tu = (
    _df12.merge(dim_lieferregister.to_df(), left_on="bl", right_on="code")
    .assign(quota=lambda x: x.clin_cnt / x.epi_cnt * 100)
    .set_index("kkr")[["clin_cnt", "epi_cnt", "quota"]]
    .sort_index(ascending=True)
    .T
)
# display(tbl.show_num_df(
#     _tu.fillna(0),
#     total_mode="",
#     font_size_th=11,
#     font_size_td=9,
# ))

con.from_df(_tu
    # .fillna(0)
    .map(lambda x: f"{x:_.0f}")
    .reset_index(names="kkr",)
    ).show()
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2024]:         n = 691_248  (17.2%) ░░░░░░░░░░░░░░░░░░░░░░░░░█████
# └ [keine DCO]:       n = 672_045  (16.7%) ░░░░░░░░░░░░░░░░░░░░░░░░░█████
# └ [keine C44,D04]:   n = 568_242  (14.1%) ░░░░░░░░░░░░░░░░░░░░░░░░░░████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy in (2024)
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# ┌──────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┐
# │   kkr    │  01-SH  │  02-HH  │  03-NI  │  04-HB  │  05-NW  │  06-HE  │  07-RP  │  08-BW  │  09-BY  │  10-SL  │  11-BE  │  12-BB  │  13-MV  │  14-SN  │  15-ST  │  16-TH  │
# │ varchar  │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │ varchar │
# ├──────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ clin_cnt │ 23_860  │ 12_999  │ 47_593  │ 4_541   │ 129_531 │ 29_173  │ 29_734  │ 80_888  │ 88_739  │ 8_774   │ 25_458  │ 20_371  │ 1_150   │ 33_715  │ 17_664  │ 14_045  │
# │ epi_cnt  │ 22_820  │ 12_347  │ 56_134  │ 4_371   │ 129_466 │ 27_955  │ 28_807  │ 74_961  │ 81_866  │ 8_349   │ 24_019  │ 19_266  │ 1_011   │ 32_952  │ 17_291  │ 13_473  │
# │ quota    │ 105     │ 105     │ 85      │ 104     │ 100     │ 104     │ 103     │ 108     │ 108     │ 105     │ 106     │ 106     │ 114     │ 102     │ 102     │ 104     │
# └──────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┘

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_7_'></a>[Verteilung von Variablen](#toc0_)
# - in den Diagrammen gibt das angegebene _`n=`_ einen Hinweis auf die verwendete Grundgesamtheit
# - die _relativen_ Barcharts enthalten ein `Total` item für den Gesamtvergleich

# %%
def show_vars(idx: int, group_reg: str, show: bool = True, filter: str=""):
    agg_counts = {"pat": "distinct oBDS_RKIPatientId", "tum": "*"}
    agg_cols = [
        ["Geschlecht", "pat"], # 0
        ["Verstorben", "pat"], # 1
        ["UICC_Stadium_p", "tum"],
        ["Diagnosesicherung", "tum"],
        ["z_dy", "tum"],
        ["Inzidenzort_BL", "tum"],
        ["z_icd10_3d", "tum"],
        ["Morphologie_Version", "tum"],
        ["TNM_Auflage_p", "tum"],
        ["z_t_p_1", "tum"],
        ["z_is_dco", "tum"],    # 10
        ["z_n_p_1", "tum"],
        ["z_m_p_1", "tum"],
        ["Grading", "tum"],
        ["DCN", "tum"],
    ]

    db_vars = (Tumor.set_alias("t")
        .project("*, left(Inzidenzort,2) as Inzidenzort_BL, z_dy, z_is_dco")
        .join(Patient, "oBDS_RKIPatientId")
        .join(dim_lieferregister, "t.z_kkr::int = code::int", "left")
        .join(dim_icd10_3d.set_alias("i"), "z_icd10_3d=i.code", how="left")
        .filter(filter if filter else "True")
        .aggregate(
            f"{group_reg}, {agg_cols[idx][0]} as value, count({agg_counts[agg_cols[idx][1]]}) as cnt"
        )
    )

    # * optional dim applikation
    if idx==2:
        db_vars = (db_vars
                .join(dim_tnm_uicc.set_alias("dim"), "value = dim.code", "left")
                .project(f"{group_reg},code_1 as value, cnt"))
    elif idx==3:
        db_vars = (db_vars
                .join(dim_dsich_clin, "value = code", "left")
                .project(f"{group_reg}, concat(value, ' - ', name) as value, cnt"))
    elif idx==6:
        db_vars = (db_vars
                .join(dim_icd10_3d, "value = code", "left")
                .project(f"{group_reg}, code_kid as value, cnt"))
    elif idx==13:
        db_vars = (db_vars
                .join(dim_grading_clin, "value = code", "left")
                .project(f"{group_reg}, case when value is null then null else concat(value, ' - ', name) end as value, cnt"))
    # elif idx==9:
    #     db_vars = (db_vars
    #             .join(dim_tnm_t, "value = code", "left")
    #             .project(f"{group_reg}, code_1 as value, cnt"))

    df= db_vars.to_df()
    if idx==4:
        df["value"] = df["value"].astype("Int64").astype(str)

    df = df.rename(columns={"value":agg_cols[idx][0]})
    if show:
        pls.plot_stacked_bars(
            df,
            swap=False,
            orientation="h",
            show_total=True,
            normalize=False,
            relative=True,
            height=700,
            show_pct_bar=True,
        )
    return df

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_1_'></a>[UICC (p)](#toc0_)
# - **Filter: `DJ` = 2020-2024, `DCO` = N, `ICD10` nur solide Tumoren** (_solide Tumoren_ schliesst folgende Diagnosen _aus_: C44, C70-C72, C76-C97, alle D)
# - nach den absoluten Werten ist auch die relative Verteilung gegeben unter Ausschluss der hohen Zahl an UICC missings
# - die Variable wird in den meisten kkr selbst gebildet. Für GTDS Länder ist dafür ein Standard definiert
#
# > [!NOTE]
# > 💡 **NI**: _"UICC-Stadium: In Tristan ist die Implementierung zur automatisierten Ermittlung des UICC-Stadiums ausstehend. Bis zur Umsetzung der Implementierung wird das KKN **keine gesonderte Berechnung** des UICC-Stadiums vornehmen, liefert aber die Werte, die gemeldet worden sind"_

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_SOLID,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_tu=show_vars(2, grouper_reg.KKR.value, show=False, filter=_filter)
# _=pls.plot_stacked_bars(_tu, swap=False, orientation='h', show_total=False, relative=False, height=700, dropna=False,)
_=pls.plot_stacked_bars(_tu, swap=False, orientation='h', show_total=True, relative=True, height=700, dropna=False, show_pct_bar=True,)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                        (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:      n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:         n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur solide Tumore]: n = 2_270_570  (56.5%) ░░░░░░░░░░░░░░████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     z_icd10_3d not in ('C44')
#     and left(z_icd10_3d,1) = 'C'
#     and right(z_icd10_3d, 2)::int8 <= 75
#
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_2_'></a>[Diagnosesicherung](#toc0_)
#
# > [!NOTE]
# > 💡 `NI`: _"Die Ausprägung **DCO als Diagnosesicherung** kommt im KKN-Datensatz nicht vor. Diese Information liegt bisher nur dem EKN vor und wird gegebenenfalls zur Anreicherung von Datenexporten fallspezifisch vom KKN beim EKN angefragt. Der Prozess zur automatisierten Übermittlung dieser Informationen vom EKN zum KKN ist in Planung"_
# >
# > ---
# > 💡 `ZfKD`: _die Kodes `6` und `7` werden von vielen KKR noch geliefert, sind allerdings in der aktuellen oBDS Referenz nicht mehr gültig_

# %%
_filters = [
    FILTERS_DY,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)
_ = show_vars(
    3,
    grouper_reg.KKR.value,
    show=True,
    filter=_filter,
    # filter="z_dy = 2024",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# ```
#
# </details>

# %% [markdown]
# ### <a id='toc1_7_3_'></a>[DCO](#toc0_)
#
# - Metrik: Anteil der als DCO markierten Fälle an Gesamt
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - aus einigen KKR sind DCO nicht, oder nur rudimentär markiert
# > - ein weiterer sichtbarer Effekt ist die Zunahme des DCO Anteils in den jüngeren DJ in einigen KKR

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_C44,
    ("left(z_icd10_3d,1) = 'C'","ICD10 nur C"),
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)


db_dco = con.sql(f"""--sql
    with t1 as (
        select  z_kkr_label,
                z_is_dco,
                (DCN = 'J') as is_dcn,
                z_dy::text as z_dy,
                z_icd10_3d,
        from    Tumor
        where {_filter}
    ),
    t2 as (
        select
                z_kkr_label,
                z_dy,
                count(*) as cnt,
                sum(z_is_dco) as sum_dco,
                sum(is_dcn) as sum_dcn,
                sum(z_is_dco) / cnt as pct_dco,
                sum(is_dcn) / cnt as pct_dcn,
        from    t1
        group by all
        union
        select
                'Total',
                z_dy,
                count(*) as cnt,
                sum(z_is_dco) as sum_dco,
                sum(is_dcn) as sum_dcn,
                sum(z_is_dco) / cnt as pct_dco,
                sum(is_dcn) / cnt as pct_dcn,
        from    t1
        group by all
        union
        select
                z_kkr_label,
                'Total',
                count(*) as cnt,
                sum(z_is_dco) as sum_dco,
                sum(is_dcn) as sum_dcn,
                sum(z_is_dco) / cnt as pct_dco,
                sum(is_dcn) / cnt as pct_dcn,
        from    t1
        group by all
        union
        select
                'Total',
                'Total',
                count(*) as cnt,
                sum(z_is_dco) as sum_dco,
                sum(is_dcn) as sum_dcn,
                sum(z_is_dco) / cnt as pct_dco,
                sum(is_dcn) / cnt as pct_dcn,
        from    t1
        group by all
    )
    select * from t2
    """)
# tbl.descr_db(db_dco, "dco data")

tbl.pivot_df(
    db_dco.project("z_kkr_label, z_dy, pct_dco").to_df(),
    precision=1,
    show_as_pct=True,
    pct_axis="",
    total_axis="",
    font_size_th=13,
    font_size_td=11,
    # swap=True,
    image_scale="800",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine C44,D04]: n = 3_158_460  (78.6%) ░░░░░░░███████████████████████
# └ [ICD10 nur C]:   n = 2_627_689  (65.4%) ░░░░░░░░░░░███████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_icd10_3d not in ('C44','D04')
# and left(z_icd10_3d,1) = 'C'
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_9e377 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_9e377 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_9e377_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.7%, transparent 71.7%);
#   font-family: Courier;
# }
# #T_9e377_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.2%, transparent 71.2%);
#   font-family: Courier;
# }
# #T_9e377_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.2%, transparent 81.2%);
#   font-family: Courier;
# }
# #T_9e377_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.7%, transparent 74.7%);
#   font-family: Courier;
# }
# #T_9e377_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.6%, transparent 75.6%);
#   font-family: Courier;
# }
# #T_9e377_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.9%, transparent 74.9%);
#   font-family: Courier;
# }
# #T_9e377_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.5%, transparent 20.5%);
#   font-family: Courier;
# }
# #T_9e377_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.2%, transparent 26.2%);
#   font-family: Courier;
# }
# #T_9e377_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 19.2%, transparent 19.2%);
#   font-family: Courier;
# }
# #T_9e377_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 24.7%, transparent 24.7%);
#   font-family: Courier;
# }
# #T_9e377_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.8%, transparent 69.8%);
#   font-family: Courier;
# }
# #T_9e377_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.4%, transparent 32.4%);
#   font-family: Courier;
# }
# #T_9e377_row2_col0, #T_9e377_row2_col1, #T_9e377_row2_col2, #T_9e377_row2_col3, #T_9e377_row2_col4, #T_9e377_row2_col5, #T_9e377_row12_col0, #T_9e377_row12_col4, #T_9e377_row13_col0, #T_9e377_row13_col3, #T_9e377_row13_col4, #T_9e377_row15_col0, #T_9e377_row15_col2, #T_9e377_row15_col3, #T_9e377_row15_col4 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_9e377_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.4%, transparent 58.4%);
#   font-family: Courier;
# }
# #T_9e377_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 51.5%, transparent 51.5%);
#   font-family: Courier;
# }
# #T_9e377_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.8%, transparent 52.8%);
#   font-family: Courier;
# }
# #T_9e377_row3_col3, #T_9e377_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.1%, transparent 47.1%);
#   font-family: Courier;
# }
# #T_9e377_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.2%, transparent 61.2%);
#   font-family: Courier;
# }
# #T_9e377_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.2%, transparent 54.2%);
#   font-family: Courier;
# }
# #T_9e377_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.8%, transparent 80.8%);
#   font-family: Courier;
# }
# #T_9e377_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.8%, transparent 81.8%);
#   font-family: Courier;
# }
# #T_9e377_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 86.6%, transparent 86.6%);
#   font-family: Courier;
# }
# #T_9e377_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.6%, transparent 81.6%);
#   font-family: Courier;
# }
# #T_9e377_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.5%, transparent 1.5%);
#   font-family: Courier;
# }
# #T_9e377_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 67.6%, transparent 67.6%);
#   font-family: Courier;
# }
# #T_9e377_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 23.8%, transparent 23.8%);
#   font-family: Courier;
# }
# #T_9e377_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.8%, transparent 21.8%);
#   font-family: Courier;
# }
# #T_9e377_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 19.0%, transparent 19.0%);
#   font-family: Courier;
# }
# #T_9e377_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 16.8%, transparent 16.8%);
#   font-family: Courier;
# }
# #T_9e377_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.2%, transparent 10.2%);
#   font-family: Courier;
# }
# #T_9e377_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 18.8%, transparent 18.8%);
#   font-family: Courier;
# }
# #T_9e377_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_9e377_row6_col1, #T_9e377_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.1%, transparent 1.1%);
#   font-family: Courier;
# }
# #T_9e377_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_9e377_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.6%, transparent 2.6%);
#   font-family: Courier;
# }
# #T_9e377_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.7%, transparent 1.7%);
#   font-family: Courier;
# }
# #T_9e377_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.7%, transparent 21.7%);
#   font-family: Courier;
# }
# #T_9e377_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.0%, transparent 20.0%);
#   font-family: Courier;
# }
# #T_9e377_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.9%, transparent 17.9%);
#   font-family: Courier;
# }
# #T_9e377_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 18.3%, transparent 18.3%);
#   font-family: Courier;
# }
# #T_9e377_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.4%, transparent 50.4%);
#   font-family: Courier;
# }
# #T_9e377_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.6%, transparent 25.6%);
#   font-family: Courier;
# }
# #T_9e377_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.7%, transparent 50.7%);
#   font-family: Courier;
# }
# #T_9e377_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.8%, transparent 57.8%);
#   font-family: Courier;
# }
# #T_9e377_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.1%, transparent 82.1%);
#   font-family: Courier;
# }
# #T_9e377_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.2%, transparent 75.2%);
#   font-family: Courier;
# }
# #T_9e377_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.5%, transparent 69.5%);
#   font-family: Courier;
# }
# #T_9e377_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 67.4%, transparent 67.4%);
#   font-family: Courier;
# }
# #T_9e377_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 62.9%, transparent 62.9%);
#   font-family: Courier;
# }
# #T_9e377_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.9%, transparent 58.9%);
#   font-family: Courier;
# }
# #T_9e377_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.8%, transparent 64.8%);
#   font-family: Courier;
# }
# #T_9e377_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.6%, transparent 80.6%);
#   font-family: Courier;
# }
# #T_9e377_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.2%, transparent 72.2%);
#   font-family: Courier;
# }
# #T_9e377_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 67.9%, transparent 67.9%);
#   font-family: Courier;
# }
# #T_9e377_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 49.0%, transparent 49.0%);
#   font-family: Courier;
# }
# #T_9e377_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.5%, transparent 50.5%);
#   font-family: Courier;
# }
# #T_9e377_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.6%, transparent 64.6%);
#   f

# %% [markdown]
# ### <a id='toc1_7_4_'></a>[DCN](#toc0_)
#
# - Metrik: Anteil der als DCN markierten Fälle an Gesamt
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - aus einigen KKR sind DCN nicht, oder nur rudimentär markiert

# %%
# _tu=show_vars(14, grouper_reg.KKR.value, show=True, filter=_filter)

_filters = [
    FILTERS_DY,
    FILTERS_NO_C44,
    ("left(z_icd10_3d,1) = 'C'","ICD10 nur C"),
]

_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    # first_n_filter_apply_to_rows=0,
)

tbl.pivot_df(
    db_dco.project("z_kkr_label, z_dy, pct_dcn").to_df(),
    precision=1,
    show_as_pct=True,
    pct_axis="",
    total_axis="",
    font_size_th=13,
    font_size_td=11,
    # swap=True,
    image_scale="800",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine C44,D04]: n = 3_158_460  (78.6%) ░░░░░░░███████████████████████
# └ [ICD10 nur C]:   n = 2_627_689  (65.4%) ░░░░░░░░░░░███████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_icd10_3d not in ('C44','D04')
# and left(z_icd10_3d,1) = 'C'
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_1e46f th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_1e46f td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_1e46f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.6%, transparent 54.6%);
#   font-family: Courier;
# }
# #T_1e46f_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.7%, transparent 54.7%);
#   font-family: Courier;
# }
# #T_1e46f_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.7%, transparent 63.7%);
#   font-family: Courier;
# }
# #T_1e46f_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.0%, transparent 58.0%);
#   font-family: Courier;
# }
# #T_1e46f_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.5%, transparent 57.5%);
#   font-family: Courier;
# }
# #T_1e46f_row1_col0, #T_1e46f_row1_col1, #T_1e46f_row1_col2, #T_1e46f_row1_col3, #T_1e46f_row1_col4, #T_1e46f_row2_col0, #T_1e46f_row2_col1, #T_1e46f_row2_col2, #T_1e46f_row2_col3, #T_1e46f_row2_col4, #T_1e46f_row12_col4, #T_1e46f_row13_col0, #T_1e46f_row13_col1, #T_1e46f_row15_col0, #T_1e46f_row15_col1 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_1e46f_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.8%, transparent 66.8%);
#   font-family: Courier;
# }
# #T_1e46f_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.1%, transparent 66.1%);
#   font-family: Courier;
# }
# #T_1e46f_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.8%, transparent 63.8%);
#   font-family: Courier;
# }
# #T_1e46f_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.3%, transparent 58.3%);
#   font-family: Courier;
# }
# #T_1e46f_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.0%, transparent 66.0%);
#   font-family: Courier;
# }
# #T_1e46f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 88.5%, transparent 88.5%);
#   font-family: Courier;
# }
# #T_1e46f_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.0%, transparent 74.0%);
#   font-family: Courier;
# }
# #T_1e46f_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 86.4%, transparent 86.4%);
#   font-family: Courier;
# }
# #T_1e46f_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 94.4%, transparent 94.4%);
#   font-family: Courier;
# }
# #T_1e46f_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.0%, transparent 17.0%);
#   font-family: Courier;
# }
# #T_1e46f_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.7%, transparent 74.7%);
#   font-family: Courier;
# }
# #T_1e46f_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.6%, transparent 63.6%);
#   font-family: Courier;
# }
# #T_1e46f_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.9%, transparent 61.9%);
#   font-family: Courier;
# }
# #T_1e46f_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.4%, transparent 55.4%);
#   font-family: Courier;
# }
# #T_1e46f_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 42.1%, transparent 42.1%);
#   font-family: Courier;
# }
# #T_1e46f_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.9%, transparent 9.9%);
#   font-family: Courier;
# }
# #T_1e46f_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.4%, transparent 12.4%);
#   font-family: Courier;
# }
# #T_1e46f_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.9%, transparent 7.9%);
#   font-family: Courier;
# }
# #T_1e46f_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.3%, transparent 3.3%);
#   font-family: Courier;
# }
# #T_1e46f_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.2%, transparent 2.2%);
#   font-family: Courier;
# }
# #T_1e46f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 30.5%, transparent 30.5%);
#   font-family: Courier;
# }
# #T_1e46f_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.8%, transparent 29.8%);
#   font-family: Courier;
# }
# #T_1e46f_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.8%, transparent 26.8%);
#   font-family: Courier;
# }
# #T_1e46f_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 24.3%, transparent 24.3%);
#   font-family: Courier;
# }
# #T_1e46f_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 41.5%, transparent 41.5%);
#   font-family: Courier;
# }
# #T_1e46f_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 42.2%, transparent 42.2%);
#   font-family: Courier;
# }
# #T_1e46f_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.0%, transparent 47.0%);
#   font-family: Courier;
# }
# #T_1e46f_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.9%, transparent 63.9%);
#   font-family: Courier;
# }
# #T_1e46f_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.6%, transparent 58.6%);
#   font-family: Courier;
# }
# #T_1e46f_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.6%, transparent 53.6%);
#   font-family: Courier;
# }
# #T_1e46f_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 62.1%, transparent 62.1%);
#   font-family: Courier;
# }
# #T_1e46f_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.2%, transparent 61.2%);
#   font-family: Courier;
# }
# #T_1e46f_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.3%, transparent 61.3%);
#   font-family: Courier;
# }
# #T_1e46f_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.2%, transparent 64.2%);
#   font-family: Courier;
# }
# #T_1e46f_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.0%, transparent 63.0%);
#   font-family: Courier;
# }
# #T_1e46f_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 40.6%, transparent 40.6%);
#   font-family: Courier;
# }
# #T_1e46f_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.9%, transparent 44.9%);
#   font-family: Courier;
# }
# #T_1e46f_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.8%, transparent 60.8%);
#   font-family: Courier;
# }
# #T_1e46f_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.1%, transparent 63.1%);
#   font-family: Courier;
# }
# #T_1e46f_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_1e46f_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.5%, transparent 32.5%);
#   font-family: Courier;
# }
# #T_1e46f_row11_col1, #T_1e46f_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.1%, transparent 44.1%);
#   font-family: Courier;
# }
# #T_1e46f_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.2%, transparent 59.2%);
#   font-family: Courier;
# }
# #T_1e46f_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 97.9%, transparent 97.9%);
#   font-family: Courier;
# }
# #T_1e46f_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.4%, transparent 3.4%);
#   font-family: Courier;
# }
# #T_1e46f_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.8%, transparent 5.8%);
#   font-family: Courier;
# }
# #T_1e46f_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.3%, transparent 5.3%);
#   font-family: Courier;
# }
# #T_1e46f_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_1e46f_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_1e46f_row13_col3, #T_1e46f_row13_col4, #T_1e46f_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_1e46f_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.1%

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_5_'></a>[Geschlecht](#toc0_)
# - Grundgesamtheit: Menge aller **Patienten**
#
# > [!NOTE]
# > 💡 `ZfKD`: _Angaben zu Geschlecht ungleich `M` oder `W` sind sehr selten, diese Fälle werden nicht gesondert verarbeitet_

# %%
_filters = [
    FILTERS_DY,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_tu=show_vars(0, grouper_reg.KKR.value, show=True, filter=_filter)
_other = _tu[~_tu["Geschlecht"].isin(["M", "W"])].groupby("Geschlecht")["cnt"].sum().to_dict()
print(f"Anzahl Ausprägungen <> M oder W im Gesamtdatensatz: {_other}")

# 3_412_547
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_420_720                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_412_547  (99.8%) ░█████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# ```
#
# </details>
# Anzahl Ausprägungen <> M oder W im Gesamtdatensatz: {'D': 43, 'U': 246, 'X': 31}

# %% [markdown]
# ### <a id='toc1_7_6_'></a>[Grading](#toc0_)

# %% [markdown]
# #### <a id='toc1_7_6_1_'></a>[Verteilung](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_GRAD,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)
_ = show_vars(
    13,
    grouper_reg.KKR.value,
    show=True,
    filter=_filter,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                                  (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:                   n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur gradingrelevante Tumore]: n = 1_265_707  (31.5%) ░░░░░░░░░░░░░░░░░░░░░█████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 33
#             or right(z_icd10_3d, 2)::int8 between 50 and 57
#             or right(z_icd10_3d, 2)::int8 between 63 and 68
#             or right(z_icd10_3d, 2)::int8 = 60
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8576
#     )
# ```
#
# </details>

# %% [markdown]
# #### <a id='toc1_7_6_2_'></a>[Anteile Unbekannt](#toc0_)
# - Metrik: Anteil Codes (`U`,`T`)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_GRAD,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_df=con.sql(query=f"""--sql
    with t1 as (
        select
            z_dy::text as z_dy,
            z_kkr_label,
            Grading,
            case
                when ifnull(Grading,'U') in ('T','U') then '1_unknown'
                else '2_notnull'
            end as categ_grad,
        from Tumor
        where {_filter}
    ),
    t2 as (
        select
            z_dy,
            z_kkr_label,
            count(*) as cnt,
            count(*) filter (where left(categ_grad, 1) = '1') as cnt_null,
            cnt_null / cnt as pct_null,
        from t1
        group by all

        union
        select
            'Total' as z_dy,
            z_kkr_label,
            count(*) as cnt,
            count(*) filter (where left(categ_grad, 1) = '1') as cnt_null,
            cnt_null / cnt as pct_null,
        from t1
        group by all
        union
        select
            z_dy,
            'Total' as z_kkr_label,
            count(*) as cnt,
            count(*) filter (where left(categ_grad, 1) = '1') as cnt_null,
            cnt_null / cnt as pct_null,
        from t1
        group by all
        
        union
        select
            'Total' as z_dy,
            'Total' as z_kkr_label,
            count(*) as cnt,
            count(*) filter (where left(categ_grad, 1) = '1') as cnt_null,
            cnt_null / cnt as pct_null,
        from t1
        group by all

    )
    select * from t2
    """).to_df()
# display(_df)

tbl.pivot_df(
    _df[["z_dy", "z_kkr_label", "pct_null"]],
    precision=2,
    show_as_pct=True,
    pct_axis="",
    total_axis="",
    font_size_th=12,
    font_size_td=11,
    swap=True,
    image_scale="80%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                                  (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:                   n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur gradingrelevante Tumore]: n = 1_265_707  (31.5%) ░░░░░░░░░░░░░░░░░░░░░█████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 33
#             or right(z_icd10_3d, 2)::int8 between 50 and 57
#             or right(z_icd10_3d, 2)::int8 between 63 and 68
#             or right(z_icd10_3d, 2)::int8 = 60
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8576
#     )
# ```
#
# </details>
# <!-- SCALE-80% -->
# <style type="text/css">
# #T_d9496 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_d9496 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_d9496_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.5%, transparent 47.5%);
#   font-family: Courier;
# }
# #T_d9496_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.4%, transparent 54.4%);
#   font-family: Courier;
# }
# #T_d9496_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.4%, transparent 56.4%);
#   font-family: Courier;
# }
# #T_d9496_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.5%, transparent 69.5%);
#   font-family: Courier;
# }
# #T_d9496_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.7%, transparent 69.7%);
#   font-family: Courier;
# }
# #T_d9496_row0_col5, #T_d9496_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.3%, transparent 59.3%);
#   font-family: Courier;
# }
# #T_d9496_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_d9496_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 95.7%, transparent 95.7%);
#   font-family: Courier;
# }
# #T_d9496_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 92.4%, transparent 92.4%);
#   font-family: Courier;
# }
# #T_d9496_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 87.2%, transparent 87.2%);
#   font-family: Courier;
# }
# #T_d9496_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 89.9%, transparent 89.9%);
#   font-family: Courier;
# }
# #T_d9496_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 93.1%, transparent 93.1%);
#   font-family: Courier;
# }
# #T_d9496_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 43.1%, transparent 43.1%);
#   font-family: Courier;
# }
# #T_d9496_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.3%, transparent 48.3%);
#   font-family: Courier;
# }
# #T_d9496_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 46.1%, transparent 46.1%);
#   font-family: Courier;
# }
# #T_d9496_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.4%, transparent 45.4%);
#   font-family: Courier;
# }
# #T_d9496_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 40.0%, transparent 40.0%);
#   font-family: Courier;
# }
# #T_d9496_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.7%, transparent 44.7%);
#   font-family: Courier;
# }
# #T_d9496_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.1%, transparent 47.1%);
#   font-family: Courier;
# }
# #T_d9496_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.4%, transparent 52.4%);
#   font-family: Courier;
# }
# #T_d9496_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 46.6%, transparent 46.6%);
#   font-family: Courier;
# }
# #T_d9496_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.1%, transparent 50.1%);
#   font-family: Courier;
# }
# #T_d9496_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.9%, transparent 53.9%);
#   font-family: Courier;
# }
# #T_d9496_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.0%, transparent 50.0%);
#   font-family: Courier;
# }
# #T_d9496_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.2%, transparent 57.2%);
#   font-family: Courier;
# }
# #T_d9496_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 51.9%, transparent 51.9%);
#   font-family: Courier;
# }
# #T_d9496_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.5%, transparent 52.5%);
#   font-family: Courier;
# }
# #T_d9496_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.2%, transparent 58.2%);
#   font-family: Courier;
# }
# #T_d9496_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 49.1%, transparent 49.1%);
#   font-family: Courier;
# }
# #T_d9496_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.8%, transparent 53.8%);
#   font-family: Courier;
# }
# #T_d9496_row5_col0, #T_d9496_row8_col1, #T_d9496_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.0%, transparent 58.0%);
#   font-family: Courier;
# }
# #T_d9496_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.1%, transparent 57.1%);
#   font-family: Courier;
# }
# #T_d9496_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.6%, transparent 60.6%);
#   font-family: Courier;
# }
# #T_d9496_row5_col3, #T_d9496_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.8%, transparent 61.8%);
#   font-family: Courier;
# }
# #T_d9496_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.7%, transparent 68.7%);
#   font-family: Courier;
# }
# #T_d9496_row5_col5, #T_d9496_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.9%, transparent 60.9%);
#   font-family: Courier;
# }
# #T_d9496_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.3%, transparent 60.3%);
#   font-family: Courier;
# }
# #T_d9496_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.7%, transparent 60.7%);
#   font-family: Courier;
# }
# #T_d9496_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 62.9%, transparent 62.9%);
#   font-family: Courier;
# }
# #T_d9496_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 75.4%, transparent 75.4%);
#   font-family: Courier;
# }
# #T_d9496_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.4%, transparent 78.4%);
#   font-family: Courier;
# }
# #T_d9496_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 67.3%, transparent 67.3%);
#   font-family: Courier;
# }
# #T_d9496_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.3%, transparent 52.3%);
#   font-family: Courier;
# }
# #T_d9496_row7_col1, #T_d9496_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.3%, transparent 54.3%);
#   font-family: Courier;
# }
# #T_d9496_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.3%, transparent 55.3%);
#   font-family: Courier;
# }
# #T_d9496_row7_col3, #T_d9496_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.8%, transparent 64.8%);
#   font-family: Courier;
# }
# #T_d9496_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 73.4%, transparent 73.4%);
#   font-family: Courier;
# }
# #T_d9496_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.9%, transparent 59.9%);
#   font-family: Courier;
# }
# #T_d9496_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.7%, transparent 59.7%);
#   font-family: Courier;
# }
# #T_d9496_row8_col2, #T_d9496_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.3%, transparent 56.3%);
#   font-family: Courier;
# }
# #T_d9496_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.6%, transparent 50.6%);
#   font-family: Courier;
# }
# #T_d9496_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.4%, transparent 53.4%);
#   font-family: Courier;
# }
# #T_d9496_row8_col5, #T_d9496_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.6%, transparent 55.6%);
#   font-family: Courier;
# }
# #T_d9496_row9_col0, #T_d9496_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.8%, transparent 69.8%);
#   font-family: Courier;
# }
# #T_d9496_row9_col1, #T_d9496_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.5%, transparent 64.5%);
#   font-family: Courier;
# }
# #T_d9496_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.2%, transparent 60.2%);
#   font-family: Courier;
# }
# #T_d9496_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.4%, transparent 58.4%);
#   font-family: Courier

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_7_'></a>[Diagnosejahr mit Altdaten](#toc0_)
# - Filter: Top 5 Diagnosejahre
# - Legende ist **absteigend sortiert nach Fallzahl im DJ**, Restkategorie `<other>` ist aufgeführt

# %%
_tu = show_vars(4, grouper_reg.KKR.value, show=False)
# print(
#     f"Anzahl {str(DY_MAX+1)} Fälle: {_tu[_tu['z_dy'] == str(DY_MAX+1)].set_index('kkr')['cnt'].to_dict()}"
# )
_ = pls.plot_stacked_bars(
    _tu,
    swap=False,
    orientation="h",
    show_total=True,
    normalize=False,
    relative=True,
    height=700,
    top_n_color=5,
    sort_values_color=True,
    show_other=True,
)

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_8_'></a>[Diagnosejahr ohne Altdaten](#toc0_)

# %%
_filters = [
    FILTERS_DY,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)
_tu = show_vars(4, grouper_reg.KKR.value, show=True, filter=_filter)

# _ = pls.plot_stacked_bars(
#     _tu,
#     swap=False,
#     orientation="h",
#     show_total=True,
#     normalize=False,
#     relative=True,
#     height=700,
#     top_n_color=5,
#     sort_values_color=True,
#     show_other=True,
# )
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_9_'></a>[Inzidenzort vs Lieferregister](#toc0_)
# - **Filter: keiner**
# - vertikal: `Inzidenzort` (Zeile `00` bündelt alle Fälle mit ungültiger Ortsangabe). horizontal: `Lieferregister`
# - Beispiel: `03-NI` liefert zu 100% Fälle aus dem Inzidenzort `03`, `13-MV` liefert 159 Fälle aus `03`
#
# > [!NOTE]
# > 💡 `ZfKD`: _Angestrebt ist eine "Diagonale", möglichst nur noch Fallübermittlungen aus dem eigenen Einzugsgebiet, was inzwischen schon besser erreicht ist. ~ 99% der Fälle stammen aus dem liefernden Register_

# %%
_tu = show_vars(5, grouper_reg.KKR.value, show=False).rename(columns={"Inzidenzort_BL":"ort"}).fillna(0)
_tu.loc[_tu["ort"]=="","ort"]="00"
_tu.loc[(_tu['ort'].astype(int) < 1) | (_tu['ort'].astype(int) > 16), "ort"]="00"
tbl.show_num_df(
    _tu.pivot_table(index="ort", columns="kkr", values="cnt", fill_value=0, dropna=False),
    data_bar_axis="xy",
    total_axis="xy",
    total_exclude=True,
    pct_axis="x",
    font_size_th=8,
    font_size_td=6,
)
# Out:
# <style type="text/css">
# #T_40b6e th {
#   text-align: right;
#   font-size: 8pt;
# }
# #T_40b6e td {
#   text-align: right;
#   font-size: 6pt;
# }
# #T_40b6e_row0_col0, #T_40b6e_row0_col1, #T_40b6e_row0_col2, #T_40b6e_row0_col3, #T_40b6e_row0_col4, #T_40b6e_row0_col5, #T_40b6e_row0_col6, #T_40b6e_row0_col7, #T_40b6e_row0_col9, #T_40b6e_row0_col11, #T_40b6e_row0_col13, #T_40b6e_row0_col14, #T_40b6e_row0_col15, #T_40b6e_row1_col1, #T_40b6e_row1_col2, #T_40b6e_row1_col3, #T_40b6e_row1_col4, #T_40b6e_row1_col5, #T_40b6e_row1_col6, #T_40b6e_row1_col7, #T_40b6e_row1_col8, #T_40b6e_row1_col9, #T_40b6e_row1_col10, #T_40b6e_row1_col14, #T_40b6e_row1_col15, #T_40b6e_row2_col0, #T_40b6e_row2_col2, #T_40b6e_row2_col3, #T_40b6e_row2_col4, #T_40b6e_row2_col5, #T_40b6e_row2_col6, #T_40b6e_row2_col7, #T_40b6e_row2_col8, #T_40b6e_row2_col9, #T_40b6e_row2_col10, #T_40b6e_row2_col11, #T_40b6e_row2_col14, #T_40b6e_row2_col15, #T_40b6e_row3_col0, #T_40b6e_row3_col1, #T_40b6e_row3_col3, #T_40b6e_row3_col4, #T_40b6e_row3_col5, #T_40b6e_row3_col6, #T_40b6e_row3_col7, #T_40b6e_row3_col8, #T_40b6e_row3_col9, #T_40b6e_row3_col11, #T_40b6e_row3_col14, #T_40b6e_row3_col15, #T_40b6e_row4_col0, #T_40b6e_row4_col1, #T_40b6e_row4_col2, #T_40b6e_row4_col4, #T_40b6e_row4_col5, #T_40b6e_row4_col6, #T_40b6e_row4_col7, #T_40b6e_row4_col8, #T_40b6e_row4_col9, #T_40b6e_row4_col10, #T_40b6e_row4_col11, #T_40b6e_row4_col12, #T_40b6e_row4_col13, #T_40b6e_row4_col14, #T_40b6e_row4_col15, #T_40b6e_row5_col0, #T_40b6e_row5_col1, #T_40b6e_row5_col2, #T_40b6e_row5_col3, #T_40b6e_row5_col5, #T_40b6e_row5_col6, #T_40b6e_row5_col7, #T_40b6e_row5_col9, #T_40b6e_row5_col10, #T_40b6e_row5_col11, #T_40b6e_row5_col12, #T_40b6e_row5_col15, #T_40b6e_row6_col0, #T_40b6e_row6_col1, #T_40b6e_row6_col2, #T_40b6e_row6_col3, #T_40b6e_row6_col4, #T_40b6e_row6_col6, #T_40b6e_row6_col7, #T_40b6e_row6_col9, #T_40b6e_row6_col11, #T_40b6e_row6_col12, #T_40b6e_row6_col15, #T_40b6e_row7_col0, #T_40b6e_row7_col1, #T_40b6e_row7_col2, #T_40b6e_row7_col3, #T_40b6e_row7_col4, #T_40b6e_row7_col5, #T_40b6e_row7_col7, #T_40b6e_row7_col9, #T_40b6e_row7_col10, #T_40b6e_row7_col11, #T_40b6e_row7_col12, #T_40b6e_row7_col14, #T_40b6e_row7_col15, #T_40b6e_row8_col0, #T_40b6e_row8_col1, #T_40b6e_row8_col2, #T_40b6e_row8_col3, #T_40b6e_row8_col4, #T_40b6e_row8_col5, #T_40b6e_row8_col6, #T_40b6e_row8_col9, #T_40b6e_row8_col10, #T_40b6e_row8_col11, #T_40b6e_row8_col14, #T_40b6e_row8_col15, #T_40b6e_row9_col0, #T_40b6e_row9_col1, #T_40b6e_row9_col2, #T_40b6e_row9_col3, #T_40b6e_row9_col4, #T_40b6e_row9_col5, #T_40b6e_row9_col6, #T_40b6e_row9_col7, #T_40b6e_row9_col9, #T_40b6e_row9_col14, #T_40b6e_row10_col0, #T_40b6e_row10_col1, #T_40b6e_row10_col2, #T_40b6e_row10_col3, #T_40b6e_row10_col4, #T_40b6e_row10_col5, #T_40b6e_row10_col6, #T_40b6e_row10_col7, #T_40b6e_row10_col8, #T_40b6e_row10_col10, #T_40b6e_row10_col11, #T_40b6e_row10_col14, #T_40b6e_row10_col15, #T_40b6e_row11_col0, #T_40b6e_row11_col1, #T_40b6e_row11_col2, #T_40b6e_row11_col3, #T_40b6e_row11_col4, #T_40b6e_row11_col5, #T_40b6e_row11_col6, #T_40b6e_row11_col7, #T_40b6e_row11_col9, #T_40b6e_row11_col14, #T_40b6e_row11_col15, #T_40b6e_row12_col0, #T_40b6e_row12_col1, #T_40b6e_row12_col2, #T_40b6e_row12_col3, #T_40b6e_row12_col4, #T_40b6e_row12_col5, #T_40b6e_row12_col6, #T_40b6e_row12_col7, #T_40b6e_row12_col8, #T_40b6e_row12_col9, #T_40b6e_row12_col14, #T_40b6e_row13_col0, #T_40b6e_row13_col1, #T_40b6e_row13_col2, #T_40b6e_row13_col3, #T_40b6e_row13_col4, #T_40b6e_row13_col5, #T_40b6e_row13_col6, #T_40b6e_row13_col7, #T_40b6e_row13_col8, #T_40b6e_row13_col9, #T_40b6e_row13_col10, #T_40b6e_row13_col14, #T_40b6e_row13_col15, #T_40b6e_row14_col0, #T_40b6e_row14_col1, #T_40b6e_row14_col2, #T_40b6e_row14_col3, #T_40b6e_row14_col4, #T_40b6e_row14_col5, #T_40b6e_row14_col6, #T_40b6e_row14_col7, #T_40b6e_row14_col9, #T_40b6e_row14_col10, #T_40b6e_row14_col14, #T_40b6e_row14_col15, #T_40b6e_row15_col0, #T_40b6e_row15_col1, #T_40b6e_row15_col2, #T_40b6e_row15_col3, #T_40b6e_row15_col4, #T_40b6e_row15_col5, #T_40b6e_row15_col6, #T_40b6e_row15_col7, #T_40b6e_row15_col8, #T_40b6e_row15_col9, #T_40b6e_row15_col10 ...
#   width: 10em;
#   font-family: Courier;
# }
# #T_40b6e_row0_col8, #T_40b6e_row0_col10, #T_40b6e_row0_col12, #T_40b6e_row1_col11, #T_40b6e_row1_col12, #T_40b6e_row1_col13, #T_40b6e_row2_col12, #T_40b6e_row2_col13, #T_40b6e_row3_col10, #T_40b6e_row3_col12, #T_40b6e_row3_col13, #T_40b6e_row5_col8, #T_40b6e_row5_col13, #T_40b6e_row5_col14, #T_40b6e_row6_col8, #T_40b6e_row6_col10, #T_40b6e_row6_col13, #T_40b6e_row6_col14, #T_40b6e_row7_col8, #T_40b6e_row7_col13, #T_40b6e_row8_col8, #T_40b6e_row8_col12, #T_40b6e_row8_col13, #T_40b6e_row9_col10, #T_40b6e_row9_col11, #T_40b6e_row9_col12, #T_40b6e_row9_col13, #T_40b6e_row9_col15, #T_40b6e_row10_col12, #T_40b6e_row10_col13, #T_40b6e_row11_col8, #T_40b6e_row11_col11, #T_40b6e_row11_col12, #T_40b6e_row11_col13, #T_40b6e_row12_col10, #T_40b6e_row12_col12, #T_40b6e_row12_col13, #T_40b6e_row12_col15, #T_40b6e_row13_col11, #T_40b6e_row13_col13, #T_40b6e_row14_col8, #T_40b6e_row14_col11, #T_40b6e_row14_col12, #T_40b6e_row15_col11, #T_40b6e_row15_col12, #T_40b6e_row15_col13, #T_40b6e_row16_col8, #T_40b6e_row16_col10, #T_40b6e_row16_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_40b6e_row0_col16, #T_40b6e_row1_col16, #T_40b6e_row2_col16, #T_40b6e_row3_col16, #T_40b6e_row4_col16, #T_40b6e_row5_col16, #T_40b6e_row6_col16, #T_40b6e_row7_col16, #T_40b6e_row8_col16, #T_40b6e_row9_col16, #T_40b6e_row10_col16, #T_40b6e_row11_col16, #T_40b6e_row12_col16, #T_40b6e_row13_col16, #T_40b6e_row14_col16, #T_40b6e_row15_col16, #T_40b6e_row16_col16, #T_40b6e_row17_col0, #T_40b6e_row17_col1, #T_40b6e_row17_col2, #T_40b6e_row17_col3, #T_40b6e_row17_col4, #T_40b6e_row17_col5, #T_40b6e_row17_col6, #T_40b6e_row17_col7, #T_40b6e_row17_col8, #T_40b6e_row17_col9, #T_40b6e_row17_col10, #T_40b6e_row17_col11, #T_40b6e_row17_col12, #T_40b6e_row17_col13, #T_40b6e_row17_col14, #T_40b6e_row17_col15, #T_40b6e_row17_col16 {
#   font-family: Courier;
# }
# #T_40b6e_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 19.1%, transparent 19.1%);
#   font-family: Courier;
# }
# #T_40b6e_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.8%, transparent 6.8%);
#   font-family: Courier;
# }
# #T_40b6e_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.3%, transparent 27.3%);
#   font-family: Courier;
# }
# #T_40b6e_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.0%, transparent 3.0%);
#   font-family: Courier;
# }
# #T_40b6e_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_40b6e_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.4%, transparent 20.4%);
#   font-family: Courier;
# }
# #T_40b6e_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.9%, transparent 15.9%);
#   font-family: Courier;
# }
# #T_40b6e_row8_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.0%, transparent 45.0%);
#   font-family: Courier;
# }
# #T_40b6e_row9_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.2%, transparent 56.2%);
#   font-family: Courier;
# }
# #T_40b6e_row10_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.2%, transparent 6.2%);
#   font-family: Courier;
# }
# #T_40b6e_row11_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.4%, transparent 14.4%);
#   font-family: Courier;
# }
# #T_40b6e_row12_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.9%, transparent 12.9%);
#   font-family: Courier;
# }
# #T_40b6e_row13_col12 {
#   wi

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_10_'></a>[ICD10 Gruppen](#toc0_)
# - **Filter: `DJ` =  2020 - 2024**
# - die verwendete ICD10 Skala entspricht der Darstellung aus *"Krebs in Deutschland"*
#
# > [!NOTE]
# > 💡 `NI`: _"Für nicht-melanozytäre Hautkrebsarten bestimmter Histologien sowie fortgeschrittene Plattenepithelkarzinome gilt ab dem 20. September 2023 eine geänderte Meldepflicht. Erst seit diesem Zeitpunkt sind die prognostisch ungünstigen Hauttumore **(C44)** an das KKN zu melden und kommen daher im gelieferten Datensatz bisher nicht vor. In den nächsten Lieferungen werden diese Daten enthalten sein"_

# %%
_filters = [
    FILTERS_DY,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)
_=show_vars(6, grouper_reg.KKR.value, show=True, filter=_filter)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# ```
#
# </details>

# %% [markdown]
# ### <a id='toc1_7_11_'></a>[Altersgruppen Kinder und Heranwachsende](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - Fälle von unter 18-jährigen Personen sind nicht flächendeckend vorhanden

# %%
_filters = [
    FILTERS_DY,
    # FILTERS_NO_DCO,
    # FILTERS_NO_C44,
    ("z_age <= 20", "ALter <= 20"),
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        z_kkr_label,
        --lpad(z_age::int::text,2,'0') as z_age,
        case 
            when z_age::int between 0 and 4 then '00-04'
            when z_age::int between 5 and 9 then '05-09'
            when z_age::int between 10 and 14 then '10-14'
            when z_age::int between 15 and 17 then '15-17'
            when z_age::int between 18 and 20 then '18-20'
        else 'U' end as categ_age
    from Tumor
    where {_filter}
""")

pls.plot_stacked_bars(
    _db.to_df().iloc[:, :2],
    swap=False,
    orientation="h",
    show_total=True,
    # normalize=False,
    relative=True,
    height=700,
)
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_420_720                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_412_547  (99.8%) ░█████████████████████████████
# └ [ALter <= 20]:     n = 10_532   (0.3%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_age <= 20
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_12_'></a>[Verstorben](#toc0_)
#
# - gezählt sind **Personen**
# - Metrik: Anteil Verstorbener an Gesamtzahl Patienten pro erstes DJ der Person

# %%
# _filters = [
#     FILTERS_DY,
#     FILTERS_NO_DCO,
#     FILTERS_NO_C44,

# ]
# _filter = hlp.get_duckdb_filter_n(
#     con=con,
#     query="from Tumor",
#     filters=_filters,
#     distinct_metric="z_pat_id",
#     first_n_filter_apply_to_rows=0,
# )
# _ = show_vars(
#     1,
#     grouper_reg.KKR.value,
#     show=True,
#     #filter=f"z_dy > 2019 and z_dy <= {DY_MAX} and z_icd10_3d != 'C44' and not z_is_dco",
#     filter=_filter,
# )

# %%
# con.table("Patient").columns

# %%
_filters = [
    FILTERS_DY,
    # ("year(Datum_Vitalstatus) between 2020 and 2024", "follow-up 2020-2024"),
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum join Patient pat on pat.oBDS_RKIPatientId = tum.z_pat_id",
    filters=_filters,
    distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

db_deceased= con.sql(f"""--sql
    with t1 as (
        select  z_kkr_label,
                (Verstorben = 'J') as is_deceased,
                min(z_dy)::text as z_dy_min,
                z_pat_id,
        from    Tumor tum
        join   Patient pat on pat.oBDS_RKIPatientId = tum.z_pat_id
        where {_filter}
        group by all
    ),
    t2 as (
        select
                z_kkr_label,
                z_dy_min,
                count(*) as cnt,
                sum(is_deceased) as cnt_deceased,
                sum(is_deceased) / cnt as pct_deceased,
        from    t1
        group by all
        union
        select
                'Total',
                z_dy_min,
                count(*) as cnt,
                sum(is_deceased) as cnt_deceased,
                sum(is_deceased) / cnt as pct_deceased,
        from    t1
        group by all
        union
        select
                z_kkr_label,
                'Total',
                count(*) as cnt,
                sum(is_deceased) as cnt_deceased,
                sum(is_deceased) / cnt as pct_deceased,
        from    t1
        group by all
        union
        select
                'Total',
                'Total',
                count(*) as cnt,
                sum(is_deceased) as cnt_deceased,
                sum(is_deceased) / cnt as pct_deceased,
        from    t1
        group by all
    )
    select * from t2
    """)

# tbl.descr_db(db_deceased, "deceased data")

tbl.pivot_df(
    db_deceased.project("z_kkr_label, z_dy_min, pct_deceased").to_df(),
    precision=1,
    show_as_pct=True,
    pct_axis="",
    total_axis="",
    font_size_th=13,
    font_size_td=11,
    # swap=True,
    image_scale="800",
)
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_420_720                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_412_547  (99.8%) ░█████████████████████████████
# └ [keine DCO]:     n = 3_300_566  (96.5%) ░░████████████████████████████
# └ [keine C44,D04]: n = 2_823_609  (82.5%) ░░░░░░████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_0c583 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_0c583 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_0c583_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 88.9%, transparent 88.9%);
#   font-family: Courier;
# }
# #T_0c583_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.6%, transparent 80.6%);
#   font-family: Courier;
# }
# #T_0c583_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.5%, transparent 72.5%);
#   font-family: Courier;
# }
# #T_0c583_row0_col3, #T_0c583_row16_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.5%, transparent 63.5%);
#   font-family: Courier;
# }
# #T_0c583_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 49.1%, transparent 49.1%);
#   font-family: Courier;
# }
# #T_0c583_row0_col5, #T_0c583_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.4%, transparent 71.4%);
#   font-family: Courier;
# }
# #T_0c583_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.9%, transparent 81.9%);
#   font-family: Courier;
# }
# #T_0c583_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.7%, transparent 72.7%);
#   font-family: Courier;
# }
# #T_0c583_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.4%, transparent 63.4%);
#   font-family: Courier;
# }
# #T_0c583_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.1%, transparent 50.1%);
#   font-family: Courier;
# }
# #T_0c583_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.0%, transparent 28.0%);
#   font-family: Courier;
# }
# #T_0c583_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.8%, transparent 59.8%);
#   font-family: Courier;
# }
# #T_0c583_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 89.3%, transparent 89.3%);
#   font-family: Courier;
# }
# #T_0c583_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.3%, transparent 81.3%);
#   font-family: Courier;
# }
# #T_0c583_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 73.5%, transparent 73.5%);
#   font-family: Courier;
# }
# #T_0c583_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.0%, transparent 61.0%);
#   font-family: Courier;
# }
# #T_0c583_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.6%, transparent 44.6%);
#   font-family: Courier;
# }
# #T_0c583_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.3%, transparent 71.3%);
#   font-family: Courier;
# }
# #T_0c583_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.9%, transparent 99.9%);
#   font-family: Courier;
# }
# #T_0c583_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 87.2%, transparent 87.2%);
#   font-family: Courier;
# }
# #T_0c583_row3_col2, #T_0c583_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.1%, transparent 77.1%);
#   font-family: Courier;
# }
# #T_0c583_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.6%, transparent 66.6%);
#   font-family: Courier;
# }
# #T_0c583_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.9%, transparent 53.9%);
#   font-family: Courier;
# }
# #T_0c583_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.5%, transparent 77.5%);
#   font-family: Courier;
# }
# #T_0c583_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.8%, transparent 85.8%);
#   font-family: Courier;
# }
# #T_0c583_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.0%, transparent 78.0%);
#   font-family: Courier;
# }
# #T_0c583_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.8%, transparent 68.8%);
#   font-family: Courier;
# }
# #T_0c583_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.0%, transparent 56.0%);
#   font-family: Courier;
# }
# #T_0c583_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 35.4%, transparent 35.4%);
#   font-family: Courier;
# }
# #T_0c583_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.1%, transparent 65.1%);
#   font-family: Courier;
# }
# #T_0c583_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.2%, transparent 80.2%);
#   font-family: Courier;
# }
# #T_0c583_row5_col1, #T_0c583_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 70.5%, transparent 70.5%);
#   font-family: Courier;
# }
# #T_0c583_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 62.1%, transparent 62.1%);
#   font-family: Courier;
# }
# #T_0c583_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 49.6%, transparent 49.6%);
#   font-family: Courier;
# }
# #T_0c583_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 39.1%, transparent 39.1%);
#   font-family: Courier;
# }
# #T_0c583_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.6%, transparent 61.6%);
#   font-family: Courier;
# }
# #T_0c583_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.5%, transparent 80.5%);
#   font-family: Courier;
# }
# #T_0c583_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 62.8%, transparent 62.8%);
#   font-family: Courier;
# }
# #T_0c583_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 49.5%, transparent 49.5%);
#   font-family: Courier;
# }
# #T_0c583_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 33.8%, transparent 33.8%);
#   font-family: Courier;
# }
# #T_0c583_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.2%, transparent 60.2%);
#   font-family: Courier;
# }
# #T_0c583_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.0%, transparent 82.0%);
#   font-family: Courier;
# }
# #T_0c583_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.3%, transparent 72.3%);
#   font-family: Courier;
# }
# #T_0c583_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.3%, transparent 61.3%);
#   font-family: Courier;
# }
# #T_0c583_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 49.0%, transparent 49.0%);
#   font-family: Courier;
# }
# #T_0c583_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.0%, transparent 31.0%);
#   font-family: Courier;
# }
# #T_0c583_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.5%, transparent 59.5%);
#   font-family: Courier;
# }
# #T_0c583_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 76.7%, transparent 76.7%);
#   font-family: Courier;
# }
# #T_0c583_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.3%, transparent 68.3%);
#   font-family: Courier;
# }
# #T_0c583_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.2%, transparent 58.2%);
#   font-family: Courier;
# }
# #T_0c583_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.9%, transparent 44.9%);
#   font-family: Courier;
# }
# #T_0c583_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.5%, transparent 29.5%);
#   font-family: Courier;
# }
# #T_0c583_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.5%, transparent 55.5%);
#   font-family: Courier;
# }
# #T_0c583_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 94.3%, transparent 94.3%);
#   font-family: Courier;
# }
# #T_0c583_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.3%, transparent 85.3%);
#   font-family: Courier;
# }
# #T_0c583_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.4%, transparent 55.4%);
#   font-family: Courier;
# }
# #T_0c583_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 33.5%, transparent 33.5%);
#   font-family: Courier;
# }
# #T_0c583_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.0%, transparent 68.0%);
#   font-family: Courier;
# }
# #T_0c583_r

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_13_'></a>[TNM-T (p)](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

# _=show_vars(9, grouper_reg.KKR.value, show=True, filter=FILTER_DY_SOLID_NO_DCO)
_=show_vars(9, grouper_reg.KKR.value, show=True, filter=_filter)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_064_712  (51.4%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_14_'></a>[TNM-N (p)](#toc0_)
# <!-- (_solide Tumoren_ schliesst folgende Diagnosen _aus_: C44, C70-C72, C76-C97, alle D) -->

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_=show_vars(11, grouper_reg.KKR.value, show=True, filter=_filter)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_064_712  (51.4%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_7_15_'></a>[TNM-M (p)](#toc0_)
# - **Filter: `DJ` = 2020-2024, `DCO` = N, `ICD10` nur TNM relevante**

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_=show_vars(12, grouper_reg.KKR.value, show=True, filter=_filter)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_064_712  (51.4%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ## <a id='toc1_8_'></a>[Todesursachen (TU)](#toc0_)

# %% [markdown]
# ### <a id='toc1_8_1_'></a>[nach ICD10 Einstellern](#toc0_)
# - gezählt sind die ersten Stellen aller TU Codes ohne jeglichen Filter

# %%
db_tu = Todesursache.project("*, upper(substr(Code, 1,1)) as tu_1d")
_ = pls.plot_bars(
    db_tu.aggregate("tu_1d, count(*) as cnt").to_df(),
    orientation="h",
    sort_values=True,
    height=500,
    top_n_index=10,
    # caption=None, 
)

# %% [markdown]
# ### <a id='toc1_8_2_'></a>[nach Sterbejahr und Todesursachen](#toc0_)
# - gezählt werden **Personen**
# - **Filter: `SJ`= 2020-2024, `Verstorben` = J**
# - `tu_type` Art der TU pro Patient
#   - `<NA>` keine Todesursache zugeordnet
#   - `c_only` nur Todesursachen Cxx
#   - `other_only` nur Todesursachen <> Cxx
#   - `c_and_other` Cxx und andere Todesursachen
#
# <!-- > 💡 `ZfKD`: _"`03-NI` und `06-HE` übermitteln deutlich weniger Todesursachen asl in den epi Daten, für `07-RP` ist der Anteil in beiden Datenräumen gering. Für `15-ST` sind auffällig wenige Todesfälle in 2023 übermittelt."_ -->

# %%
_filters = [
    # FILTERS_DY,
    (f"year(Datum_Vitalstatus::date) between 2020 and {DY_MAX}","SJ 2020-2024"),
    ("Verstorben='J'","nur Verstorbene"),
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum join Patient pat on pat.oBDS_RKIPatientId = tum.oBDS_RKIPatientId",
    filters=_filters,
    distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

# _filter = f"""--sql
#     year(Datum_Vitalstatus::date) between 2020 and {DY_MAX}
#     and Verstorben='J'
# """

db_tu2 = con.sql(f"""--sql
    with t1 as (
        -- raw list, 1 pat -> n tu
        select
            pat.oBDS_RKIPatientId as z_pat_id,
            year(Datum_Vitalstatus::date) as SJ,
            -- check both independantly
            case when left(code,1)='C' then true else false end as has_c,
            case when left(code,1)<>'C' then true else false end as has_other,
            pat.z_kkr,
            Code,
            Version,
            IsGrundleiden,
        from Patient pat
        left join Todesursache tu on pat.oBDS_RKIPatientId = tu.oBDS_RKIPatientId
        where {_filter}
    ),
    t2 as (
        -- 1 pat -> 1 tu_type
        select
            z_pat_id,
            SJ,
            z_kkr,
            case
                when max(has_c) and max(has_other) then 'c_and_other'
                when max(has_c) and not max(has_other) then 'c_only'
                when not max(has_c) and max(has_other) then 'other_only'
                -- use null for a prominent, grey bar in diagram
                when not max(has_c) and not max(has_other) then null
                -- this should never show
                else 'U'
            end as tu_type,
        from t1
        -- SJ and kkr are neutral in the group
        group by z_pat_id, SJ, z_kkr
    ),
    t3 as (
        -- assign label
        select
            SJ,
            tu_type,
            lr.kkr as z_kkr_label,
        from t2
        left join dim_lieferregister lr on t2.z_kkr = lr.code
    )
    select * from t3
    """)
# tbl.descr_db(db_tu2,"tu_type")
df_tu2 = db_tu2.to_df()

_ = pls.plot_facet_stacked_bars(
    df_tu2,
    subplots_per_row=4,
    top_n_color=5,
    # sort_values_color=True,
    # sort_values_facet=True,
    show_other=False,
    relative=True,
    annotations=True,
    # renderer="svg",
)
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_420_720                      (100.0%) ██████████████████████████████
# └ [SJ 2020-2024]:    n = 2_679_098  (78.3%) ░░░░░░░███████████████████████
# └ [nur Verstorbene]:   n = 896_564  (26.2%) ░░░░░░░░░░░░░░░░░░░░░░░███████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# year(Datum_Vitalstatus::date) between 2020 and 2024
# and Verstorben='J'
# ```
#
# </details>

# %%
# _filter = f"""--sql
#     year(Datum_Vitalstatus::date) between 2020 and {DY_MAX}
#     and Verstorben='J'
# """

# # # * get list of all patient and their first TU
# _tu = (Patient.set_alias("p")
#     .join(Todesursache, "oBDS_RKIPatientId", "inner")
#     .aggregate("p.oBDS_RKIPatientId, min(Code) as code")
# )
# # _tu

# db_tu=(
#     Patient
#     .join(_tu, "oBDS_RKIPatientId", "left")
#     .join(Tumor, "oBDS_RKIPatientId", "left")
#     .filter(_filter)
#     .project("""--sql
#             --z_dy 
#             year(Datum_Vitalstatus::date) as SJ
#             --,left(code,3) as tu
#             ,case 
#                 when left(code,1)='C' then 'C' 
#                 when left(code,1)<>'C' then '<other>' 
#                 else null end as tu_type
#             ,z_kkr_label
#     """)
# )
# df_tu = db_tu.to_df()

# hlp.print_filter(_filter)

# _ = pls.plot_facet_stacked_bars(
#     df_tu,
#     subplots_per_row=4,
#     top_n_color=5,
#     sort_values_color=True,
#     show_other=False,
#     relative=True,
#     annotations=True,
#     renderer="svg",
# )

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_3_'></a>[nach ICD10 Dreistellern (TOP 5)](#toc0_)
# - Grundgesamtheit: alle **Todesursachen**, kein Filter
#
# > 💡 `ZfKD`: _Enthalten sind in einigen KKR auch `C79` (Metastasen), welche in offizieller Todesursachen-Statistik nicht kodiert sind_

# %%
_tu = (
    Todesursache.aggregate("z_kkr, left(Code,3) as tu_3d, count(*) as cnt")
    .join(dim_lieferregister, "z_kkr::int = code::int")
    .project("tu_3d,kkr, cnt")
    .to_df()
    # .pivot_table(index='tu_3d', columns='kkr', values='cnt', fill_value=0, dropna=False)
)
# tbl.show_num_df(_df, data_bar_axis="xy", total_axis="xy", total_exclude=True, pct_axis="x",)
tbl.pivot_df(
    _tu,
    top_n_index=5,
    data_bar_axis="xy",
    pct_axis="",
    heatmap_axis="",
    total_axis="xy",
    font_size_th=8,
    font_size_td=6,
    swap=True,
    # total_exclude=True,
    image_scale="80%"
)
# Out:
# <!-- SCALE-80% -->
# <style type="text/css">
# #T_83410 th {
#   text-align: right;
#   font-size: 8pt;
# }
# #T_83410 td {
#   text-align: right;
#   font-size: 6pt;
# }
# #T_83410_row0_col0, #T_83410_row1_col1, #T_83410_row3_col2, #T_83410_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_83410_row0_col1, #T_83410_row3_col5, #T_83410_row9_col2, #T_83410_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_83410_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_83410_row0_col3, #T_83410_row0_col4, #T_83410_row1_col3, #T_83410_row1_col4, #T_83410_row2_col3, #T_83410_row2_col4, #T_83410_row3_col3, #T_83410_row3_col4, #T_83410_row7_col3, #T_83410_row7_col4, #T_83410_row9_col3, #T_83410_row9_col4 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_83410_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.0%, transparent 3.0%);
#   font-family: Courier;
# }
# #T_83410_row1_col0, #T_83410_row9_col1, #T_83410_row12_col4, #T_83410_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.3%, transparent 0.3%);
#   font-family: Courier;
# }
# #T_83410_row1_col2, #T_83410_row10_col1, #T_83410_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.1%, transparent 1.1%);
#   font-family: Courier;
# }
# #T_83410_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.7%, transparent 1.7%);
#   font-family: Courier;
# }
# #T_83410_row2_col0, #T_83410_row6_col0, #T_83410_row10_col0, #T_83410_row11_col0, #T_83410_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.6%, transparent 0.6%);
#   font-family: Courier;
# }
# #T_83410_row2_col1, #T_83410_row5_col4, #T_83410_row6_col1, #T_83410_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_83410_row2_col2, #T_83410_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.6%, transparent 2.6%);
#   font-family: Courier;
# }
# #T_83410_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.1%, transparent 4.1%);
#   font-family: Courier;
# }
# #T_83410_row3_col0, #T_83410_row3_col1, #T_83410_row4_col3, #T_83410_row4_col4, #T_83410_row5_col1, #T_83410_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_83410_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.9%, transparent 2.9%);
#   font-family: Courier;
# }
# #T_83410_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.5%, transparent 4.5%);
#   font-family: Courier;
# }
# #T_83410_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.1%, transparent 12.1%);
#   font-family: Courier;
# }
# #T_83410_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 19.5%, transparent 19.5%);
#   font-family: Courier;
# }
# #T_83410_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_83410_row5_col2, #T_83410_row9_col0, #T_83410_row12_col0, #T_83410_row15_col1, #T_83410_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_83410_row5_col3, #T_83410_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.8%, transparent 0.8%);
#   font-family: Courier;
# }
# #T_83410_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.0%, transparent 2.0%);
#   font-family: Courier;
# }
# #T_83410_row6_col2, #T_83410_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_83410_row6_col3, #T_83410_row12_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_83410_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.6%, transparent 3.6%);
#   font-family: Courier;
# }
# #T_83410_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.7%, transparent 9.7%);
#   font-family: Courier;
# }
# #T_83410_row7_col0, #T_83410_row11_col3, #T_83410_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.4%, transparent 1.4%);
#   font-family: Courier;
# }
# #T_83410_row7_col1, #T_83410_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.2%, transparent 2.2%);
#   font-family: Courier;
# }
# #T_83410_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.3%, transparent 4.3%);
#   font-family: Courier;
# }
# #T_83410_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.9%, transparent 7.9%);
#   font-family: Courier;
# }
# #T_83410_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.4%, transparent 2.4%);
#   font-family: Courier;
# }
# #T_83410_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.1%, transparent 3.1%);
#   font-family: Courier;
# }
# #T_83410_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.1%, transparent 6.1%);
#   font-family: Courier;
# }
# #T_83410_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.3%, transparent 2.3%);
#   font-family: Courier;
# }
# #T_83410_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.7%, transparent 6.7%);
#   font-family: Courier;
# }
# #T_83410_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.5%, transparent 20.5%);
#   font-family: Courier;
# }
# #T_83410_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.2%, transparent 1.2%);
#   font-family: Courier;
# }
# #T_83410_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.8%, transparent 2.8%);
#   font-family: Courier;
# }
# #T_83410_row10_col3, #T_83410_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.5%, transparent 1.5%);
#   font-family: Courier;
# }
# #T_83410_row10_col4, #T_83410_row13_col4, #T_83410_row15_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.3%, transparent 1.3%);
#   font-family: Courier;
# }
# #T_83410_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.3%, transparent 7.3%);
#   font-family: Courier;
# }
# #T_83410_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.7%, transparent 5.7%);
#   font-family: Courier;
# }
# #T_83410_row12_col2, #T_83410_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_83410_row12_col3, #T_83410_row14_col0, #T_83410_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.5%, transparent 0.5%);
#   font-family: Courier;
# }
# #T_83410_row13_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.6%, transparent 8.6%);
#   font-family: Courier;
# }
# #T_83410_row14_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.2%, transparent 4.2%);
#   font-family: Courier;
# }
# #T_83410_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.2%, transparent 12.2%);
#   font-family: Courier;
# }
# #T_83410_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.9%, transparent 17.9%);
#   font-family: Courier;
# }
# #T_83410_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 41.7%, transparent 41.7%);
#   font-family: Courier;
# }
# #T_83410_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.6%, transparent 12.6%);
#   font-family: Courier;
# }
# #T_83410_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.6%, transparent 15.6%);
#   font-family: Courier;
# }
# #T_83410_row16_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# </style>
# <table id="T_83410">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tu_3d</th>
#       <th id="T_83410_lev

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_4_'></a>[nach IsGrundleiden](#toc0_)
# - Grundgesamtheit: **alle Todesursachen**

# %%
_tu = (
    Todesursache.aggregate(
        "z_kkr, cast(IsGrundleiden as bool) as is_grundleiden, count(*) as cnt"
    )
    .join(dim_lieferregister, "z_kkr::int = code::int")
    .project("kkr, is_grundleiden, cnt")
    .to_df()
)
_=pls.plot_stacked_bars(_tu, orientation="h", height=700, relative=True, show_total=True, show_pct_bar=True)

# %% [markdown]
# ## <a id='toc1_9_'></a>[Therapien](#toc0_)

# %% [markdown]
# <br>
#
# ### <a id='toc1_9_1_'></a>[OP](#toc0_)

# %% [markdown]
# #### <a id='toc1_9_1_1_'></a>[nach ICD10](#toc0_)
# - Grundgesamtheit: alle **OP Meldungen**

# %%
FILTERS_OP_ORDER = ("z_op_order = 1", "nur erste OP")

_filters = [
    FILTERS_DY,
    FILTERS_OP_ORDER
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum left join OP op on op.z_tum_id = tum.z_tum_id",
    filters=_filters,
    distinct_metric="OPId",
    first_n_filter_apply_to_rows=0,
)

_op = (OP
    .join(Tumor
        .set_alias("t")
        .project("*, left(Diagnose_ICD10_Code,3) as icd10_3d"), 
        "z_tum_id")
    .filter(_filter)
    .aggregate("icd10_3d, t.z_kkr, count(*) as cnt")
    .join(dim_lieferregister, "z_kkr::int = code::int")
    .project("kkr, icd10_3d, cnt")
    .to_df()
    )
_=pls.plot_stacked_bars(_op, orientation="h", height=700, top_n_color=10, relative=True, sort_values_color=True, show_other=True, show_total=True, show_pct_bar=True)
# Out:
# <!-- START_TOKEN -->
# count: distinct OPId
# ---
# n = 2_090_962                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 2_059_981  (98.5%) ░█████████████████████████████
# └ [nur erste OP]: n = 1_641_865  (78.5%) ░░░░░░░███████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_op_order = 1
# ```
#
# </details>

# %% [markdown]
# <br>
#
# #### <a id='toc1_9_1_2_'></a>[nach Intention](#toc0_)
# - Grundgesamtheit: alle **OP Meldungen**

# %%
_op = (OP
    .join(Tumor.set_alias("t"), "z_tum_id")
    .aggregate("Intention, t.z_kkr_label, count(*) as cnt")
    .join(dim_op_intention.set_alias("i"), "Intention=i.code")
    .project("z_kkr_label,concat(i.code, ' -  ', i.name) as label, cnt")
    .to_df()
    )
_=pls.plot_stacked_bars(_op, orientation="h", height=700, top_n_color=0, relative=True, show_total=True, show_pct_bar=True)

# %% [markdown]
# <br>
#
# ### <a id='toc1_9_2_'></a>[OPS](#toc0_)

# %% [markdown]
# #### <a id='toc1_9_2_1_'></a>[nach OPS ICD Kapitel (Top 10)](#toc0_)
# - Grundgesamtheit: **alle OPS Codes**
#
# > 💡 `ZfKD`: _Lediglich `02-HH` und `05-NW` übermitteln ausschliesslich Kapitel 5. Der Anteil von Meldungen <> Kapitel 5 sind wahrscheinlich diagnostische Massnahmen oder nicht-operative Therapien. Vorschlag: nur noch Kapitel 5 übermitteln_

# %%
_ops = (OPS
    # .join(Tumor.set_alias("t"), "oBDS_RKIPatientTumorId")
    .aggregate("left(Code,1) as code_1d, z_kkr, count(*) as cnt")
    .join(dim_lieferregister, "z_kkr::int=code::int")
    .project("kkr, code_1d, cnt")
    .to_df()
    )
_=pls.plot_stacked_bars(_ops, orientation="h", height=700, top_n_color=10, relative=True, sort_values_color=False, show_total=True)

# %% [markdown]
# ### <a id='toc1_9_3_'></a>[SYST](#toc0_)

# %% [markdown]
# #### <a id='toc1_9_3_1_'></a>[nach Stellung_OP](#toc0_)
#
# - Grundgesamtheit: **alle SYST Elemente**

# %%
_syst = (SYST
    .join(Tumor.set_alias("t"), "z_tum_id")
    .aggregate("Stellung_OP, t.z_kkr_label, count(*) as cnt")
    .join(dim_syst_op_stellung.set_alias("s"), "Stellung_OP=s.code")
    .project("z_kkr_label,concat(s.code, ' -  ', s.name) as label, cnt")
    .to_df()
    )
_=pls.plot_stacked_bars(_syst, orientation="h", height=700, top_n_color=0, relative=True, show_total=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 4
#       1 _syst = (SYST
#       2     .join(Tumor.set_alias("t"), "z_tum_id")
#       3     .aggregate("Stellung_OP, t.z_kkr_label, count(*) as cnt")
# ----> 4     .join(dim_syst_op_stellung.set_alias("s"), "Stellung_OP=s.code")
#       5     .project("z_kkr_label,concat(s.code, ' -  ', s.name) as label, cnt")
#       6     .to_df()
#       7     )
#       8 _=pls.plot_stacked_bars(_syst, orientation="h", height=700, top_n_color=0, relative=True, show_total=True)
#
# NameError: name 'dim_syst_op_stellung' is not defined

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_10_'></a>[Missings- und Unbekannt-Kodierungen](#toc0_)
# - es sind folgende Schwellwerte angezeigt:
#   - 🟩 0 bis <5%
#   - 🟨 **missings**: 5% bis <100% | **unbekannt**: 5% bis <35%>
#   - 🟥 **missings**: bei 100% | **unbekannt** >= 35%
# - dargestellt sind Variablen aus dem Schema in folgender Notation: `[Elementknoten]Variablenname`
# - die graumelierte `0` kennzeichnet einen leeren Wert (=keine missings), 0% entsteht durch Rundung von kleinen Werten
# - `Total`
#   - ist als Spalte neu eingefügt, und bildet den Anteil von missings bzw unbekannt deutschlandweit ab
#   - ⚠️ verliert an Aussagekraft, wenn aus KKR keine Daten vorliegen für diese Variable (100% missings), der Wert wirkt dann geschönt
#
# **unbekannt**
# - bei 100% missings wird auch unbekannt auf 100% gesetzt
# - Beispiele für gewertete Unbekannt-Kodierungen:
#   - `Diagnosesicherung` = 9
#   - `Seitenlokalisation` = U
#   - `Datumsgenauigkeit` in ('M','V')
# - der Quellcode zur Bestimmung von `Unbekannt` Kodierungen ist hier abrufbar: [sql](sql/check_if_unknown.sql)

# %%
with open("../sql/check_if_unknown.sql") as f:
    _macro_check_if_unknown = f.read()
_=con.execute(_macro_check_if_unknown)

# %%
def show_missings2(
    filter_col: str,
    filter_row: str = "true",
    use_unknown: bool = False,
    swap: bool = True,
    debug: bool = False,
    font_size_th: int = 12,
    font_size_td: int = 11,
    image_scale: str = None,
):
    """
    filter_col: filter for columns  
    filter_row: filter for tablerows  
    use_unknown: show unknowns instead of missings  
    print_filter: print filter string  
    debug: show debug info  
    
    hint for filter_col:
    ```python
    regexp_matches(tablecolumn, 'atem|radio|geschl|inzidenz|Anzahl_Tage_Diagnose_OP','i')
    ```
    or
    ```python
    table = 'OPS'
    ```
    
    or

    ['sel3_TNM',
    'sel4_datum',
    'sel5_pflicht',
    'sel6_mamma',
    'sel7_prostata',
    'sel8_prio',
    'sel9_darm',
    'sel10_melanom',
    'sel11_fo',
    'sel12_free',
    'sel13_unknown']

    """
    # * get all columns and tables
    items = (dim_tree
        # .filter("regexp_matches(tablecolumn, 'atem|radio|geschl|inzidenz|Anzahl_Tage_Diagnose_OP','i')")
        .filter(filter_col)
        .project("""--sql
            tablecolumn,
            regexp_extract(tablecolumn, '\](.*)', 1) as col_name,
            tables,
        """)
        .to_df()
        .to_dict()
    )
    if debug:
        print(items)

    # * create empty df
    df_missings_all = pd.DataFrame()

    for col, tab, col_name in zip(items["tablecolumn"].values(), items["tables"].values(), items["col_name"].values()):

        # * create stub, care for the unclosed brackets (closing in query_1)
        query_0 = (f"""--sql
            with t1 as (
                select
                    (ifnull(t_1.{col_name}::text, '') = '') as is_missing,
                    mem.fx_check_if_unknown(t_1.{col_name}, '{col_name}') AS is_unknown,
                    t_1.z_kkr as z_kkr,
                from {tab} t_1
                
        """)

        # ! use extra query for patient oriented tables, join is different here
        if tab in ('Patient', 'Todesursache'):
            query_1 = (f"""--sql
                where oBDS_RKIPatientId in
                    -- avoid join to not have a table prefix like "tum.", to reuse the filter
                    (select z_pat_id from Tumor where {filter_row})
            ),
            """)
        else:
            query_1 = (f"""--sql
                where z_tum_id in (select z_tum_id from Tumor where {filter_row})
            ),
            """)
            
        # ! use extra metrics for unknown. missings / unknown -> invalid
        if not use_unknown:
            query_2 = ("""--sql
                t2 as (
                    select
                        is_missing as is_invalid,
                        z_kkr,
                        count(*)::int as cnt,
                    from t1
                    group by is_missing,z_kkr
                ),
            """)
        else:
            query_2 = ("""--sql
                t2 as (
                    select
                        is_unknown as is_invalid,
                        z_kkr,
                        case
                            -- check if there are any rows at all
                            -- if not, return 0, which makes nonexisting data also unknown
                            when count(*) filter (not is_missing) = 0 then 0
                            else count(*)::int
                        end as cnt,
                    from t1
                    group by is_unknown,z_kkr
                ),
            """)

        query_rest = (f"""--sql
            t3 as (
                select
                    *,
                    sum(cnt) over (partition by z_kkr) as cnt_all,
                from t2
                order by z_kkr
            ),
            t4 as (
                select
                    z_kkr,
                    cnt as cnt_valid,
                    cnt_all,
                from t3
                where not is_invalid
                -- filter for the **valid** rows
                -- these can be better distinguished from non existing data

                -- ! TOTALS can be activated here. problem is, non existing data bias the total
                -- when kkr dont have any data, total looks fine. this is not intuitive!

                -- now calc the total. must be on t2 since t3 is filtered
                union
                select
                    -- 0 = Total
                    0 as z_kkr,
                    -- sum all cnt but only for the valid
                    sum(cnt) filter (not is_invalid) as cnt_valid,
                    -- sum all cnt
                    sum(cnt) as cnt_all
                from t2
            ),
            t5 as (
                select
                    '{col}' as col,
                    kkr as z_kkr,
                    cnt_valid,
                    cnt_all,
                    case
                        -- no data at all -> 100% (red)
                        when ifnull(cnt_all,0) = 0 then 1
                        -- calculate diff to 100%. empty valids -> 0
                        else 1 - coalesce(cnt_valid/cnt_all::float,0)
                    end as pct_invalid
                from t4
                -- fill up non existing data
                right join dim_lieferregister on z_kkr = code
                --where kkr <> 'Total'
            )
            select * from t5
        """)

        query = query_0 + query_1 + query_2 + query_rest
        # print(query)
        db_missings = con.sql(query)
                
        df_missings = db_missings.to_df()

        if df_missings_all.empty:
            df_missings_all = df_missings
        else:
            df_missings_all = pd.concat([df_missings_all, df_missings], axis=0)

    # * debug
    # con.from_df(df_missings_all).filter("z_kkr <> 0").sum("cnt_all").show()
    # return df_missings_all.sort_values(["z_kkr"])#["cnt_invalid"].sum()

    if debug:
        print(query)
        display(df_missings_all.sort_values(["col","z_kkr"]))

    if use_unknown:
        print("🟠 unknowns")
    else:
        print("🟠 missings")

    _df = df_missings_all[["z_kkr","col","pct_invalid"]] if swap else df_missings_all[["col","z_kkr","pct_invalid"]]

    display(tbl.pivot_df(
        df=_df,
        total_axis="",
        precision=1,
        show_as_pct=True,
        pct_axis="",
        # kkr_col="z_kkr",
        # swap=True,
        kpi_mode="rag_abs",
        kpi_rag_list=[0.05,1] if not use_unknown else [0.05, 0.35],
        font_size_th=font_size_th,
        font_size_td=font_size_td,
        image_scale=image_scale,
        )
    )

# %% [markdown]
# <br>
#
# ### <a id='toc1_10_1_'></a>[Verpflichtende Tumorvariablen](#toc0_)
# - kein Filter
# - Pflichtangaben aus anderen Elementknoten (z.B. Datum aus dem OP Knoten) sind nicht aufgeführt, da diese selbst optional sind
#
# > 💡 `ZfKD`: _Pflichtfelder sind nahezu komplett vorhanden, die wenigen Ausnahmen werden allerdings Stand heute nicht korrigiert_
#
# > 💡 `ZfKD`: _`Gesamtbeurteilung_Tumorstatus`ist zwar vollständig geliefert (siehe vorherige Grafiken), aber häufig als Unbekannt kodiert. Viele Pflichtvariablen haben keine Unbekannt Kodes, etwas auffällig sind hier `Diagnosesicherung` und `Seitenlokalisation`. Ähnlich auch `Morphologie` (kein Pflichtfeld)._

# %%
os.environ['IMAGE_SCALE'] = "100%"

_filters = [
    FILTERS_DY,
]
_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col="sel5_pflicht",
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    # swap=True,
    # image_scale="100%"
)

show_missings2(
    filter_col="sel5_pflicht",
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    # image_scale="100%"
)
# show_missings2(
#     filter_col="sel5_pflicht",
#     filter_row = _filter,
#     use_unknown=True,
#     # debug=True,
#     # image_scale="100%",
#     # swap = False,
# )
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_c5fcb th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_c5fcb td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_c5fcb_row0_col0, #T_c5fcb_row0_col1, #T_c5fcb_row0_col2, #T_c5fcb_row0_col3, #T_c5fcb_row0_col4, #T_c5fcb_row0_col5, #T_c5fcb_row0_col6, #T_c5fcb_row0_col7, #T_c5fcb_row0_col8, #T_c5fcb_row0_col9, #T_c5fcb_row1_col0, #T_c5fcb_row1_col1, #T_c5fcb_row1_col2, #T_c5fcb_row1_col3, #T_c5fcb_row1_col4, #T_c5fcb_row1_col5, #T_c5fcb_row1_col6, #T_c5fcb_row1_col7, #T_c5fcb_row1_col8, #T_c5fcb_row1_col9, #T_c5fcb_row2_col0, #T_c5fcb_row2_col1, #T_c5fcb_row2_col2, #T_c5fcb_row2_col3, #T_c5fcb_row2_col4, #T_c5fcb_row2_col5, #T_c5fcb_row2_col6, #T_c5fcb_row2_col7, #T_c5fcb_row2_col8, #T_c5fcb_row2_col9, #T_c5fcb_row3_col0, #T_c5fcb_row3_col1, #T_c5fcb_row3_col2, #T_c5fcb_row3_col3, #T_c5fcb_row3_col4, #T_c5fcb_row3_col5, #T_c5fcb_row3_col6, #T_c5fcb_row3_col7, #T_c5fcb_row3_col8, #T_c5fcb_row3_col9, #T_c5fcb_row4_col0, #T_c5fcb_row4_col1, #T_c5fcb_row4_col2, #T_c5fcb_row4_col3, #T_c5fcb_row4_col4, #T_c5fcb_row4_col5, #T_c5fcb_row4_col6, #T_c5fcb_row4_col7, #T_c5fcb_row4_col8, #T_c5fcb_row4_col9, #T_c5fcb_row5_col0, #T_c5fcb_row5_col1, #T_c5fcb_row5_col2, #T_c5fcb_row5_col3, #T_c5fcb_row5_col4, #T_c5fcb_row5_col5, #T_c5fcb_row5_col6, #T_c5fcb_row5_col7, #T_c5fcb_row5_col8, #T_c5fcb_row5_col9, #T_c5fcb_row6_col0, #T_c5fcb_row6_col1, #T_c5fcb_row6_col2, #T_c5fcb_row6_col3, #T_c5fcb_row6_col4, #T_c5fcb_row6_col5, #T_c5fcb_row6_col6, #T_c5fcb_row6_col7, #T_c5fcb_row6_col8, #T_c5fcb_row6_col9, #T_c5fcb_row7_col0, #T_c5fcb_row7_col1, #T_c5fcb_row7_col2, #T_c5fcb_row7_col3, #T_c5fcb_row7_col4, #T_c5fcb_row7_col5, #T_c5fcb_row7_col6, #T_c5fcb_row7_col7, #T_c5fcb_row7_col8, #T_c5fcb_row7_col9, #T_c5fcb_row8_col0, #T_c5fcb_row8_col1, #T_c5fcb_row8_col2, #T_c5fcb_row8_col3, #T_c5fcb_row8_col4, #T_c5fcb_row8_col5, #T_c5fcb_row8_col6, #T_c5fcb_row8_col7, #T_c5fcb_row8_col8, #T_c5fcb_row8_col9, #T_c5fcb_row9_col0, #T_c5fcb_row9_col1, #T_c5fcb_row9_col2, #T_c5fcb_row9_col3, #T_c5fcb_row9_col4, #T_c5fcb_row9_col5, #T_c5fcb_row9_col6, #T_c5fcb_row9_col7, #T_c5fcb_row9_col8, #T_c5fcb_row9_col9, #T_c5fcb_row10_col0, #T_c5fcb_row10_col1, #T_c5fcb_row10_col2, #T_c5fcb_row10_col3, #T_c5fcb_row10_col4, #T_c5fcb_row10_col5, #T_c5fcb_row10_col6, #T_c5fcb_row10_col7, #T_c5fcb_row10_col8, #T_c5fcb_row10_col9, #T_c5fcb_row11_col0, #T_c5fcb_row11_col1, #T_c5fcb_row11_col2, #T_c5fcb_row11_col3, #T_c5fcb_row11_col4, #T_c5fcb_row11_col5, #T_c5fcb_row11_col6, #T_c5fcb_row11_col7, #T_c5fcb_row11_col8, #T_c5fcb_row11_col9, #T_c5fcb_row12_col0, #T_c5fcb_row12_col1, #T_c5fcb_row12_col2, #T_c5fcb_row12_col3, #T_c5fcb_row12_col4, #T_c5fcb_row12_col6, #T_c5fcb_row12_col7, #T_c5fcb_row12_col9, #T_c5fcb_row13_col0, #T_c5fcb_row13_col1, #T_c5fcb_row13_col2, #T_c5fcb_row13_col3, #T_c5fcb_row13_col4, #T_c5fcb_row13_col5, #T_c5fcb_row13_col6, #T_c5fcb_row13_col7, #T_c5fcb_row13_col8, #T_c5fcb_row13_col9, #T_c5fcb_row14_col0, #T_c5fcb_row14_col1, #T_c5fcb_row14_col2, #T_c5fcb_row14_col3, #T_c5fcb_row14_col4, #T_c5fcb_row14_col5, #T_c5fcb_row14_col6, #T_c5fcb_row14_col7, #T_c5fcb_row14_col8, #T_c5fcb_row14_col9, #T_c5fcb_row15_col0, #T_c5fcb_row15_col1, #T_c5fcb_row15_col2, #T_c5fcb_row15_col3, #T_c5fcb_row15_col4, #T_c5fcb_row15_col5, #T_c5fcb_row15_col6, #T_c5fcb_row15_col7, #T_c5fcb_row15_col8, #T_c5fcb_row15_col9, #T_c5fcb_row16_col0, #T_c5fcb_row16_col1, #T_c5fcb_row16_col2, #T_c5fcb_row16_col3, #T_c5fcb_row16_col4, #T_c5fcb_row16_col6, #T_c5fcb_row16_col7, #T_c5fcb_row16_col9 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_c5fcb_row12_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_c5fcb_row12_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_c5fcb_row16_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_c5fcb_row16_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.3%, transparent 2.3%);
#   font-family: Courier;
# }
# </style>
# <table id="T_c5fcb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_c5fcb_level0_col0" class="col_heading level0 col0" >[Patient]Datum_Vitalstatus</th>
#       <th id="T_c5fcb_level0_col1" class="col_heading level0 col1" >[Patient]Geburtsdatum</th>
#       <th id="T_c5fcb_level0_col2" class="col_heading level0 col2" >[Patient]Geschlecht</th>
#       <th id="T_c5fcb_level0_col3" class="col_heading level0 col3" >[Patient]Verstorben</th>
#       <th id="T_c5fcb_level0_col4" class="col_heading level0 col4" >[Tumor]DCN</th>
#       <th id="T_c5fcb_level0_col5" class="col_heading level0 col5" >[Tumor]Diagnose_ICD10_Code</th>
#       <th id="T_c5fcb_level0_col6" class="col_heading level0 col6" >[Tumor]Diagnosedatum</th>
#       <th id="T_c5fcb_level0_col7" class="col_heading level0 col7" >[Tumor]Diagnosesicherung</th>
#       <th id="T_c5fcb_level0_col8" class="col_heading level0 col8" >[Tumor]Inzidenzort</th>
#       <th id="T_c5fcb_level0_col9" class="col_heading level0 col9" >[Tumor]Seitenlokalisation</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5fcb_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_c5fcb_row0_col0" class="data row0 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col1" class="data row0 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col2" class="data row0 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col3" class="data row0 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col4" class="data row0 col4" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col5" class="data row0 col5" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col6" class="data row0 col6" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col7" class="data row0 col7" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col8" class="data row0 col8" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row0_col9" class="data row0 col9" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_c5fcb_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_c5fcb_row1_col0" class="data row1 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col1" class="data row1 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col2" class="data row1 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col3" class="data row1 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col4" class="data row1 col4" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col5" class="data row1 col5" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col6" class="data row1 col6" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col7" class="data row1 col7" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col8" class="data row1 col8" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_c5fcb_row1_col9" class="data row1 col9" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_c5fcb_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T
# 🟠 unknowns
# <style type="text/css">
# #T_b74bb th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_b74bb td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_b74bb_row0_col0, #T_b74bb_row0_col1, #T_b74bb_row0_col3, #T_b74bb_row0_col4, #T_b74bb_row0_col6, #T_b74bb_row0_col8, #T_b74bb_row1_col0, #T_b74bb_row1_col1, #T_b74bb_row1_col3, #T_b74bb_row1_col4, #T_b74bb_row1_col6, #T_b74bb_row1_col8, #T_b74bb_row2_col0, #T_b74bb_row2_col1, #T_b74bb_row2_col3, #T_b74bb_row2_col4, #T_b74bb_row2_col6, #T_b74bb_row2_col8, #T_b74bb_row3_col0, #T_b74bb_row3_col1, #T_b74bb_row3_col3, #T_b74bb_row3_col4, #T_b74bb_row3_col6, #T_b74bb_row3_col8, #T_b74bb_row4_col3, #T_b74bb_row4_col4, #T_b74bb_row4_col6, #T_b74bb_row4_col8, #T_b74bb_row5_col3, #T_b74bb_row5_col4, #T_b74bb_row5_col6, #T_b74bb_row5_col8, #T_b74bb_row6_col0, #T_b74bb_row6_col3, #T_b74bb_row6_col4, #T_b74bb_row6_col6, #T_b74bb_row6_col8, #T_b74bb_row7_col3, #T_b74bb_row7_col4, #T_b74bb_row7_col6, #T_b74bb_row7_col8, #T_b74bb_row8_col3, #T_b74bb_row8_col4, #T_b74bb_row8_col6, #T_b74bb_row9_col0, #T_b74bb_row9_col1, #T_b74bb_row9_col3, #T_b74bb_row9_col4, #T_b74bb_row9_col6, #T_b74bb_row9_col8, #T_b74bb_row10_col3, #T_b74bb_row10_col4, #T_b74bb_row10_col6, #T_b74bb_row10_col8, #T_b74bb_row11_col1, #T_b74bb_row11_col2, #T_b74bb_row11_col3, #T_b74bb_row11_col4, #T_b74bb_row11_col6, #T_b74bb_row11_col8, #T_b74bb_row12_col3, #T_b74bb_row12_col4, #T_b74bb_row12_col6, #T_b74bb_row13_col2, #T_b74bb_row13_col3, #T_b74bb_row13_col4, #T_b74bb_row13_col6, #T_b74bb_row13_col8, #T_b74bb_row14_col3, #T_b74bb_row14_col4, #T_b74bb_row14_col6, #T_b74bb_row14_col8, #T_b74bb_row15_col1, #T_b74bb_row15_col3, #T_b74bb_row15_col4, #T_b74bb_row15_col6, #T_b74bb_row15_col8, #T_b74bb_row16_col3, #T_b74bb_row16_col4, #T_b74bb_row16_col6 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_b74bb_row0_col2, #T_b74bb_row1_col2, #T_b74bb_row4_col2, #T_b74bb_row5_col0, #T_b74bb_row5_col2, #T_b74bb_row7_col1, #T_b74bb_row8_col1, #T_b74bb_row8_col2, #T_b74bb_row8_col8, #T_b74bb_row10_col1, #T_b74bb_row10_col2, #T_b74bb_row12_col1, #T_b74bb_row12_col8, #T_b74bb_row13_col1, #T_b74bb_row14_col0, #T_b74bb_row14_col1, #T_b74bb_row14_col2, #T_b74bb_row16_col2, #T_b74bb_row16_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_b74bb_row0_col5, #T_b74bb_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.6%, transparent 5.6%);
#   font-family: Courier;
# }
# #T_b74bb_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.5%, transparent 14.5%);
#   font-family: Courier;
# }
# #T_b74bb_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.2%, transparent 28.2%);
#   font-family: Courier;
# }
# #T_b74bb_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.2%, transparent 7.2%);
#   font-family: Courier;
# }
# #T_b74bb_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.2%, transparent 34.2%);
#   font-family: Courier;
# }
# #T_b74bb_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.2%, transparent 8.2%);
#   font-family: Courier;
# }
# #T_b74bb_row2_col2, #T_b74bb_row3_col2, #T_b74bb_row5_col1, #T_b74bb_row6_col1, #T_b74bb_row7_col2, #T_b74bb_row12_col2, #T_b74bb_row15_col2, #T_b74bb_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_b74bb_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.3%, transparent 7.3%);
#   font-family: Courier;
# }
# #T_b74bb_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.8%, transparent 32.8%);
#   font-family: Courier;
# }
# #T_b74bb_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.9%, transparent 8.9%);
#   font-family: Courier;
# }
# #T_b74bb_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.5%, transparent 8.5%);
#   font-family: Courier;
# }
# #T_b74bb_row3_col7, #T_b74bb_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.4%, transparent 7.4%);
#   font-family: Courier;
# }
# #T_b74bb_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.1%, transparent 26.1%);
#   font-family: Courier;
# }
# #T_b74bb_row4_col0, #T_b74bb_row6_col2, #T_b74bb_row9_col2, #T_b74bb_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_b74bb_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_b74bb_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.5%, transparent 5.5%);
#   font-family: Courier;
# }
# #T_b74bb_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.7%, transparent 25.7%);
#   font-family: Courier;
# }
# #T_b74bb_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_b74bb_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.4%, transparent 5.4%);
#   font-family: Courier;
# }
# #T_b74bb_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.3%, transparent 12.3%);
#   font-family: Courier;
# }
# #T_b74bb_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.5%, transparent 12.5%);
#   font-family: Courier;
# }
# #T_b74bb_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 97.2%, transparent 97.2%);
#   font-family: Courier;
# }
# #T_b74bb_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.7%, transparent 8.7%);
#   font-family: Courier;
# }
# #T_b74bb_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.3%, transparent 6.3%);
#   font-family: Courier;
# }
# #T_b74bb_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.0%, transparent 50.0%);
#   font-family: Courier;
# }
# #T_b74bb_row7_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 33.4%, transparent 33.4%);
#   font-family: Courier;
# }
# #T_b74bb_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.3%, transparent 1.3%);
#   font-family: Courier;
# }
# #T_b74bb_row8_col5, #T_b74bb_row14_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.8%, transparent 8.8%);
#   font-family: Courier;
# }
# #T_b74bb_row8_col7, #T_b74bb_row9_col5, #T_b74bb_row13_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.9%, transparent 5.9%);
#   font-family: Courier;
# }
# #T_b74bb_row8_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.4%, transparent 20.4%);
#   font-family: Courier;
# }
# #T_b74bb_row9_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.8%, transparent 3.8%);
#   font-family: Courier;
# }
# #T_b74bb_row9_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.0%, transparent 32.0%);
#   font-family: Courier;
# }
# #T_b74bb_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_b74bb_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.4%, transparent 9.4%);
#   font-family: Courier;
# }
# #T_b74bb_row10_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.3%, transparent 4.3%);
#   font-family: Courier;
# }
# #T_b74bb_row10_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.8%, transparent 10.8%);
#   font-family: Courier;
# }
# #T_b74bb_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_b74bb_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.0%, transparent 10.0%);
#   font-family: Courier;
# }
# #T_b74bb_row11_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.7%, transparent 3.7%);
#   font-family: Courier;
# }
# #T_b74bb_row11_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.2%, transparent 15.2%);
#   font-family: Courier;
# }
# #T_b74bb_row12_col0 {
#   width: 10em;
#   background: linear-gr

# %% [markdown]
# ### <a id='toc1_10_2_'></a>[Weitere Tumorangaben](#toc0_)

# %%
_fil = """--sql
    tablecolumn in (
        --'[Tumor]Diagnosesicherung',
        --'[Tumor]T_p',
        --'[Tumor]UICC_Stadium_p',
        '[Tumor]Morphologie_Code',
        --'[Tumor]Diagnosedatum_Genauigkeit',
        '[Tumor]Topographie_Code',
        '[Tumor]Grading',
)"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    # font_size_th=12,
    # font_size_td=11,
    image_scale="60%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=True,
    # debug=True,
    # font_size_th=12,
    # font_size_td=11,
    image_scale="60%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_038_346  (75.7%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-60% -->
# <style type="text/css">
# #T_6aa09 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_6aa09 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_6aa09_row0_col0, #T_6aa09_row0_col1, #T_6aa09_row0_col2, #T_6aa09_row1_col0, #T_6aa09_row1_col1, #T_6aa09_row3_col0, #T_6aa09_row3_col1, #T_6aa09_row3_col2, #T_6aa09_row4_col0, #T_6aa09_row4_col1, #T_6aa09_row4_col2, #T_6aa09_row7_col0, #T_6aa09_row7_col1, #T_6aa09_row9_col0, #T_6aa09_row9_col1 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_6aa09_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_6aa09_row2_col0, #T_6aa09_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.4%, transparent 45.4%);
#   font-family: Courier;
# }
# #T_6aa09_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.9%, transparent 15.9%);
#   font-family: Courier;
# }
# #T_6aa09_row5_col0, #T_6aa09_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.9%, transparent 12.9%);
#   font-family: Courier;
# }
# #T_6aa09_row5_col2, #T_6aa09_row12_col0, #T_6aa09_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_6aa09_row6_col0, #T_6aa09_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_6aa09_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.4%, transparent 26.4%);
#   font-family: Courier;
# }
# #T_6aa09_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_6aa09_row8_col0, #T_6aa09_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.2%, transparent 21.2%);
#   font-family: Courier;
# }
# #T_6aa09_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_6aa09_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_6aa09_row10_col0, #T_6aa09_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_6aa09_row10_col2, #T_6aa09_row11_col2, #T_6aa09_row13_col0, #T_6aa09_row13_col1, #T_6aa09_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_6aa09_row11_col0, #T_6aa09_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.8%, transparent 1.8%);
#   font-family: Courier;
# }
# #T_6aa09_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.6%, transparent 2.6%);
#   font-family: Courier;
# }
# #T_6aa09_row14_col0, #T_6aa09_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.5%, transparent 3.5%);
#   font-family: Courier;
# }
# #T_6aa09_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.3%, transparent 0.3%);
#   font-family: Courier;
# }
# #T_6aa09_row15_col0, #T_6aa09_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.6%, transparent 12.6%);
#   font-family: Courier;
# }
# #T_6aa09_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.5%, transparent 9.5%);
#   font-family: Courier;
# }
# #T_6aa09_row16_col0, #T_6aa09_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 13.8%, transparent 13.8%);
#   font-family: Courier;
# }
# #T_6aa09_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.6%, transparent 3.6%);
#   font-family: Courier;
# }
# </style>
# <table id="T_6aa09">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_6aa09_level0_col0" class="col_heading level0 col0" >[Tumor]Grading</th>
#       <th id="T_6aa09_level0_col1" class="col_heading level0 col1" >[Tumor]Morphologie_Code</th>
#       <th id="T_6aa09_level0_col2" class="col_heading level0 col2" >[Tumor]Topographie_Code</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa09_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_6aa09_row0_col0" class="data row0 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row0_col1" class="data row0 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row0_col2" class="data row0 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_6aa09_row1_col0" class="data row1 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row1_col1" class="data row1 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row1_col2" class="data row1 col2" >0.0% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_6aa09_row2_col0" class="data row2 col0" >4.6% 🟩</td>
#       <td id="T_6aa09_row2_col1" class="data row2 col1" >4.6% 🟩</td>
#       <td id="T_6aa09_row2_col2" class="data row2 col2" >1.6% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_6aa09_row3_col0" class="data row3 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row3_col1" class="data row3 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row3_col2" class="data row3 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_6aa09_row4_col0" class="data row4 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row4_col1" class="data row4 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row4_col2" class="data row4 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_6aa09_row5_col0" class="data row5 col0" >1.3% 🟩</td>
#       <td id="T_6aa09_row5_col1" class="data row5 col1" >1.3% 🟩</td>
#       <td id="T_6aa09_row5_col2" class="data row5 col2" >0.0% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_6aa09_row6_col0" class="data row6 col0" >10.1% 🟨</td>
#       <td id="T_6aa09_row6_col1" class="data row6 col1" >10.1% 🟨</td>
#       <td id="T_6aa09_row6_col2" class="data row6 col2" >2.7% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row7" class="row_heading level0 row7" >08-BW</th>
#       <td id="T_6aa09_row7_col0" class="data row7 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row7_col1" class="data row7 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row7_col2" class="data row7 col2" >0.2% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row8" class="row_heading level0 row8" >09-BY</th>
#       <td id="T_6aa09_row8_col0" class="data row8 col0" >2.2% 🟩</td>
#       <td id="T_6aa09_row8_col1" class="data row8 col1" >2.2% 🟩</td>
#       <td id="T_6aa09_row8_col2" class="data row8 col2" >0.1% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row9" class="row_heading level0 row9" >10-SL</th>
#       <td id="T_6aa09_row9_col0" class="data row9 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row9_col1" class="data row9 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aa09_row9_col2" class="data row9 col2" >0.0% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aa09_level0_row10" class="row_heading level0 row10" >11-BE</th>
#       <td id="T_6aa09_row10_col0" class="data row10 col0" >0.1% 🟩</td>
#       <td id="T_6aa09_row10_col1" class="data row10 col1" >0.1% 🟩</td>
#       <td id="T_6aa09_row10_col
# 🟠 unknowns
# <!-- SCALE-60% -->
# <style type="text/css">
# #T_d2a77 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_d2a77 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_d2a77_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.2%, transparent 64.2%);
#   font-family: Courier;
# }
# #T_d2a77_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.2%, transparent 8.2%);
#   font-family: Courier;
# }
# #T_d2a77_row0_col2, #T_d2a77_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_d2a77_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_d2a77_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.7%, transparent 10.7%);
#   font-family: Courier;
# }
# #T_d2a77_row1_col2, #T_d2a77_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.5%, transparent 3.5%);
#   font-family: Courier;
# }
# #T_d2a77_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.8%, transparent 71.8%);
#   font-family: Courier;
# }
# #T_d2a77_row2_col2, #T_d2a77_row9_col2, #T_d2a77_row12_col2, #T_d2a77_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.1%, transparent 3.1%);
#   font-family: Courier;
# }
# #T_d2a77_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.4%, transparent 57.4%);
#   font-family: Courier;
# }
# #T_d2a77_row3_col1, #T_d2a77_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.7%, transparent 7.7%);
#   font-family: Courier;
# }
# #T_d2a77_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 70.8%, transparent 70.8%);
#   font-family: Courier;
# }
# #T_d2a77_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.1%, transparent 12.1%);
#   font-family: Courier;
# }
# #T_d2a77_row4_col2, #T_d2a77_row11_col2, #T_d2a77_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.2%, transparent 3.2%);
#   font-family: Courier;
# }
# #T_d2a77_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.6%, transparent 82.6%);
#   font-family: Courier;
# }
# #T_d2a77_row5_col1, #T_d2a77_row10_col2, #T_d2a77_row13_col2, #T_d2a77_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.3%, transparent 3.3%);
#   font-family: Courier;
# }
# #T_d2a77_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.2%, transparent 2.2%);
#   font-family: Courier;
# }
# #T_d2a77_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.3%, transparent 54.3%);
#   font-family: Courier;
# }
# #T_d2a77_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.1%, transparent 4.1%);
#   font-family: Courier;
# }
# #T_d2a77_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.6%, transparent 2.6%);
#   font-family: Courier;
# }
# #T_d2a77_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 90.1%, transparent 90.1%);
#   font-family: Courier;
# }
# #T_d2a77_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.3%, transparent 15.3%);
#   font-family: Courier;
# }
# #T_d2a77_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.5%, transparent 4.5%);
#   font-family: Courier;
# }
# #T_d2a77_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.7%, transparent 82.7%);
#   font-family: Courier;
# }
# #T_d2a77_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_d2a77_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.8%, transparent 2.8%);
#   font-family: Courier;
# }
# #T_d2a77_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.1%, transparent 66.1%);
#   font-family: Courier;
# }
# #T_d2a77_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.7%, transparent 8.7%);
#   font-family: Courier;
# }
# #T_d2a77_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.3%, transparent 82.3%);
#   font-family: Courier;
# }
# #T_d2a77_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 83.2%, transparent 83.2%);
#   font-family: Courier;
# }
# #T_d2a77_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.9%, transparent 5.9%);
#   font-family: Courier;
# }
# #T_d2a77_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 73.1%, transparent 73.1%);
#   font-family: Courier;
# }
# #T_d2a77_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.1%, transparent 5.1%);
#   font-family: Courier;
# }
# #T_d2a77_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 83.5%, transparent 83.5%);
#   font-family: Courier;
# }
# #T_d2a77_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.7%, transparent 6.7%);
#   font-family: Courier;
# }
# #T_d2a77_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.7%, transparent 64.7%);
#   font-family: Courier;
# }
# #T_d2a77_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.5%, transparent 6.5%);
#   font-family: Courier;
# }
# #T_d2a77_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.4%, transparent 59.4%);
#   font-family: Courier;
# }
# #T_d2a77_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.8%, transparent 4.8%);
#   font-family: Courier;
# }
# #T_d2a77_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 76.6%, transparent 76.6%);
#   font-family: Courier;
# }
# #T_d2a77_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.8%, transparent 7.8%);
#   font-family: Courier;
# }
# </style>
# <table id="T_d2a77">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_d2a77_level0_col0" class="col_heading level0 col0" >[Tumor]Grading</th>
#       <th id="T_d2a77_level0_col1" class="col_heading level0 col1" >[Tumor]Morphologie_Code</th>
#       <th id="T_d2a77_level0_col2" class="col_heading level0 col2" >[Tumor]Topographie_Code</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2a77_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_d2a77_row0_col0" class="data row0 col0" >36.0% 🟥</td>
#       <td id="T_d2a77_row0_col1" class="data row0 col1" >4.6% 🟩</td>
#       <td id="T_d2a77_row0_col2" class="data row0 col2" >1.4% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_d2a77_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_d2a77_row1_col0" class="data row1 col0" >56.0% 🟥</td>
#       <td id="T_d2a77_row1_col1" class="data row1 col1" >6.0% 🟨</td>
#       <td id="T_d2a77_row1_col2" class="data row1 col2" >2.0% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_d2a77_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_d2a77_row2_col0" class="data row2 col0" >40.2% 🟥</td>
#       <td id="T_d2a77_row2_col1" class="data row2 col1" >1.4% 🟩</td>
#       <td id="T_d2a77_row2_col2" class="data row2 col2" >1.7% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_d2a77_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_d2a77_row3_col0" class="data row3 col0" >32.2% 🟨</td>
#       <td id="T_d2a77_row3_col1" class="data row3 col1" >4.3% 🟩</td>
#       <td id="T_d2a77_row3_col2" class="data row3 col2" >2.0% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_d2a77_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_d2a77_row4_col0" class="data row4 col0" >39.7% 🟥</td>
#       <td id="T_d2a77_row4_col1" class="data row4 col1" >6.8% 🟨</td>
#       <td id="T_d2a77_row4_col2" class="data row4 col2" >1.8% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_d2a77_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_d2a77_row5_col0" class="data row5 col0" >46.3% 🟥</td>
#       <td id

# %% [markdown]
# <br>
#
# ### <a id='toc1_10_3_'></a>[Tumorstadien](#toc0_)
# - **Filter: `DJ` 2020-2024, `DCO` = N, `ICD10` nur solide Tumoren**
#
# > 💡 `ZfKD`: _"`05-NW` hat die Auflage als Konstante im Datensatz hinterlegt"_

# %%
_fil = """--sql
    sel3_TNM
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)


show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=True
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=True,
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_064_712  (51.4%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_3d378 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_3d378 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_3d378_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 38.4%, transparent 38.4%);
#   font-family: Courier;
# }
# #T_3d378_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 43.3%, transparent 43.3%);
#   font-family: Courier;
# }
# #T_3d378_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 37.6%, transparent 37.6%);
#   font-family: Courier;
# }
# #T_3d378_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 36.7%, transparent 36.7%);
#   font-family: Courier;
# }
# #T_3d378_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 36.3%, transparent 36.3%);
#   font-family: Courier;
# }
# #T_3d378_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.4%, transparent 34.4%);
#   font-family: Courier;
# }
# #T_3d378_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 37.3%, transparent 37.3%);
#   font-family: Courier;
# }
# #T_3d378_row0_col7, #T_3d378_row0_col11, #T_3d378_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.6%, transparent 34.6%);
#   font-family: Courier;
# }
# #T_3d378_row0_col8, #T_3d378_row5_col4, #T_3d378_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.2%, transparent 47.2%);
#   font-family: Courier;
# }
# #T_3d378_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.8%, transparent 48.8%);
#   font-family: Courier;
# }
# #T_3d378_row0_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.9%, transparent 45.9%);
#   font-family: Courier;
# }
# #T_3d378_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.6%, transparent 21.6%);
#   font-family: Courier;
# }
# #T_3d378_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 93.2%, transparent 93.2%);
#   font-family: Courier;
# }
# #T_3d378_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.0%, transparent 60.0%);
#   font-family: Courier;
# }
# #T_3d378_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 16.4%, transparent 16.4%);
#   font-family: Courier;
# }
# #T_3d378_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 38.0%, transparent 38.0%);
#   font-family: Courier;
# }
# #T_3d378_row1_col6, #T_3d378_row1_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 42.5%, transparent 42.5%);
#   font-family: Courier;
# }
# #T_3d378_row1_col7, #T_3d378_row1_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 43.2%, transparent 43.2%);
#   font-family: Courier;
# }
# #T_3d378_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.0%, transparent 45.0%);
#   font-family: Courier;
# }
# #T_3d378_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.7%, transparent 71.7%);
#   font-family: Courier;
# }
# #T_3d378_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.3%, transparent 52.3%);
#   font-family: Courier;
# }
# #T_3d378_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 51.0%, transparent 51.0%);
#   font-family: Courier;
# }
# #T_3d378_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.5%, transparent 50.5%);
#   font-family: Courier;
# }
# #T_3d378_row2_col3, #T_3d378_row15_col4, #T_3d378_row15_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 43.4%, transparent 43.4%);
#   font-family: Courier;
# }
# #T_3d378_row2_col4, #T_3d378_row5_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.0%, transparent 48.0%);
#   font-family: Courier;
# }
# #T_3d378_row2_col5, #T_3d378_row2_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 37.8%, transparent 37.8%);
#   font-family: Courier;
# }
# #T_3d378_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.5%, transparent 47.5%);
#   font-family: Courier;
# }
# #T_3d378_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 37.7%, transparent 37.7%);
#   font-family: Courier;
# }
# #T_3d378_row2_col8, #T_3d378_row2_col9, #T_3d378_row4_col8, #T_3d378_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_3d378_row2_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.1%, transparent 48.1%);
#   font-family: Courier;
# }
# #T_3d378_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.7%, transparent 28.7%);
#   font-family: Courier;
# }
# #T_3d378_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 44.7%, transparent 44.7%);
#   font-family: Courier;
# }
# #T_3d378_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.6%, transparent 28.6%);
#   font-family: Courier;
# }
# #T_3d378_row3_col3, #T_3d378_row10_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 42.4%, transparent 42.4%);
#   font-family: Courier;
# }
# #T_3d378_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.3%, transparent 26.3%);
#   font-family: Courier;
# }
# #T_3d378_row3_col5, #T_3d378_row3_col7, #T_3d378_row3_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 41.1%, transparent 41.1%);
#   font-family: Courier;
# }
# #T_3d378_row3_col6, #T_3d378_row3_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.3%, transparent 27.3%);
#   font-family: Courier;
# }
# #T_3d378_row3_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 30.7%, transparent 30.7%);
#   font-family: Courier;
# }
# #T_3d378_row3_col9, #T_3d378_row8_col4, #T_3d378_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 46.5%, transparent 46.5%);
#   font-family: Courier;
# }
# #T_3d378_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 24.6%, transparent 24.6%);
#   font-family: Courier;
# }
# #T_3d378_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 91.2%, transparent 91.2%);
#   font-family: Courier;
# }
# #T_3d378_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 36.5%, transparent 36.5%);
#   font-family: Courier;
# }
# #T_3d378_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.0%, transparent 56.0%);
#   font-family: Courier;
# }
# #T_3d378_row4_col4, #T_3d378_row4_col5 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_3d378_row4_col6, #T_3d378_row4_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 42.3%, transparent 42.3%);
#   font-family: Courier;
# }
# #T_3d378_row4_col7, #T_3d378_row4_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 42.6%, transparent 42.6%);
#   font-family: Courier;
# }
# #T_3d378_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.9%, transparent 53.9%);
#   font-family: Courier;
# }
# #T_3d378_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.2%, transparent 56.2%);
#   font-family: Courier;
# }
# #T_3d378_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.1%, transparent 52.1%);
#   font-family: Courier;
# }
# #T_3d378_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.5%, transparent 45.5%);
#   font-family: Courier;
# }
# #T_3d378_row5_col5, #T_3d378_row5_col7, #T_3d378_row5_col11, #T_3d378_row14_col4, #T_3d378_row14_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 40.4%, transparent 40.4%);
#   font-family: Courier;
# }
# #T_3d378_row5_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.8%, transparent 57.8%);
#   font-family: Courier;
# }
# #T_3d378_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.3%, transparent 60.3%);
#   font-family: Courier;
# }
# #T_3d378_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.8%, transparent 68.8%);
#   font-family: Courier;
# }
# #T_3d378_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.2%, transparent 52.2%);
#   font-family: Courier;
# }
# #T_3d378_row6_col2 {
#   widt
# 🟠 unknowns
# <style type="text/css">
# #T_e4472 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_e4472 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_e4472_row0_col0, #T_e4472_row0_col1, #T_e4472_row0_col4, #T_e4472_row0_col5, #T_e4472_row0_col10, #T_e4472_row0_col11, #T_e4472_row1_col4, #T_e4472_row1_col5, #T_e4472_row1_col8, #T_e4472_row1_col9, #T_e4472_row1_col10, #T_e4472_row1_col11, #T_e4472_row2_col0, #T_e4472_row2_col4, #T_e4472_row2_col5, #T_e4472_row2_col8, #T_e4472_row2_col9, #T_e4472_row2_col10, #T_e4472_row2_col11, #T_e4472_row3_col0, #T_e4472_row3_col4, #T_e4472_row3_col5, #T_e4472_row3_col8, #T_e4472_row3_col9, #T_e4472_row3_col10, #T_e4472_row3_col11, #T_e4472_row4_col4, #T_e4472_row4_col5, #T_e4472_row4_col10, #T_e4472_row4_col11, #T_e4472_row5_col1, #T_e4472_row5_col4, #T_e4472_row5_col5, #T_e4472_row5_col10, #T_e4472_row5_col11, #T_e4472_row6_col0, #T_e4472_row6_col1, #T_e4472_row6_col4, #T_e4472_row6_col5, #T_e4472_row6_col9, #T_e4472_row6_col10, #T_e4472_row6_col11, #T_e4472_row7_col0, #T_e4472_row7_col1, #T_e4472_row7_col4, #T_e4472_row7_col5, #T_e4472_row7_col8, #T_e4472_row7_col9, #T_e4472_row7_col10, #T_e4472_row7_col11, #T_e4472_row8_col4, #T_e4472_row8_col5, #T_e4472_row8_col10, #T_e4472_row8_col11, #T_e4472_row9_col4, #T_e4472_row9_col5, #T_e4472_row9_col8, #T_e4472_row9_col10, #T_e4472_row9_col11, #T_e4472_row10_col4, #T_e4472_row10_col5, #T_e4472_row10_col10, #T_e4472_row10_col11, #T_e4472_row11_col4, #T_e4472_row11_col5, #T_e4472_row11_col9, #T_e4472_row11_col10, #T_e4472_row11_col11, #T_e4472_row12_col4, #T_e4472_row12_col5, #T_e4472_row12_col10, #T_e4472_row12_col11, #T_e4472_row13_col4, #T_e4472_row13_col5, #T_e4472_row13_col10, #T_e4472_row13_col11, #T_e4472_row14_col4, #T_e4472_row14_col5, #T_e4472_row14_col10, #T_e4472_row14_col11, #T_e4472_row15_col4, #T_e4472_row15_col5, #T_e4472_row15_col9, #T_e4472_row15_col10, #T_e4472_row15_col11, #T_e4472_row16_col4, #T_e4472_row16_col5, #T_e4472_row16_col10, #T_e4472_row16_col11 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_e4472_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.2%, transparent 11.2%);
#   font-family: Courier;
# }
# #T_e4472_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.4%, transparent 11.4%);
#   font-family: Courier;
# }
# #T_e4472_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.3%, transparent 7.3%);
#   font-family: Courier;
# }
# #T_e4472_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.7%, transparent 7.7%);
#   font-family: Courier;
# }
# #T_e4472_row0_col8, #T_e4472_row0_col9, #T_e4472_row2_col1, #T_e4472_row3_col1, #T_e4472_row5_col0, #T_e4472_row5_col8, #T_e4472_row5_col9, #T_e4472_row6_col8, #T_e4472_row8_col0, #T_e4472_row8_col1, #T_e4472_row8_col8, #T_e4472_row8_col9, #T_e4472_row9_col0, #T_e4472_row9_col1, #T_e4472_row9_col9, #T_e4472_row10_col8, #T_e4472_row10_col9, #T_e4472_row11_col8, #T_e4472_row12_col8, #T_e4472_row12_col9, #T_e4472_row13_col8, #T_e4472_row13_col9, #T_e4472_row14_col8, #T_e4472_row14_col9, #T_e4472_row15_col8, #T_e4472_row16_col8, #T_e4472_row16_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_e4472_row1_col0, #T_e4472_row1_col1, #T_e4472_row8_col7, #T_e4472_row13_col0, #T_e4472_row13_col1, #T_e4472_row13_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_e4472_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_e4472_row1_col3, #T_e4472_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.2%, transparent 2.2%);
#   font-family: Courier;
# }
# #T_e4472_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_e4472_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_e4472_row2_col2, #T_e4472_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.9%, transparent 5.9%);
#   font-family: Courier;
# }
# #T_e4472_row2_col3, #T_e4472_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.4%, transparent 2.4%);
#   font-family: Courier;
# }
# #T_e4472_row2_col6, #T_e4472_row15_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.0%, transparent 4.0%);
#   font-family: Courier;
# }
# #T_e4472_row2_col7, #T_e4472_row3_col7, #T_e4472_row11_col7, #T_e4472_row14_col0, #T_e4472_row14_col7, #T_e4472_row15_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_e4472_row3_col2, #T_e4472_row11_col6, #T_e4472_row13_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.3%, transparent 5.3%);
#   font-family: Courier;
# }
# #T_e4472_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.8%, transparent 1.8%);
#   font-family: Courier;
# }
# #T_e4472_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.2%, transparent 4.2%);
#   font-family: Courier;
# }
# #T_e4472_row4_col0, #T_e4472_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.2%, transparent 1.2%);
#   font-family: Courier;
# }
# #T_e4472_row4_col1, #T_e4472_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.4%, transparent 3.4%);
#   font-family: Courier;
# }
# #T_e4472_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.1%, transparent 9.1%);
#   font-family: Courier;
# }
# #T_e4472_row4_col3, #T_e4472_row14_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.1%, transparent 4.1%);
#   font-family: Courier;
# }
# #T_e4472_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.0%, transparent 8.0%);
#   font-family: Courier;
# }
# #T_e4472_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.5%, transparent 1.5%);
#   font-family: Courier;
# }
# #T_e4472_row4_col8, #T_e4472_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_e4472_row5_col2, #T_e4472_row13_col2, #T_e4472_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.3%, transparent 4.3%);
#   font-family: Courier;
# }
# #T_e4472_row5_col3, #T_e4472_row9_col3, #T_e4472_row10_col3, #T_e4472_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.1%, transparent 3.1%);
#   font-family: Courier;
# }
# #T_e4472_row5_col6, #T_e4472_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.6%, transparent 3.6%);
#   font-family: Courier;
# }
# #T_e4472_row5_col7, #T_e4472_row10_col7, #T_e4472_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.3%, transparent 0.3%);
#   font-family: Courier;
# }
# #T_e4472_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.0%, transparent 6.0%);
#   font-family: Courier;
# }
# #T_e4472_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.9%, transparent 4.9%);
#   font-family: Courier;
# }
# #T_e4472_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.1%, transparent 7.1%);
#   font-family: Courier;
# }
# #T_e4472_row6_col7, #T_e4472_row9_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_e4472_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.8%, transparent 3.8%);
#   font-family: Courier;
# }
# #T_e4472_row7_col3, #T_e4472_row12_col0, #T_e4472_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.1%, transparent 1.1%);
#   font-family: Courier;
# }
# #T_e4472_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.5%, transparent 4.5%);
#   font-family: Courier;
# }
# #T_e4472_row7_col7, #T_e4472_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_e4472_row8_col2 {

# %% [markdown]
# <br>
#
# ### <a id='toc1_10_4_'></a>[Therapieangaben](#toc0_)
# - **Filter: `DJ` 2020-2024, `DCO` = N, `ICD10` != C44**
# - fiktives Rechenbeispiel für `[Bestrahlung]Anzahl_Tage_Diagnose_ST`:
#   - 5363 Bestrahlungen sind in den 01-SH Daten unter Beachtung des Filters (DCO/DJ/ICD10) für den zugeordneten Tumor
#   - davon enthalten 302 ein leeres Feld `Anzahl_Tage_Diagnose_ST` -> ~ 6%

# %% [markdown]
# #### <a id='toc1_10_4_1_'></a>[OP](#toc0_)
#
# > 💡 `ZfKD`: _Für überlieferte OP liegen `Datum_OP` und `Intention` komplett vollständig vor. Der Tagesabstand hat wenige Lücken, während `Lokale_Beurteilung_Residualstatus` auch ausserhalb von Tristan erkennbar häufiger fehlt._

# %%
_fil = """--sql
tables = 'OP' and tablecolumn not ilike '%genauigkeit'
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="80%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="80%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_038_346  (75.7%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-80% -->
# <style type="text/css">
# #T_6651f th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_6651f td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_6651f_row0_col0, #T_6651f_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.4%, transparent 1.4%);
#   font-family: Courier;
# }
# #T_6651f_row0_col1, #T_6651f_row0_col2, #T_6651f_row1_col0, #T_6651f_row1_col1, #T_6651f_row1_col2, #T_6651f_row2_col1, #T_6651f_row2_col2, #T_6651f_row3_col1, #T_6651f_row3_col2, #T_6651f_row4_col1, #T_6651f_row4_col2, #T_6651f_row5_col0, #T_6651f_row5_col1, #T_6651f_row5_col2, #T_6651f_row6_col1, #T_6651f_row6_col2, #T_6651f_row7_col1, #T_6651f_row7_col2, #T_6651f_row8_col1, #T_6651f_row8_col2, #T_6651f_row9_col1, #T_6651f_row9_col2, #T_6651f_row10_col0, #T_6651f_row10_col1, #T_6651f_row10_col2, #T_6651f_row11_col0, #T_6651f_row11_col1, #T_6651f_row11_col2, #T_6651f_row12_col0, #T_6651f_row12_col1, #T_6651f_row12_col2, #T_6651f_row13_col0, #T_6651f_row13_col1, #T_6651f_row13_col2, #T_6651f_row14_col0, #T_6651f_row14_col1, #T_6651f_row14_col2, #T_6651f_row15_col0, #T_6651f_row15_col1, #T_6651f_row15_col2, #T_6651f_row16_col1, #T_6651f_row16_col2 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_6651f_row0_col3, #T_6651f_row2_col3, #T_6651f_row3_col3, #T_6651f_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_6651f_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.1%, transparent 4.1%);
#   font-family: Courier;
# }
# #T_6651f_row2_col0, #T_6651f_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.4%, transparent 2.4%);
#   font-family: Courier;
# }
# #T_6651f_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.9%, transparent 2.9%);
#   font-family: Courier;
# }
# #T_6651f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.8%, transparent 2.8%);
#   font-family: Courier;
# }
# #T_6651f_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.9%, transparent 7.9%);
#   font-family: Courier;
# }
# #T_6651f_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.2%, transparent 10.2%);
#   font-family: Courier;
# }
# #T_6651f_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.2%, transparent 5.2%);
#   font-family: Courier;
# }
# #T_6651f_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_6651f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.3%, transparent 2.3%);
#   font-family: Courier;
# }
# #T_6651f_row7_col3, #T_6651f_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_6651f_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.8%, transparent 12.8%);
#   font-family: Courier;
# }
# #T_6651f_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.7%, transparent 10.7%);
#   font-family: Courier;
# }
# #T_6651f_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.0%, transparent 11.0%);
#   font-family: Courier;
# }
# #T_6651f_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.0%, transparent 5.0%);
#   font-family: Courier;
# }
# #T_6651f_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.8%, transparent 6.8%);
#   font-family: Courier;
# }
# #T_6651f_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.0%, transparent 17.0%);
#   font-family: Courier;
# }
# #T_6651f_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.6%, transparent 17.6%);
#   font-family: Courier;
# }
# #T_6651f_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 18.3%, transparent 18.3%);
#   font-family: Courier;
# }
# </style>
# <table id="T_6651f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_6651f_level0_col0" class="col_heading level0 col0" >[OP]Anzahl_Tage_Diagnose_OP</th>
#       <th id="T_6651f_level0_col1" class="col_heading level0 col1" >[OP]Datum_OP</th>
#       <th id="T_6651f_level0_col2" class="col_heading level0 col2" >[OP]Intention</th>
#       <th id="T_6651f_level0_col3" class="col_heading level0 col3" >[OP]Lokale_Beurteilung_Residualstatus</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6651f_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_6651f_row0_col0" class="data row0 col0" >1.4% 🟩</td>
#       <td id="T_6651f_row0_col1" class="data row0 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row0_col2" class="data row0 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row0_col3" class="data row0 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_6651f_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_6651f_row1_col0" class="data row1 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row1_col1" class="data row1 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row1_col2" class="data row1 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row1_col3" class="data row1 col3" >4.1% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6651f_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_6651f_row2_col0" class="data row2 col0" >2.4% 🟩</td>
#       <td id="T_6651f_row2_col1" class="data row2 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row2_col2" class="data row2 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row2_col3" class="data row2 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_6651f_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_6651f_row3_col0" class="data row3 col0" >2.9% 🟩</td>
#       <td id="T_6651f_row3_col1" class="data row3 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row3_col2" class="data row3 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row3_col3" class="data row3 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_6651f_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_6651f_row4_col0" class="data row4 col0" >2.8% 🟩</td>
#       <td id="T_6651f_row4_col1" class="data row4 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row4_col2" class="data row4 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row4_col3" class="data row4 col3" >7.9% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_6651f_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_6651f_row5_col0" class="data row5 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row5_col1" class="data row5 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row5_col2" class="data row5 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row5_col3" class="data row5 col3" >10.2% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_6651f_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_6651f_row6_col0" class="data row6 col0" >5.2% 🟨</td>
#       <td id="T_6651f_row6_col1" class="data row6 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row6_col2" class="data row6 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6651f_row6_col3" class="data row6 col3" >1.9% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6651f_level0_row7" class="row_heading level0 row7" >08-BW</th>
#       <td id="T_6651f_row7_col0" class="data row7 col0" >2.3% 🟩</td>
#       <td id="T_6651f_row7_col1" class="data row7 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_66
# 🟠 unknowns
# <!-- SCALE-80% -->
# <style type="text/css">
# #T_6aaff th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_6aaff td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_6aaff_row0_col0, #T_6aaff_row0_col1, #T_6aaff_row1_col0, #T_6aaff_row1_col1, #T_6aaff_row2_col0, #T_6aaff_row2_col1, #T_6aaff_row3_col0, #T_6aaff_row3_col1, #T_6aaff_row4_col0, #T_6aaff_row5_col0, #T_6aaff_row5_col3, #T_6aaff_row6_col0, #T_6aaff_row6_col1, #T_6aaff_row7_col0, #T_6aaff_row7_col1, #T_6aaff_row8_col0, #T_6aaff_row8_col3, #T_6aaff_row9_col0, #T_6aaff_row9_col1, #T_6aaff_row10_col0, #T_6aaff_row10_col3, #T_6aaff_row11_col0, #T_6aaff_row11_col1, #T_6aaff_row11_col3, #T_6aaff_row12_col0, #T_6aaff_row12_col3, #T_6aaff_row13_col0, #T_6aaff_row13_col3, #T_6aaff_row14_col0, #T_6aaff_row14_col3, #T_6aaff_row15_col0, #T_6aaff_row15_col3, #T_6aaff_row16_col0 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_6aaff_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_6aaff_row0_col3, #T_6aaff_row2_col3, #T_6aaff_row3_col3, #T_6aaff_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_6aaff_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.6%, transparent 0.6%);
#   font-family: Courier;
# }
# #T_6aaff_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_6aaff_row2_col2, #T_6aaff_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.2%, transparent 1.2%);
#   font-family: Courier;
# }
# #T_6aaff_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.6%, transparent 1.6%);
#   font-family: Courier;
# }
# #T_6aaff_row4_col1, #T_6aaff_row5_col1, #T_6aaff_row10_col1, #T_6aaff_row12_col1, #T_6aaff_row13_col1, #T_6aaff_row14_col1, #T_6aaff_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_6aaff_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.2%, transparent 3.2%);
#   font-family: Courier;
# }
# #T_6aaff_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.0%, transparent 3.0%);
#   font-family: Courier;
# }
# #T_6aaff_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.8%, transparent 1.8%);
#   font-family: Courier;
# }
# #T_6aaff_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.3%, transparent 1.3%);
#   font-family: Courier;
# }
# #T_6aaff_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.4%, transparent 1.4%);
#   font-family: Courier;
# }
# #T_6aaff_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 13.1%, transparent 13.1%);
#   font-family: Courier;
# }
# #T_6aaff_row8_col1, #T_6aaff_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_6aaff_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 13.5%, transparent 13.5%);
#   font-family: Courier;
# }
# #T_6aaff_row9_col2, #T_6aaff_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.8%, transparent 2.8%);
#   font-family: Courier;
# }
# #T_6aaff_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.3%, transparent 0.3%);
#   font-family: Courier;
# }
# #T_6aaff_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.5%, transparent 0.5%);
#   font-family: Courier;
# }
# #T_6aaff_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.1%, transparent 1.1%);
#   font-family: Courier;
# }
# #T_6aaff_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.8%, transparent 0.8%);
#   font-family: Courier;
# }
# #T_6aaff_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.0%, transparent 2.0%);
#   font-family: Courier;
# }
# #T_6aaff_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_6aaff_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.6%, transparent 3.6%);
#   font-family: Courier;
# }
# </style>
# <table id="T_6aaff">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_6aaff_level0_col0" class="col_heading level0 col0" >[OP]Anzahl_Tage_Diagnose_OP</th>
#       <th id="T_6aaff_level0_col1" class="col_heading level0 col1" >[OP]Datum_OP</th>
#       <th id="T_6aaff_level0_col2" class="col_heading level0 col2" >[OP]Intention</th>
#       <th id="T_6aaff_level0_col3" class="col_heading level0 col3" >[OP]Lokale_Beurteilung_Residualstatus</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aaff_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_6aaff_row0_col0" class="data row0 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row0_col1" class="data row0 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row0_col2" class="data row0 col2" >2.5% 🟩</td>
#       <td id="T_6aaff_row0_col3" class="data row0 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_6aaff_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_6aaff_row1_col0" class="data row1 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row1_col1" class="data row1 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row1_col2" class="data row1 col2" >0.6% 🟩</td>
#       <td id="T_6aaff_row1_col3" class="data row1 col3" >0.4% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aaff_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_6aaff_row2_col0" class="data row2 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row2_col1" class="data row2 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row2_col2" class="data row2 col2" >1.2% 🟩</td>
#       <td id="T_6aaff_row2_col3" class="data row2 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_6aaff_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_6aaff_row3_col0" class="data row3 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row3_col1" class="data row3 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row3_col2" class="data row3 col2" >1.6% 🟩</td>
#       <td id="T_6aaff_row3_col3" class="data row3 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_6aaff_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_6aaff_row4_col0" class="data row4 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row4_col1" class="data row4 col1" >0.0% 🟩</td>
#       <td id="T_6aaff_row4_col2" class="data row4 col2" >3.2% 🟩</td>
#       <td id="T_6aaff_row4_col3" class="data row4 col3" >3.0% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aaff_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_6aaff_row5_col0" class="data row5 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row5_col1" class="data row5 col1" >0.0% 🟩</td>
#       <td id="T_6aaff_row5_col2" class="data row5 col2" >1.8% 🟩</td>
#       <td id="T_6aaff_row5_col3" class="data row5 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_6aaff_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_6aaff_row6_col0" class="data row6 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row6_col1" class="data row6 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6aaff_row6_col2" class="data row6 col2" >1.3% 🟩</td>
#       <td id="T_6aaff_row6_col3" class="data row6 col3" >1.4% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_6aaff_level0_row7" class="

# %% [markdown]
# #### <a id='toc1_10_4_2_'></a>[ST](#toc0_)
#
# > 💡 `ZfKD`: _`Datum_Beginn_Bestrahlung` und `Intention` sind nahezu komplett verfügbar in den dokumentierten ST / Bestrahlungen, mit Abstrichen auch `Anzahl_Tage_Diagnose_ST`._
# > _`Anzahl_Tage_ST_Dauer` und `Stellung_OP` fehlen bei Tristan_
# > _`Applikationsart` wird nicht von allen kkr übermittelt, davon abgesehen ist `Seite_Zielgebiet` zuverlässig angegeben, die CodeVersionen ergänzen sich, wobei `2014` deutlich häufiger angewendet wird als `2021`._

# %%
_fil = """--sql
        tablecolumn not ilike '%genauigkeit'
        and (
            tables in ('ST', 'Bestrahlung')
            or regexp_matches(tablecolumn,'codeversion|zielgebiet','i')
)"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_038_346  (75.7%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_b2c0a th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_b2c0a td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_b2c0a_row0_col0, #T_b2c0a_row0_col1, #T_b2c0a_row0_col2, #T_b2c0a_row0_col3, #T_b2c0a_row0_col7, #T_b2c0a_row2_col0, #T_b2c0a_row2_col1, #T_b2c0a_row2_col2, #T_b2c0a_row2_col3, #T_b2c0a_row2_col7, #T_b2c0a_row3_col0, #T_b2c0a_row3_col1, #T_b2c0a_row3_col2, #T_b2c0a_row3_col3, #T_b2c0a_row3_col7, #T_b2c0a_row4_col0, #T_b2c0a_row4_col4, #T_b2c0a_row9_col0, #T_b2c0a_row9_col1, #T_b2c0a_row9_col2, #T_b2c0a_row9_col3, #T_b2c0a_row9_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_b2c0a_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.9%, transparent 3.9%);
#   font-family: Courier;
# }
# #T_b2c0a_row0_col5, #T_b2c0a_row0_col6, #T_b2c0a_row1_col4, #T_b2c0a_row1_col5, #T_b2c0a_row1_col6, #T_b2c0a_row2_col5, #T_b2c0a_row3_col5, #T_b2c0a_row4_col1, #T_b2c0a_row4_col5, #T_b2c0a_row5_col4, #T_b2c0a_row5_col5, #T_b2c0a_row6_col2, #T_b2c0a_row6_col5, #T_b2c0a_row7_col5, #T_b2c0a_row7_col6, #T_b2c0a_row7_col7, #T_b2c0a_row8_col5, #T_b2c0a_row9_col5, #T_b2c0a_row9_col6, #T_b2c0a_row13_col4, #T_b2c0a_row13_col5, #T_b2c0a_row14_col5, #T_b2c0a_row15_col4, #T_b2c0a_row15_col5 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_b2c0a_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.9%, transparent 56.9%);
#   font-family: Courier;
# }
# #T_b2c0a_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 43.1%, transparent 43.1%);
#   font-family: Courier;
# }
# #T_b2c0a_row1_col2, #T_b2c0a_row1_col7, #T_b2c0a_row3_col6, #T_b2c0a_row4_col6, #T_b2c0a_row5_col2, #T_b2c0a_row6_col6, #T_b2c0a_row7_col3, #T_b2c0a_row10_col2, #T_b2c0a_row10_col4, #T_b2c0a_row10_col5, #T_b2c0a_row10_col7, #T_b2c0a_row11_col2, #T_b2c0a_row11_col4, #T_b2c0a_row11_col5, #T_b2c0a_row11_col7, #T_b2c0a_row12_col2, #T_b2c0a_row12_col3, #T_b2c0a_row12_col5, #T_b2c0a_row12_col6, #T_b2c0a_row13_col6, #T_b2c0a_row13_col7, #T_b2c0a_row14_col2, #T_b2c0a_row14_col4, #T_b2c0a_row14_col6, #T_b2c0a_row14_col7, #T_b2c0a_row16_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_b2c0a_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_b2c0a_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.4%, transparent 5.4%);
#   font-family: Courier;
# }
# #T_b2c0a_row2_col6, #T_b2c0a_row10_col6, #T_b2c0a_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.3%, transparent 0.3%);
#   font-family: Courier;
# }
# #T_b2c0a_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.2%, transparent 6.2%);
#   font-family: Courier;
# }
# #T_b2c0a_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_b2c0a_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.5%, transparent 8.5%);
#   font-family: Courier;
# }
# #T_b2c0a_row4_col7, #T_b2c0a_row15_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_b2c0a_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.8%, transparent 20.8%);
#   font-family: Courier;
# }
# #T_b2c0a_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.3%, transparent 79.3%);
#   font-family: Courier;
# }
# #T_b2c0a_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.6%, transparent 4.6%);
#   font-family: Courier;
# }
# #T_b2c0a_row5_col6, #T_b2c0a_row7_col4, #T_b2c0a_row8_col4, #T_b2c0a_row11_col6, #T_b2c0a_row12_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_b2c0a_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.6%, transparent 0.6%);
#   font-family: Courier;
# }
# #T_b2c0a_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 36.9%, transparent 36.9%);
#   font-family: Courier;
# }
# #T_b2c0a_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.1%, transparent 63.1%);
#   font-family: Courier;
# }
# #T_b2c0a_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.7%, transparent 14.7%);
#   font-family: Courier;
# }
# #T_b2c0a_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.1%, transparent 9.1%);
#   font-family: Courier;
# }
# #T_b2c0a_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_b2c0a_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 36.8%, transparent 36.8%);
#   font-family: Courier;
# }
# #T_b2c0a_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.3%, transparent 64.3%);
#   font-family: Courier;
# }
# #T_b2c0a_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.1%, transparent 1.1%);
#   font-family: Courier;
# }
# #T_b2c0a_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.5%, transparent 25.5%);
#   font-family: Courier;
# }
# #T_b2c0a_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 76.4%, transparent 76.4%);
#   font-family: Courier;
# }
# #T_b2c0a_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_b2c0a_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.6%, transparent 3.6%);
#   font-family: Courier;
# }
# #T_b2c0a_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.6%, transparent 2.6%);
#   font-family: Courier;
# }
# #T_b2c0a_row8_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.8%, transparent 2.8%);
#   font-family: Courier;
# }
# #T_b2c0a_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.8%, transparent 4.8%);
#   font-family: Courier;
# }
# #T_b2c0a_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 30.7%, transparent 30.7%);
#   font-family: Courier;
# }
# #T_b2c0a_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 69.7%, transparent 69.7%);
#   font-family: Courier;
# }
# #T_b2c0a_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.4%, transparent 1.4%);
#   font-family: Courier;
# }
# #T_b2c0a_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.3%, transparent 27.3%);
#   font-family: Courier;
# }
# #T_b2c0a_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.8%, transparent 72.8%);
#   font-family: Courier;
# }
# #T_b2c0a_row11_col3, #T_b2c0a_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.3%, transparent 1.3%);
#   font-family: Courier;
# }
# #T_b2c0a_row12_col0, #T_b2c0a_row13_col2, #T_b2c0a_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_b2c0a_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.7%, transparent 99.7%);
#   font-family: Courier;
# }
# #T_b2c0a_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_b2c0a_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.2%, transparent 52.2%);
#   font-family: Courier;
# }
# #T_b2c0a_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.2%, transparent 48.2%);
#   font-family: Courier;
# }
# #T_b2c0a_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 35.5%, transparent 35.5%);
#   font-family: Courier;
# }
# #T_b2c0a_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.5%, transparent 64.5%);
#   font-family: Courier;
# }
# #T_b2c0a_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 38.9%, transparent 38.9%);
#   font-family: Courier;
# }
# #T_b2c0a_row15_col1 {
#   width: 10em;
#   background: linear-
# 🟠 unknowns
# <style type="text/css">
# #T_6715a th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_6715a td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_6715a_row0_col0, #T_6715a_row0_col1, #T_6715a_row0_col2, #T_6715a_row0_col3, #T_6715a_row0_col7, #T_6715a_row2_col0, #T_6715a_row2_col1, #T_6715a_row2_col2, #T_6715a_row2_col3, #T_6715a_row2_col7, #T_6715a_row3_col0, #T_6715a_row3_col1, #T_6715a_row3_col2, #T_6715a_row3_col3, #T_6715a_row3_col7, #T_6715a_row4_col0, #T_6715a_row4_col4, #T_6715a_row9_col0, #T_6715a_row9_col1, #T_6715a_row9_col2, #T_6715a_row9_col3, #T_6715a_row9_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_6715a_row0_col4, #T_6715a_row0_col5, #T_6715a_row1_col0, #T_6715a_row1_col1, #T_6715a_row1_col3, #T_6715a_row1_col4, #T_6715a_row1_col5, #T_6715a_row1_col7, #T_6715a_row2_col4, #T_6715a_row2_col5, #T_6715a_row3_col4, #T_6715a_row3_col5, #T_6715a_row4_col1, #T_6715a_row4_col3, #T_6715a_row4_col7, #T_6715a_row5_col0, #T_6715a_row5_col1, #T_6715a_row5_col3, #T_6715a_row5_col4, #T_6715a_row5_col7, #T_6715a_row6_col0, #T_6715a_row6_col1, #T_6715a_row6_col3, #T_6715a_row6_col4, #T_6715a_row6_col5, #T_6715a_row6_col7, #T_6715a_row7_col0, #T_6715a_row7_col1, #T_6715a_row7_col3, #T_6715a_row7_col4, #T_6715a_row7_col5, #T_6715a_row7_col7, #T_6715a_row8_col0, #T_6715a_row8_col1, #T_6715a_row8_col3, #T_6715a_row8_col4, #T_6715a_row8_col7, #T_6715a_row9_col4, #T_6715a_row9_col5, #T_6715a_row10_col0, #T_6715a_row10_col1, #T_6715a_row10_col3, #T_6715a_row10_col4, #T_6715a_row10_col5, #T_6715a_row10_col7, #T_6715a_row11_col0, #T_6715a_row11_col1, #T_6715a_row11_col3, #T_6715a_row11_col4, #T_6715a_row11_col5, #T_6715a_row11_col7, #T_6715a_row12_col0, #T_6715a_row12_col1, #T_6715a_row12_col3, #T_6715a_row12_col4, #T_6715a_row12_col7, #T_6715a_row13_col0, #T_6715a_row13_col1, #T_6715a_row13_col3, #T_6715a_row13_col4, #T_6715a_row13_col7, #T_6715a_row14_col0, #T_6715a_row14_col1, #T_6715a_row14_col3, #T_6715a_row14_col4, #T_6715a_row14_col7, #T_6715a_row15_col0, #T_6715a_row15_col1, #T_6715a_row15_col3, #T_6715a_row15_col4, #T_6715a_row15_col7, #T_6715a_row16_col0, #T_6715a_row16_col1, #T_6715a_row16_col3, #T_6715a_row16_col4, #T_6715a_row16_col7 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_6715a_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.5%, transparent 0.5%);
#   font-family: Courier;
# }
# #T_6715a_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.6%, transparent 12.6%);
#   font-family: Courier;
# }
# #T_6715a_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_6715a_row2_col6, #T_6715a_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_6715a_row3_col6, #T_6715a_row11_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.6%, transparent 0.6%);
#   font-family: Courier;
# }
# #T_6715a_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 28.0%, transparent 28.0%);
#   font-family: Courier;
# }
# #T_6715a_row4_col5, #T_6715a_row5_col5, #T_6715a_row12_col5, #T_6715a_row13_col5, #T_6715a_row14_col5, #T_6715a_row15_col5, #T_6715a_row16_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_6715a_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.5%, transparent 17.5%);
#   font-family: Courier;
# }
# #T_6715a_row5_col6, #T_6715a_row15_col6, #T_6715a_row16_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.3%, transparent 1.3%);
#   font-family: Courier;
# }
# #T_6715a_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.2%, transparent 7.2%);
#   font-family: Courier;
# }
# #T_6715a_row6_col6, #T_6715a_row14_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_6715a_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.0%, transparent 21.0%);
#   font-family: Courier;
# }
# #T_6715a_row7_col6, #T_6715a_row10_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.8%, transparent 0.8%);
#   font-family: Courier;
# }
# #T_6715a_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.0%, transparent 15.0%);
#   font-family: Courier;
# }
# #T_6715a_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_6715a_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.1%, transparent 1.1%);
#   font-family: Courier;
# }
# #T_6715a_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.2%, transparent 6.2%);
#   font-family: Courier;
# }
# #T_6715a_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.4%, transparent 26.4%);
#   font-family: Courier;
# }
# #T_6715a_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.2%, transparent 27.2%);
#   font-family: Courier;
# }
# #T_6715a_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.6%, transparent 20.6%);
#   font-family: Courier;
# }
# #T_6715a_row12_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_6715a_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.8%, transparent 20.8%);
#   font-family: Courier;
# }
# #T_6715a_row13_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.4%, transparent 2.4%);
#   font-family: Courier;
# }
# #T_6715a_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.2%, transparent 17.2%);
#   font-family: Courier;
# }
# #T_6715a_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.9%, transparent 31.9%);
#   font-family: Courier;
# }
# #T_6715a_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.2%, transparent 20.2%);
#   font-family: Courier;
# }
# </style>
# <table id="T_6715a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_6715a_level0_col0" class="col_heading level0 col0" >[Applikationsart]CodeVersion2014</th>
#       <th id="T_6715a_level0_col1" class="col_heading level0 col1" >[Applikationsart]CodeVersion2021</th>
#       <th id="T_6715a_level0_col2" class="col_heading level0 col2" >[Applikationsart]Seite_Zielgebiet</th>
#       <th id="T_6715a_level0_col3" class="col_heading level0 col3" >[Bestrahlung]Anzahl_Tage_Bestrahlung_Dauer</th>
#       <th id="T_6715a_level0_col4" class="col_heading level0 col4" >[Bestrahlung]Anzahl_Tage_Diagnose_Bestrahlung</th>
#       <th id="T_6715a_level0_col5" class="col_heading level0 col5" >[Bestrahlung]Datum_Beginn_Bestrahlung</th>
#       <th id="T_6715a_level0_col6" class="col_heading level0 col6" >[ST]Intention</th>
#       <th id="T_6715a_level0_col7" class="col_heading level0 col7" >[ST]Stellung_OP</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6715a_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_6715a_row0_col0" class="data row0 col0" >100.0% 🟥</td>
#       <td id="T_6715a_row0_col1" class="data row0 col1" >100.0% 🟥</td>
#       <td id="T_6715a_row0_col2" class="data row0 col2" >100.0% 🟥</td>
#       <td id="T_6715a_row0_col3" class="data row0 col3" >100.0% 🟥</td>
#       <td id="T_6715a_row0_col4" class="data row0 col4" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6715a_row0_col5" class="data row0 col5" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_6715a_row0_col6" class="data row

# %% [markdown]
# #### <a id='toc1_10_4_3_'></a>[SYST](#toc0_)
#
# > 💡 `ZfKD`: _Die meisten Angaben im SYST Element liegen komplett vor. `Anzahl_Tage_SYST_Dauer` fehlt häufig, was auch an noch nicht abgeschlossenen Therapien liegen könnte - wohingegen `08-BW` hier als einzige keine missings ausweisen._

# %%
_fil = """--sql
tables in ('SYST') and tablecolumn not ilike '%genauigkeit'
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_038_346  (75.7%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_782fc th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_782fc td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_782fc_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.1%, transparent 9.1%);
#   font-family: Courier;
# }
# #T_782fc_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.6%, transparent 59.6%);
#   font-family: Courier;
# }
# #T_782fc_row0_col2, #T_782fc_row0_col3, #T_782fc_row0_col4, #T_782fc_row0_col5, #T_782fc_row1_col0, #T_782fc_row1_col2, #T_782fc_row1_col3, #T_782fc_row1_col4, #T_782fc_row1_col5, #T_782fc_row2_col2, #T_782fc_row2_col3, #T_782fc_row2_col4, #T_782fc_row2_col5, #T_782fc_row3_col2, #T_782fc_row3_col3, #T_782fc_row3_col4, #T_782fc_row3_col5, #T_782fc_row4_col2, #T_782fc_row4_col3, #T_782fc_row4_col4, #T_782fc_row4_col5, #T_782fc_row5_col0, #T_782fc_row5_col2, #T_782fc_row5_col3, #T_782fc_row5_col4, #T_782fc_row5_col5, #T_782fc_row6_col2, #T_782fc_row6_col3, #T_782fc_row6_col4, #T_782fc_row6_col5, #T_782fc_row7_col2, #T_782fc_row7_col3, #T_782fc_row7_col4, #T_782fc_row7_col5, #T_782fc_row8_col2, #T_782fc_row8_col3, #T_782fc_row8_col4, #T_782fc_row8_col5, #T_782fc_row9_col2, #T_782fc_row9_col3, #T_782fc_row9_col4, #T_782fc_row9_col5, #T_782fc_row10_col2, #T_782fc_row10_col3, #T_782fc_row10_col4, #T_782fc_row10_col5, #T_782fc_row11_col2, #T_782fc_row11_col3, #T_782fc_row11_col4, #T_782fc_row11_col5, #T_782fc_row12_col2, #T_782fc_row12_col3, #T_782fc_row12_col4, #T_782fc_row12_col5, #T_782fc_row13_col0, #T_782fc_row13_col2, #T_782fc_row13_col3, #T_782fc_row13_col4, #T_782fc_row13_col5, #T_782fc_row14_col0, #T_782fc_row14_col2, #T_782fc_row14_col3, #T_782fc_row14_col4, #T_782fc_row14_col5, #T_782fc_row15_col2, #T_782fc_row15_col3, #T_782fc_row15_col4, #T_782fc_row15_col5, #T_782fc_row16_col2, #T_782fc_row16_col3, #T_782fc_row16_col4, #T_782fc_row16_col5 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_782fc_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.0%, transparent 48.0%);
#   font-family: Courier;
# }
# #T_782fc_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.0%, transparent 15.0%);
#   font-family: Courier;
# }
# #T_782fc_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.2%, transparent 72.2%);
#   font-family: Courier;
# }
# #T_782fc_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.8%, transparent 22.8%);
#   font-family: Courier;
# }
# #T_782fc_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 61.3%, transparent 61.3%);
#   font-family: Courier;
# }
# #T_782fc_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.7%, transparent 1.7%);
#   font-family: Courier;
# }
# #T_782fc_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 74.1%, transparent 74.1%);
#   font-family: Courier;
# }
# #T_782fc_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.9%, transparent 60.9%);
#   font-family: Courier;
# }
# #T_782fc_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 26.9%, transparent 26.9%);
#   font-family: Courier;
# }
# #T_782fc_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_782fc_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.5%, transparent 0.5%);
#   font-family: Courier;
# }
# #T_782fc_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.6%, transparent 58.6%);
#   font-family: Courier;
# }
# #T_782fc_row8_col0, #T_782fc_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_782fc_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.1%, transparent 71.1%);
#   font-family: Courier;
# }
# #T_782fc_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.9%, transparent 25.9%);
#   font-family: Courier;
# }
# #T_782fc_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.2%, transparent 82.2%);
#   font-family: Courier;
# }
# #T_782fc_row10_col0, #T_782fc_row11_col0, #T_782fc_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_782fc_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.3%, transparent 54.3%);
#   font-family: Courier;
# }
# #T_782fc_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.0%, transparent 68.0%);
#   font-family: Courier;
# }
# #T_782fc_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.0%, transparent 63.0%);
#   font-family: Courier;
# }
# #T_782fc_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.6%, transparent 56.6%);
#   font-family: Courier;
# }
# #T_782fc_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 67.8%, transparent 67.8%);
#   font-family: Courier;
# }
# #T_782fc_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 62.2%, transparent 62.2%);
#   font-family: Courier;
# }
# #T_782fc_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.7%, transparent 3.7%);
#   font-family: Courier;
# }
# #T_782fc_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.7%, transparent 66.7%);
#   font-family: Courier;
# }
# </style>
# <table id="T_782fc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_782fc_level0_col0" class="col_heading level0 col0" >[SYST]Anzahl_Tage_Diagnose_SYST</th>
#       <th id="T_782fc_level0_col1" class="col_heading level0 col1" >[SYST]Anzahl_Tage_SYST_Dauer</th>
#       <th id="T_782fc_level0_col2" class="col_heading level0 col2" >[SYST]Datum_Beginn_SYST</th>
#       <th id="T_782fc_level0_col3" class="col_heading level0 col3" >[SYST]Intention</th>
#       <th id="T_782fc_level0_col4" class="col_heading level0 col4" >[SYST]Stellung_OP</th>
#       <th id="T_782fc_level0_col5" class="col_heading level0 col5" >[SYST]Therapieart</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_782fc_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_782fc_row0_col0" class="data row0 col0" >5.4% 🟨</td>
#       <td id="T_782fc_row0_col1" class="data row0 col1" >35.2% 🟨</td>
#       <td id="T_782fc_row0_col2" class="data row0 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_782fc_row0_col3" class="data row0 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_782fc_row0_col4" class="data row0 col4" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_782fc_row0_col5" class="data row0 col5" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_782fc_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_782fc_row1_col0" class="data row1 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_782fc_row1_col1" class="data row1 col1" >28.4% 🟨</td>
#       <td id="T_782fc_row1_col2" class="data row1 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_782fc_row1_col3" class="data row1 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_782fc_row1_col4" class="data row1 col4" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_782fc_row1_col5" class="data row1 col5" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_782fc_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_782fc_row2_col0" class="data row2 col0" >8.9% 🟨</td>
#       <td id="T_782fc_row2_col1" class="data row2 col1" >42.6% 🟨</td>
#       <td id="T_782fc_row2_col2" class="data row2 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
# 🟠 unknowns
# <style type="text/css">
# #T_27a5d th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_27a5d td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_27a5d_row0_col0, #T_27a5d_row0_col1, #T_27a5d_row0_col2, #T_27a5d_row0_col4, #T_27a5d_row0_col5, #T_27a5d_row1_col0, #T_27a5d_row1_col1, #T_27a5d_row1_col2, #T_27a5d_row1_col4, #T_27a5d_row1_col5, #T_27a5d_row2_col0, #T_27a5d_row2_col1, #T_27a5d_row2_col4, #T_27a5d_row2_col5, #T_27a5d_row3_col0, #T_27a5d_row3_col1, #T_27a5d_row3_col4, #T_27a5d_row3_col5, #T_27a5d_row4_col0, #T_27a5d_row4_col1, #T_27a5d_row4_col4, #T_27a5d_row4_col5, #T_27a5d_row5_col0, #T_27a5d_row5_col1, #T_27a5d_row5_col4, #T_27a5d_row5_col5, #T_27a5d_row6_col0, #T_27a5d_row6_col1, #T_27a5d_row6_col4, #T_27a5d_row6_col5, #T_27a5d_row7_col0, #T_27a5d_row7_col1, #T_27a5d_row7_col2, #T_27a5d_row7_col4, #T_27a5d_row7_col5, #T_27a5d_row8_col0, #T_27a5d_row8_col1, #T_27a5d_row8_col4, #T_27a5d_row8_col5, #T_27a5d_row9_col0, #T_27a5d_row9_col1, #T_27a5d_row9_col2, #T_27a5d_row9_col4, #T_27a5d_row9_col5, #T_27a5d_row10_col0, #T_27a5d_row10_col1, #T_27a5d_row10_col4, #T_27a5d_row10_col5, #T_27a5d_row11_col0, #T_27a5d_row11_col1, #T_27a5d_row11_col4, #T_27a5d_row11_col5, #T_27a5d_row12_col0, #T_27a5d_row12_col1, #T_27a5d_row12_col4, #T_27a5d_row12_col5, #T_27a5d_row13_col0, #T_27a5d_row13_col1, #T_27a5d_row13_col4, #T_27a5d_row13_col5, #T_27a5d_row14_col0, #T_27a5d_row14_col1, #T_27a5d_row14_col4, #T_27a5d_row14_col5, #T_27a5d_row15_col0, #T_27a5d_row15_col1, #T_27a5d_row15_col4, #T_27a5d_row15_col5, #T_27a5d_row16_col0, #T_27a5d_row16_col1, #T_27a5d_row16_col4, #T_27a5d_row16_col5 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_27a5d_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_27a5d_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.0%, transparent 8.0%);
#   font-family: Courier;
# }
# #T_27a5d_row2_col2, #T_27a5d_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_27a5d_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.6%, transparent 34.6%);
#   font-family: Courier;
# }
# #T_27a5d_row3_col2, #T_27a5d_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_27a5d_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.6%, transparent 15.6%);
#   font-family: Courier;
# }
# #T_27a5d_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.8%, transparent 4.8%);
#   font-family: Courier;
# }
# #T_27a5d_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.2%, transparent 56.2%);
#   font-family: Courier;
# }
# #T_27a5d_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.1%, transparent 29.1%);
#   font-family: Courier;
# }
# #T_27a5d_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.8%, transparent 29.8%);
#   font-family: Courier;
# }
# #T_27a5d_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 39.0%, transparent 39.0%);
#   font-family: Courier;
# }
# #T_27a5d_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.6%, transparent 5.6%);
#   font-family: Courier;
# }
# #T_27a5d_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.5%, transparent 82.5%);
#   font-family: Courier;
# }
# #T_27a5d_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.3%, transparent 98.3%);
#   font-family: Courier;
# }
# #T_27a5d_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_27a5d_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.7%, transparent 14.7%);
#   font-family: Courier;
# }
# #T_27a5d_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.5%, transparent 0.5%);
#   font-family: Courier;
# }
# #T_27a5d_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.4%, transparent 32.4%);
#   font-family: Courier;
# }
# #T_27a5d_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.1%, transparent 1.1%);
#   font-family: Courier;
# }
# #T_27a5d_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.6%, transparent 9.6%);
#   font-family: Courier;
# }
# #T_27a5d_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.3%, transparent 3.3%);
#   font-family: Courier;
# }
# #T_27a5d_row13_col3, #T_27a5d_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 46.8%, transparent 46.8%);
#   font-family: Courier;
# }
# #T_27a5d_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.6%, transparent 8.6%);
#   font-family: Courier;
# }
# #T_27a5d_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 16.2%, transparent 16.2%);
#   font-family: Courier;
# }
# #T_27a5d_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.3%, transparent 2.3%);
#   font-family: Courier;
# }
# #T_27a5d_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 19.0%, transparent 19.0%);
#   font-family: Courier;
# }
# #T_27a5d_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.4%, transparent 2.4%);
#   font-family: Courier;
# }
# </style>
# <table id="T_27a5d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_27a5d_level0_col0" class="col_heading level0 col0" >[SYST]Anzahl_Tage_Diagnose_SYST</th>
#       <th id="T_27a5d_level0_col1" class="col_heading level0 col1" >[SYST]Anzahl_Tage_SYST_Dauer</th>
#       <th id="T_27a5d_level0_col2" class="col_heading level0 col2" >[SYST]Datum_Beginn_SYST</th>
#       <th id="T_27a5d_level0_col3" class="col_heading level0 col3" >[SYST]Intention</th>
#       <th id="T_27a5d_level0_col4" class="col_heading level0 col4" >[SYST]Stellung_OP</th>
#       <th id="T_27a5d_level0_col5" class="col_heading level0 col5" >[SYST]Therapieart</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27a5d_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_27a5d_row0_col0" class="data row0 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row0_col1" class="data row0 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row0_col2" class="data row0 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row0_col3" class="data row0 col3" >8.3% 🟨</td>
#       <td id="T_27a5d_row0_col4" class="data row0 col4" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row0_col5" class="data row0 col5" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_27a5d_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_27a5d_row1_col0" class="data row1 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row1_col1" class="data row1 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row1_col2" class="data row1 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row1_col3" class="data row1 col3" >0.7% 🟩</td>
#       <td id="T_27a5d_row1_col4" class="data row1 col4" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row1_col5" class="data row1 col5" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_27a5d_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_27a5d_row2_col0" class="data row2 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5d_row2_col1" class="data row2 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_27a5

# %% [markdown]
# ### <a id='toc1_10_5_'></a>[Folgeereignisse](#toc0_)
#
# > 💡 `ZfKD`: _`Datum_Folgeereignis` und `Gesamtbeurteilung_Tumorstatus` liegen komplett vor, die anderen Angaben zum Tumorstatus allerdings nicht. Angaben für `Folgeereignis_TNM` fehlen ganz überwiegend, auch wenn Folgereignisse keine TNM enthalten müssen. Die Erkennung von Rezidiven ist so deutlich erschwert._

# %%
_fil = """--sql
tablecolumn not ilike '%genauigkeit' and sel11_fo
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_038_346  (75.7%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_c6e41 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_c6e41 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_c6e41_row0_col0, #T_c6e41_row0_col1, #T_c6e41_row1_col0, #T_c6e41_row1_col1, #T_c6e41_row2_col0, #T_c6e41_row2_col1, #T_c6e41_row3_col0, #T_c6e41_row3_col1, #T_c6e41_row4_col0, #T_c6e41_row4_col1, #T_c6e41_row5_col0, #T_c6e41_row5_col1, #T_c6e41_row6_col0, #T_c6e41_row6_col1, #T_c6e41_row6_col2, #T_c6e41_row6_col4, #T_c6e41_row7_col0, #T_c6e41_row7_col1, #T_c6e41_row7_col2, #T_c6e41_row7_col3, #T_c6e41_row7_col4, #T_c6e41_row8_col0, #T_c6e41_row8_col1, #T_c6e41_row9_col0, #T_c6e41_row9_col1, #T_c6e41_row10_col0, #T_c6e41_row10_col1, #T_c6e41_row11_col0, #T_c6e41_row11_col1, #T_c6e41_row12_col0, #T_c6e41_row12_col1, #T_c6e41_row13_col0, #T_c6e41_row13_col1, #T_c6e41_row14_col0, #T_c6e41_row14_col1, #T_c6e41_row15_col0, #T_c6e41_row15_col1, #T_c6e41_row16_col0, #T_c6e41_row16_col1 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_c6e41_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.1%, transparent 48.1%);
#   font-family: Courier;
# }
# #T_c6e41_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.6%, transparent 47.6%);
#   font-family: Courier;
# }
# #T_c6e41_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.8%, transparent 81.8%);
#   font-family: Courier;
# }
# #T_c6e41_row0_col5, #T_c6e41_row0_col6, #T_c6e41_row0_col7, #T_c6e41_row0_col8, #T_c6e41_row1_col6, #T_c6e41_row1_col7, #T_c6e41_row1_col8, #T_c6e41_row2_col5, #T_c6e41_row2_col6, #T_c6e41_row2_col7, #T_c6e41_row2_col8, #T_c6e41_row3_col5, #T_c6e41_row3_col6, #T_c6e41_row3_col7, #T_c6e41_row3_col8, #T_c6e41_row4_col6, #T_c6e41_row6_col7, #T_c6e41_row6_col8, #T_c6e41_row9_col5, #T_c6e41_row9_col6, #T_c6e41_row9_col7, #T_c6e41_row9_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_c6e41_row1_col2, #T_c6e41_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.6%, transparent 57.6%);
#   font-family: Courier;
# }
# #T_c6e41_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.9%, transparent 57.9%);
#   font-family: Courier;
# }
# #T_c6e41_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.8%, transparent 52.8%);
#   font-family: Courier;
# }
# #T_c6e41_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.0%, transparent 56.0%);
#   font-family: Courier;
# }
# #T_c6e41_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.3%, transparent 54.3%);
#   font-family: Courier;
# }
# #T_c6e41_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 84.2%, transparent 84.2%);
#   font-family: Courier;
# }
# #T_c6e41_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.4%, transparent 53.4%);
#   font-family: Courier;
# }
# #T_c6e41_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.7%, transparent 52.7%);
#   font-family: Courier;
# }
# #T_c6e41_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.2%, transparent 82.2%);
#   font-family: Courier;
# }
# #T_c6e41_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.4%, transparent 22.4%);
#   font-family: Courier;
# }
# #T_c6e41_row4_col3, #T_c6e41_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 23.5%, transparent 23.5%);
#   font-family: Courier;
# }
# #T_c6e41_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 24.2%, transparent 24.2%);
#   font-family: Courier;
# }
# #T_c6e41_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 93.0%, transparent 93.0%);
#   font-family: Courier;
# }
# #T_c6e41_row4_col7, #T_c6e41_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.2%, transparent 99.2%);
#   font-family: Courier;
# }
# #T_c6e41_row4_col8, #T_c6e41_row15_col7, #T_c6e41_row15_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.3%, transparent 99.3%);
#   font-family: Courier;
# }
# #T_c6e41_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 30.5%, transparent 30.5%);
#   font-family: Courier;
# }
# #T_c6e41_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.5%, transparent 32.5%);
#   font-family: Courier;
# }
# #T_c6e41_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 35.6%, transparent 35.6%);
#   font-family: Courier;
# }
# #T_c6e41_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 89.2%, transparent 89.2%);
#   font-family: Courier;
# }
# #T_c6e41_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 95.6%, transparent 95.6%);
#   font-family: Courier;
# }
# #T_c6e41_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.5%, transparent 98.5%);
#   font-family: Courier;
# }
# #T_c6e41_row5_col8, #T_c6e41_row8_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.9%, transparent 98.9%);
#   font-family: Courier;
# }
# #T_c6e41_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.1%, transparent 6.1%);
#   font-family: Courier;
# }
# #T_c6e41_row6_col5, #T_c6e41_row11_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.2%, transparent 98.2%);
#   font-family: Courier;
# }
# #T_c6e41_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.4%, transparent 98.4%);
#   font-family: Courier;
# }
# #T_c6e41_row7_col6, #T_c6e41_row14_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.0%, transparent 99.0%);
#   font-family: Courier;
# }
# #T_c6e41_row7_col7, #T_c6e41_row12_col7, #T_c6e41_row13_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.1%, transparent 99.1%);
#   font-family: Courier;
# }
# #T_c6e41_row7_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.8%, transparent 99.8%);
#   font-family: Courier;
# }
# #T_c6e41_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.7%, transparent 34.7%);
#   font-family: Courier;
# }
# #T_c6e41_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 37.0%, transparent 37.0%);
#   font-family: Courier;
# }
# #T_c6e41_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 41.5%, transparent 41.5%);
#   font-family: Courier;
# }
# #T_c6e41_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.4%, transparent 82.4%);
#   font-family: Courier;
# }
# #T_c6e41_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 88.4%, transparent 88.4%);
#   font-family: Courier;
# }
# #T_c6e41_row8_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 96.7%, transparent 96.7%);
#   font-family: Courier;
# }
# #T_c6e41_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.3%, transparent 60.3%);
#   font-family: Courier;
# }
# #T_c6e41_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 47.2%, transparent 47.2%);
#   font-family: Courier;
# }
# #T_c6e41_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.6%, transparent 85.6%);
#   font-family: Courier;
# }
# #T_c6e41_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.2%, transparent 31.2%);
#   font-family: Courier;
# }
# #T_c6e41_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.5%, transparent 29.5%);
#   font-family: Courier;
# }
# #T_c6e41_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 35.4%, transparent 35.4%);
#   font-family: Courier;
# }
# #T_c6e41_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.0%, transparent 79.0%);
#   font-family: Courier;
# }
# #T_c6e41_row10_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 93.2%, transparent 93.2%);
#   font-family: Courier;
# }
# #T_c6e41_row10_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 97.4%, transparent 97.4%);
#   font-family: Courier;
# }
# #T_c6e41_row10_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 97.1%, transpar
# 🟠 unknowns
# <style type="text/css">
# #T_c85de th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_c85de td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_c85de_row0_col0, #T_c85de_row0_col1, #T_c85de_row0_col2, #T_c85de_row0_col3, #T_c85de_row0_col4, #T_c85de_row2_col0, #T_c85de_row2_col1, #T_c85de_row2_col2, #T_c85de_row2_col3, #T_c85de_row2_col4, #T_c85de_row3_col0, #T_c85de_row3_col1, #T_c85de_row3_col2, #T_c85de_row3_col3, #T_c85de_row3_col4, #T_c85de_row4_col7, #T_c85de_row4_col8, #T_c85de_row5_col7, #T_c85de_row5_col8, #T_c85de_row6_col8, #T_c85de_row7_col0, #T_c85de_row7_col6, #T_c85de_row7_col7, #T_c85de_row7_col8, #T_c85de_row8_col7, #T_c85de_row8_col8, #T_c85de_row9_col0, #T_c85de_row9_col1, #T_c85de_row9_col2, #T_c85de_row9_col3, #T_c85de_row9_col4, #T_c85de_row10_col7, #T_c85de_row10_col8, #T_c85de_row11_col7, #T_c85de_row11_col8, #T_c85de_row12_col7, #T_c85de_row12_col8, #T_c85de_row13_col7, #T_c85de_row13_col8, #T_c85de_row14_col6, #T_c85de_row14_col7, #T_c85de_row14_col8, #T_c85de_row15_col6, #T_c85de_row15_col7, #T_c85de_row15_col8, #T_c85de_row16_col7, #T_c85de_row16_col8 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_c85de_row0_col5, #T_c85de_row0_col6, #T_c85de_row0_col7, #T_c85de_row0_col8, #T_c85de_row1_col6, #T_c85de_row1_col7, #T_c85de_row1_col8, #T_c85de_row2_col5, #T_c85de_row2_col6, #T_c85de_row2_col7, #T_c85de_row2_col8, #T_c85de_row3_col5, #T_c85de_row3_col6, #T_c85de_row3_col7, #T_c85de_row3_col8, #T_c85de_row4_col6, #T_c85de_row6_col7, #T_c85de_row9_col5, #T_c85de_row9_col6, #T_c85de_row9_col7, #T_c85de_row9_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_c85de_row1_col0, #T_c85de_row5_col0, #T_c85de_row5_col6, #T_c85de_row6_col6, #T_c85de_row8_col6, #T_c85de_row10_col0, #T_c85de_row10_col6, #T_c85de_row11_col0, #T_c85de_row11_col6, #T_c85de_row12_col0, #T_c85de_row12_col6, #T_c85de_row13_col0, #T_c85de_row13_col6, #T_c85de_row15_col0, #T_c85de_row16_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_c85de_row1_col1, #T_c85de_row7_col5, #T_c85de_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_c85de_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.0%, transparent 6.0%);
#   font-family: Courier;
# }
# #T_c85de_row1_col3, #T_c85de_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.7%, transparent 2.7%);
#   font-family: Courier;
# }
# #T_c85de_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.9%, transparent 7.9%);
#   font-family: Courier;
# }
# #T_c85de_row1_col5, #T_c85de_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.0%, transparent 2.0%);
#   font-family: Courier;
# }
# #T_c85de_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.9%, transparent 3.9%);
#   font-family: Courier;
# }
# #T_c85de_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.3%, transparent 20.3%);
#   font-family: Courier;
# }
# #T_c85de_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.6%, transparent 17.6%);
#   font-family: Courier;
# }
# #T_c85de_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.9%, transparent 17.9%);
#   font-family: Courier;
# }
# #T_c85de_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 19.3%, transparent 19.3%);
#   font-family: Courier;
# }
# #T_c85de_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_c85de_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 24.1%, transparent 24.1%);
#   font-family: Courier;
# }
# #T_c85de_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.6%, transparent 2.6%);
#   font-family: Courier;
# }
# #T_c85de_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.2%, transparent 2.2%);
#   font-family: Courier;
# }
# #T_c85de_row5_col4, #T_c85de_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.3%, transparent 3.3%);
#   font-family: Courier;
# }
# #T_c85de_row5_col5, #T_c85de_row8_col0, #T_c85de_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_c85de_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.1%, transparent 6.1%);
#   font-family: Courier;
# }
# #T_c85de_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.7%, transparent 10.7%);
#   font-family: Courier;
# }
# #T_c85de_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.2%, transparent 14.2%);
#   font-family: Courier;
# }
# #T_c85de_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.8%, transparent 10.8%);
#   font-family: Courier;
# }
# #T_c85de_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.8%, transparent 17.8%);
#   font-family: Courier;
# }
# #T_c85de_row6_col5, #T_c85de_row12_col5, #T_c85de_row14_col5, #T_c85de_row16_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_c85de_row7_col1, #T_c85de_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.8%, transparent 2.8%);
#   font-family: Courier;
# }
# #T_c85de_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 33.9%, transparent 33.9%);
#   font-family: Courier;
# }
# #T_c85de_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 37.7%, transparent 37.7%);
#   font-family: Courier;
# }
# #T_c85de_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 39.3%, transparent 39.3%);
#   font-family: Courier;
# }
# #T_c85de_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.3%, transparent 29.3%);
#   font-family: Courier;
# }
# #T_c85de_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.1%, transparent 7.1%);
#   font-family: Courier;
# }
# #T_c85de_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.1%, transparent 8.1%);
#   font-family: Courier;
# }
# #T_c85de_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.0%, transparent 10.0%);
#   font-family: Courier;
# }
# #T_c85de_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 23.0%, transparent 23.0%);
#   font-family: Courier;
# }
# #T_c85de_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.5%, transparent 2.5%);
#   font-family: Courier;
# }
# #T_c85de_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.5%, transparent 4.5%);
#   font-family: Courier;
# }
# #T_c85de_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.8%, transparent 1.8%);
#   font-family: Courier;
# }
# #T_c85de_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.7%, transparent 17.7%);
#   font-family: Courier;
# }
# #T_c85de_row11_col2, #T_c85de_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.6%, transparent 3.6%);
#   font-family: Courier;
# }
# #T_c85de_row11_col3, #T_c85de_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.1%, transparent 3.1%);
#   font-family: Courier;
# }
# #T_c85de_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.8%, transparent 5.8%);
#   font-family: Courier;
# }
# #T_c85de_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_c85de_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.9%, transparent 25.9%);
#   font-family: Courier;
# }
# #T_c85de_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.3%, transparent 2.3%);
#   font-family: Courier;
# }
# #T_c85de_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.4%, transparent 14.4%);
#   font-family: Courier;
# }
# #T_c85de_row13_col2 {
#   width: 10em;
#   backgro

# %% [markdown]
# ### <a id='toc1_10_6_'></a>[Freitexte](#toc0_)
#
# > 💡 `ZfKD`: _Protokolle und Substanzen werden nach und nach in den Datensatz eingebunden. Protokolle bislang ausschliesslich als Freitext. Bei Substanzen komplementieren sich Freitexte und Kodierungen, bei vielen GTDS Ländern überwiegen inzwischen die Kodierungen._

# %%
_fil = """--sql
not regexp_matches(tablecolumn,'genauigkeit','i') and sel12_free
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=True,
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=True,
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_038_346  (75.7%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_1db80 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_1db80 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_1db80_row0_col0, #T_1db80_row1_col0, #T_1db80_row1_col2, #T_1db80_row2_col0, #T_1db80_row3_col0, #T_1db80_row4_col0, #T_1db80_row4_col2, #T_1db80_row5_col0, #T_1db80_row6_col0, #T_1db80_row6_col2, #T_1db80_row7_col0, #T_1db80_row7_col2, #T_1db80_row9_col0, #T_1db80_row10_col0, #T_1db80_row11_col0, #T_1db80_row12_col0, #T_1db80_row13_col0, #T_1db80_row14_col0, #T_1db80_row15_col0 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_1db80_row0_col1, #T_1db80_row1_col1, #T_1db80_row1_col3, #T_1db80_row2_col1, #T_1db80_row3_col1, #T_1db80_row4_col1, #T_1db80_row4_col3, #T_1db80_row5_col1, #T_1db80_row6_col1, #T_1db80_row6_col3, #T_1db80_row7_col1, #T_1db80_row7_col3, #T_1db80_row8_col1, #T_1db80_row9_col1, #T_1db80_row10_col1, #T_1db80_row11_col1, #T_1db80_row12_col1, #T_1db80_row12_col3, #T_1db80_row13_col1, #T_1db80_row14_col1, #T_1db80_row15_col1, #T_1db80_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_1db80_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.6%, transparent 98.6%);
#   font-family: Courier;
# }
# #T_1db80_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.4%, transparent 1.4%);
#   font-family: Courier;
# }
# #T_1db80_row2_col2, #T_1db80_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.2%, transparent 99.2%);
#   font-family: Courier;
# }
# #T_1db80_row2_col3, #T_1db80_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.8%, transparent 0.8%);
#   font-family: Courier;
# }
# #T_1db80_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.9%, transparent 85.9%);
#   font-family: Courier;
# }
# #T_1db80_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.1%, transparent 14.1%);
#   font-family: Courier;
# }
# #T_1db80_row8_col0, #T_1db80_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_1db80_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.3%, transparent 48.3%);
#   font-family: Courier;
# }
# #T_1db80_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 51.7%, transparent 51.7%);
#   font-family: Courier;
# }
# #T_1db80_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.9%, transparent 99.9%);
#   font-family: Courier;
# }
# #T_1db80_row9_col3, #T_1db80_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_1db80_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 91.4%, transparent 91.4%);
#   font-family: Courier;
# }
# #T_1db80_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.6%, transparent 8.6%);
#   font-family: Courier;
# }
# #T_1db80_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 91.9%, transparent 91.9%);
#   font-family: Courier;
# }
# #T_1db80_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.1%, transparent 8.1%);
#   font-family: Courier;
# }
# #T_1db80_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 91.3%, transparent 91.3%);
#   font-family: Courier;
# }
# #T_1db80_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.7%, transparent 8.7%);
#   font-family: Courier;
# }
# #T_1db80_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.9%, transparent 80.9%);
#   font-family: Courier;
# }
# #T_1db80_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 19.1%, transparent 19.1%);
#   font-family: Courier;
# }
# #T_1db80_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.0%, transparent 64.0%);
#   font-family: Courier;
# }
# #T_1db80_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 36.0%, transparent 36.0%);
#   font-family: Courier;
# }
# #T_1db80_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 45.7%, transparent 45.7%);
#   font-family: Courier;
# }
# #T_1db80_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.3%, transparent 54.3%);
#   font-family: Courier;
# }
# </style>
# <table id="T_1db80">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_1db80_level0_col0" class="col_heading level0 col0" >[Protokoll]Bezeichnung</th>
#       <th id="T_1db80_level0_col1" class="col_heading level0 col1" >[Protokoll]Protokoll_TypProtokollschluessel_Code</th>
#       <th id="T_1db80_level0_col2" class="col_heading level0 col2" >[Substanz]Bezeichnung</th>
#       <th id="T_1db80_level0_col3" class="col_heading level0 col3" >[Substanz]SYST_TypSubstanzATC_Code</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1db80_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_1db80_row0_col0" class="data row0 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row0_col1" class="data row0 col1" >100.0% 🟥</td>
#       <td id="T_1db80_row0_col2" class="data row0 col2" >98.6% 🟨</td>
#       <td id="T_1db80_row0_col3" class="data row0 col3" >1.4% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_1db80_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_1db80_row1_col0" class="data row1 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row1_col1" class="data row1 col1" >100.0% 🟥</td>
#       <td id="T_1db80_row1_col2" class="data row1 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row1_col3" class="data row1 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1db80_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_1db80_row2_col0" class="data row2 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row2_col1" class="data row2 col1" >100.0% 🟥</td>
#       <td id="T_1db80_row2_col2" class="data row2 col2" >99.2% 🟨</td>
#       <td id="T_1db80_row2_col3" class="data row2 col3" >0.8% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_1db80_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_1db80_row3_col0" class="data row3 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row3_col1" class="data row3 col1" >100.0% 🟥</td>
#       <td id="T_1db80_row3_col2" class="data row3 col2" >99.2% 🟨</td>
#       <td id="T_1db80_row3_col3" class="data row3 col3" >0.8% 🟩</td>
#     </tr>
#     <tr>
#       <th id="T_1db80_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_1db80_row4_col0" class="data row4 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row4_col1" class="data row4 col1" >100.0% 🟥</td>
#       <td id="T_1db80_row4_col2" class="data row4 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row4_col3" class="data row4 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1db80_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_1db80_row5_col0" class="data row5 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row5_col1" class="data row5 col1" >100.0% 🟥</td>
#       <td id="T_1db80_row5_col2" class="data row5 col2" >85.9% 🟨</td>
#       <td id="T_1db80_row5_col3" class="data row5 col3" >14.1% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_1db80_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_1db80_row6_col0" class="data row6 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row6_col1" class="data row6 col1" >100.0% 🟥</td>
#       <td id="T_1db80_row6_col2" class="data row6 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1db80_row6_col3" cla
# 🟠 unknowns
# <style type="text/css">
# #T_5f47a th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_5f47a td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_5f47a_row0_col0, #T_5f47a_row0_col2, #T_5f47a_row0_col3, #T_5f47a_row1_col0, #T_5f47a_row1_col2, #T_5f47a_row2_col0, #T_5f47a_row2_col2, #T_5f47a_row2_col3, #T_5f47a_row3_col0, #T_5f47a_row3_col2, #T_5f47a_row3_col3, #T_5f47a_row4_col0, #T_5f47a_row4_col2, #T_5f47a_row5_col0, #T_5f47a_row5_col2, #T_5f47a_row5_col3, #T_5f47a_row6_col0, #T_5f47a_row6_col2, #T_5f47a_row7_col0, #T_5f47a_row7_col2, #T_5f47a_row8_col0, #T_5f47a_row8_col2, #T_5f47a_row8_col3, #T_5f47a_row9_col0, #T_5f47a_row9_col2, #T_5f47a_row9_col3, #T_5f47a_row10_col0, #T_5f47a_row10_col2, #T_5f47a_row10_col3, #T_5f47a_row11_col0, #T_5f47a_row11_col2, #T_5f47a_row11_col3, #T_5f47a_row12_col0, #T_5f47a_row12_col2, #T_5f47a_row13_col0, #T_5f47a_row13_col2, #T_5f47a_row13_col3, #T_5f47a_row14_col0, #T_5f47a_row14_col2, #T_5f47a_row14_col3, #T_5f47a_row15_col0, #T_5f47a_row15_col2, #T_5f47a_row15_col3, #T_5f47a_row16_col0, #T_5f47a_row16_col2, #T_5f47a_row16_col3 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_5f47a_row0_col1, #T_5f47a_row1_col1, #T_5f47a_row1_col3, #T_5f47a_row2_col1, #T_5f47a_row3_col1, #T_5f47a_row4_col1, #T_5f47a_row4_col3, #T_5f47a_row5_col1, #T_5f47a_row6_col1, #T_5f47a_row6_col3, #T_5f47a_row7_col1, #T_5f47a_row7_col3, #T_5f47a_row8_col1, #T_5f47a_row9_col1, #T_5f47a_row10_col1, #T_5f47a_row11_col1, #T_5f47a_row12_col1, #T_5f47a_row12_col3, #T_5f47a_row13_col1, #T_5f47a_row14_col1, #T_5f47a_row15_col1, #T_5f47a_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# </style>
# <table id="T_5f47a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_5f47a_level0_col0" class="col_heading level0 col0" >[Protokoll]Bezeichnung</th>
#       <th id="T_5f47a_level0_col1" class="col_heading level0 col1" >[Protokoll]Protokoll_TypProtokollschluessel_Code</th>
#       <th id="T_5f47a_level0_col2" class="col_heading level0 col2" >[Substanz]Bezeichnung</th>
#       <th id="T_5f47a_level0_col3" class="col_heading level0 col3" >[Substanz]SYST_TypSubstanzATC_Code</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f47a_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_5f47a_row0_col0" class="data row0 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row0_col1" class="data row0 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row0_col2" class="data row0 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row0_col3" class="data row0 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_5f47a_row1_col0" class="data row1 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row1_col1" class="data row1 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row1_col2" class="data row1 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row1_col3" class="data row1 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_5f47a_row2_col0" class="data row2 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row2_col1" class="data row2 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row2_col2" class="data row2 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row2_col3" class="data row2 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_5f47a_row3_col0" class="data row3 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row3_col1" class="data row3 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row3_col2" class="data row3 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row3_col3" class="data row3 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_5f47a_row4_col0" class="data row4 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row4_col1" class="data row4 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row4_col2" class="data row4 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row4_col3" class="data row4 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_5f47a_row5_col0" class="data row5 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row5_col1" class="data row5 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row5_col2" class="data row5 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row5_col3" class="data row5 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_5f47a_row6_col0" class="data row6 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row6_col1" class="data row6 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row6_col2" class="data row6 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row6_col3" class="data row6 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row7" class="row_heading level0 row7" >08-BW</th>
#       <td id="T_5f47a_row7_col0" class="data row7 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row7_col1" class="data row7 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row7_col2" class="data row7 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row7_col3" class="data row7 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row8" class="row_heading level0 row8" >09-BY</th>
#       <td id="T_5f47a_row8_col0" class="data row8 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row8_col1" class="data row8 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row8_col2" class="data row8 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row8_col3" class="data row8 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row9" class="row_heading level0 row9" >10-SL</th>
#       <td id="T_5f47a_row9_col0" class="data row9 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row9_col1" class="data row9 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row9_col2" class="data row9 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row9_col3" class="data row9 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row10" class="row_heading level0 row10" >11-BE</th>
#       <td id="T_5f47a_row10_col0" class="data row10 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row10_col1" class="data row10 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row10_col2" class="data row10 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row10_col3" class="data row10 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_5f47a_level0_row11" class="row_heading level0 row11" >12-BB</th>
#       <td id="T_5f47a_row11_col0" class="data row11 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row11_col1" class="data row11 col1" >100.0% 🟥</td>
#       <td id="T_5f47a_row11_col2" class="data row11 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_5f47a_row11_col3" class="data row11 co

# %% [markdown]
# <br>
#
# ### <a id='toc1_10_7_'></a>[Organspezifische Variablen](#toc0_)
# - die Prozentwerte sind bei allen Darstellungen gerundet, "100%" bei einer gelben Ampel kann interpretiert werden als knapp unter 100%
# > 💡 `HH` _"Fehlende Modul-Angaben (C50, C61) 2021. Sind bei uns noch nicht im xml enthalten."_

# %% [markdown]
# <br>
#
# #### <a id='toc1_10_7_1_'></a>[Mamma](#toc0_)
# - **Filter: `DJ` 2020-2024, `DCO` = N, `ICD10` = C50**

# %%
_fil = """--sql
sel6_mamma
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_C50,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)


show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [ICD10 C50]:      n = 391_652   (9.8%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C50'
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_b51bd th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_b51bd td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_b51bd_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.5%, transparent 15.5%);
#   font-family: Courier;
# }
# #T_b51bd_row0_col1, #T_b51bd_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.3%, transparent 14.3%);
#   font-family: Courier;
# }
# #T_b51bd_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.1%, transparent 21.1%);
#   font-family: Courier;
# }
# #T_b51bd_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.7%, transparent 68.7%);
#   font-family: Courier;
# }
# #T_b51bd_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 38.7%, transparent 38.7%);
#   font-family: Courier;
# }
# #T_b51bd_row1_col0, #T_b51bd_row1_col1, #T_b51bd_row1_col2, #T_b51bd_row1_col3, #T_b51bd_row1_col4, #T_b51bd_row1_col5, #T_b51bd_row10_col4, #T_b51bd_row13_col4, #T_b51bd_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_b51bd_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.6%, transparent 5.6%);
#   font-family: Courier;
# }
# #T_b51bd_row2_col1, #T_b51bd_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.5%, transparent 5.5%);
#   font-family: Courier;
# }
# #T_b51bd_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.7%, transparent 34.7%);
#   font-family: Courier;
# }
# #T_b51bd_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.7%, transparent 66.7%);
#   font-family: Courier;
# }
# #T_b51bd_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 30.6%, transparent 30.6%);
#   font-family: Courier;
# }
# #T_b51bd_row3_col0, #T_b51bd_row3_col1, #T_b51bd_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_b51bd_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.0%, transparent 8.0%);
#   font-family: Courier;
# }
# #T_b51bd_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 34.3%, transparent 34.3%);
#   font-family: Courier;
# }
# #T_b51bd_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.5%, transparent 20.5%);
#   font-family: Courier;
# }
# #T_b51bd_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 18.2%, transparent 18.2%);
#   font-family: Courier;
# }
# #T_b51bd_row4_col1, #T_b51bd_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.5%, transparent 17.5%);
#   font-family: Courier;
# }
# #T_b51bd_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.4%, transparent 31.4%);
#   font-family: Courier;
# }
# #T_b51bd_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.1%, transparent 72.1%);
#   font-family: Courier;
# }
# #T_b51bd_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 50.7%, transparent 50.7%);
#   font-family: Courier;
# }
# #T_b51bd_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 18.1%, transparent 18.1%);
#   font-family: Courier;
# }
# #T_b51bd_row5_col1, #T_b51bd_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.7%, transparent 17.7%);
#   font-family: Courier;
# }
# #T_b51bd_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.4%, transparent 17.4%);
#   font-family: Courier;
# }
# #T_b51bd_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 37.9%, transparent 37.9%);
#   font-family: Courier;
# }
# #T_b51bd_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.9%, transparent 80.9%);
#   font-family: Courier;
# }
# #T_b51bd_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 55.6%, transparent 55.6%);
#   font-family: Courier;
# }
# #T_b51bd_row6_col0, #T_b51bd_row6_col1, #T_b51bd_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.1%, transparent 48.1%);
#   font-family: Courier;
# }
# #T_b51bd_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.0%, transparent 54.0%);
#   font-family: Courier;
# }
# #T_b51bd_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.7%, transparent 78.7%);
#   font-family: Courier;
# }
# #T_b51bd_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.5%, transparent 59.5%);
#   font-family: Courier;
# }
# #T_b51bd_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.6%, transparent 11.6%);
#   font-family: Courier;
# }
# #T_b51bd_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.4%, transparent 11.4%);
#   font-family: Courier;
# }
# #T_b51bd_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.8%, transparent 15.8%);
#   font-family: Courier;
# }
# #T_b51bd_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.6%, transparent 29.6%);
#   font-family: Courier;
# }
# #T_b51bd_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.8%, transparent 54.8%);
#   font-family: Courier;
# }
# #T_b51bd_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 33.2%, transparent 33.2%);
#   font-family: Courier;
# }
# #T_b51bd_row8_col0, #T_b51bd_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.1%, transparent 11.1%);
#   font-family: Courier;
# }
# #T_b51bd_row8_col1, #T_b51bd_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 23.9%, transparent 23.9%);
#   font-family: Courier;
# }
# #T_b51bd_row8_col3, #T_b51bd_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 37.4%, transparent 37.4%);
#   font-family: Courier;
# }
# #T_b51bd_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 99.3%, transparent 99.3%);
#   font-family: Courier;
# }
# #T_b51bd_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.9%, transparent 78.9%);
#   font-family: Courier;
# }
# #T_b51bd_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.1%, transparent 5.1%);
#   font-family: Courier;
# }
# #T_b51bd_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.9%, transparent 4.9%);
#   font-family: Courier;
# }
# #T_b51bd_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.7%, transparent 4.7%);
#   font-family: Courier;
# }
# #T_b51bd_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.9%, transparent 27.9%);
#   font-family: Courier;
# }
# #T_b51bd_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 70.0%, transparent 70.0%);
#   font-family: Courier;
# }
# #T_b51bd_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.2%, transparent 25.2%);
#   font-family: Courier;
# }
# #T_b51bd_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.5%, transparent 0.5%);
#   font-family: Courier;
# }
# #T_b51bd_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.0%, transparent 7.0%);
#   font-family: Courier;
# }
# #T_b51bd_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.1%, transparent 7.1%);
#   font-family: Courier;
# }
# #T_b51bd_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 23.6%, transparent 23.6%);
#   font-family: Courier;
# }
# #T_b51bd_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 38.8%, transparent 38.8%);
#   font-family: Courier;
# }
# #T_b51bd_row11_col0, #T_b51bd_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_b51bd_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.3%, transparent 8.3%);
#   font-family: Courier;
# }
# #T_b51bd_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.4%, transparent 8.4%);
#   font-family: Courier;
# }
# #T_b51bd_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 33.0%, transparent 33
# 🟠 unknowns
# <style type="text/css">
# #T_e7ad5 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_e7ad5 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_e7ad5_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_e7ad5_row0_col1, #T_e7ad5_row0_col2, #T_e7ad5_row2_col1, #T_e7ad5_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_e7ad5_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.7%, transparent 6.7%);
#   font-family: Courier;
# }
# #T_e7ad5_row0_col4, #T_e7ad5_row0_col5, #T_e7ad5_row2_col4, #T_e7ad5_row2_col5, #T_e7ad5_row3_col4, #T_e7ad5_row3_col5, #T_e7ad5_row4_col4, #T_e7ad5_row4_col5, #T_e7ad5_row5_col4, #T_e7ad5_row5_col5, #T_e7ad5_row6_col4, #T_e7ad5_row6_col5, #T_e7ad5_row7_col4, #T_e7ad5_row7_col5, #T_e7ad5_row8_col4, #T_e7ad5_row8_col5, #T_e7ad5_row9_col4, #T_e7ad5_row9_col5, #T_e7ad5_row10_col4, #T_e7ad5_row10_col5, #T_e7ad5_row11_col4, #T_e7ad5_row11_col5, #T_e7ad5_row12_col4, #T_e7ad5_row12_col5, #T_e7ad5_row13_col4, #T_e7ad5_row13_col5, #T_e7ad5_row14_col4, #T_e7ad5_row14_col5, #T_e7ad5_row15_col4, #T_e7ad5_row15_col5, #T_e7ad5_row16_col4, #T_e7ad5_row16_col5 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_e7ad5_row1_col0, #T_e7ad5_row1_col1, #T_e7ad5_row1_col2, #T_e7ad5_row1_col3, #T_e7ad5_row1_col4, #T_e7ad5_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_e7ad5_row2_col0, #T_e7ad5_row2_col3, #T_e7ad5_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.6%, transparent 1.6%);
#   font-family: Courier;
# }
# #T_e7ad5_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.9%, transparent 2.9%);
#   font-family: Courier;
# }
# #T_e7ad5_row3_col1, #T_e7ad5_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.0%, transparent 2.0%);
#   font-family: Courier;
# }
# #T_e7ad5_row3_col3, #T_e7ad5_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.9%, transparent 0.9%);
#   font-family: Courier;
# }
# #T_e7ad5_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.0%, transparent 3.0%);
#   font-family: Courier;
# }
# #T_e7ad5_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.4%, transparent 1.4%);
#   font-family: Courier;
# }
# #T_e7ad5_row4_col2, #T_e7ad5_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.5%, transparent 1.5%);
#   font-family: Courier;
# }
# #T_e7ad5_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.9%, transparent 5.9%);
#   font-family: Courier;
# }
# #T_e7ad5_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.0%, transparent 8.0%);
#   font-family: Courier;
# }
# #T_e7ad5_row5_col1, #T_e7ad5_row6_col1, #T_e7ad5_row6_col2, #T_e7ad5_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.7%, transparent 1.7%);
#   font-family: Courier;
# }
# #T_e7ad5_row5_col2, #T_e7ad5_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.3%, transparent 2.3%);
#   font-family: Courier;
# }
# #T_e7ad5_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.0%, transparent 4.0%);
#   font-family: Courier;
# }
# #T_e7ad5_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.3%, transparent 1.3%);
#   font-family: Courier;
# }
# #T_e7ad5_row7_col1, #T_e7ad5_row7_col2, #T_e7ad5_row9_col2, #T_e7ad5_row11_col1, #T_e7ad5_row12_col1, #T_e7ad5_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_e7ad5_row7_col3, #T_e7ad5_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_e7ad5_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.1%, transparent 8.1%);
#   font-family: Courier;
# }
# #T_e7ad5_row8_col1, #T_e7ad5_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_e7ad5_row8_col3, #T_e7ad5_row10_col1, #T_e7ad5_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.6%, transparent 2.6%);
#   font-family: Courier;
# }
# #T_e7ad5_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_e7ad5_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.1%, transparent 7.1%);
#   font-family: Courier;
# }
# #T_e7ad5_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 8.2%, transparent 8.2%);
#   font-family: Courier;
# }
# #T_e7ad5_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.9%, transparent 4.9%);
#   font-family: Courier;
# }
# #T_e7ad5_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.9%, transparent 6.9%);
#   font-family: Courier;
# }
# #T_e7ad5_row11_col2, #T_e7ad5_row12_col2, #T_e7ad5_row14_col1, #T_e7ad5_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.5%, transparent 0.5%);
#   font-family: Courier;
# }
# #T_e7ad5_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.1%, transparent 6.1%);
#   font-family: Courier;
# }
# #T_e7ad5_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 11.9%, transparent 11.9%);
#   font-family: Courier;
# }
# #T_e7ad5_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.3%, transparent 6.3%);
#   font-family: Courier;
# }
# #T_e7ad5_row13_col1, #T_e7ad5_row13_col2, #T_e7ad5_row13_col3, #T_e7ad5_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.3%, transparent 3.3%);
#   font-family: Courier;
# }
# #T_e7ad5_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.9%, transparent 14.9%);
#   font-family: Courier;
# }
# #T_e7ad5_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.4%, transparent 4.4%);
#   font-family: Courier;
# }
# #T_e7ad5_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.0%, transparent 5.0%);
#   font-family: Courier;
# }
# #T_e7ad5_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.3%, transparent 0.3%);
#   font-family: Courier;
# }
# #T_e7ad5_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.8%, transparent 4.8%);
#   font-family: Courier;
# }
# #T_e7ad5_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.1%, transparent 1.1%);
#   font-family: Courier;
# }
# </style>
# <table id="T_e7ad5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_e7ad5_level0_col0" class="col_heading level0 col0" >[Tumor]Her2neuStatus</th>
#       <th id="T_e7ad5_level0_col1" class="col_heading level0 col1" >[Tumor]HormonrezeptorStatus_Oestrogen</th>
#       <th id="T_e7ad5_level0_col2" class="col_heading level0 col2" >[Tumor]HormonrezeptorStatus_Progesteron</th>
#       <th id="T_e7ad5_level0_col3" class="col_heading level0 col3" >[Tumor]Praetherapeutischer_Menopausenstatus</th>
#       <th id="T_e7ad5_level0_col4" class="col_heading level0 col4" >[Tumor]TumorgroesseDCIS</th>
#       <th id="T_e7ad5_level0_col5" class="col_heading level0 col5" >[Tumor]TumorgroesseInvasiv</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7ad5_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_e7ad5_row0_col0" class="data row0 col0" >1.9% 🟩</td>
#       <td id="T_e7ad5_row0_col1" class="data row0 col1" >0.7% 🟩</td>
#       <td id="T_e7ad5_row0_col2" class="data row0 col2" >0.7% 🟩</td>
#       <td id="T_e7ad5_row0_col3" class="data row0 col3" >6.7% 🟨</td>
#       <td id="T_e7ad5_row0_col4" cl

# %% [markdown]
# <br>
#
# #### <a id='toc1_10_7_2_'></a>[Prostata](#toc0_)
# - **Filter: `DJ` 2020-2024, `DCO` = N, `ICD10` = C61**
#
# > 💡 `ZfKD` _Auch innerhalb eines KKR gibt es deutliche Varianzen zwischen Variablen des organspezifischen Moduls, z.B. in 11-16_

# %%
_fil = """--sql
sel7_prostata
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d = 'C61'", "ICD C61"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    # font_size_th=12,
    # font_size_td=11,
    image_scale="70%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    # font_size_th=12,
    # font_size_td=11,
    image_scale="70%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [ICD C61]:        n = 375_506   (9.4%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C61'
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-70% -->
# <style type="text/css">
# #T_a6ba5 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_a6ba5 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_a6ba5_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.5%, transparent 17.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 41.4%, transparent 41.4%);
#   font-family: Courier;
# }
# #T_a6ba5_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 41.3%, transparent 41.3%);
#   font-family: Courier;
# }
# #T_a6ba5_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.7%, transparent 15.7%);
#   font-family: Courier;
# }
# #T_a6ba5_row1_col0, #T_a6ba5_row1_col1, #T_a6ba5_row1_col2, #T_a6ba5_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_a6ba5_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.8%, transparent 9.8%);
#   font-family: Courier;
# }
# #T_a6ba5_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 40.9%, transparent 40.9%);
#   font-family: Courier;
# }
# #T_a6ba5_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 40.5%, transparent 40.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row2_col3, #T_a6ba5_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.9%, transparent 7.9%);
#   font-family: Courier;
# }
# #T_a6ba5_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.6%, transparent 7.6%);
#   font-family: Courier;
# }
# #T_a6ba5_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 30.9%, transparent 30.9%);
#   font-family: Courier;
# }
# #T_a6ba5_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.5%, transparent 29.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.4%, transparent 7.4%);
#   font-family: Courier;
# }
# #T_a6ba5_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 36.5%, transparent 36.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row4_col1 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_a6ba5_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 30.8%, transparent 30.8%);
#   font-family: Courier;
# }
# #T_a6ba5_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.1%, transparent 12.1%);
#   font-family: Courier;
# }
# #T_a6ba5_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 63.7%, transparent 63.7%);
#   font-family: Courier;
# }
# #T_a6ba5_row5_col1, #T_a6ba5_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 43.7%, transparent 43.7%);
#   font-family: Courier;
# }
# #T_a6ba5_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 23.0%, transparent 23.0%);
#   font-family: Courier;
# }
# #T_a6ba5_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.8%, transparent 66.8%);
#   font-family: Courier;
# }
# #T_a6ba5_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.6%, transparent 72.6%);
#   font-family: Courier;
# }
# #T_a6ba5_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.7%, transparent 66.7%);
#   font-family: Courier;
# }
# #T_a6ba5_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.0%, transparent 64.0%);
#   font-family: Courier;
# }
# #T_a6ba5_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 13.3%, transparent 13.3%);
#   font-family: Courier;
# }
# #T_a6ba5_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 95.3%, transparent 95.3%);
#   font-family: Courier;
# }
# #T_a6ba5_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 32.7%, transparent 32.7%);
#   font-family: Courier;
# }
# #T_a6ba5_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.1%, transparent 10.1%);
#   font-family: Courier;
# }
# #T_a6ba5_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.7%, transparent 29.7%);
#   font-family: Courier;
# }
# #T_a6ba5_row8_col1, #T_a6ba5_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 39.8%, transparent 39.8%);
#   font-family: Courier;
# }
# #T_a6ba5_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 18.8%, transparent 18.8%);
#   font-family: Courier;
# }
# #T_a6ba5_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 7.5%, transparent 7.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.2%, transparent 25.2%);
#   font-family: Courier;
# }
# #T_a6ba5_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 22.2%, transparent 22.2%);
#   font-family: Courier;
# }
# #T_a6ba5_row9_col3, #T_a6ba5_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.2%, transparent 4.2%);
#   font-family: Courier;
# }
# #T_a6ba5_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 42.8%, transparent 42.8%);
#   font-family: Courier;
# }
# #T_a6ba5_row10_col1, #T_a6ba5_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.5%, transparent 21.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.4%, transparent 9.4%);
#   font-family: Courier;
# }
# #T_a6ba5_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.3%, transparent 52.3%);
#   font-family: Courier;
# }
# #T_a6ba5_row11_col1, #T_a6ba5_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 21.2%, transparent 21.2%);
#   font-family: Courier;
# }
# #T_a6ba5_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.5%, transparent 9.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 40.3%, transparent 40.3%);
#   font-family: Courier;
# }
# #T_a6ba5_row12_col1, #T_a6ba5_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.0%, transparent 20.0%);
#   font-family: Courier;
# }
# #T_a6ba5_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.5%, transparent 12.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 33.9%, transparent 33.9%);
#   font-family: Courier;
# }
# #T_a6ba5_row13_col1, #T_a6ba5_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.8%, transparent 12.8%);
#   font-family: Courier;
# }
# #T_a6ba5_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 66.0%, transparent 66.0%);
#   font-family: Courier;
# }
# #T_a6ba5_row14_col1, #T_a6ba5_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 27.2%, transparent 27.2%);
#   font-family: Courier;
# }
# #T_a6ba5_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 88.2%, transparent 88.2%);
#   font-family: Courier;
# }
# #T_a6ba5_row15_col1, #T_a6ba5_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 25.4%, transparent 25.4%);
#   font-family: Courier;
# }
# #T_a6ba5_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 18.9%, transparent 18.9%);
#   font-family: Courier;
# }
# #T_a6ba5_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 35.8%, transparent 35.8%);
#   font-family: Courier;
# }
# #T_a6ba5_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 38.2%, transparent 38.2%);
#   font-family: Courier;
# }
# #T_a6ba5_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 35.5%, transparent 35.5%);
#   font-family: Courier;
# }
# #T_a6ba5_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.0%, transparent 17.0%);
#   font-family: Courier;
# }
# </style>
# <table id="T_a6ba5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_a6ba5_level0_col0" class="col_heading level0 col0" >[Tumor]AnlassGleasonScore</th>
#       <th id="T_a6ba5_level0_col1" class="col_heading level0 col1" >[Tumor]DatumPSA</th>
#       <th
# 🟠 unknowns
# <!-- SCALE-70% -->
# <style type="text/css">
# #T_e04eb th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_e04eb td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_e04eb_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_e04eb_row0_col1, #T_e04eb_row0_col2, #T_e04eb_row0_col3, #T_e04eb_row2_col1, #T_e04eb_row2_col2, #T_e04eb_row2_col3, #T_e04eb_row3_col1, #T_e04eb_row3_col2, #T_e04eb_row3_col3, #T_e04eb_row4_col0, #T_e04eb_row4_col1, #T_e04eb_row4_col2, #T_e04eb_row4_col3, #T_e04eb_row5_col0, #T_e04eb_row5_col1, #T_e04eb_row5_col2, #T_e04eb_row5_col3, #T_e04eb_row6_col2, #T_e04eb_row6_col3, #T_e04eb_row7_col1, #T_e04eb_row7_col2, #T_e04eb_row7_col3, #T_e04eb_row8_col1, #T_e04eb_row8_col2, #T_e04eb_row8_col3, #T_e04eb_row9_col1, #T_e04eb_row9_col2, #T_e04eb_row9_col3, #T_e04eb_row10_col2, #T_e04eb_row10_col3, #T_e04eb_row11_col2, #T_e04eb_row11_col3, #T_e04eb_row12_col2, #T_e04eb_row12_col3, #T_e04eb_row13_col2, #T_e04eb_row13_col3, #T_e04eb_row14_col1, #T_e04eb_row14_col2, #T_e04eb_row14_col3, #T_e04eb_row15_col1, #T_e04eb_row15_col2, #T_e04eb_row15_col3, #T_e04eb_row16_col2, #T_e04eb_row16_col3 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_e04eb_row1_col0, #T_e04eb_row1_col1, #T_e04eb_row1_col2, #T_e04eb_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_e04eb_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.8%, transparent 0.8%);
#   font-family: Courier;
# }
# #T_e04eb_row3_col0, #T_e04eb_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_e04eb_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_e04eb_row6_col1, #T_e04eb_row10_col1, #T_e04eb_row11_col1, #T_e04eb_row13_col1, #T_e04eb_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.0%, transparent 0.0%);
#   font-family: Courier;
# }
# #T_e04eb_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.5%, transparent 0.5%);
#   font-family: Courier;
# }
# #T_e04eb_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.4%, transparent 6.4%);
#   font-family: Courier;
# }
# #T_e04eb_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.6%, transparent 0.6%);
#   font-family: Courier;
# }
# #T_e04eb_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.2%, transparent 3.2%);
#   font-family: Courier;
# }
# #T_e04eb_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_e04eb_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.2%, transparent 0.2%);
#   font-family: Courier;
# }
# #T_e04eb_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.1%, transparent 0.1%);
#   font-family: Courier;
# }
# #T_e04eb_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.2%, transparent 1.2%);
#   font-family: Courier;
# }
# #T_e04eb_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.3%, transparent 0.3%);
#   font-family: Courier;
# }
# #T_e04eb_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.6%, transparent 1.6%);
#   font-family: Courier;
# }
# </style>
# <table id="T_e04eb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_e04eb_level0_col0" class="col_heading level0 col0" >[Tumor]AnlassGleasonScore</th>
#       <th id="T_e04eb_level0_col1" class="col_heading level0 col1" >[Tumor]DatumPSA</th>
#       <th id="T_e04eb_level0_col2" class="col_heading level0 col2" >[Tumor]PSA</th>
#       <th id="T_e04eb_level0_col3" class="col_heading level0 col3" >[Tumor]ScoreErgebnis</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e04eb_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_e04eb_row0_col0" class="data row0 col0" >2.1% 🟩</td>
#       <td id="T_e04eb_row0_col1" class="data row0 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row0_col2" class="data row0 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row0_col3" class="data row0 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_e04eb_row1_col0" class="data row1 col0" >100.0% 🟥</td>
#       <td id="T_e04eb_row1_col1" class="data row1 col1" >100.0% 🟥</td>
#       <td id="T_e04eb_row1_col2" class="data row1 col2" >100.0% 🟥</td>
#       <td id="T_e04eb_row1_col3" class="data row1 col3" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_e04eb_row2_col0" class="data row2 col0" >0.8% 🟩</td>
#       <td id="T_e04eb_row2_col1" class="data row2 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row2_col2" class="data row2 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row2_col3" class="data row2 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_e04eb_row3_col0" class="data row3 col0" >0.7% 🟩</td>
#       <td id="T_e04eb_row3_col1" class="data row3 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row3_col2" class="data row3 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row3_col3" class="data row3 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_e04eb_row4_col0" class="data row4 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row4_col1" class="data row4 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row4_col2" class="data row4 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row4_col3" class="data row4 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_e04eb_row5_col0" class="data row5 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row5_col1" class="data row5 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row5_col2" class="data row5 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row5_col3" class="data row5 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_e04eb_row6_col0" class="data row6 col0" >0.4% 🟩</td>
#       <td id="T_e04eb_row6_col1" class="data row6 col1" >0.0% 🟩</td>
#       <td id="T_e04eb_row6_col2" class="data row6 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row6_col3" class="data row6 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row7" class="row_heading level0 row7" >08-BW</th>
#       <td id="T_e04eb_row7_col0" class="data row7 col0" >0.5% 🟩</td>
#       <td id="T_e04eb_row7_col1" class="data row7 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row7_col2" class="data row7 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_e04eb_row7_col3" class="data row7 col3" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row8" class="row_heading level0 row8" >09-BY</th>
#       <td id="T_e04eb_row8_col0" class="data row8 col0" >6.4% 🟨</td>
#       <td id="T_e04eb_row8_c

# %% [markdown]
# <br>
#
# #### <a id='toc1_10_7_3_'></a>[Darm](#toc0_)
# - **Filter: `DJ` 2020-2024, `DCO` = N, `ICD10` = C18-C20**

# %%
_fil = """--sql
sel9_darm
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d in ('C18','C19','C20')", "ICD C18-20"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)



show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="50%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="50%"
    )
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [ICD C18-20]:     n = 276_412   (6.9%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d in ('C18','C19','C20')
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-50% -->
# <style type="text/css">
# #T_23328 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_23328 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_23328_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.2%, transparent 53.2%);
#   font-family: Courier;
# }
# #T_23328_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 86.5%, transparent 86.5%);
#   font-family: Courier;
# }
# #T_23328_row1_col0, #T_23328_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_23328_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 65.0%, transparent 65.0%);
#   font-family: Courier;
# }
# #T_23328_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 88.3%, transparent 88.3%);
#   font-family: Courier;
# }
# #T_23328_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 29.5%, transparent 29.5%);
#   font-family: Courier;
# }
# #T_23328_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 86.7%, transparent 86.7%);
#   font-family: Courier;
# }
# #T_23328_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 73.8%, transparent 73.8%);
#   font-family: Courier;
# }
# #T_23328_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.7%, transparent 82.7%);
#   font-family: Courier;
# }
# #T_23328_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.5%, transparent 71.5%);
#   font-family: Courier;
# }
# #T_23328_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 81.1%, transparent 81.1%);
#   font-family: Courier;
# }
# #T_23328_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 87.4%, transparent 87.4%);
#   font-family: Courier;
# }
# #T_23328_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 90.8%, transparent 90.8%);
#   font-family: Courier;
# }
# #T_23328_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.5%, transparent 64.5%);
#   font-family: Courier;
# }
# #T_23328_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 82.4%, transparent 82.4%);
#   font-family: Courier;
# }
# #T_23328_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.2%, transparent 80.2%);
#   font-family: Courier;
# }
# #T_23328_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.6%, transparent 85.6%);
#   font-family: Courier;
# }
# #T_23328_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 79.2%, transparent 79.2%);
#   font-family: Courier;
# }
# #T_23328_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 83.0%, transparent 83.0%);
#   font-family: Courier;
# }
# #T_23328_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.9%, transparent 64.9%);
#   font-family: Courier;
# }
# #T_23328_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 89.7%, transparent 89.7%);
#   font-family: Courier;
# }
# #T_23328_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 72.9%, transparent 72.9%);
#   font-family: Courier;
# }
# #T_23328_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 84.5%, transparent 84.5%);
#   font-family: Courier;
# }
# #T_23328_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 64.1%, transparent 64.1%);
#   font-family: Courier;
# }
# #T_23328_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.9%, transparent 80.9%);
#   font-family: Courier;
# }
# #T_23328_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 88.9%, transparent 88.9%);
#   font-family: Courier;
# }
# #T_23328_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 77.2%, transparent 77.2%);
#   font-family: Courier;
# }
# #T_23328_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 93.5%, transparent 93.5%);
#   font-family: Courier;
# }
# #T_23328_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 95.1%, transparent 95.1%);
#   font-family: Courier;
# }
# #T_23328_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 84.0%, transparent 84.0%);
#   font-family: Courier;
# }
# #T_23328_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 91.1%, transparent 91.1%);
#   font-family: Courier;
# }
# #T_23328_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 73.9%, transparent 73.9%);
#   font-family: Courier;
# }
# #T_23328_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 85.1%, transparent 85.1%);
#   font-family: Courier;
# }
# </style>
# <table id="T_23328">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_23328_level0_col0" class="col_heading level0 col0" >[Tumor]RASMutation</th>
#       <th id="T_23328_level0_col1" class="col_heading level0 col1" >[Tumor]RektumAbstandAnokutanlinie</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23328_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_23328_row0_col0" class="data row0 col0" >53.2% 🟨</td>
#       <td id="T_23328_row0_col1" class="data row0 col1" >86.5% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_23328_row1_col0" class="data row1 col0" >100.0% 🟥</td>
#       <td id="T_23328_row1_col1" class="data row1 col1" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_23328_row2_col0" class="data row2 col0" >65.0% 🟨</td>
#       <td id="T_23328_row2_col1" class="data row2 col1" >88.3% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_23328_row3_col0" class="data row3 col0" >29.5% 🟨</td>
#       <td id="T_23328_row3_col1" class="data row3 col1" >86.7% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_23328_row4_col0" class="data row4 col0" >73.8% 🟨</td>
#       <td id="T_23328_row4_col1" class="data row4 col1" >82.7% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_23328_row5_col0" class="data row5 col0" >71.5% 🟨</td>
#       <td id="T_23328_row5_col1" class="data row5 col1" >81.1% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_23328_row6_col0" class="data row6 col0" >87.4% 🟨</td>
#       <td id="T_23328_row6_col1" class="data row6 col1" >90.8% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row7" class="row_heading level0 row7" >08-BW</th>
#       <td id="T_23328_row7_col0" class="data row7 col0" >64.5% 🟨</td>
#       <td id="T_23328_row7_col1" class="data row7 col1" >82.4% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row8" class="row_heading level0 row8" >09-BY</th>
#       <td id="T_23328_row8_col0" class="data row8 col0" >80.2% 🟨</td>
#       <td id="T_23328_row8_col1" class="data row8 col1" >85.6% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row9" class="row_heading level0 row9" >10-SL</th>
#       <td id="T_23328_row9_col0" class="data row9 col0" >79.2% 🟨</td>
#       <td id="T_23328_row9_col1" class="data row9 col1" >83.0% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row10" class="row_heading level0 row10" >11-BE</th>
#       <td id="T_23328_row10_col0" class="data row10 col0" >64.9% 🟨</td>
#       <td id="T_23328_row10_col1" class="data row10 col1" >89.7% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row11" class="row_heading level0 row11" >12-BB</th>
#       <td id="T_23328_row11_col0" class="data row11 col0" >72.9% 🟨</td>
#       <td id="T_23328_row11_col1" class="data row11 col1" >84.5% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_23328_level0_row12" class="row_head
# 🟠 unknowns
# <!-- SCALE-50% -->
# <style type="text/css">
# #T_79370 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_79370 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_79370_row0_col0, #T_79370_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.2%, transparent 12.2%);
#   font-family: Courier;
# }
# #T_79370_row0_col1, #T_79370_row2_col1, #T_79370_row3_col1, #T_79370_row4_col1, #T_79370_row5_col1, #T_79370_row6_col1, #T_79370_row7_col1, #T_79370_row8_col1, #T_79370_row9_col1, #T_79370_row10_col1, #T_79370_row11_col1, #T_79370_row12_col1, #T_79370_row13_col1, #T_79370_row14_col1, #T_79370_row15_col1, #T_79370_row16_col1 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_79370_row1_col0, #T_79370_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_79370_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.7%, transparent 3.7%);
#   font-family: Courier;
# }
# #T_79370_row4_col0, #T_79370_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.2%, transparent 2.2%);
#   font-family: Courier;
# }
# #T_79370_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.8%, transparent 2.8%);
#   font-family: Courier;
# }
# #T_79370_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_79370_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.7%, transparent 2.7%);
#   font-family: Courier;
# }
# #T_79370_row8_col0, #T_79370_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_79370_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.8%, transparent 3.8%);
#   font-family: Courier;
# }
# #T_79370_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 6.6%, transparent 6.6%);
#   font-family: Courier;
# }
# #T_79370_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_79370_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.0%, transparent 4.0%);
#   font-family: Courier;
# }
# #T_79370_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.0%, transparent 1.0%);
#   font-family: Courier;
# }
# #T_79370_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 3.0%, transparent 3.0%);
#   font-family: Courier;
# }
# </style>
# <table id="T_79370">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_79370_level0_col0" class="col_heading level0 col0" >[Tumor]RASMutation</th>
#       <th id="T_79370_level0_col1" class="col_heading level0 col1" >[Tumor]RektumAbstandAnokutanlinie</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79370_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_79370_row0_col0" class="data row0 col0" >12.2% 🟨</td>
#       <td id="T_79370_row0_col1" class="data row0 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_79370_row1_col0" class="data row1 col0" >100.0% 🟥</td>
#       <td id="T_79370_row1_col1" class="data row1 col1" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_79370_row2_col0" class="data row2 col0" >3.7% 🟩</td>
#       <td id="T_79370_row2_col1" class="data row2 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_79370_row3_col0" class="data row3 col0" >12.2% 🟨</td>
#       <td id="T_79370_row3_col1" class="data row3 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_79370_row4_col0" class="data row4 col0" >2.2% 🟩</td>
#       <td id="T_79370_row4_col1" class="data row4 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_79370_row5_col0" class="data row5 col0" >2.8% 🟩</td>
#       <td id="T_79370_row5_col1" class="data row5 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_79370_row6_col0" class="data row6 col0" >0.7% 🟩</td>
#       <td id="T_79370_row6_col1" class="data row6 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row7" class="row_heading level0 row7" >08-BW</th>
#       <td id="T_79370_row7_col0" class="data row7 col0" >2.7% 🟩</td>
#       <td id="T_79370_row7_col1" class="data row7 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row8" class="row_heading level0 row8" >09-BY</th>
#       <td id="T_79370_row8_col0" class="data row8 col0" >1.9% 🟩</td>
#       <td id="T_79370_row8_col1" class="data row8 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row9" class="row_heading level0 row9" >10-SL</th>
#       <td id="T_79370_row9_col0" class="data row9 col0" >3.8% 🟩</td>
#       <td id="T_79370_row9_col1" class="data row9 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row10" class="row_heading level0 row10" >11-BE</th>
#       <td id="T_79370_row10_col0" class="data row10 col0" >6.6% 🟨</td>
#       <td id="T_79370_row10_col1" class="data row10 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row11" class="row_heading level0 row11" >12-BB</th>
#       <td id="T_79370_row11_col0" class="data row11 col0" >2.1% 🟩</td>
#       <td id="T_79370_row11_col1" class="data row11 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row12" class="row_heading level0 row12" >13-MV</th>
#       <td id="T_79370_row12_col0" class="data row12 col0" >4.0% 🟩</td>
#       <td id="T_79370_row12_col1" class="data row12 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row13" class="row_heading level0 row13" >14-SN</th>
#       <td id="T_79370_row13_col0" class="data row13 col0" >1.0% 🟩</td>
#       <td id="T_79370_row13_col1" class="data row13 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row14" class="row_heading level0 row14" >15-ST</th>
#       <td id="T_79370_row14_col0" class="data row14 col0" >2.2% 🟩</td>
#       <td id="T_79370_row14_col1" class="data row14 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row15" class="row_heading level0 row15" >16-TH</th>
#       <td id="T_79370_row15_col0" class="data row15 col0" >1.9% 🟩</td>
#       <td id="T_79370_row15_col1" class="data row15 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_79370_level0_row16" class="row_heading level0 row16" >Total</th>
#       <td id="T_79370_row16_col0" class="data row16 col0" >3.0% 🟩</td>
#       <td id="T_79370_row16_col1" class="data row16 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <br>
#
# #### <a id='toc1_10_7_4_'></a>[Melanom](#toc0_)
# - **Filter: `DJ` 2020-2024, `DCO` = N, `ICD10` = C43**

# %%
_fil = """--sql
sel10_melanom
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d = 'C43'", "ICD C43"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="50%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="50%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [ICD C43]:        n = 143_542   (3.6%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C43'
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-50% -->
# <style type="text/css">
# #T_dba31 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_dba31 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_dba31_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.0%, transparent 98.0%);
#   font-family: Courier;
# }
# #T_dba31_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.2%, transparent 52.2%);
#   font-family: Courier;
# }
# #T_dba31_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 58.5%, transparent 58.5%);
#   font-family: Courier;
# }
# #T_dba31_row1_col0, #T_dba31_row1_col1, #T_dba31_row1_col2, #T_dba31_row5_col0, #T_dba31_row5_col1, #T_dba31_row5_col2, #T_dba31_row8_col0, #T_dba31_row8_col1, #T_dba31_row8_col2, #T_dba31_row10_col0, #T_dba31_row10_col1, #T_dba31_row10_col2, #T_dba31_row11_col0, #T_dba31_row11_col1, #T_dba31_row11_col2, #T_dba31_row12_col0, #T_dba31_row12_col1, #T_dba31_row12_col2, #T_dba31_row13_col0, #T_dba31_row13_col1, #T_dba31_row13_col2, #T_dba31_row14_col0, #T_dba31_row14_col1, #T_dba31_row14_col2, #T_dba31_row15_col0, #T_dba31_row15_col1, #T_dba31_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# #T_dba31_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 93.8%, transparent 93.8%);
#   font-family: Courier;
# }
# #T_dba31_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 38.9%, transparent 38.9%);
#   font-family: Courier;
# }
# #T_dba31_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 56.4%, transparent 56.4%);
#   font-family: Courier;
# }
# #T_dba31_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 78.0%, transparent 78.0%);
#   font-family: Courier;
# }
# #T_dba31_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.5%, transparent 17.5%);
#   font-family: Courier;
# }
# #T_dba31_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 12.9%, transparent 12.9%);
#   font-family: Courier;
# }
# #T_dba31_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 84.3%, transparent 84.3%);
#   font-family: Courier;
# }
# #T_dba31_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 57.8%, transparent 57.8%);
#   font-family: Courier;
# }
# #T_dba31_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.6%, transparent 71.6%);
#   font-family: Courier;
# }
# #T_dba31_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.3%, transparent 98.3%);
#   font-family: Courier;
# }
# #T_dba31_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 84.2%, transparent 84.2%);
#   font-family: Courier;
# }
# #T_dba31_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 87.0%, transparent 87.0%);
#   font-family: Courier;
# }
# #T_dba31_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 91.8%, transparent 91.8%);
#   font-family: Courier;
# }
# #T_dba31_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.3%, transparent 17.3%);
#   font-family: Courier;
# }
# #T_dba31_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 39.3%, transparent 39.3%);
#   font-family: Courier;
# }
# #T_dba31_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 97.5%, transparent 97.5%);
#   font-family: Courier;
# }
# #T_dba31_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 39.5%, transparent 39.5%);
#   font-family: Courier;
# }
# #T_dba31_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.2%, transparent 54.2%);
#   font-family: Courier;
# }
# #T_dba31_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 94.6%, transparent 94.6%);
#   font-family: Courier;
# }
# #T_dba31_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 68.1%, transparent 68.1%);
#   font-family: Courier;
# }
# #T_dba31_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 76.7%, transparent 76.7%);
#   font-family: Courier;
# }
# </style>
# <table id="T_dba31">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_dba31_level0_col0" class="col_heading level0 col0" >[Tumor]LDH</th>
#       <th id="T_dba31_level0_col1" class="col_heading level0 col1" >[Tumor]Tumordicke</th>
#       <th id="T_dba31_level0_col2" class="col_heading level0 col2" >[Tumor]Ulzeration</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dba31_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_dba31_row0_col0" class="data row0 col0" >98.0% 🟨</td>
#       <td id="T_dba31_row0_col1" class="data row0 col1" >52.2% 🟨</td>
#       <td id="T_dba31_row0_col2" class="data row0 col2" >58.5% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_dba31_row1_col0" class="data row1 col0" >100.0% 🟥</td>
#       <td id="T_dba31_row1_col1" class="data row1 col1" >100.0% 🟥</td>
#       <td id="T_dba31_row1_col2" class="data row1 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_dba31_row2_col0" class="data row2 col0" >93.8% 🟨</td>
#       <td id="T_dba31_row2_col1" class="data row2 col1" >38.9% 🟨</td>
#       <td id="T_dba31_row2_col2" class="data row2 col2" >56.4% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_dba31_row3_col0" class="data row3 col0" >78.0% 🟨</td>
#       <td id="T_dba31_row3_col1" class="data row3 col1" >17.5% 🟨</td>
#       <td id="T_dba31_row3_col2" class="data row3 col2" >12.9% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_dba31_row4_col0" class="data row4 col0" >84.3% 🟨</td>
#       <td id="T_dba31_row4_col1" class="data row4 col1" >57.8% 🟨</td>
#       <td id="T_dba31_row4_col2" class="data row4 col2" >71.6% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_dba31_row5_col0" class="data row5 col0" >100.0% 🟥</td>
#       <td id="T_dba31_row5_col1" class="data row5 col1" >100.0% 🟥</td>
#       <td id="T_dba31_row5_col2" class="data row5 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_dba31_row6_col0" class="data row6 col0" >98.3% 🟨</td>
#       <td id="T_dba31_row6_col1" class="data row6 col1" >84.2% 🟨</td>
#       <td id="T_dba31_row6_col2" class="data row6 col2" >87.0% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row7" class="row_heading level0 row7" >08-BW</th>
#       <td id="T_dba31_row7_col0" class="data row7 col0" >91.8% 🟨</td>
#       <td id="T_dba31_row7_col1" class="data row7 col1" >17.3% 🟨</td>
#       <td id="T_dba31_row7_col2" class="data row7 col2" >39.3% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row8" class="row_heading level0 row8" >09-BY</th>
#       <td id="T_dba31_row8_col0" class="data row8 col0" >100.0% 🟥</td>
#       <td id="T_dba31_row8_col1" class="data row8 col1" >100.0% 🟥</td>
#       <td id="T_dba31_row8_col2" class="data row8 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row9" class="row_heading level0 row9" >10-SL</th>
#       <td id="T_dba31_row9_col0" class="data row9 col0" >97.5% 🟨</td>
#       <td id="T_dba31_row9_col1" class="data row9 col1" >39.5% 🟨</td>
#       <td id="T_dba31_row9_col2" class="data row9 col2" >54.2% 🟨</td>
#     </tr>
#     <tr>
#       <th id="T_dba31_level0_row10" class="row_heading level0 row10" >11-BE</th>
#       <td id="T_dba31_row10_col0" class="data row10 col0" >100.0% 🟥</td>
#       <td id="T_dba31_row10_col1" class="data row10 col1" >100.0% 🟥</td>
#       <td id="T_dba31_row10_col2" class="data row10 col2" >10
# 🟠 unknowns
# <!-- SCALE-50% -->
# <style type="text/css">
# #T_1460b th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_1460b td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_1460b_row0_col0, #T_1460b_row0_col1, #T_1460b_row0_col2, #T_1460b_row2_col0, #T_1460b_row2_col1, #T_1460b_row2_col2, #T_1460b_row3_col0, #T_1460b_row3_col1, #T_1460b_row3_col2, #T_1460b_row4_col0, #T_1460b_row4_col1, #T_1460b_row4_col2, #T_1460b_row6_col0, #T_1460b_row6_col1, #T_1460b_row6_col2, #T_1460b_row7_col0, #T_1460b_row7_col1, #T_1460b_row7_col2, #T_1460b_row9_col0, #T_1460b_row9_col1, #T_1460b_row9_col2, #T_1460b_row16_col0, #T_1460b_row16_col1, #T_1460b_row16_col2 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_1460b_row1_col0, #T_1460b_row1_col1, #T_1460b_row1_col2, #T_1460b_row5_col0, #T_1460b_row5_col1, #T_1460b_row5_col2, #T_1460b_row8_col0, #T_1460b_row8_col1, #T_1460b_row8_col2, #T_1460b_row10_col0, #T_1460b_row10_col1, #T_1460b_row10_col2, #T_1460b_row11_col0, #T_1460b_row11_col1, #T_1460b_row11_col2, #T_1460b_row12_col0, #T_1460b_row12_col1, #T_1460b_row12_col2, #T_1460b_row13_col0, #T_1460b_row13_col1, #T_1460b_row13_col2, #T_1460b_row14_col0, #T_1460b_row14_col1, #T_1460b_row14_col2, #T_1460b_row15_col0, #T_1460b_row15_col1, #T_1460b_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 100.0%, transparent 100.0%);
#   font-family: Courier;
# }
# </style>
# <table id="T_1460b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th id="T_1460b_level0_col0" class="col_heading level0 col0" >[Tumor]LDH</th>
#       <th id="T_1460b_level0_col1" class="col_heading level0 col1" >[Tumor]Tumordicke</th>
#       <th id="T_1460b_level0_col2" class="col_heading level0 col2" >[Tumor]Ulzeration</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >z_kkr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1460b_level0_row0" class="row_heading level0 row0" >01-SH</th>
#       <td id="T_1460b_row0_col0" class="data row0 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row0_col1" class="data row0 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row0_col2" class="data row0 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row1" class="row_heading level0 row1" >02-HH</th>
#       <td id="T_1460b_row1_col0" class="data row1 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row1_col1" class="data row1 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row1_col2" class="data row1 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row2" class="row_heading level0 row2" >03-NI</th>
#       <td id="T_1460b_row2_col0" class="data row2 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row2_col1" class="data row2 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row2_col2" class="data row2 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row3" class="row_heading level0 row3" >04-HB</th>
#       <td id="T_1460b_row3_col0" class="data row3 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row3_col1" class="data row3 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row3_col2" class="data row3 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row4" class="row_heading level0 row4" >05-NW</th>
#       <td id="T_1460b_row4_col0" class="data row4 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row4_col1" class="data row4 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row4_col2" class="data row4 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row5" class="row_heading level0 row5" >06-HE</th>
#       <td id="T_1460b_row5_col0" class="data row5 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row5_col1" class="data row5 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row5_col2" class="data row5 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row6" class="row_heading level0 row6" >07-RP</th>
#       <td id="T_1460b_row6_col0" class="data row6 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row6_col1" class="data row6 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row6_col2" class="data row6 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row7" class="row_heading level0 row7" >08-BW</th>
#       <td id="T_1460b_row7_col0" class="data row7 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row7_col1" class="data row7 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row7_col2" class="data row7 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row8" class="row_heading level0 row8" >09-BY</th>
#       <td id="T_1460b_row8_col0" class="data row8 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row8_col1" class="data row8 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row8_col2" class="data row8 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row9" class="row_heading level0 row9" >10-SL</th>
#       <td id="T_1460b_row9_col0" class="data row9 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row9_col1" class="data row9 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row9_col2" class="data row9 col2" ><span style="color: #A9A9A9">0 🟩</span></td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row10" class="row_heading level0 row10" >11-BE</th>
#       <td id="T_1460b_row10_col0" class="data row10 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row10_col1" class="data row10 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row10_col2" class="data row10 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row11" class="row_heading level0 row11" >12-BB</th>
#       <td id="T_1460b_row11_col0" class="data row11 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row11_col1" class="data row11 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row11_col2" class="data row11 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row12" class="row_heading level0 row12" >13-MV</th>
#       <td id="T_1460b_row12_col0" class="data row12 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row12_col1" class="data row12 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row12_col2" class="data row12 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row13" class="row_heading level0 row13" >14-SN</th>
#       <td id="T_1460b_row13_col0" class="data row13 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row13_col1" class="data row13 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row13_col2" class="data row13 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row14" class="row_heading level0 row14" >15-ST</th>
#       <td id="T_1460b_row14_col0" class="data row14 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row14_col1" class="data row14 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row14_col2" class="data row14 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row15" class="row_heading level0 row15" >16-TH</th>
#       <td id="T_1460b_row15_col0" class="data row15 col0" >100.0% 🟥</td>
#       <td id="T_1460b_row15_col1" class="data row15 col1" >100.0% 🟥</td>
#       <td id="T_1460b_row15_col2" class="data row15 col2" >100.0% 🟥</td>
#     </tr>
#     <tr>
#       <th id="T_1460b_level0_row16" class="row_heading level0 row16" >Total</th>
#       <td id="T_1460b_row16_col0" class="data row16 col0" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row16_col1" class="data row16 col1" ><span style="color: #A9A9A9">0 🟩</span></td>
#       <td id="T_1460b_row16_col2" class="data row16 col2" ><span style="color: #A9A9A9">0 🟩</span></td>

# %%
# show_missings(
#     kpi.MISSINGS.value,
#     filter=f"{fil_pd_dco_dy} and sel10_melanom and icd10_3d in ('C43')",
#     group_table=grouper_table.TABLECOL.value,
# )

# %% [markdown]
# ## <a id='toc1_11_'></a>[🆕 Weitere Klassifikationen](#toc0_)
#
# - Freitexte werden per regex in diesem [sql script](../sql/check_if_class.sql) zugeordnet

# %% [markdown]
# ### <a id='toc1_11_1_'></a>[nach Quelle](#toc0_)
# - `source`
#   - `diag`: Klassifikation ist der Diagnose zugeordnet
#   - `fol`: Klassifikation ist einem Folgeereignis zugeordnet

# %%
with open("../sql/check_if_class.sql") as f:
    _macro_check_if_class = f.read()
_=con.execute(_macro_check_if_class)

# %%
db_class = (con.sql("""--sql
        with dia_fol as (
            select Name, Stadium, z_tum_id,
            'diag' as source 
            from Diagnose_WeitereKlassifikation
            union
            select Name, Stadium, z_tum_id,
            'fol' as source 
            from Folgeereignis_WeitereKlassifikation
        )
        select
            tum.z_tum_id,
            Name,
            Stadium,
            z_kkr_label,
            source,
            z_dy,
            case when z_dy < 2020 then '(<2020)' else z_dy::text end as z_dy_str,
            mem.fx_check_if_class(Name) as class,
        from dia_fol
        join Tumor tum on dia_fol.z_tum_id = tum.z_tum_id
        --where Stadium is not null
    """)
)
# tbl.descr_db(db_class, "db_class")
con.register("db_class", db_class)

_filters = [
    ("Stadium is not null", "Stadium vorhanden"),
    ("z_dy < 2025","")
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from db_class",
    filters=_filters,
)

db_class_filtered = db_class.filter(_filter)
# Out:
# <!-- START_TOKEN -->
# n = 849_517                        (100.0%) ██████████████████████████████
# └ [Stadium vorhanden]: n = 849_517 (100.0%) ██████████████████████████████
# └ [z_dy < 2025]:       n = 848_904  (99.9%) ░█████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Stadium is not null
# and z_dy < 2025
# ```
#
# </details>

# %%
_df = (db_class_filtered
    .aggregate("class, source, count(*) as cnt")
    .to_df()
)

pls.plot_stacked_bars(
    _df,
    orientation="h",
    sort_values_index=True,
    height=600,
    normalize=True,
    show_pct_all=True,
    top_n_index=20,
    color_palette=const.PALETTE_RKI2,
    null_label="(no_match)",
)

# %%
_df = (db_class_filtered
    .aggregate("class, z_kkr_label, count(*) as cnt")
    .to_df()
)
tbl.pivot_df(
    _df,
    top_n_index=10,
    data_bar_axis="",
    heatmap_axis="xy",
    # total_exclude=True,
    pct_axis="",
    total_axis="",
)
# Out:
# <style type="text/css">
# #T_6409f th {
#   text-align: right;
# }
# #T_6409f td {
#   text-align: right;
# }
# #T_6409f_row0_col0, #T_6409f_row0_col9, #T_6409f_row1_col1, #T_6409f_row1_col9, #T_6409f_row2_col6, #T_6409f_row2_col9, #T_6409f_row4_col1, #T_6409f_row4_col3, #T_6409f_row4_col15, #T_6409f_row5_col2, #T_6409f_row5_col6, #T_6409f_row5_col10, #T_6409f_row6_col3, #T_6409f_row6_col5, #T_6409f_row6_col15, #T_6409f_row9_col10, #T_6409f_row9_col11 {
#   font-family: Courier;
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_6409f_row0_col1, #T_6409f_row2_col5, #T_6409f_row3_col14, #T_6409f_row4_col8, #T_6409f_row4_col13, #T_6409f_row6_col11, #T_6409f_row7_col5, #T_6409f_row9_col1 {
#   font-family: Courier;
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_6409f_row0_col2, #T_6409f_row3_col8, #T_6409f_row3_col10, #T_6409f_row3_col11, #T_6409f_row4_col2, #T_6409f_row4_col10, #T_6409f_row5_col14, #T_6409f_row6_col9 {
#   font-family: Courier;
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_6409f_row0_col3, #T_6409f_row1_col3, #T_6409f_row1_col4, #T_6409f_row2_col0, #T_6409f_row2_col1, #T_6409f_row2_col3, #T_6409f_row2_col4, #T_6409f_row2_col12, #T_6409f_row3_col0, #T_6409f_row3_col1, #T_6409f_row3_col3, #T_6409f_row3_col4, #T_6409f_row4_col4, #T_6409f_row5_col0, #T_6409f_row5_col1, #T_6409f_row5_col3, #T_6409f_row5_col4, #T_6409f_row6_col0, #T_6409f_row6_col4, #T_6409f_row6_col6, #T_6409f_row7_col0, #T_6409f_row7_col2, #T_6409f_row7_col3, #T_6409f_row7_col4, #T_6409f_row7_col6, #T_6409f_row7_col8, #T_6409f_row7_col9, #T_6409f_row7_col10, #T_6409f_row7_col11, #T_6409f_row7_col12, #T_6409f_row7_col13, #T_6409f_row7_col14, #T_6409f_row7_col15, #T_6409f_row8_col0, #T_6409f_row8_col1, #T_6409f_row8_col2, #T_6409f_row8_col3, #T_6409f_row8_col5, #T_6409f_row8_col6, #T_6409f_row8_col8, #T_6409f_row8_col9, #T_6409f_row8_col10, #T_6409f_row8_col11, #T_6409f_row8_col12, #T_6409f_row8_col13, #T_6409f_row8_col14, #T_6409f_row8_col15, #T_6409f_row9_col3, #T_6409f_row9_col4, #T_6409f_row9_col12, #T_6409f_row9_col15 {
#   font-family: Courier;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6409f_row0_col4 {
#   font-family: Courier;
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_6409f_row0_col5, #T_6409f_row0_col13, #T_6409f_row9_col13 {
#   font-family: Courier;
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_6409f_row0_col6, #T_6409f_row1_col2, #T_6409f_row2_col10, #T_6409f_row3_col15, #T_6409f_row6_col2, #T_6409f_row6_col8, #T_6409f_row6_col13 {
#   font-family: Courier;
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_6409f_row0_col7 {
#   font-family: Courier;
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_6409f_row0_col8 {
#   font-family: Courier;
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_6409f_row0_col10, #T_6409f_row0_col15, #T_6409f_row2_col13, #T_6409f_row6_col10, #T_6409f_row7_col1, #T_6409f_row9_col0, #T_6409f_row9_col9 {
#   font-family: Courier;
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_6409f_row0_col11, #T_6409f_row3_col7, #T_6409f_row5_col5 {
#   font-family: Courier;
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_6409f_row0_col12, #T_6409f_row0_col14, #T_6409f_row1_col5, #T_6409f_row1_col10, #T_6409f_row2_col8 {
#   font-family: Courier;
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_6409f_row1_col0, #T_6409f_row1_col12, #T_6409f_row1_col14, #T_6409f_row2_col2, #T_6409f_row2_col11, #T_6409f_row2_col14, #T_6409f_row4_col0, #T_6409f_row5_col9, #T_6409f_row5_col15, #T_6409f_row6_col1, #T_6409f_row6_col12, #T_6409f_row9_col14 {
#   font-family: Courier;
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_6409f_row1_col6, #T_6409f_row1_col15, #T_6409f_row2_col15, #T_6409f_row3_col2, #T_6409f_row3_col5, #T_6409f_row3_col6, #T_6409f_row3_col9, #T_6409f_row3_col12, #T_6409f_row4_col6, #T_6409f_row4_col9, #T_6409f_row4_col11, #T_6409f_row4_col12, #T_6409f_row4_col14, #T_6409f_row5_col11, #T_6409f_row5_col12, #T_6409f_row6_col14, #T_6409f_row8_col7, #T_6409f_row9_col6 {
#   font-family: Courier;
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_6409f_row1_col7, #T_6409f_row1_col8 {
#   font-family: Courier;
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_6409f_row1_col11, #T_6409f_row3_col13, #T_6409f_row4_col5 {
#   font-family: Courier;
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_6409f_row1_col13, #T_6409f_row5_col13 {
#   font-family: Courier;
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_6409f_row2_col7, #T_6409f_row4_col7 {
#   font-family: Courier;
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_6409f_row5_col7 {
#   font-family: Courier;
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_6409f_row5_col8 {
#   font-family: Courier;
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_6409f_row6_col7, #T_6409f_row9_col5 {
#   font-family: Courier;
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_6409f_row7_col7 {
#   font-family: Courier;
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_6409f_row8_col4 {
#   font-family: Courier;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6409f_row9_col2 {
#   font-family: Courier;
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_6409f_row9_col7 {
#   font-family: Courier;
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_6409f_row9_col8 {
#   font-family: Courier;
#   background-color: #e7f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_6409f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >z_kkr_label</th>
#       <th id="T_6409f_level0_col0" class="col_heading level0 col0" >01-SH</th>
#       <th id="T_6409f_level0_col1" class="col_heading level0 col1" >02-HH</th>
#       <th id="T_6409f_level0_col2" class="col_heading level0 col2" >03-NI</th>
#       <th id="T_6409f_level0_col3" class="col_heading level0 col3" >04-HB</th>
#       <th id="T_6409f_level0_col4" class="col_heading level0 col4" >05-NW</th>
#       <th id="T_6409f_level0_col5" class="col_heading level0 col5" >06-HE</th>
#       <th id="T_6409f_level0_col6" class="col_heading level0 col6" >07-RP</th>
#       <th id="T_6409f_level0_col7" class="col_heading level0 col7" >08-BW</th>
#       <th id="T_6409f_level0_col8" class="col_heading level0 col8" >09-BY</th>
#       <th id="T_6409f_level0_col9" class="col_heading level0 col9" >10-SL</th>
#       <th id="T_6409f_level0_col10" class="col_heading level0 col10" >11-BE</th>
#       <th id="T_6409f_level0_col11" class="col_heading level0 col11" >12-BB</th>
#       <th id="T_6409f_level0_col12" class="col_heading level0 col12" >13-MV</th>
#       <th id="T_6409f_level0_col13" class="col_heading level0 col13" >14-SN</th>
#       <th id="T_6409f_level0_col14" class="col_heading level0 col14" >15-ST</th>
#       <th id="T_6409f_level0_col15" class="col_heading level0 col15" >16-TH</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6409f_level0_row0" class="row_heading level0 row0" >(NA)</th>
#       <td id="T_6409f_row0_col0" class="data row0 col0" >1_007 </td>
#       <td id="T_6409f_row0_col1" class="data row0 col1" >2_933 </td>
#       <td id="T_6409f_row0_col2" class="data row0 col2" >3_898 </td>
#       <td id="T_6409f_row0_col3" class="data row0 col3" >422 </td>
#       <td id="T_6409f_row0_col4" class="data row0 col4" >22_029 </td>
#       <td id="T_6409f_row0_col5" class="data row0 col5" >7_535 </td>
#       <td id="T_6409f_row0_col6" class="data row0 col6" >2_286

# %% [markdown]
# ### <a id='toc1_11_2_'></a>[nach Jahren](#toc0_)

# %%
_df = (db_class_filtered
    .aggregate("class, z_dy_str as z_dy, count(*) as cnt")
    .to_df()
)

pls.plot_stacked_bars(
    _df,
    orientation="h",
    height=450,
    # normalize=True,
    # show_pct_all=True,
    top_n_color=10,
    first_col_grey=True,
    relative=True,
    swap=True,
    show_other=True,
)

# %%
# db_class_agg = (db_class_filtered
#     .aggregate("z_kkr_label, source, class, count(*) as cnt, count(distinct z_tum_id) as cnt_tum")
# )

# # db_class_top_n = db_class_agg.aggregate("class, sum(cnt) as cnt").order("cnt desc").project("class").limit(TOP_N)

# _df = (db_class_agg
#     .project("class, z_kkr_label, cnt")
#     .filter("class in (select class from db_class_top_n)")
#     .to_df()
#     .dropna()
# )
# tbl.pivot_df(
#     _df,
#     data_bar_axis="",
#     heatmap_axis="xy",
#     pct_axis="",
#     total_axis="xy",
#     total_exclude=True,
#     top_n_index=10,
# )

# %% [markdown]
# ### <a id='toc1_11_3_'></a>[PSA](#toc0_)

# %% [markdown]
# #### <a id='toc1_11_3_1_'></a>[Angabe zu Diagnose vs Weitere Klassifikationen](#toc0_)
#
# - Kategorien für die Kombination von PSA Werten zu jedem Tumor
#   - `1_all_null`: keine PSA Werte zum Tumor
#   - `2_tum_only`: PSA Wert nur vom Organmodul
#   - `3_class_only`: PSA Wert nur aus Weitere Klassifikationen (Diagnose oder Folgeereignis)
#   - `4_tum_and_class`: PSA Werte aus Organmodul und Weitere Klassifikationen

# %%
db_comb =con.sql("""--sql
    with t0 as (
        select
            PSA as psa,
            z_tum_id,
            z_kkr_label,
            z_dy,
            z_icd10_3d,
            z_is_dco,
        from Tumor
    ),
    t1_diag as (
        select z_tum_id, count(*) as cnt
        from Diagnose_WeitereKlassifikation 
        where Name ilike '%psa%'
        and Stadium is not null
        group by all
    ),
    t1_fol as (
        select z_tum_id, count(*) as cnt
        from Folgeereignis_WeitereKlassifikation
        where Name ilike '%psa%'
        and Stadium is not null
        group by all
    ),
    t2 as (
        select
            --t0.z_tum_id,
            z_kkr_label,
            z_dy,
            z_icd10_3d,
            z_is_dco,
            (psa is not null) as has_psa,
            (t1_diag.z_tum_id is not null) as has_diag,
            (t1_fol.z_tum_id is not null) as has_fol,
            (t1_fol.z_tum_id is not null or t1_diag.z_tum_id is not null) as has_class,
            --t1_diag.cnt as cnt_psa_diag,
            --t1_fol.cnt as cnt_psa_fol,
            t1_diag.cnt + t1_fol.cnt as cnt_class,
            case
                when not has_psa and not has_class then '1_all_null'
                when has_psa and not has_class then '2_tum_only'
                when not has_psa and has_class then '3_class_only'
                when has_psa and has_class then '4_tum_and_class'
                --when psa is null and t1_diag.z_tum_id is null and t1_fol.z_tum_id is null then '1_all_null'
                --when psa is not null and t1_diag.z_tum_id is null and t1_fol.z_tum_id is null then '2_tum_only'
                --when psa is null and (t1_diag.z_tum_id is not null or t1_fol.z_tum_id is null) then '3_class_only'
                --when psa is not null and t1_diag.z_tum_id is not null and t1_fol.z_tum_id is not null then '4_tum_and_class'
                --when coalesce(psa::text, t1_diag.z_tum_id, t1_fol.z_tum_id) is not null then '5_mixed'
            else 'U' end as categ_psa
        from t0
        left join t1_diag on t0.z_tum_id = t1_diag.z_tum_id
        left join t1_fol on t0.z_tum_id = t1_fol.z_tum_id
    )
    select * from t2
""")
con.register("db_comb", db_comb)

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d = 'C61'", "ICD C61"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from db_comb",
    filters=_filters,
)

db_comb_filtered = db_comb.filter(_filter)

# db_comb.filter("categ_psa = 'U'").show()
# tbl.descr_db(db_comb, "db_comb")


pls.plot_stacked_bars(
    db_comb_filtered.project("z_kkr_label, categ_psa").to_df(),
    orientation="h",
    relative=True,
    show_total=True,
    show_pct_bar=True,
    first_col_grey=True,
    color_palette=const.PALETTE_RKI2,
    height=900,
)

pls.plot_upset(
    db_comb_filtered.project("columns('^has_')").project("* exclude (has_class)").to_df(),
    include_false_subsets=False,
    )
del db_comb
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [ICD C61]:        n = 375_506   (9.4%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C61'
# ```
#
# </details>
# n = 375_506 | n(true) = 245_759

# %% [markdown]
# #### <a id='toc1_11_3_2_'></a>[Weitere Klassifikationen: Diagnose vs Folgeereignis](#toc0_)
#
# - Kategorien für die Kombination von PSA Werten zu jedem Tumor
#   - `1_none`: keine PSA Wert in Weitere Klassifikationen
#   - `2_both`: PSA Wert sowohl für Diagnose als auch für Folgeereignis vorhanden
#   - `3_diag_only`: PSA Wert nur für Diagnose vorhanden
#   - `4_fol_only`: PSA Werte nur für Folgeereignis vorhanden

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d = 'C61'", "ICD C61"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
)

db_comb =con.sql(f"""--sql
    with t0 as (
        select
            PSA as psa,
            z_tum_id,
            z_kkr_label,
            z_dy,
            z_icd10_3d,
            z_is_dco,
        from Tumor
        where {_filter}
    ),
    t1_diag as (
        select z_tum_id, count(*) as cnt
        from Diagnose_WeitereKlassifikation 
        where Name ilike '%psa%'
        and Stadium is not null
        group by all
    ),
    t1_fol as (
        select z_tum_id, count(*) as cnt
        from Folgeereignis_WeitereKlassifikation
        where Name ilike '%psa%'
        and Stadium is not null
        group by all
    ),
    t2 as (
        select
            --t0.z_tum_id,
            z_kkr_label,
            -- z_dy,
            --z_icd10_3d,
            --z_is_dco,
            (psa is not null) as has_psa,
            (t1_diag.z_tum_id is not null) as has_diag,
            (t1_fol.z_tum_id is not null) as has_fol,
            (t1_fol.z_tum_id is not null or t1_diag.z_tum_id is not null) as has_class,
            t1_diag.cnt + t1_fol.cnt as cnt_class,
            case
                when not has_class then '1_none'
                when has_diag and has_fol then '2_both'
                when has_diag and not has_fol then '3_diag_only'
                when not has_diag and has_fol then '4_fol_only'
            else 'U' end as categ_psa2
        from t0
        left join t1_diag on t0.z_tum_id = t1_diag.z_tum_id
        left join t1_fol on t0.z_tum_id = t1_fol.z_tum_id
    )
    select * from t2
""")

# db_comb.show()

pls.plot_stacked_bars(
    db_comb.project("z_kkr_label, categ_psa2").to_df(),
    orientation="h",
    relative=True,
    show_total=True,
    show_pct_bar=True,
    first_col_grey=True,
    color_palette=const.PALETTE_RKI2,
    height=700,
)

del db_comb
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [ICD C61]:        n = 375_506   (9.4%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C61'
# ```
#
# </details>

# %% [markdown]
# ### <a id='toc1_11_4_'></a>[UICC](#toc0_)

# %%
db_uicc =con.sql("""--sql
    with t0 as (
        select
            UICC_Stadium_p as uicc,
            z_tum_id,
            z_kkr_label,
            z_dy,
            z_icd10,
            z_icd10_3d,
            z_is_dco,
            Morphologie_Code,
        from Tumor
    ),
    t1_diag as (
        select z_tum_id, count(*) as cnt
        from Diagnose_WeitereKlassifikation 
        where Name ilike '%uicc%'
        and Stadium is not null
        group by all
    ),
    t1_fol as (
        select z_tum_id, count(*) as cnt
        from Folgeereignis_WeitereKlassifikation
        where Name ilike '%uicc%'
        and Stadium is not null
        group by all
    ),
    t2 as (
        select
            t0.*,
            (uicc is not null) as has_uicc,
            (t1_diag.z_tum_id is not null) as has_diag,
            (t1_fol.z_tum_id is not null) as has_fol,
            (t1_fol.z_tum_id is not null or t1_diag.z_tum_id is not null) as has_class,
            case
                when not has_uicc and not has_class then '1_all_null'
                when has_uicc and not has_class then '2_tum_only'
                when not has_uicc and has_class then '3_class_only'
                when has_uicc and has_class then '4_tum_and_class'
            else 'U' end as categ_uicc
        from t0
        left join t1_diag on t0.z_tum_id = t1_diag.z_tum_id
        left join t1_fol on t0.z_tum_id = t1_fol.z_tum_id
    )
    select * from t2
""")
con.register("db_uicc", db_uicc)

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from db_uicc",
    filters=_filters,
)

db_uicc_filtered = db_uicc.filter(_filter)

# db_uicc_filtered.filter("categ_uicc = 'U'").show()
# tbl.descr_db(db_uicc, "db_uicc")


pls.plot_stacked_bars(
    db_uicc_filtered.project("z_kkr_label, categ_uicc").to_df(),
    orientation="h",
    relative=True,
    show_total=True,
    show_pct_bar=True,
    first_col_grey=True,
)

pls.plot_upset(
    db_uicc_filtered.project("columns('^has_')").project("* exclude (has_class)").to_df(),
    include_false_subsets=False,
    )
del db_uicc
# Out:
# <!-- START_TOKEN -->
# n = 4_015_983                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_758_513  (93.6%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_637_144  (90.6%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_064_712  (51.4%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>
# n = 2_064_712 | n(true) = 655_640

# %% [markdown]
# ## <a id='toc1_12_'></a>[🆕 Freitexte](#toc0_)

# %%
# import plotly.express as px
# dir(px.colors.qualitative)

# %%
db_subst = con.sql("""--sql
    select
        z_tum_id,
        lpad(z_kkr::text, 2, '0') as z_kkr,
        (SYST_TypSubstanzATC_Code is not null) as has_code,
        (Bezeichnung is not null) as has_text,
        case when z_substance_prediction_score >= 0.85 then true else false end as has_pred,
        case
            when not has_code and not has_text and not has_pred then '1_all_null'
            when has_code and not has_text and not has_pred then '2_code_only'
            when not has_code and has_text and not has_pred then '3_text_unpredicted'
            when not has_code and has_text and has_pred then '4_predicted'
        else 'U' end as categ_subst
    from Substanz
""")

pls.plot_stacked_bars(
    db_subst.project("z_kkr, categ_subst").to_df(),
    orientation="h",
    # relative=True,
    # show_total=True,
    show_pct_bar=True,
    first_col_grey=True,
    color_palette=const.PALETTE_RKI2,
    # color_palette="Pastel",
)

# %% [markdown]
# <br>
#
# ## <a id='toc1_13_'></a>[Datum_Vitalstatus](#toc0_)

# %% [markdown]
# ### <a id='toc1_13_1_'></a>[Verteilung Monat](#toc0_)
# - **Filter: alle Patienten mit `Verstorben`=N, `DJ` und `SJ` 2020-2024**
#
# > 💡 `HH`: _"Das liegt an unserer Darstellung des Vitalstatus-Datum. Nach Abschluss der DC-Recherche, die nach Abschluss des 'Todesjahres' durchgeführt wird, wird bei allen Patienten bei denen wir keine weiteren Meldungen bzw Informationen zum Vitalstatus bekommen haben der 31.12. des abgeschlossenen 'Todesjahres' gesetzt. In diesem Fall ist dies das aktuelle Jahr - 2 -> 31.12.2022, da die DC-Recherche zum Zeitpunkt der Datenlieferung noch nicht abgeschlossen war. Wenn jetzt ein Patient die letzte Meldung mit einem Leistungsdatum in 2019 hatte, wir aber keine weiteren Informationen bekommen haben, gehen wir also nach Abschluss der Recherche davon aus, dass der Patient am 31.12.2022 noch gelebt hat. Dadurch 'verbessert' sich tatsächlich der Vitalstatus in unseren Daten, ansonsten wäre dieser nämlich irgendwann in 2019."_
#
# > 💡 `ZfKD`: angestrebt ist die Verwendung eines einzelnen Erhebungszeitpunkts (z.B. Dezember)

# %%
_filters = [
    FILTERS_DY,
    ("Verstorben = 'N'",""),
    ("year(Datum_Vitalstatus) >= 2020","Vitalstatus >= 2020"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum join Patient pat on tum.oBDS_RKIPatientId = pat.oBDS_RKIPatientId",
    filters=_filters,
    distinct_metric="z_pat_id",
)


_tu = (Patient
    # to get tum cols
    .join(Tumor, "oBDS_RKIPatientId", "inner")
    .filter(_filter)
    # apply tum filter
    .project("z_kkr_label, month(cast(Datum_Vitalstatus as date)) as Vitalstatus_MM, oBDS_RKIPatientId, year(Datum_Vitalstatus::date)::text as Vitalstatus_YY")
    # count pat, not tum
    .aggregate("z_kkr_label,Vitalstatus_MM, Vitalstatus_YY, count(distinct oBDS_RKIPatientId) as cnt")
    .order("z_kkr_label,Vitalstatus_MM")
    .to_df()
    .astype({"Vitalstatus_MM": "Int64"}).astype({"Vitalstatus_MM": str})
)
_tu.Vitalstatus_MM = _tu.Vitalstatus_MM.str.zfill(2)

# _tu
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_420_720                          (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:        n = 3_412_547  (99.8%) ░█████████████████████████████
# └ [Verstorben = 'N']:    n = 2_431_448  (71.1%) ░░░░░░░░░█████████████████████
# └ [Vitalstatus >= 2020]: n = 2_426_295  (70.9%) ░░░░░░░░░█████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Verstorben = 'N'
# and year(Datum_Vitalstatus) >= 2020
# ```
#
# </details>

# %%
# _=pls.plot_facet_stacked_bars(
#     _tu[[
#         "Vitalstatus_YY",
#         "Vitalstatus_MM",
#         "z_kkr_label",
#         "cnt"
#     ]].sort_values(["Vitalstatus_YY"]),
#     relative=True,
#     subplot_size=400,
#     # subplots_per_row=4,
#     # top_n_color=5,
#     # sort_values_index=True,
#     sort_values_facet=True,
#     # show_other=False,
#     annotations=True,
# )
# todo fix facet()

# %%
_ = pls.plot_stacked_bars(
    _tu[["z_kkr_label","Vitalstatus_MM","cnt"]],
    orientation="v",
    show_total=True,
    normalize=False,
    relative=True,
    height=1000,
    renderer="png",
)

# %% [markdown]
# ### <a id='toc1_13_2_'></a>[Vitalstatus Jahr](#toc0_)

# %%
# _filter = """--sql
#     year(Datum_Vitalstatus) >= 2020
#     and Verstorben = 'N'"""

# hlp.print_filter(_filter)

# _df = con.sql(f"""--sql
#     select
#         year(Datum_Vitalstatus)::text as SJ,
#         lpad(z_kkr::text, 2, '0') as kkr
#     from Patient
#     where {_filter}
#     """).to_df()

pls.plot_stacked_bars(
    # _df,
    _tu[["z_kkr_label","Vitalstatus_YY","cnt"]],
    # swap=True,
    relative=True,
)

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_14_'></a>[🔢 Numerische Variablen](#toc0_)

# %%
df_numerics = (
    Tumor.project("""--sql
        z_kkr_label
        ,z_age
        ,Tumordicke
        ,Anzahl_Tage_Diagnose_Tod::int as Anzahl_Tage_Diagnose_Tod
        ,PSA
        ,LK_befallen::int as LK_befallen
        ,LK_untersucht::int as LK_untersucht
        ,RektumAbstandAnokutanlinie::int as RektumAbstandAnokutanlinie
        ,LDH::int as LDH
        """)
    .order("z_kkr_label")
    .to_df()
)

# %% [markdown]
# <br>
#
# ### <a id='toc1_14_1_'></a>[Diagnosealter](#toc0_)
# - berechnet aus `Diagnosejahr` - `Geburtsjahr`
# - negative Werte entstehen aus falscher Datumsreihenfolge von Ereignissen
# - die Datumsangaben sind **nicht bereinigt**, um strukturelle Effekte sichtbar zu machen
#
# > 💡 `HH`: _"Ja, das liegt an dem Geschätzt-Flag in den Datumsangaben. In unseren Daten haben wir noch die alte Ausprägung 'Jahr geschätzt', diese wird dann im ZFKD-Datensatz mit 'Vollständig geschätzt' übersetzt. Theoretisch könnten Sie statt 1900 auch das angegebene Jahr nutzen… Aber diese Schätz-Angabe ist uns auch ein Dorn im Auge. Wir werden es auch noch in unseren Daten bereinigen. Zumeist handelt es sich da bei uns um Dokumentations oder Verständnisfehler."_

# %%
_=pls.plot_box_large(df_numerics["z_age"], height=150, width=2000, summary=False)
_=pls.plot_boxes_large(df_numerics[["z_kkr_label", "z_age"]], height=400, width=2000, )
# Out:
# column (n = 4_015_983) |     notnull      |   min   | lower |  q25  | median | mean  |  q75  | upper  |  max   |  std  |  cv
# -----------------------+------------------+---------+-------+-------+--------+-------+-------+--------+--------+-------+-----
# z_age                  | 4_015_983 (100%) | -122.00 | 30.25 | 59.67 |  70.00 | 68.01 | 79.33 | 108.50 | 125.25 | 15.27 | 0.22
#
#
# item (n = 4_015_983) |   count   |   min   | lower |  q25  | median | mean  |  q75  | upper  |  max   |  std  |  cv
# ---------------------+-----------+---------+-------+-------+--------+-------+-------+--------+--------+-------+-----
# 01-SH                |   194_283 |  -86.25 | 32.58 | 61.58 |  72.50 | 70.09 | 80.92 | 106.67 | 112.50 | 14.37 | 0.21
# 02-HH                |    69_613 |  -95.17 | 22.83 | 56.42 |  68.58 | 66.06 | 78.83 | 104.83 | 104.83 | 16.54 | 0.25
# 03-NI                |   277_590 |  -93.33 | 30.58 | 58.92 |  68.75 | 67.02 | 77.83 | 105.33 | 105.33 | 14.50 | 0.22
# 04-HB                |    30_960 |  -85.83 | 32.08 | 61.08 |  71.58 | 69.41 | 80.42 | 107.33 | 107.33 | 14.72 | 0.21
# 05-NW                | 1_017_558 |    0.00 | 30.33 | 60.33 |  70.75 | 69.00 | 80.33 | 110.33 | 124.67 | 14.67 | 0.21
# 06-HE                |   207_946 |  -97.50 | 28.08 | 57.58 |  68.00 | 65.94 | 77.25 | 105.00 | 124.67 | 15.48 | 0.23
# 07-RP                |   162_063 |   18.00 | 30.33 | 58.83 |  68.67 | 67.02 | 77.83 | 102.75 | 124.67 | 14.34 | 0.21
# 08-BW                |   457_569 | -100.83 | 28.17 | 59.00 |  69.75 | 67.45 | 79.58 | 107.83 | 123.17 | 16.54 | 0.25
# 09-BY                |   572_135 | -122.00 | 29.00 | 58.42 |  68.75 | 66.79 | 78.08 | 106.67 | 124.67 | 15.87 | 0.24
# 10-SL                |    63_249 |  -76.17 | 32.50 | 61.25 |  70.83 | 69.37 | 80.42 | 103.92 | 103.92 | 14.41 | 0.21
# 11-BE                |   146_981 |  -96.50 | 24.50 | 57.00 |  68.75 | 65.78 | 78.67 | 106.75 | 123.92 | 17.95 | 0.27
# 12-BB                |   130_868 |  -99.92 | 29.25 | 58.50 |  68.17 | 66.63 | 78.00 | 105.00 | 108.50 | 15.23 | 0.23
# 13-MV                |   110_032 |  -96.58 | 33.92 | 61.25 |  70.42 | 68.97 | 79.50 | 106.25 | 123.17 | 13.72 | 0.20
# 14-SN                |   334_093 |  -76.25 | 36.25 | 62.58 |  72.08 | 70.02 | 80.17 | 105.00 | 122.00 | 13.77 | 0.20
# 15-ST                |   163_371 | -103.42 | 34.83 | 62.17 |  71.75 | 69.56 | 80.42 | 104.17 | 125.25 | 16.02 | 0.23
# 16-TH                |    77_672 |  -81.83 | 32.33 | 59.42 |  68.67 | 66.89 | 77.50 | 103.08 | 103.08 | 14.55 | 0.22

# %% [markdown]
# <br>
#
# ### <a id='toc1_14_2_'></a>[Anzahl Tage zwischen Diagnose und Tod](#toc0_)
#
# > 💡 `ZfKD`: _Es treten Extremwerte auf, weit ausserhalb des Interquartilsabstandes. Grund dafür sind mutmasslich fehlende Datumsangaben, die auf 1900 kodiert werden._
# > _In der KKR Verteilung sind die Extreme in den GTDS Ländern besonders ausgeprägt_

# %%
_=pls.plot_box_large(df_numerics["Anzahl_Tage_Diagnose_Tod"], height=150, width=2000, use_log=True, summary=False)
_=pls.plot_boxes_large(df_numerics[["z_kkr_label", "Anzahl_Tage_Diagnose_Tod"]], height=400, width=2000, summary=True, use_log=True)
# Out:
# column (n = 4_015_983)   |     notnull     |   min   | lower |  q25  | median |  mean  |  q75   | upper |  max   |   std    |  cv
# -------------------------+-----------------+---------+-------+-------+--------+--------+--------+-------+--------+----------+-----
# Anzahl_Tage_Diagnose_Tod | 1_154_107 (28%) | -27_320 |  -212 | 52.00 | 259.00 | 653.42 | 706.00 | 1_687 | 30_590 | 1_271.47 | 1.95
#
#
# item (n = 4_015_983) |  count  |   min   | lower |  q25   | median |   mean   |   q75    | upper |  max   |   std    |  cv
# ---------------------+---------+---------+-------+--------+--------+----------+----------+-------+--------+----------+-----
# 01-SH                |  55_342 |       0 |     0 |  31.00 | 217.00 |   391.41 |   611.00 | 1_481 |  2_185 |   450.63 | 1.15
# 02-HH                |  23_361 |       0 |     0 |  38.00 | 184.00 |   349.72 |   521.00 | 1_245 |  2_159 |   415.34 | 1.19
# 03-NI                |  85_931 |       0 |     0 |  81.00 | 273.00 |   420.74 |   625.00 | 1_441 |  2_187 |   431.13 | 1.02
# 04-HB                |  10_380 |       0 |     0 |  33.00 | 187.00 |   366.26 |   568.00 | 1_370 |  2_126 |   433.75 | 1.18
# 05-NW                | 279_472 |       0 |     0 |  39.00 | 215.00 |   375.82 |   582.00 | 1_396 |  2_064 |   426.00 | 1.13
# 06-HE                |  62_551 |       0 |     0 |  84.00 | 291.00 |   593.66 |   716.00 | 1_664 | 20_880 |   967.44 | 1.63
# 07-RP                |  33_079 |       0 |     0 |  63.00 | 221.00 |   358.28 |   531.00 | 1_232 |  2_141 |   383.08 | 1.07
# 08-BW                | 130_832 |       0 |     0 |  47.00 | 214.00 |   355.38 |   542.00 | 1_284 |  2_192 |   391.62 | 1.10
# 09-BY                | 181_562 |       0 |     0 |  39.00 | 296.00 | 1_055.89 |   980.00 | 2_391 | 30_590 | 1_954.06 | 1.85
# 10-SL                |   3_859 |       0 |     0 |   0.00 |   0.00 |    93.34 |    56.00 |   140 |  2_054 |   239.94 | 2.57
# 11-BE                |  49_512 |       0 |     0 |  29.00 | 184.00 |   452.70 |   583.00 | 1_414 | 12_262 |   769.67 | 1.70
# 12-BB                |  48_367 |       0 |     0 |  42.00 | 251.00 |   949.41 |   838.00 | 2_032 | 21_026 | 1_806.10 | 1.90
# 13-MV                |  25_806 | -27_320 |  -212 | 113.00 | 394.00 | 1_146.03 | 1_127.00 | 2_648 | 16_507 | 1_859.12 | 1.62
# 14-SN                |  98_743 |       0 |     0 | 154.00 | 558.00 | 1_405.87 | 1_610.00 | 3_793 | 25_923 | 2_062.48 | 1.47
# 15-ST                |  53_400 |       0 |     0 |  56.00 | 322.00 |   963.14 |   991.00 | 2_393 | 16_227 | 1_696.78 | 1.76
# 16-TH                |  11_910 |       0 |     0 |  45.00 | 165.00 |   301.56 |   427.75 | 1_001 |  2_112 |   354.96 | 1.18

# %% [markdown]
# <br>
#
# ### <a id='toc1_14_3_'></a>[Tumordicke](#toc0_)

# %%
_=pls.plot_box_large(df_numerics["Tumordicke"], height=150, width=2000, use_log=False, violin=False, summary=True)
_=pls.plot_boxes_large(df_numerics[["z_kkr_label", "Tumordicke"]], height=400, width=2000, summary=False, use_log=True)
# Out:
# column (n = 4_015_983) |   notnull   |  min  | lower |  q25  | median | mean  |  q75  | upper |  max   |  std  |  cv
# -----------------------+-------------+-------+-------+-------+--------+-------+-------+-------+--------+-------+------
# Tumordicke             | 59_055 (1%) | 0.010 | 0.010 | 0.400 |  0.900 | 1.950 | 2.200 | 4.900 | 99.000 | 3.516 | 1.804

# %% [markdown]
# ### <a id='toc1_14_4_'></a>[PSA](#toc0_)

# %%
_=pls.plot_box_large(df_numerics["PSA"], height=150, width=2000, use_log=True, violin=False)
_=pls.plot_boxes_large(df_numerics[["z_kkr_label", "PSA"]], height=400, width=2000, summary=False, use_log=True)
# Out:
# column (n = 4_015_983) |   notnull    |  min  | lower |  q25  | median |  mean  |  q75   | upper  |    max     |   std   |  cv
# -----------------------+--------------+-------+-------+-------+--------+--------+--------+--------+------------+---------+------
# PSA                    | 244_596 (6%) | 0.000 | 0.000 | 5.630 |  8.730 | 90.297 | 18.000 | 36.550 | 99_999.000 | 741.436 | 8.211

# %% [markdown]
# ### <a id='toc1_14_5_'></a>[LK_befallen](#toc0_)

# %%
_=pls.plot_box_large(df_numerics["LK_befallen"], height=150, width=2000,  use_log=False, violin=False)
_=pls.plot_boxes_large(df_numerics[["z_kkr_label", "LK_befallen"]], height=400, width=2000,  summary=False, use_log=True)
# Out:
# column (n = 4_015_983) |    notnull    | min | lower |  q25  | median | mean  |  q75  | upper | max |  std  |  cv
# -----------------------+---------------+-----+-------+-------+--------+-------+-------+-------+-----+-------+------
# LK_befallen            | 796_925 (19%) |   0 |     0 | 0.000 |  0.000 | 0.916 | 0.000 |     0 | 722 | 3.076 | 3.358

# %% [markdown]
# ### <a id='toc1_14_6_'></a>[LK_untersucht](#toc0_)

# %%
_=pls.plot_box_large(df_numerics["LK_untersucht"], height=150, width=2000,  use_log=False, violin=False)
_=pls.plot_boxes_large(df_numerics[["z_kkr_label", "LK_untersucht"]], height=400, width=2000,  summary=False, use_log=True)
# Out:
# column (n = 4_015_983) |    notnull    | min | lower |  q25  | median |  mean  |  q75   | upper |  max  |  std   |  cv
# -----------------------+---------------+-----+-------+-------+--------+--------+--------+-------+-------+--------+------
# LK_untersucht          | 968_685 (24%) |   0 |     0 | 1.000 |  5.000 | 10.630 | 17.000 |    41 | 2_319 | 13.662 | 1.285

# %% [markdown]
# ### <a id='toc1_14_7_'></a>[RektumAbstandAnokutanlinie](#toc0_)

# %%
_=pls.plot_box_large(df_numerics["RektumAbstandAnokutanlinie"], height=150, width=2000,  use_log=False, violin=False)
_=pls.plot_boxes_large(df_numerics[["z_kkr_label", "RektumAbstandAnokutanlinie"]], height=400, width=2000,  summary=False, use_log=True)
# Out:
# column (n = 4_015_983)     |   notnull   | min | lower |  q25  | median |  mean  |  q75   | upper | max |  std   |  cv
# ---------------------------+-------------+-----+-------+-------+--------+--------+--------+-------+-----+--------+------
# RektumAbstandAnokutanlinie | 42_445 (1%) |   0 |     0 | 5.000 |  9.000 | 11.282 | 14.000 |    27 | 930 | 16.945 | 1.502

# %% [markdown]
# ### <a id='toc1_14_8_'></a>[LDH](#toc0_)

# %%
_=pls.plot_box_large(df_numerics["LDH"], height=150, width=2000,  use_log=False, violin=False)
_=pls.plot_boxes_large(df_numerics[["z_kkr_label", "LDH"]], height=400, width=2000,  summary=False, use_log=True)
# Out:
# column (n = 4_015_983) |  notnull   | min | lower |   q25   | median  |  mean   |   q75   | upper |  max  |   std   |  cv
# -----------------------+------------+-----+-------+---------+---------+---------+---------+-------+-------+---------+------
# LDH                    | 8_083 (0%) |   1 |    85 | 173.000 | 198.000 | 223.739 | 232.000 |   320 | 5_756 | 207.009 | 0.925
