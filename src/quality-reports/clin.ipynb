# %% [markdown]
# # <a id='toc1_'></a>[Bericht zur Qualität der klinischen Daten](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Bericht zur Qualität der klinischen Daten](#toc1_)
#   - [Informationen zum Dokument](#toc1_1_)
#   - [Änderungen seit der letzten Version](#toc1_2_)
#   - [Datenstand](#toc1_3_)
#   - [Lieferdatum](#toc1_4_)
#   - [Fallzahlen](#toc1_5_)
#     - [absolut](#toc1_5_1_)
#     - [relativ](#toc1_5_2_)
#       - [nach KKR](#toc1_5_2_1_)
#       - [nach System](#toc1_5_2_2_)
#   - [Fehlende Therapieangaben](#toc1_6_)
#     - [alle Therapien](#toc1_6_1_)
#     - [OP](#toc1_6_2_)
#       - [OP wenn OP erwartet](#toc1_6_2_1_)
#         - [C50](#toc1_6_2_1_1_)
#         - [C18-C20](#toc1_6_2_1_2_)
#     - [ST](#toc1_6_3_)
#       - [ST wenn ST erwartet](#toc1_6_3_1_)
#     - [SYST](#toc1_6_4_)
#       - [SYST wenn SYST erwartet](#toc1_6_4_1_)
#   - [Fallzahlen epi vs clin](#toc1_7_)
#   - [Verteilung von Variablen](#toc1_8_)
#     - [UICC (p)](#toc1_8_1_)
#     - [Diagnosesicherung](#toc1_8_2_)
#     - [DCO](#toc1_8_3_)
#     - [DCN](#toc1_8_4_)
#     - [Grading](#toc1_8_5_)
#       - [Verteilung](#toc1_8_5_1_)
#     - [Diagnosejahr mit Altdaten](#toc1_8_6_)
#     - [Inzidenzort vs Lieferregister](#toc1_8_7_)
#     - [Diagnosegruppen](#toc1_8_8_)
#     - [Altersgruppen Kinder und Heranwachsende](#toc1_8_9_)
#     - [Verstorben](#toc1_8_10_)
#     - [TNM-T (p)](#toc1_8_11_)
#     - [TNM-N (p)](#toc1_8_12_)
#     - [TNM-M (pc)](#toc1_8_13_)
#   - [Todesursachen (TU)](#toc1_9_)
#     - [nach ICD10 Einstellern](#toc1_9_1_)
#     - [nach Sterbejahr und Todesursachen](#toc1_9_2_)
#     - [nach ICD10 Dreistellern (TOP 5)](#toc1_9_3_)
#     - [nach IsGrundleiden](#toc1_9_4_)
#   - [Therapien](#toc1_10_)
#     - [OP](#toc1_10_1_)
#       - [nach ICD10](#toc1_10_1_1_)
#       - [nach Intention](#toc1_10_1_2_)
#     - [OPS](#toc1_10_2_)
#       - [nach OPS ICD Kapitel (Top 10)](#toc1_10_2_1_)
#     - [SYST](#toc1_10_3_)
#       - [nach Stellung_OP](#toc1_10_3_1_)
#   - [Missings- und Unbekannt-Kodierungen](#toc1_11_)
#     - [Verpflichtende Tumorvariablen](#toc1_11_1_)
#     - [Weitere Tumorangaben](#toc1_11_2_)
#     - [Tumorstadien](#toc1_11_3_)
#     - [Therapieangaben](#toc1_11_4_)
#       - [OP](#toc1_11_4_1_)
#       - [ST](#toc1_11_4_2_)
#       - [SYST](#toc1_11_4_3_)
#     - [Folgeereignisse](#toc1_11_5_)
#     - [Freitexte](#toc1_11_6_)
#     - [Organspezifische Variablen](#toc1_11_7_)
#       - [Mamma](#toc1_11_7_1_)
#       - [Prostata](#toc1_11_7_2_)
#       - [Darm](#toc1_11_7_3_)
#       - [Melanom](#toc1_11_7_4_)
#   - [Weitere Klassifikationen](#toc1_12_)
#     - [nach Quelle](#toc1_12_1_)
#     - [nach KKR](#toc1_12_2_)
#     - [PSA](#toc1_12_3_)
#       - [Angabe zu Diagnose vs Weitere Klassifikationen](#toc1_12_3_1_)
#       - [Kombinationen der PSA Merkmale](#toc1_12_3_2_)
#       - [Weitere Klassifikationen: Diagnose vs Folgeereignis](#toc1_12_3_3_)
#     - [UICC](#toc1_12_4_)
#       - [Kombinationen](#toc1_12_4_1_)
#       - [nach KKR](#toc1_12_4_2_)
#   - [Freitextkodierung](#toc1_13_)
#     - [Substanzen](#toc1_13_1_)
#   - [Datum Vitalstatus](#toc1_14_)
#     - [Zeitpunkt der Erhebung](#toc1_14_1_)
#   - [Numerische Variablen](#toc1_15_)
#     - [Diagnosealter](#toc1_15_1_)
#     - [Anzahl Tage zwischen Diagnose und Tod](#toc1_15_2_)
#     - [PSA](#toc1_15_3_)
#     - [LK_untersucht](#toc1_15_4_)
#     - [LK_befallen](#toc1_15_5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_1_'></a>[Informationen zum Dokument](#toc0_)
# - Neben den Hinweisen zum Verständnis der Auswertungen sind auch häufig **Interpretationen** angefügt, diese sind optisch abgesetzt als **Notiz** erkennbar
# - die jeweils angewendeten **Filter** sind für jede Auswertung dargestellt, jeweils zur besseren Einordnung als Anteil von der Gesamtzahl der Entität in unserer Datenbank
# - die _relativen_ Barcharts enthalten ein `Total` item für den Gesamtvergleich
# - die Filter können exakt nachvollzogen werden mit Hilfe der **ausklappbaren SQL Abfragen**
# - in den Diagrammen gibt ebenfalls das angegebene _`n=`_ einen Hinweis auf die verwendete Grundgesamtheit
# - der komplette Quellcode dieses Dokumentes ist [hier abrufbar](../../clin.ipynb)

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_2_'></a>[Änderungen seit der letzten Version](#toc0_)
# - Neulieferung für Daten mit **Diagnosejahr 2024**

# %% [markdown]
# <br>
#
# ## <a id='toc1_3_'></a>[Datenstand](#toc0_)

# %%
import os
from pathlib import Path
import pandas as pd
import duckdb as ddb
from connection_helper import sql
from pandas_plots import tbl, pls, hlp, const
from enum import Enum

os.environ["DY_MAX"] = "2024"  # set before import
from mod.filters import *

# hlp.show_package_version()

dir_db=Path("C://temp") if hlp.get_os(hlp.OperatingSystem.WINDOWS) else Path(os.path.expanduser("~/tmp"))
file_db_clin = dir_db/'2026-05-12_data_clin.duckdb'
file_db_intern = dir_db/'2026-05-12_internal_clin.duckdb'
file_db_epi = dir_db/'2026-05-13_data_epi.duckdb'
URL_V2 = 'https://gitlab.opencode.de/robert-koch-institut/zentrum-fuer-krebsregisterdaten/cancerdata-references/-/raw/main/data/v2/'

if not file_db_clin.exists() or not file_db_epi.exists() or not file_db_intern.exists():
    raise FileNotFoundError()

TO_PDF = False

hlp.setup_rendering(
    static=True,
    # apply_dark_theme=True,
    # to_pdf=TO_PDF,
)

# %%
# # ! settings
class grouper_reg(Enum):
    KKR = "kkr"
    SYSTEM = "system"
    TOTAL = "Total"

class kpi(Enum):
    MISSINGS = "kpi_missing"
    UNKNOWN = "kpi_unknown"
    
class grouper_table(Enum):
    TABLECOL = "tablecolumn"
    TABLES = "tables"

# %%
# print()›
sql.print_meta(file_db_clin)
# Out:
# database file:           2026-05-12_data_clin.duckdb
# data tag:                v2.4
# last kkr data import:    2026-04-18
# sql table created:       2026-05-12 16:38:32
# doi:                     10.18444/5.03.01.0005.0021.0003
# document created:        2026-05-20 18:31:58

# %%
con = ddb.connect()
_=con.execute("PRAGMA disable_progress_bar;")
_=con.execute(f"ATTACH DATABASE '{file_db_epi}' AS epi (READ_ONLY);")
_=con.execute(f"ATTACH DATABASE '{file_db_intern}' AS intern (READ_ONLY);")
_=con.execute(f"ATTACH DATABASE '{file_db_clin}' AS clin (READ_ONLY); SET SCHEMA 'clin';")
_=con.execute("ATTACH DATABASE ':memory:' AS mem; SET SCHEMA 'clin';")

# %%
# load from web
dim_icd10_3d = sql.load_file_to_duckdb(con, URL_V2 + "Aggregationen/icd10_3d.csv", sep=";")

# %%
Applikationsart = con.sql("select * from clin.Applikationsart")
Bestrahlung = con.sql("select * from clin.Bestrahlung")
Diagnose_Fernmetastase = con.sql("select * from clin.Diagnose_Fernmetastase")
Diagnose_WeitereKlassifikation = con.sql("select * from clin.Diagnose_WeitereKlassifikation")
Folgeereignis = con.sql("select * from clin.Folgeereignis")
Folgeereignis_Fernmetastase = con.sql("select * from clin.Folgeereignis_Fernmetastase")
Folgeereignis_TNM = con.sql("select * from clin.Folgeereignis_TNM")
Folgeereignis_WeitereKlassifikation = con.sql("select * from clin.Folgeereignis_WeitereKlassifikation")
Lieferung = con.sql("select * from clin.Lieferung")
OP = con.sql("select * from clin.OP")
OPS = con.sql("select * from clin.OPS")
Protokoll = con.sql("select * from clin.Protokoll")
ST = con.sql("select * from clin.ST")
SYST= con.sql("select * from clin.SYST")
Substanz = con.sql("select * from clin.Substanz")
Todesursache = con.sql("select * from clin.Todesursache")
_meta = con.sql("select * from clin._meta")
Tumor = con.sql("select * from clin.Tumor")
Patient = con.sql("select * from clin.Patient")

dim_lieferregister = con.sql("select * from clin.dim_lieferregister")
dim_tnm_t = con.sql("select * from clin.dim_tnm_t")
dim_tnm_uicc = con.sql("select * from clin.dim_tnm_uicc")
dim_grading_clin = con.sql("select * from clin.dim_grading_clin")

# hack eg: 7.2 -> 72
dim_dsich_clin = con.sql("""--sql
    select
        replace(code,'.','') as code, name
        --code, name
    from clin.dim_diagnosesicherung_clin
""")
dim_op_intention = con.sql("select * from clin.dim_op_intention")

dim_tree = sql.load_file_to_duckdb(con, "../quality-reports/data/dim_tree.csv", sep=";")

# ! depr
# _treecompletion = con.sql("select * from intern._treecompletion").project('*, Diagnose_ICD10_Code_DREI as icd10_3d').project('* exclude (Diagnose_ICD10_Code_DREI)')

# * epi (Fallzahlen)
Tumor4 = (con
    .sql("select * from epi.Tumor4")
    .project("""--sql
        *,
        left(ICDGM10,3) as z_icd10_3d,
        DJ as z_dy,
        case
            when DCO = 1 then true
            when DCO = 2 then false
            else null
        end as z_is_dco
    """)
    # .project("*, case when IARC like '%A_%' then cast(1 as int16) else cast(0 as int16) end as is_deleted")
)

# %% [markdown]
# <br>
#
# ## <a id='toc1_4_'></a>[Lieferdatum](#toc0_)
# - `kkr` = Klinisches Krebsregister
# - `Lieferdatum` = Datum der letzten Übermittlung durch die KKR
# - `Diagnosemonat` = letzter Diagnosemonat in den Daten

# %%
_tu_latest = Tumor.filter(f"z_dy = {DY_MAX}").aggregate("z_kkr_label, count(*) as cnt")  # noqa: F405

_tu=(Tumor.set_alias("t")
    .join(Lieferung.set_alias("l"), "l.Lieferregister::int = t.z_kkr::int", "inner")
    .aggregate("t.z_kkr_label, left(cast(max(Diagnosedatum) as varchar),7) as Diagnosemonat, max(Lieferdatum) as Lieferdatum")
    .join(_tu_latest.set_alias("latest"), "z_kkr_label", "left")
    # .project("z_kkr_label, Diagnosemonat")
    .order("z_kkr_label")
    .to_df().set_index("z_kkr_label")
    .astype({"Lieferdatum":str})
    .assign(Tumorfälle_2024 = lambda x: x["cnt"].apply(lambda y: f"{y:_.0f}"))
    .drop(columns=["cnt"])
    .T
)


if TO_PDF:
    display(_tu)
else:
    # * print as img, looks better for wide tables
    con.from_df(_tu
        .reset_index(names="z_kkr_label")
    ).show()

_late_kkr = con.from_df(_tu.T.reset_index(names="z_kkr_label")).filter("year(Lieferdatum::date) < 2026").z_kkr_label.fetchall()
# print("kkr ohne aktuelle Daten: ", _late_kkr)
# Out:
# ┌─────────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │   z_kkr_label   │   01-SH    │   02-HH    │   03-NI    │   04-HB    │   05-NW    │   06-HE    │   07-RP    │   08-BW    │   09-BY    │   10-SL    │   11-BE    │   12-BB    │   13-MV    │   14-SN    │   15-ST    │   16-TH    │
# │     varchar     │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │  varchar   │
# ├─────────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┤
# ...

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_5_'></a>[Fallzahlen](#toc0_)
# - in den Darstellungen sind keine Filter angewendet, solange nicht explizit angegeben

# %% [markdown]
# <br>
#
# ### <a id='toc1_5_1_'></a>[absolut](#toc0_)
# - aufgespannt sind die Fallzahlen für Lieferregister und Elementknoten
# - für jedes Register ist hier insbesondere einsehbar, wie viele Tumore/Patienten aus der aktuellsten Lieferung verarbeitet wurden
# - kein Filter, "Altfälle" (DJ < 2020) sind also enthalten
# - aufgeteilt auf 2 Tabellen zur besseren Übersicht
# - die `%` Werte sowie die farbigen Datenbalken zeigen das relative Gewicht jedes KKR an "D gesamt" (`Total` Zeile)
# - Erklärung für einige Elementknoten:
#   - **Diagnose**
#     - `diag_weitere` = Weitere Klassifikation im Elementknoten "Diagnose"
#     - `diag_fm` = Fernmetastasen im Elementknoten "Diagnose"
#   - **Folge**
#     - `folge_fm`= Fernmetastasen im Elementknoten "Folgeereignis"
#     - `folge_weitere` = Weitere Klassifikation im Elementknoten "Folgeereignis"
#     - `folge_tnm` = TNM im Elementknoten "Folgeereignis"
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - inzwischen liegen die meisten Elemente flächendeckend vor, bis auf `Applikationsart` und `Folgeereignis_WeitereKlassifikation`
# > - einige Elemente sind überproportional zur Verteilung der Tumore vorhanden, z.B. Weitere Klassifikationen bei Folgeereignissen aus `05-NW`
# > - die für viele Analysen relevanten `Folgeereignisse` sind nun zwar deutschlandweit verfügbar, aber aus einigen KKR mit sehr geringem Anteil

# %%
with open("../sql/clin_data.sql") as f:
    sql_clin_data = f.read()
db_clin_all = con.sql(sql_clin_data)

# tbl.descr_db(db_clin_all, "db_clin_all", width=1000)

# %%
col_count_str = [
    f"sum({col}) as {col}" for col in db_clin_all.columns if (col.endswith("_cnt"))
]
col_missing_str = [
    f"sum({col}) as {col}" for col in db_clin_all.columns if col.endswith("_missing")
]

def get_absolute_cases(
    db_all,
    cols: list[str],
    group=grouper_reg.KKR.value,
    filter: str = "",
    total_include: bool = False,
):
    # * empty filter must be neutral in the query
    if not filter:
        filter = "True"

    # * is executed twice
    def get_db(group: str):
        _project = "'Total' as Total, *" if group == grouper_reg.TOTAL.value else "*"
        return (
            db_all.filter(filter)
            .project(_project)
            .aggregate(
                f"""--sql
                    {group},
                    count(*) as tum_cnt, 
                    count(distinct z_pat_id) as pat_cnt,
                    {','.join(cols)},
                    """
            )
            .order(group)
        )

    db = get_db(group)
    if group != grouper_reg.TOTAL.value and total_include:
        db = db.union(get_db(grouper_reg.TOTAL.value))
    return db


def get_relative_cases(
    db_all, group=grouper_reg.KKR.value, filter: str = "", total_include: bool = False
):
    db_abs = get_absolute_cases(
        db_clin_all,
        cols=col_count_str,
        group=group,
        filter=filter,
        total_include=total_include,
    )
    db_rel = db_abs.aggregate(
        f"""--sql
            {group},
            sum(tum_cnt)/sum(pat_cnt) as tum_per_pat,
            sum(op_cnt)/sum(tum_cnt) as op_per_tum,
            sum(ops_cnt)/sum(tum_cnt) as ops_per_tum,
            sum(st_cnt)/sum(tum_cnt) as st_per_tum,
            sum(syst_cnt)/sum(tum_cnt) as syst_per_tum,
            sum(folge_cnt)/sum(tum_cnt) as folge_per_tum,
            """
    ).order(group)
    df = db_rel.to_df().set_index(group)
    return df


def get_missing_cases(db_all, group=grouper_reg.KKR.value, filter: str = "", total_include: bool = False):
    db_abs = get_absolute_cases(
        db_clin_all, cols=col_missing_str, group=group, filter=filter, total_include=total_include
    )
    db_miss = db_abs.aggregate(
        f"""--sql
            {group},
            sum(op_missing)/sum(tum_cnt) as op_missing_per_tum,
            sum(st_missing)/sum(tum_cnt) as st_missing_per_tum,
            sum(syst_missing)/sum(tum_cnt) as syst_missing_per_tum,
            sum(folge_missing)/sum(tum_cnt) as folge_missings_per_tum,
            sum(thera_missing)/sum(tum_cnt) as treat_missing_per_tum,
            """
    ).order(group)
    df = db_miss.to_df().set_index(group)
    return df

# %%
db_cases_abs = get_absolute_cases(
    db_clin_all, group=grouper_reg.KKR.value, cols=col_count_str, total_include=False
)
_tu = db_cases_abs.to_df().set_index("kkr")[
    [
        "tum_cnt",
        "pat_cnt",
        "op_cnt",
        "ops_cnt",
        "syst_cnt",
        "st_cnt",
        "bestr_cnt",
        "app_cnt",

        "diag_weitere_cnt",
        "diag_fm_cnt",
        "folge_cnt",
        "folge_weitere_cnt",
        "folge_fm_cnt",
        "folge_tnm_cnt",
        "proto_cnt",
        "subst_cnt",
    ]
].rename(columns=lambda c: c.removesuffix("_cnt"))
tbl.show_num_df(
    _tu.iloc[:, :8].export_plot_data(),
    data_bar_axis="x",
    total_axis="x",
    pct_axis="x",
    font_size_th=13,
    font_size_td=11,
    # kpi_mode="max_min_x",
)
# Out:
# <style type="text/css">
# #T_38783 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_38783 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_38783_row0_col0, #T_38783_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.8%, transparent 4.8%);
#   font-family: Courier;
# }
# #T_38783_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 5.0%, transparent 5.0%);
#   font-family: Courier;
# }
# #T_38783_row0_col2, #T_38783_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.7%, transparent 2.7%);
#   font-family: Courier;
# }
# #T_38783_row0_col4, #T_38783_row6_col0, #T_38783_row10_col4, #T_38783_row10_col5, #T_38783_row10_col6, #T_38783_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.0%, transparent 4.0%);
#   font-family: Courier;
# }
# #T_38783_row0_col5, #T_38783_row11_col5, #T_38783_row11_col6, #T_38783_row14_col6 {
#   width: 10em;
# ...

# %%
tbl.show_num_df(
    _tu.iloc[:, 8:].export_plot_data(),
    data_bar_axis="x",
    total_axis="x",
    pct_axis="x",
    font_size_th=13,
    font_size_td=11,
    # kpi_mode="max_min_x",
)
# Out:
# <style type="text/css">
# #T_1c94e th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_1c94e td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_1c94e_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.9%, transparent 1.9%);
#   font-family: Courier;
# }
# #T_1c94e_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 4.2%, transparent 4.2%);
#   font-family: Courier;
# }
# #T_1c94e_row0_col2, #T_1c94e_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.3%, transparent 0.3%);
#   font-family: Courier;
# }
# #T_1c94e_row0_col3, #T_1c94e_row1_col3, #T_1c94e_row2_col3, #T_1c94e_row3_col3, #T_1c94e_row9_col3 {
#   width: 10em;
#   font-family: Courier;
# }
# #T_1c94e_row0_col4, #T_1c94e_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 2.1%, transparent 2.1%);
#   font-family: Courier;
# }
# #T_1c94e_row0_col6, #T_1c94e_row3_col7 {
#   width: 10em;
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_5_2_'></a>[relativ](#toc0_)
# - der Filter ist gewählt, um eine bessere Vergleichbarkeit der Werte zu gewährleisten
# - die Metriken sind **einfache Verhältniszahlen**, z.B: `op_per_tum` = alle OP / alle Tumore (pro kkr)
# - es sind jeweils die kumulierten Werte aufgespannt:
#   - nach einzelnen **Lieferregistern**
#   - nach verwendeten **Tumordokumentationssystemen** (um systemische Effekte darstellen zu können)
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - die Quote Tumor pro Patient ist verlässlich konstant
# > - bei den Therapien gibt es einige Auffälligkeiten, wie z.B. wenige Folgeereignisse aus den `tristan` Ländern, oder hohe ST pro Tumor Quote aus `07-RP`

# %% [markdown]
# #### <a id='toc1_5_2_1_'></a>[nach KKR](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
    FILTERS_NO_180D_DEAD,
    FILTERS_NO_M1,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)
_tu = get_relative_cases(db_clin_all, group=grouper_reg.KKR.value, filter=_filter, total_include=True)
tbl.show_num_df(
    _tu.export_plot_data(),
    data_bar_axis="xy",
    total_axis="",
    pct_axis="",
    precision=1,
    show_as_pct=True,
    # kpi_mode="min_max_x",
    # total_exclude=True,
    font_size_th=13,
    font_size_td=11,
    # font_size_th=8,
    # font_size_td=6,
    image_scale='800',
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:                     n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [keine C44,D04]:                 n = 3_065_024  (75.4%) ░░░░░░░░██████████████████████
# └ [keine Verstorbenen < 180 Tage]: n = 2_688_879  (66.2%) ░░░░░░░░░░░███████████████████
# └ [kein M1]:                       n = 2_472_554  (60.9%) ░░░░░░░░░░░░██████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# and ifnull(z_period_diag_death_day,181) >= 180
# and ifnull(z_m_pc_1,'') <> '1'
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_9f205 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_9f205 td {
#   text-align: right;
# ...

# %% [markdown]
# #### <a id='toc1_5_2_2_'></a>[nach System](#toc0_)

# %%
_tu = get_relative_cases(db_clin_all, group=grouper_reg.SYSTEM.value, filter=_filter, total_include=True)
tbl.show_num_df(
    _tu.export_plot_data(),
    data_bar_axis="xy",
    total_axis="",
    pct_axis="",
    precision=1,
    show_as_pct=True,
    font_size_th=13,
    font_size_td=11,
    # font_size_th=8,
    # font_size_td=6,
    image_scale='800',
)
# Out:
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_2cfdb th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_2cfdb td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_2cfdb_row0_col0, #T_2cfdb_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 48.3%, transparent 48.3%);
#   font-family: Courier;
# }
# #T_2cfdb_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 31.2%, transparent 31.2%);
#   font-family: Courier;
# }
# #T_2cfdb_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 60.5%, transparent 60.5%);
#   font-family: Courier;
# }
# #T_2cfdb_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 10.3%, transparent 10.3%);
#   font-family: Courier;
# }
# #T_2cfdb_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 20.9%, transparent 20.9%);
#   font-family: Courier;
# }
# #T_2cfdb_row0_col5, #T_2cfdb_row5_col0 {
#   width: 10em;
# ...

# %% [markdown]
# <br>
#
# ## <a id='toc1_6_'></a>[Fehlende Therapieangaben](#toc0_)
#
# - ein Wert von bspw. 0.68 ist zu interpretieren als: _"68% aller Tumorfälle im KKR haben keine zugeordneten OP Angaben, die restlichen 32% mindestens eine."_
# - in der Darstellung sind die Max/Min Werte pro Kennzahl mit 🟥/🟩 markiert (kleiner ist besser)

# %%
# _filters = [
#     FILTERS_DY,
#     FILTERS_NO_DCO,
#     FILTERS_SOLID,
# ]
# _filter = hlp.get_duckdb_filter_n(
#     con=con,
#     query="from Tumor",
#     filters=_filters,
#     # distinct_metric="z_tum_id",
#     first_n_filter_apply_to_rows=0,
# )

# _tu = get_missing_cases(
#     db_clin_all,
#     group=grouper_reg.KKR.value,
#     filter=_filter,
#     total_include=True,
# )

# tbl.show_num_df(
#     _tu,
#     data_bar_axis="xy",
#     total_axis="",
#     pct_axis="",
#     precision=1,
#     show_as_pct=True,
#     kpi_mode="min_max_x",
#     total_exclude=True,
#     font_size_th=13,
#     font_size_td=11,
#     # font_size_th=7,
#     # font_size_td=5,
#     image_scale='800',
# )

# %% [markdown]
# ### <a id='toc1_6_1_'></a>[alle Therapien](#toc0_)
# - da hier alle Therapieangabe im Überblick dargestellt sind können keine therapiespezifischen Filter wie etwa "nur solide Tumoren" wirken
# - der Filter `DJ 2020-2024 ohne letzte 6m` soll gezielt Effekte des jüngsten Lieferjahres ausschliessen
# - Metrik: Anteil Tumore ohne jegliche Therapieangaben an Gesamt
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - der Anteil liegt in den neuen Bundesländern und Berlin fast durchgehend niedriger (10%-19%) als in den alten Bundesländern (17%-31%)
# > - im Zeitverlauf ist zwischen 2020 und 2023 keine eindeutige Tendenz zu beobachten
# > - trotz Ausschluss der Diagnosen im 2. Halbjahr 2023 liegt der Anteil von Fällen ohne Therapieangabenin 2023 noch etwas über dem Wert der Vorjahre, auch hier ist wahrscheinlich noch mit nachträglichen Ergänzungen zu rechnen

# %%
_filters = [
    # FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_C,
    FILTERS_NO_C44,
    FILTERS_NO_180D_DEAD,
    # FILTERS_SOLID,
    FILTERS_NO_M1,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        --z_tum_id,
        z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_treat,
        count(*) as cnt,
        cnt_no_treat / cnt as pct_no_treat
    from Tumor
    where {_filter}
    group by all
    union
    select
        --z_tum_id,
        'Total' as z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_treat,
        count(*) as cnt,
        cnt_no_treat / cnt as pct_no_treat
    from Tumor
    where {_filter}
    group by all
    union
    select
        --z_tum_id,
        z_kkr_label,
        'Total' as z_dy,
        sum(case when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_treat,
        count(*) as cnt,
        cnt_no_treat / cnt as pct_no_treat
    from Tumor
    where {_filter}
    group by all
    union
    select
        --z_tum_id,
        'Total' as z_kkr_label,
        'Total' as z_dy,
        sum(case when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_treat,
        count(*) as cnt,
        cnt_no_treat / cnt as pct_no_treat
    from Tumor
    where {_filter}
    group by all
    
""")
# _db.show()
tbl.pivot_df(
    _db.project("z_kkr_label, z_dy, pct_no_treat",).to_df().export_plot_data(),
    # show_as_pct=True,
    total_axis="",
    precision=1,
    show_as_pct=True,
    pct_axis="",
    data_bar_axis="xy",
    # heatmap_axis="xy",
    kpi_mode="min_max_x",
    font_size_th=13,
    font_size_td=11,
    # font_size_th=7,
    # font_size_td=5,
    image_scale='800',
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_447_269  (84.8%) ░░░░░█████████████████████████
# └ [keine DCO]:                     n = 3_335_696  (82.1%) ░░░░░░████████████████████████
# └ [ICD10 nur C]:                   n = 2_787_382  (68.6%) ░░░░░░░░░░████████████████████
# └ [keine C44,D04]:                 n = 2_301_507  (56.6%) ░░░░░░░░░░░░░░████████████████
# └ [keine Verstorbenen < 180 Tage]: n = 1_968_506  (48.5%) ░░░░░░░░░░░░░░░░██████████████
# └ [kein M1]:                       n = 1_771_571  (43.6%) ░░░░░░░░░░░░░░░░░█████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and left(z_icd10_3d,1) = 'C'
# and z_icd10_3d not in ('C44','D04')
# and ifnull(z_period_diag_death_day,181) >= 180
# and ifnull(z_m_pc_1,'') <> '1'
# ```
#
# </details>
# ...

# %% [markdown]
# ### <a id='toc1_6_2_'></a>[OP](#toc0_)
# - **nur solide Tumoren**  schliesst folgende Diagnosen aus: C44, C76-C97, alle D
#   - Metrik: Anteil Tumore ohne OP an Gesamt

# %%
_filters = [
    # FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
    FILTERS_SOLID,
    FILTERS_NO_180D_DEAD,
    FILTERS_NO_M1,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_op_count = 0 then 1 else 0 end) as cnt_no_op,
        count(*) as cnt,
        cnt_no_op / cnt as pct_no_op,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        z_dy::text as z_dy,
        sum(case when z_tum_op_count = 0 then 1 else 0 end) as cnt_no_op,
        count(*) as cnt,
        cnt_no_op / cnt as pct_no_op,
    from Tumor
    where {_filter}
    group by all
    union
    select
        z_kkr_label,
        'Total',
        sum(case when z_tum_op_count = 0 then 1 else 0 end) as cnt_no_op,
        count(*) as cnt,
        cnt_no_op / cnt as pct_no_op,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        'Total',
        sum(case when z_tum_op_count = 0 then 1 else 0 end) as cnt_no_op,
        count(*) as cnt,
        cnt_no_op / cnt as pct_no_op,
    from Tumor
    where {_filter}
    group by all

""")
# _db.show()
tbl.pivot_df(
    _db.project("z_kkr_label, z_dy, pct_no_op",).to_df().export_plot_data(),
    # show_as_pct=True,
    total_axis="",
    precision=1,
    show_as_pct=True,
    pct_axis="",
    data_bar_axis="xy",
    # heatmap_axis="xy",
    kpi_mode="min_max_x",
    font_size_th=13,
    font_size_td=11,
    image_scale='800',
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_447_269  (84.8%) ░░░░░█████████████████████████
# └ [keine DCO]:                     n = 3_335_696  (82.1%) ░░░░░░████████████████████████
# └ [keine C44,D04]:                 n = 2_781_485  (68.5%) ░░░░░░░░░░████████████████████
# └ [nur solide Tumore]:             n = 2_073_984  (51.0%) ░░░░░░░░░░░░░░░███████████████
# └ [keine Verstorbenen < 180 Tage]: n = 1_789_432  (44.0%) ░░░░░░░░░░░░░░░░░█████████████
# └ [kein M1]:                       n = 1_597_594  (39.3%) ░░░░░░░░░░░░░░░░░░░███████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# and
#     z_icd10_3d not in ('C44')
#     and left(z_icd10_3d,1) = 'C'
#     and right(z_icd10_3d, 2)::int8 <= 75
# ...

# %% [markdown]
# #### <a id='toc1_6_2_1_'></a>[OP wenn OP erwartet](#toc0_)
# - dargestellt ist die Verteilung von OP Kategorien bei Tumoren, für die eine OP erwartet werden kann
# - Kategorien
#   - `1_op`: mind. eine OPS im definierten Bereich (3Steller, organspezifisch) ist dokumentiert
#   - `2_no_op_but_tp`: keine OPS, aber T_p 1-4 ist dokumentiert
#   - `3_rest`: keine der zuvor genannten Merkmale trifft zu

# %% [markdown]
# ##### <a id='toc1_6_2_1_1_'></a>[C50](#toc0_)

# %%
FILTERS_C50 = ("z_icd10_3d = 'C50'", "ICD10 C50")
_filters = [
    # FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_C50,
    FILTERS_NO_M1,
    FILTERS_NO_180D_DEAD,
    # FILTERS_AGE_LT_80,
]
_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    # query="from Tumor tum left join OPS ops on ops.z_tum_id = tum.z_tum_id",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

db_op_c50 = con.sql(f"""--sql
    with t1 as (
        select
            tum.z_tum_id,
            z_kkr_label,
            op.Intention,
            z_tum_op_count,
            z_tum_st_count,
            z_tum_sy_count,
            case when {FILTERS_OPS_C50[0]} then true else false end as has_ops,
            case when z_t_p_1 in ('1','2','3','4') then true else false end as has_t_p,
            case when st.Stellung_OP = 'O' or sy.Stellung_OP = 'O' then true else false end as has_stell_op,
            sy.SYSTId
        from Tumor tum
        left join op on op.z_tum_id = tum.z_tum_id
        left join OPS ops on op.OPId = ops.OP_TypId
        left join ST st on tum.z_tum_id = st.z_tum_id
        left join SYST sy on tum.z_tum_id = sy.z_tum_id
        where {_filter}
    ),
    t2 as (
        select
            z_tum_id,
            any_value(z_kkr_label) as z_kkr_label,
            case
                when max(has_ops) then '1_op'
                when max(has_t_p) then '2_no_op_but_tp'
                --when max(has_stell_op) then '3_no_op_tp_but_other'
                when not(max(has_ops and has_t_p and has_stell_op)) then '3_rest'
                else 'U'
            end as categ_op,
            --Intention,
        from t1
        group by z_tum_id
    )
    select * from t2
""")
# tbl.descr_db(db_op_c50, "db_op_c50")
# db_op_c50.filter("z_tum_id = 'cdb36878-a43c-4413-9b56-14220b042323'").show()
# db_op_c50.filter("left(categ_op,1) = '4'").show()
# hlp.get_tum_details("c46d2307-ff1d-4dae-9725-d1e558dbd49f",con=con)

pls.plot_stacked_bars(
    db_op_c50.project("z_kkr_label, categ_op").to_df().export_plot_data(),
    show_total=True,
    relative=True,
    normalize=True,
    orientation="h",
    show_pct_bar=True,
    # caption="C50",
    title="OP Kategorien nach KKR (C50)",
    color_palette=const.PALETTE_RKI2,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_447_269  (84.8%) ░░░░░█████████████████████████
# └ [keine DCO]:                     n = 3_335_696  (82.1%) ░░░░░░████████████████████████
# └ [ICD10 C50]:                       n = 356_237   (8.8%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# └ [kein M1]:                         n = 330_742   (8.1%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# └ [keine Verstorbenen < 180 Tage]:   n = 323_899   (8.0%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and z_icd10_3d = 'C50'
# and ifnull(z_m_pc_1,'') <> '1'
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>
# <!-- ALT_TEXT:OP Kategorien nach KKR (C50)-->

# %% [markdown]
# ##### <a id='toc1_6_2_1_2_'></a>[C18-C20](#toc0_)

# %%
FILTER_C18C20 = ("z_icd10_3d in ('C18', 'C19', 'C20')", "ICD10 C18-C20")
_filters = [
    # FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTER_C18C20,
    FILTERS_NO_M1,
    FILTERS_NO_180D_DEAD,
    # FILTERS_AGE_LT_80,
]
_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

db_op_c50 = con.sql(f"""--sql
    with t1 as (
        select
            tum.z_tum_id,
            z_kkr_label,
            op.Intention,
            z_tum_op_count,
            z_tum_st_count,
            z_tum_sy_count,
            case when {FILTERS_OPS_C18C20[0]} then true else false end as has_ops,
            case when z_t_p_1 in ('1','2','3','4') then true else false end as has_t_p,
            case when st.Stellung_OP = 'O' or sy.Stellung_OP = 'O' then true else false end as has_stell_op,
            sy.SYSTId
        from Tumor tum
        left join op on op.z_tum_id = tum.z_tum_id
        left join OPS ops on op.OPId = ops.OP_TypId
        left join ST st on tum.z_tum_id = st.z_tum_id
        left join SYST sy on tum.z_tum_id = sy.z_tum_id
        where {_filter}
    ),
    t2 as (
        select
            z_tum_id,
            any_value(z_kkr_label) as z_kkr_label,
            case
                when max(has_ops) then '1_op'
                when max(has_t_p) then '2_no_op_but_tp'
                --when max(has_stell_op) then '3_no_op_tp_but_other'
                when not(max(has_ops and has_t_p and has_stell_op)) then '3_rest'
                else 'U'
            end as categ_op,
            --Intention,
        from t1
        group by z_tum_id
    )
    select * from t2
""")
# tbl.descr_db(db_op_c50, "db_op_c50")
# db_op_c50.filter("z_tum_id = 'cdb36878-a43c-4413-9b56-14220b042323'").show()
# db_op_c50.filter("left(categ_op,1) = '4'").show()
# hlp.get_tum_details("c46d2307-ff1d-4dae-9725-d1e558dbd49f",con=con)

pls.plot_stacked_bars(
    db_op_c50.project("z_kkr_label, categ_op").to_df().export_plot_data(),
    show_total=True,
    relative=True,
    normalize=True,
    orientation="h",
    show_pct_bar=True,
    # caption="C18-C20",
    title="OP-Kategorien nach KKR (C18-C20)",
    color_palette=const.PALETTE_RKI2,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_447_269  (84.8%) ░░░░░█████████████████████████
# └ [keine DCO]:                     n = 3_335_696  (82.1%) ░░░░░░████████████████████████
# └ [ICD10 C18-C20]:                   n = 252_341   (6.2%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# └ [kein M1]:                         n = 206_884   (5.1%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# └ [keine Verstorbenen < 180 Tage]:   n = 185_172   (4.6%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and z_icd10_3d in ('C18', 'C19', 'C20')
# and ifnull(z_m_pc_1,'') <> '1'
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>
# <!-- ALT_TEXT:OP-Kategorien nach KKR (C18-C20)-->

# %% [markdown]
# ### <a id='toc1_6_3_'></a>[ST](#toc0_)
# - Metrik: Anteil Tumore ohne Strahlentherapie an Gesamt
# - die experimentelle Darstellung verwendet eine heatmap, um Nuancen in diesem relativ homogenen Diagramm optisch hervorzuheben
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - der Anteil Tumore ohne ST (~73%) entspricht grob der Annahme von 30% Anteil von Strahlentherapien an primären Diagnosen
# > - `05-NW` und `06-HE` weisen optisch relativ hohe Anteile auf
# > - in nahezu allen KKR nimmt der Anteil in jüngeren DJ zu

# %%
_filters = [
    # FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_SOLID,
    FILTERS_NO_M1,
    FILTERS_NO_180D_DEAD,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_st_count = 0 then 1 else 0 end) as cnt_no_st,
        count(*) as cnt,
        cnt_no_st / cnt as pct_no_st,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        z_dy::text as z_dy,
        sum(case when z_tum_st_count = 0 then 1 else 0 end) as cnt_no_st,
        count(*) as cnt,
        cnt_no_st / cnt as pct_no_st,
    from Tumor
    where {_filter}
    group by all
    union
    select
        z_kkr_label,
        'Total',
        sum(case when z_tum_st_count = 0 then 1 else 0 end) as cnt_no_st,
        count(*) as cnt,
        cnt_no_st / cnt as pct_no_st,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        'Total',
        sum(case when z_tum_st_count = 0 then 1 else 0 end) as cnt_no_st,
        count(*) as cnt,
        cnt_no_st / cnt as pct_no_st,
    from Tumor
    where {_filter}
    group by all

""")
# _db.show()
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_447_269  (84.8%) ░░░░░█████████████████████████
# └ [keine DCO]:                     n = 3_335_696  (82.1%) ░░░░░░████████████████████████
# └ [nur solide Tumore]:             n = 2_073_984  (51.0%) ░░░░░░░░░░░░░░░███████████████
# └ [kein M1]:                       n = 1_763_564  (43.4%) ░░░░░░░░░░░░░░░░░█████████████
# └ [keine Verstorbenen < 180 Tage]: n = 1_597_594  (39.3%) ░░░░░░░░░░░░░░░░░░░███████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and
#     z_icd10_3d not in ('C44')
#     and left(z_icd10_3d,1) = 'C'
#     and right(z_icd10_3d, 2)::int8 <= 75
# and ifnull(z_m_pc_1,'') <> '1'
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>

# %%
tbl.pivot_df(
    _db.project("z_kkr_label, z_dy, pct_no_st",).to_df(),
    # show_as_pct=True,
    total_axis="",
    precision=1,
    show_as_pct=True,
    pct_axis="",
    data_bar_axis="",
    heatmap_axis="xy",
    # kpi_mode="min_max_x",
    font_size_th=11,
    font_size_td=10,
    # swap=True,
    image_scale="600",
)
# Out:
# <!-- SCALE-600 -->
# <style type="text/css">
# #T_443b7 th {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_443b7 td {
#   text-align: right;
#   font-size: 10pt;
# }
# #T_443b7_row0_col0, #T_443b7_row9_col2 {
#   font-family: Courier;
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_443b7_row0_col1, #T_443b7_row1_col2, #T_443b7_row13_col3 {
#   font-family: Courier;
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_443b7_row0_col2 {
#   font-family: Courier;
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_443b7_row0_col3 {
#   font-family: Courier;
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_443b7_row0_col4 {
#   font-family: Courier;
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_443b7_row0_col5 {
#   font-family: Courier;
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_443b7_row1_col0 {
#   font-family: Courier;
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_443b7_row1_col1 {
# ...

# %% [markdown]
# #### <a id='toc1_6_3_1_'></a>[ST wenn ST erwartet](#toc0_)
# - Beispiel: Anteil ST bei C50 nach OP: brusterhaltender Therapie (BET)
# - BET: ein OPS Code mit den ersten 5 Stellen `5-870` liegt vor
#
# > Kategorien:
# >   - `1_op_st` - Strahlentherapie nach BET
# >   - `2_op_no_st_but_sy` - BET, keine Strahlentherapie aber systemische
# >   - `3_no_treat` - keine Therapie

# %%
_filters = [
    FILTERS_DY_DELAY,
    FILTERS_C50,
    # FILTERS_M0,
    FILTERS_NO_M1,
    FILTERS_BET,
    FILTERS_NO_180D_DEAD,
    # FILTERS_AGE_LT_80,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum left join OPS ops on ops.z_tum_id = tum.z_tum_id",
    filters=_filters,
    distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

db_st = con.sql(f"""--sql
    select
        --tum.z_tum_id,
        z_kkr_label,
        any_value(
        case
            when z_tum_st_count > 0 then '1_op_st'
            when z_tum_sy_count > 0 then '2_op_no_st_but_sy'
            when z_tum_st_count + z_tum_sy_count = 0 then '3_op_no_st_sy'
            else 'U' end
        ) as categ_st,
    from Tumor tum
    join OPS ops on ops.z_tum_id = tum.z_tum_id
    where {_filter}
    group by tum.z_tum_id, z_kkr_label,
""")

pls.plot_stacked_bars(
    db_st.to_df(),
    show_total=True,
    relative=True,
    normalize=True,
    orientation="h",
    show_pct_bar=True,
    title= " Anteil ST nach OP mit BET bei C50",
    color_palette=const.PALETTE_RKI2,
)
# Out:
# <!-- START_TOKEN -->
# count: distinct z_tum_id
# ---
# n = 4_062_856                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_447_269  (84.8%) ░░░░░█████████████████████████
# └ [ICD10 C50]:                       n = 363_831   (9.0%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# └ [kein M1]:                         n = 338_236   (8.3%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# └ [nur OPS für BET]:                 n = 190_253   (4.7%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# └ [keine Verstorbenen < 180 Tage]:   n = 189_842   (4.7%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Diagnosedatum between '2020-01-01' and '2024-06-30'
# and z_icd10_3d = 'C50'
# and ifnull(z_m_pc_1,'') <> '1'
# and left(Code,5) in ('5-870')
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>
# <!-- ALT_TEXT: Anteil ST nach OP mit BET bei C50-->

# %% [markdown]
# ### <a id='toc1_6_4_'></a>[SYST](#toc0_)
# - Metrik: Anteil Tumore **ohne** systemische Therapie an Gesamt
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - entgegen dem Trend sinkt der Anteil in `04-HB` im letzten DJ
# > - den stabil geringsten Anteil weist `16-TH` auf

# %%
_filters = [
    FILTERS_DY,
    FILTERS_DY_DELAY,
    FILTERS_NO_DCO,
    FILTERS_NO_M1,
    FILTERS_NO_180D_DEAD,
    # FILTERS_NO_SOLID,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        z_kkr_label,
        z_dy::text as z_dy,
        sum(case when z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_sy,
        count(*) as cnt,
        cnt_no_sy / cnt as pct_no_sy,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        z_dy::text as z_dy,
        sum(case when z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_sy,
        count(*) as cnt,
        cnt_no_sy / cnt as pct_no_sy,
    from Tumor
    where {_filter}
    group by all
    union
    select
        z_kkr_label,
        'Total',
        sum(case when z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_sy,
        count(*) as cnt,
        cnt_no_sy / cnt as pct_no_sy,
    from Tumor
    where {_filter}
    group by all
    union
    select
        'Total',
        'Total',
        sum(case when z_tum_sy_count = 0 then 1 else 0 end) as cnt_no_sy,
        count(*) as cnt,
        cnt_no_sy / cnt as pct_no_sy,
    from Tumor
    where {_filter}
    group by all

""")
# _db.show()
tbl.pivot_df(
    _db.project("z_kkr_label, z_dy, pct_no_sy",).to_df(),
    # show_as_pct=True,
    total_axis="",
    precision=1,
    show_as_pct=True,
    pct_axis="",
    data_bar_axis="",
    heatmap_axis="xy",
    # kpi_mode="min_max_x",
    font_size_th=11,
    font_size_td=10,
    # swap=True,
    image_scale="600",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:   n = 3_447_269  (84.8%) ░░░░░█████████████████████████
# └ [keine DCO]:                     n = 3_335_696  (82.1%) ░░░░░░████████████████████████
# └ [kein M1]:                       n = 3_011_971  (74.1%) ░░░░░░░░██████████████████████
# └ [keine Verstorbenen < 180 Tage]: n = 2_783_094  (68.5%) ░░░░░░░░░░████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Diagnosedatum between '2020-01-01' and '2024-06-30'
# and not z_is_dco
# and ifnull(z_m_pc_1,'') <> '1'
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>
# <!-- SCALE-600 -->
# <style type="text/css">
# #T_46eac th {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_46eac td {
# ...

# %% [markdown]
# #### <a id='toc1_6_4_1_'></a>[SYST wenn SYST erwartet](#toc0_)
# - Beispiel: akut verlaufenden Leukämien und Lymphome (akute myeloide und lymphatische Leukämie, diffuses großzelliges B-Zell-Lymphom, follikuläres Lymphom Grad IIIb)
#
# > Kategorien:
# >   - `1_sy` - systemische Therapie
# >   - `2_no_sy_but_other` - keine systemische Therapie, aber andere Therapie
# >   - `3_no_treat` - keine Therapie

# %%
_filters = [
    FILTERS_DY_DELAY,
    ("z_icd10 in ('C91.0', 'C92.0', 'C83.3', 'C82.4')", "akut verlaufende Leukämien und Lymphome"),
    FILTERS_NO_DCO,
    # FILTERS_M0,
    FILTERS_NO_M1,
    FILTERS_NO_180D_DEAD,
    # FILTERS_AGE_LT_80,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)


db_sy = con.sql(f"""--sql
    select
        --tum.z_tum_id,
        z_kkr_label,
        case 
            when z_tum_sy_count > 0 then '1_sy'
            when z_tum_st_count + z_tum_op_count > 0 then '2_no_sy_but_other'
            when z_tum_op_count + z_tum_st_count + z_tum_sy_count = 0 then '3_no_treat'
            else 'U'
            end as categ_sy,
    from Tumor tum
    where {_filter}
""")

pls.plot_stacked_bars(
    db_sy.to_df(),
    show_total=True,
    relative=True,
    normalize=True,
    orientation="h",
    show_pct_bar=True,
    title="Anteil SYST bei akut verlaufenden Leukämien und Lymphomen",
    color_palette=const.PALETTE_RKI2,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                              (100.0%) ██████████████████████████████
# └ [DJ 2020-2024 ohne letzte 6m]:             n = 3_447_269  (84.8%) ░░░░░█████████████████████████
# └ [akut verlaufende Leukämien und Lymphome]:    n = 51_375   (1.3%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# └ [keine DCO]:                                  n = 49_776   (1.2%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# └ [kein M1]:                                    n = 49_724   (1.2%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# └ [keine Verstorbenen < 180 Tage]:              n = 36_693   (0.9%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Diagnosedatum between '2020-01-01' and '2024-06-30'
# and z_icd10 in ('C91.0', 'C92.0', 'C83.3', 'C82.4')
# and not z_is_dco
# and ifnull(z_m_pc_1,'') <> '1'
# and ifnull(z_period_diag_death_day,181) >= 180
# ```
#
# </details>
# ...

# %% [markdown]
# <br>
#
# ## <a id='toc1_7_'></a>[Fallzahlen epi vs clin](#toc0_)
# - Ziel der Darstellung: Abschätzung der Vollzähligkeit der klinischen Daten
# - dargestellt sind die gefilterten Fallzahlen jeweils aus den epi und den klinischen Daten, hier allerdings nur aus dem aktuellstem DJ
# - Hinweis: Die Auswertung Daten basiert auf `Inzidenzort` anstatt `Lieferregister`, da in den epi Daten bislang die einzelnen Länder des GKR nicht aufgeschlüsselt waren, und ein matching auf EKRNR somit fehlschlägt
#
# > [!NOTE]
# > 💡 **NI**: _"Die **höhere Fallzahl** des epidemiologischen Registers im Vergleich zum klinischen Register ist vermutlich auf unterschiedliche Filterkriterien in den beiden Registern zurückzuführen. Im KKN werden neben den Kriterien die das Lieferschema vorgibt auch noch weitere Plausibilitätsprüfungen angewandt. Tumoren, welche diese Prüfungen nicht bestehen, werden vom Export ausgeschlossen"_
# >
# > ---
# > 💡 **ZfKD**: Die quota in den anderen KKR entspricht der Erwartung, dass die Fallzahl bei klin. Daten höher sein sollte als bei epi Daten.

# %%
_filters = [
    (f"z_dy in ({DY_MAX})",f"DJ {DY_MAX}"),
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_db2=(db_clin_all
    # .filter("left(kkr,2) = bl and bl::int between 1 and 16")  # * very few cases
    .filter(f"{_filter}")
    .aggregate("bl, count(*) as clin_cnt")
    .join(dim_lieferregister.set_alias("l"), "bl::int8 = l.code", "left")
    .project("bl,clin_cnt")
    )

_db1=(Tumor4
    # .project("*, case when left(GKZlk,2)::int > 10 then left(GKZlk,2) else EKRNR end as EKRNR_")
    # .filter("EKRNR_ = left(GKZlk,2) and left(GKZlk,2)::int between 1 and 16")
    # .filter(f"DJ in ({DY_MAX}) and not is_deleted")
    # .filter("left(ICDGM10,3) <> 'C44' and  DCO = 2")
    .filter("not is_deleted")
    .filter(_filter)
    .aggregate("left(GKZlk,2) as bl, count(*) as epi_cnt")
    )

_df12 = _db1.join(_db2, "bl", "right").to_df()


_tu = (
    _df12.merge(dim_lieferregister.to_df(), left_on="bl", right_on="code")
    .assign(quota=lambda x: x.clin_cnt / x.epi_cnt * 100)
    .set_index("kkr")[["clin_cnt", "epi_cnt", "quota"]]
    .sort_index(ascending=True)
    .T
)
# display(tbl.show_num_df(
#     _tu.fillna(0),
#     total_mode="",
#     font_size_th=11,
#     font_size_td=9,
# ))

con.from_df(_tu
    # .fillna(0)
    .map(lambda x: f"{x:_.0f}")
    .reset_index(names="kkr",)
    ).show()
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2024]:         n = 723_706  (17.8%) ░░░░░░░░░░░░░░░░░░░░░░░░░█████
# └ [keine DCO]:       n = 704_349  (17.3%) ░░░░░░░░░░░░░░░░░░░░░░░░░█████
# └ [keine C44,D04]:   n = 592_575  (14.6%) ░░░░░░░░░░░░░░░░░░░░░░░░░░████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy in (2024)
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# ┌──────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┐
# │   kkr    │  01-SH  │  02-HH  │  03-NI  │  04-HB  │  05-NW  │  06-HE  │  07-RP  │  08-BW  │  09-BY  │  10-SL  │  11-BE  │  12-BB  │  13-MV  │  14-SN  │  15-ST  │  16-TH  │
# ...

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_8_'></a>[Verteilung von Variablen](#toc0_)

# %%
def show_vars(idx: int, group_reg: str, show: bool = True, filter: str=""):
    agg_counts = {"pat": "distinct oBDS_RKIPatientId", "tum": "*"}
    agg_cols = [
        ["Geschlecht", "pat"], # 0
        ["Verstorben", "pat"], # 1
        ["UICC_Stadium_p", "tum"],
        ["Diagnosesicherung", "tum"],
        ["z_dy", "tum"],
        ["Inzidenzort_BL", "tum"],
        ["z_icd10_3d", "tum"],
        ["Morphologie_Version", "tum"],
        ["TNM_Auflage_p", "tum"],
        ["z_t_p_1", "tum"],
        ["z_is_dco", "tum"],    # 10
        ["z_n_p_1", "tum"],
        ["z_m_p_1", "tum"],
        ["Grading", "tum"],
        ["DCN", "tum"],
        ["z_m_pc_1", "tum"],
    ]

    db_vars = (Tumor.set_alias("t")
        .project("*, left(Inzidenzort,2) as Inzidenzort_BL, z_dy, z_is_dco")
        .join(Patient, "oBDS_RKIPatientId")
        .join(dim_lieferregister, "t.z_kkr::int = code::int", "left")
        .join(dim_icd10_3d.set_alias("i"), "z_icd10_3d=i.code", how="left")
        .filter(filter if filter else "True")
        .aggregate(
            f"{group_reg}, {agg_cols[idx][0]} as value, count({agg_counts[agg_cols[idx][1]]}) as cnt"
        )
    )

    # * optional dim applikation
    if idx==2:
        db_vars = (db_vars
                .join(dim_tnm_uicc.set_alias("dim"), "value = dim.code", "left")
                .project(f"{group_reg},code_1 as value, cnt"))
    elif idx==3:
        db_vars = (db_vars
                .join(dim_dsich_clin, "value = code", "left")
                .project(f"{group_reg}, concat(value, ' - ', name) as value, cnt"))
    elif idx==6:
        db_vars = (db_vars
                .join(dim_icd10_3d, "value = code", "left")
                .project(f"{group_reg}, code_kid as value, cnt"))
    elif idx==13:
        db_vars = (db_vars
                .join(dim_grading_clin, "value = code", "left")
                .project(f"{group_reg}, case when value is null then null else concat(value, ' - ', name) end as value, cnt"))
    # elif idx==9:
    #     db_vars = (db_vars
    #             .join(dim_tnm_t, "value = code", "left")
    #             .project(f"{group_reg}, code_1 as value, cnt"))

    df= db_vars.to_df()
    if idx==4:
        df["value"] = df["value"].astype("Int64").astype(str)

    df = df.rename(columns={"value":agg_cols[idx][0]})
    if show:
        pls.plot_stacked_bars(
            df,
            swap=False,
            orientation="h",
            show_total=True,
            normalize=False,
            relative=True,
            height=700,
            show_pct_bar=True,
        )
    return df

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_1_'></a>[UICC (p)](#toc0_)
# - nach den absoluten Werten ist auch die relative Verteilung gegeben unter Ausschluss der hohen Zahl an UICC missings
# - die Variable wird in den meisten KKR selbst gebildet. Für GTDS Länder ist dafür ein Standard definiert

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
    FILTERS_TNM,
    # FILTERS_SOLID,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)

_tu=show_vars(2, grouper_reg.KKR.value, show=False, filter=_filter)
# _=pls.plot_stacked_bars(_tu.export_plot_data(), swap=False, orientation='h', show_total=False, relative=False, height=700, dropna=False,)
_ = pls.plot_stacked_bars(
    _tu.export_plot_data(),
    swap=False,
    orientation="h",
    show_total=True,
    relative=True,
    height=700,
    dropna=False,
    show_pct_bar=True,
    title="UICC (p)",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [keine C44,D04]:            n = 3_065_024  (75.4%) ░░░░░░░░██████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_082_538  (51.3%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_2_'></a>[Diagnosesicherung](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**: _die Kodes `6` und `7` werden von vielen KKR noch geliefert, sind allerdings in der aktuellen oBDS Referenz nicht mehr gültig_

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_C44,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)
_ = show_vars(
    3,
    grouper_reg.KKR.value,
    show=True,
    filter=_filter,
    # filter="z_dy = 2024",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine C44,D04]: n = 3_185_327  (78.4%) ░░░░░░░███████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>

# %% [markdown]
# ### <a id='toc1_8_3_'></a>[DCO](#toc0_)
#
# - Metrik: Anteil der als DCO markierten Fälle an Gesamt
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - aus einigen KKR sind DCO nicht, oder nur rudimentär markiert
# > - ein weiterer sichtbarer Effekt ist die Zunahme des DCO Anteils in den jüngeren DJ in einigen KKR

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_C44,
    ("left(z_icd10_3d,1) = 'C'","ICD10 nur C"),
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    first_n_filter_apply_to_rows=0,
)


db_dco = con.sql(f"""--sql
    with t1 as (
        select  z_kkr_label,
                z_is_dco,
                (DCN = 'J') as is_dcn,
                z_dy::text as z_dy,
                z_icd10_3d,
        from    Tumor
        where {_filter}
    ),
    t2 as (
        select
                z_kkr_label,
                z_dy,
                count(*) as cnt,
                sum(z_is_dco) as sum_dco,
                sum(is_dcn) as sum_dcn,
                sum(z_is_dco) / cnt as pct_dco,
                sum(is_dcn) / cnt as pct_dcn,
        from    t1
        group by all
        union
        select
                'Total',
                z_dy,
                count(*) as cnt,
                sum(z_is_dco) as sum_dco,
                sum(is_dcn) as sum_dcn,
                sum(z_is_dco) / cnt as pct_dco,
                sum(is_dcn) / cnt as pct_dcn,
        from    t1
        group by all
        union
        select
                z_kkr_label,
                'Total',
                count(*) as cnt,
                sum(z_is_dco) as sum_dco,
                sum(is_dcn) as sum_dcn,
                sum(z_is_dco) / cnt as pct_dco,
                sum(is_dcn) / cnt as pct_dcn,
        from    t1
        group by all
        union
        select
                'Total',
                'Total',
                count(*) as cnt,
                sum(z_is_dco) as sum_dco,
                sum(is_dcn) as sum_dcn,
                sum(z_is_dco) / cnt as pct_dco,
                sum(is_dcn) / cnt as pct_dcn,
        from    t1
        group by all
    )
    select * from t2
    """)
# tbl.descr_db(db_dco, "dco data")

tbl.pivot_df(
    db_dco.project("z_kkr_label, z_dy, pct_dco").to_df(),
    precision=1,
    show_as_pct=True,
    pct_axis="",
    total_axis="",
    font_size_th=13,
    font_size_td=11,
    # swap=True,
    image_scale="800",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine C44,D04]: n = 3_185_327  (78.4%) ░░░░░░░███████████████████████
# └ [ICD10 nur C]:   n = 2_649_060  (65.2%) ░░░░░░░░░░░███████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_icd10_3d not in ('C44','D04')
# and left(z_icd10_3d,1) = 'C'
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_9ddc6 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_9ddc6 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_9ddc6_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.7%, transparent 71.7%);
#   font-family: Courier;
# }
# #T_9ddc6_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 71.2%, transparent 71.2%);
#   font-family: Courier;
# }
# ...

# %% [markdown]
# ### <a id='toc1_8_4_'></a>[DCN](#toc0_)
#
# - Metrik: Anteil der als DCN markierten Fälle an Gesamt
#
# > [!NOTE]
# > 💡 **ZfKD**: aus einigen KKR sind DCN nicht, oder nur rudimentär markiert

# %%
# _tu=show_vars(14, grouper_reg.KKR.value, show=True, filter=_filter)

_filters = [
    FILTERS_DY,
    FILTERS_NO_C44,
    ("left(z_icd10_3d,1) = 'C'","ICD10 nur C"),
]

_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
    # first_n_filter_apply_to_rows=0,
)

tbl.pivot_df(
    db_dco.project("z_kkr_label, z_dy, pct_dcn").to_df(),
    precision=1,
    show_as_pct=True,
    pct_axis="",
    total_axis="",
    font_size_th=13,
    font_size_td=11,
    # swap=True,
    image_scale="800",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine C44,D04]: n = 3_185_327  (78.4%) ░░░░░░░███████████████████████
# └ [ICD10 nur C]:   n = 2_649_060  (65.2%) ░░░░░░░░░░░███████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_icd10_3d not in ('C44','D04')
# and left(z_icd10_3d,1) = 'C'
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_efa43 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_efa43 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_efa43_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.6%, transparent 54.6%);
#   font-family: Courier;
# }
# #T_efa43_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 54.7%, transparent 54.7%);
#   font-family: Courier;
# }
# ...

# %% [markdown]
# ### <a id='toc1_8_5_'></a>[Grading](#toc0_)

# %% [markdown]
# #### <a id='toc1_8_5_1_'></a>[Verteilung](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_GRAD,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)
_ = show_vars(
    13,
    grouper_reg.KKR.value,
    show=True,
    filter=_filter,
    # title="Grading",
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                                  (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:                   n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [nur gradingrelevante Tumore]: n = 1_275_551  (31.4%) ░░░░░░░░░░░░░░░░░░░░░█████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 33
#             or right(z_icd10_3d, 2)::int8 between 50 and 57
#             or right(z_icd10_3d, 2)::int8 between 63 and 68
#             or right(z_icd10_3d, 2)::int8 = 60
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8576
#     )
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_6_'></a>[Diagnosejahr mit Altdaten](#toc0_)

# %%
_filters = [
    # FILTERS_DY,
    # FILTERS_NO_DCO,
    ("z_dy < 2025","DJ < 2025"),

]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        --z_icd10_3d,
        z_kkr_label,
        z_dy,
        case
            when z_dy < 2020 then 'alt'
        else z_dy::text end as dy,
        count(*) as cnt
    from Tumor
    where {_filter}
    group by all
    """)

# _db.filter("True").show()

pls.plot_stacked_bars(
    _db.project("z_kkr_label, dy, cnt").to_df(),
    orientation='h',
    relative=True,
    show_pct_bar=True,
    show_total=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                (100.0%) ██████████████████████████████
# └ [DJ < 2025]: n = 4_051_316  (99.7%) ░█████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy < 2025
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_7_'></a>[Inzidenzort vs Lieferregister](#toc0_)
# - **Filter: keiner**
# - vertikal: `Inzidenzort` (Zeile `00` bündelt alle Fälle mit ungültiger Ortsangabe). horizontal: `Lieferregister`
# - Beispiel: `03-NI` liefert zu 100% Fälle aus dem Inzidenzort `03`, `13-MV` liefert 159 Fälle aus `03`
#
# > [!NOTE]
# > 💡 **ZfKD**: _Angestrebt ist eine "Diagonale", möglichst nur noch Fallübermittlungen aus dem eigenen Einzugsgebiet, was inzwischen schon besser erreicht ist. ~ 99% der Fälle stammen aus dem liefernden Register_

# %%
_tu = show_vars(5, grouper_reg.KKR.value, show=False).rename(columns={"Inzidenzort_BL":"ort"}).fillna(0)
_tu.loc[_tu["ort"]=="","ort"]="00"
_tu.loc[(_tu['ort'].astype(int) < 1) | (_tu['ort'].astype(int) > 16), "ort"]="00"
tbl.show_num_df(
    _tu.pivot_table(index="ort", columns="kkr", values="cnt", fill_value=0, dropna=False),
    data_bar_axis="xy",
    total_axis="xy",
    total_exclude=True,
    pct_axis="x",
    font_size_th=8,
    font_size_td=6,
)
# Out:
# <style type="text/css">
# #T_7d4e0 th {
#   text-align: right;
#   font-size: 8pt;
# }
# #T_7d4e0 td {
#   text-align: right;
#   font-size: 6pt;
# }
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_8_'></a>[Diagnosegruppen](#toc0_)
# - die verwendete ICD10 Skala entspricht der Darstellung aus *"Krebs in Deutschland"*

# %%
# C00-C75 außer C44
# C44
# C76-C80
# C81-C96
# D
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,

]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        --z_icd10_3d,
        z_kkr_label,
        z_dy,
        case 
            when left(z_icd10_3d,1) = 'D' then 'D'
            when z_icd10_3d = 'C44' then 'C44'
            when right(z_icd10_3d,2)::int8 < 76 then 'C00-C75 o. C44'
            when right(z_icd10_3d,2)::int8 < 81 then 'C76-C80'
            when right(z_icd10_3d,2)::int8 < 97 then 'C81-C96'
        else null end as grp,
        count(*) as cnt
    from Tumor
    where {_filter}
    group by all
    """)

# _db.filter("True").show()

pls.plot_stacked_bars(
    _db.project("z_kkr_label, grp, cnt").to_df(),
    orientation='h',
    relative=True,
    show_pct_bar=True,
    show_total=True,
    title="Diagnosegruppen"
)

# pls.plot_facet_stacked_bars(
#     _db.project("z_dy, grp, z_kkr_label, cnt").to_df(),
#     relative=True,
#     annotations=True,
#     fill_index=True,
#     title="ICD10 Gruppen"
    
# )
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_672_629  (90.4%) ░░░███████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# ```
#
# </details>
# <!-- ALT_TEXT:Diagnosegruppen-->

# %% [markdown]
# ### <a id='toc1_8_9_'></a>[Altersgruppen Kinder und Heranwachsende](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**: Fälle von unter 18-jährigen Personen sind nicht flächendeckend vorhanden

# %%
_filters = [
    FILTERS_DY,
    # FILTERS_NO_DCO,
    # FILTERS_NO_C44,
    ("z_age <= 20", "Alter <= 20"),
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_db = con.sql(f"""--sql
    select
        z_kkr_label,
        z_dy,
        --lpad(z_age::int::text,2,'0') as z_age,
        case 
            when z_age::int between 0 and 4 then '00-04'
            when z_age::int between 5 and 9 then '05-09'
            when z_age::int between 10 and 14 then '10-14'
            when z_age::int between 15 and 17 then '15-17'
            when z_age::int between 18 and 20 then '18-20'
        else null end as categ_age
    from Tumor
    where {_filter}
""")

pls.plot_stacked_bars(
    _db.project("z_kkr_label, categ_age").to_df().export_plot_data(),
    swap=False,
    orientation="h",
    show_total=True,
    # normalize=False,
    relative=True,
    height=700,
    show_pct_bar=True,
    title="Altersgruppen Kinder und Heranwachsende",
)

# pls.plot_facet_stacked_bars(
#     _db.project("z_dy, categ_age, z_kkr_label").to_df(),
#     relative=True,
#     annotations=True,
#     fill_index=True,
# )
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_452_844                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_444_458  (99.8%) ░█████████████████████████████
# └ [Alter <= 20]:     n = 10_614   (0.3%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and z_age <= 20
# ```
#
# </details>
# <!-- ALT_TEXT:Altersgruppen Kinder und Heranwachsende-->

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_10_'></a>[Verstorben](#toc0_)
#
# - gezählt sind **Personen**
# - Metrik: Anteil Verstorbener an Gesamtzahl Patienten pro erstes DJ der Person
#
# > [!NOTE]
# >  💡 **ZfKD**: Sterbefälle in TH sind noch nicht vollständig eingegangen

# %%
# _filters = [
#     FILTERS_DY,
#     FILTERS_NO_DCO,
#     FILTERS_NO_C44,

# ]
# _filter = hlp.get_duckdb_filter_n(
#     con=con,
#     query="from Tumor",
#     filters=_filters,
#     distinct_metric="z_pat_id",
#     first_n_filter_apply_to_rows=0,
# )
# _ = show_vars(
#     1,
#     grouper_reg.KKR.value,
#     show=True,
#     #filter=f"z_dy > 2019 and z_dy <= {DY_MAX} and z_icd10_3d != 'C44' and not z_is_dco",
#     filter=_filter,
# )

# %%
# con.table("Patient").columns

# %%
_filters = [
    FILTERS_DY,
    # ("year(Datum_Vitalstatus) between 2020 and 2024", "follow-up 2020-2024"),
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum join Patient pat on pat.oBDS_RKIPatientId = tum.z_pat_id",
    filters=_filters,
    distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

db_deceased= con.sql(f"""--sql
    with t1 as (
        select  z_kkr_label,
                (Verstorben = 'J') as is_deceased,
                min(z_dy)::text as z_dy_min,
                z_pat_id,
        from    Tumor tum
        join   Patient pat on pat.oBDS_RKIPatientId = tum.z_pat_id
        where {_filter}
        group by all
    ),
    t2 as (
        select
                z_kkr_label,
                z_dy_min,
                count(*) as cnt,
                sum(is_deceased) as cnt_deceased,
                sum(is_deceased) / cnt as pct_deceased,
        from    t1
        group by all
        union
        select
                'Total',
                z_dy_min,
                count(*) as cnt,
                sum(is_deceased) as cnt_deceased,
                sum(is_deceased) / cnt as pct_deceased,
        from    t1
        group by all
        union
        select
                z_kkr_label,
                'Total',
                count(*) as cnt,
                sum(is_deceased) as cnt_deceased,
                sum(is_deceased) / cnt as pct_deceased,
        from    t1
        group by all
        union
        select
                'Total',
                'Total',
                count(*) as cnt,
                sum(is_deceased) as cnt_deceased,
                sum(is_deceased) / cnt as pct_deceased,
        from    t1
        group by all
    )
    select * from t2
    """)

# tbl.descr_db(db_deceased, "deceased data")

tbl.pivot_df(
    db_deceased.project("z_kkr_label, z_dy_min, pct_deceased").to_df(),
    precision=1,
    show_as_pct=True,
    pct_axis="",
    total_axis="",
    font_size_th=13,
    font_size_td=11,
    # swap=True,
    image_scale="800",
)
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_452_844                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_444_458  (99.8%) ░█████████████████████████████
# └ [keine DCO]:     n = 3_332_300  (96.5%) ░░████████████████████████████
# └ [keine C44,D04]: n = 2_848_584  (82.5%) ░░░░░░████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# <!-- SCALE-800 -->
# <style type="text/css">
# #T_1f5b7 th {
#   text-align: right;
#   font-size: 13pt;
# }
# #T_1f5b7 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_1f5b7_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 88.9%, transparent 88.9%);
#   font-family: Courier;
# }
# #T_1f5b7_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 80.6%, transparent 80.6%);
#   font-family: Courier;
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_11_'></a>[TNM-T (p)](#toc0_)

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

# _=show_vars(9, grouper_reg.KKR.value, show=True, filter=FILTER_DY_SOLID_NO_DCO)
_=show_vars(9, grouper_reg.KKR.value, show=True, filter=_filter)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_082_538  (51.3%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_12_'></a>[TNM-N (p)](#toc0_)
# <!-- (_solide Tumoren_ schliesst folgende Diagnosen _aus_: C44, C70-C72, C76-C97, alle D) -->

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_=show_vars(11, grouper_reg.KKR.value, show=True, filter=_filter)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_082_538  (51.3%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ### <a id='toc1_8_13_'></a>[TNM-M (pc)](#toc0_)

# %% [markdown]
# - abweichend von den anderen TNM Angaben ist hier die Verbundvariable `z_m_pc_1` dargestellt
# - diese enthält den Wert aus `p`, wenn leer dann aus `c`

# %%
_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

_=show_vars(15, grouper_reg.KKR.value, show=True, filter=_filter)
# _=show_vars(12, grouper_reg.KKR.value, show=True, filter=_filter)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_082_538  (51.3%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>

# %% [markdown]
# <br>
#
# ## <a id='toc1_9_'></a>[Todesursachen (TU)](#toc0_)

# %% [markdown]
# ### <a id='toc1_9_1_'></a>[nach ICD10 Einstellern](#toc0_)
# - gezählt sind die ersten Stellen aller TU Codes ohne jeglichen Filter

# %%
db_tu = Todesursache.project("*, upper(substr(Code, 1,1)) as tu_1d")
_ = pls.plot_bars(
    db_tu.aggregate("tu_1d, count(*) as cnt").to_df().export_plot_data(),
    orientation="h",
    sort_values=True,
    height=500,
    top_n_index=10,
    # caption=None, 
    title="nach ICD10 Einstellern",
)
# Out:
# <!-- ALT_TEXT:nach ICD10 Einstellern-->

# %% [markdown]
# ### <a id='toc1_9_2_'></a>[nach Sterbejahr und Todesursachen](#toc0_)
# - gezählt werden **Personen**
# - `tu_type` Art der TU pro Patient
#   - `<NA>` keine Todesursache zugeordnet
#   - `c_only` nur Todesursachen Cxx
#   - `other_only` nur Todesursachen <> Cxx
#   - `c_and_other` Cxx und andere Todesursachen
#
# <!-- > 💡 ZfKD: _"`03-NI` und `06-HE` übermitteln deutlich weniger Todesursachen asl in den epi Daten, für `07-RP` ist der Anteil in beiden Datenräumen gering. Für `15-ST` sind auffällig wenige Todesfälle in 2023 übermittelt."_ -->

# %%
_filters = [
    # FILTERS_DY,
    (f"year(Datum_Vitalstatus::date) between 2020 and {DY_MAX}","SJ 2020-2024"),
    ("Verstorben='J'","nur Verstorbene"),
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum join Patient pat on pat.oBDS_RKIPatientId = tum.oBDS_RKIPatientId",
    filters=_filters,
    distinct_metric="z_pat_id",
    first_n_filter_apply_to_rows=0,
)

# _filter = f"""--sql
#     year(Datum_Vitalstatus::date) between 2020 and {DY_MAX}
#     and Verstorben='J'
# """

db_tu2 = con.sql(f"""--sql
    with t1 as (
        -- raw list, 1 pat -> n tu
        select
            pat.oBDS_RKIPatientId as z_pat_id,
            year(Datum_Vitalstatus::date) as SJ,
            -- check both independantly
            case when left(code,1)='C' then true else false end as has_c,
            case when left(code,1)<>'C' then true else false end as has_other,
            pat.z_kkr,
            Code,
            Version,
            IsGrundleiden,
        from Patient pat
        left join Todesursache tu on pat.oBDS_RKIPatientId = tu.oBDS_RKIPatientId
        where {_filter}
    ),
    t2 as (
        -- 1 pat -> 1 tu_type
        select
            z_pat_id,
            SJ,
            z_kkr,
            case
                when max(has_c) and max(has_other) then 'c_and_other'
                when max(has_c) and not max(has_other) then 'c_only'
                when not max(has_c) and max(has_other) then 'other_only'
                -- use null for a prominent, grey bar in diagram
                when not max(has_c) and not max(has_other) then null
                -- this should never show
                else 'U'
            end as tu_type,
        from t1
        -- SJ and kkr are neutral in the group
        group by z_pat_id, SJ, z_kkr
    ),
    t3 as (
        -- assign label
        select
            SJ,
            tu_type,
            lr.kkr as z_kkr_label,
        from t2
        left join dim_lieferregister lr on t2.z_kkr = lr.code
    )
    select * from t3
    """)
# tbl.descr_db(db_tu2,"tu_type")
df_tu2 = db_tu2.to_df()

_ = pls.plot_facet_stacked_bars(
    df_tu2.export_plot_data(),
    subplots_per_row=4,
    top_n_color=5,
    # sort_values_color=True,
    # sort_values_facet=True,
    show_other=False,
    relative=True,
    annotations=True,
    # renderer="svg",
    title="nach Sterbejahr und Todesursachen",
)
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_452_844                      (100.0%) ██████████████████████████████
# └ [SJ 2020-2024]:    n = 2_636_984  (76.4%) ░░░░░░░░██████████████████████
# └ [nur Verstorbene]:   n = 900_310  (26.1%) ░░░░░░░░░░░░░░░░░░░░░░░███████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# year(Datum_Vitalstatus::date) between 2020 and 2024
# and Verstorben='J'
# ```
#
# </details>
# <!-- ALT_TEXT:nach Sterbejahr und Todesursachen-->

# %%
# _filter = f"""--sql
#     year(Datum_Vitalstatus::date) between 2020 and {DY_MAX}
#     and Verstorben='J'
# """

# # # * get list of all patient and their first TU
# _tu = (Patient.set_alias("p")
#     .join(Todesursache, "oBDS_RKIPatientId", "inner")
#     .aggregate("p.oBDS_RKIPatientId, min(Code) as code")
# )
# # _tu

# db_tu=(
#     Patient
#     .join(_tu, "oBDS_RKIPatientId", "left")
#     .join(Tumor, "oBDS_RKIPatientId", "left")
#     .filter(_filter)
#     .project("""--sql
#             --z_dy 
#             year(Datum_Vitalstatus::date) as SJ
#             --,left(code,3) as tu
#             ,case 
#                 when left(code,1)='C' then 'C' 
#                 when left(code,1)<>'C' then '<other>' 
#                 else null end as tu_type
#             ,z_kkr_label
#     """)
# )
# df_tu = db_tu.to_df()

# hlp.print_filter(_filter)

# _ = pls.plot_facet_stacked_bars(
#     df_tu,
#     subplots_per_row=4,
#     top_n_color=5,
#     sort_values_color=True,
#     show_other=False,
#     relative=True,
#     annotations=True,
#     renderer="svg",
# )

# %% [markdown]
# <br>
#
# ### <a id='toc1_9_3_'></a>[nach ICD10 Dreistellern (TOP 5)](#toc0_)
# - Grundgesamtheit: alle **Todesursachen**, kein Filter
#
# > 💡 **ZfKD**: _Enthalten sind in einigen KKR auch `C79` (Metastasen), welche in offizieller Todesursachen-Statistik nicht kodiert sind_

# %%
_tu = (
    Todesursache.aggregate("z_kkr, left(Code,3) as tu_3d, count(*) as cnt")
    .join(dim_lieferregister, "z_kkr::int = code::int")
    .project("tu_3d,kkr, cnt")
    .to_df()
    # .pivot_table(index='tu_3d', columns='kkr', values='cnt', fill_value=0, dropna=False)
)
# tbl.show_num_df(_df, data_bar_axis="xy", total_axis="xy", total_exclude=True, pct_axis="x",)
tbl.pivot_df(
    _tu,
    top_n_index=5,
    data_bar_axis="xy",
    pct_axis="",
    heatmap_axis="",
    total_axis="xy",
    font_size_th=8,
    font_size_td=6,
    swap=True,
    # total_exclude=True,
    image_scale="80%"
)
# Out:
# <!-- SCALE-80% -->
# <style type="text/css">
# #T_8ad33 th {
#   text-align: right;
#   font-size: 8pt;
# }
# #T_8ad33 td {
#   text-align: right;
#   font-size: 6pt;
# }
# #T_8ad33_row0_col0, #T_8ad33_row1_col1, #T_8ad33_row3_col2, #T_8ad33_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.4%, transparent 0.4%);
#   font-family: Courier;
# }
# #T_8ad33_row0_col1, #T_8ad33_row3_col5, #T_8ad33_row9_col2, #T_8ad33_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 0.7%, transparent 0.7%);
#   font-family: Courier;
# }
# #T_8ad33_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.8%, transparent 1.8%);
#   font-family: Courier;
# }
# #T_8ad33_row0_col3, #T_8ad33_row0_col4, #T_8ad33_row1_col3, #T_8ad33_row1_col4, #T_8ad33_row2_col3, #T_8ad33_row2_col4, #T_8ad33_row3_col3, #T_8ad33_row3_col4, #T_8ad33_row7_col3, #T_8ad33_row7_col4, #T_8ad33_row9_col3, #T_8ad33_row9_col4 {
#   width: 10em;
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_9_4_'></a>[nach IsGrundleiden](#toc0_)
# - Grundgesamtheit: **alle Todesursachen**

# %%
_tu = (
    Todesursache.aggregate(
        "z_kkr, cast(IsGrundleiden as bool) as is_grundleiden, count(*) as cnt"
    )
    .join(dim_lieferregister, "z_kkr::int = code::int")
    .project("kkr, is_grundleiden, cnt")
    .to_df()
)
_ = pls.plot_stacked_bars(
    _tu.export_plot_data(),
    orientation="h",
    height=700,
    relative=True,
    show_total=True,
    show_pct_bar=True,
    title="nach IsGrundleiden",
    first_col_grey=True,
)
# Out:
# <!-- ALT_TEXT:nach IsGrundleiden-->

# %% [markdown]
# ## <a id='toc1_10_'></a>[Therapien](#toc0_)

# %% [markdown]
# <br>
#
# ### <a id='toc1_10_1_'></a>[OP](#toc0_)

# %% [markdown]
# #### <a id='toc1_10_1_1_'></a>[nach ICD10](#toc0_)
# - Grundgesamtheit: alle **OP Meldungen**

# %%
FILTERS_OP_ORDER = ("z_op_order = 1", "nur erste OP")

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
    FILTERS_OP_ORDER
]
_filter = hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum left join OP op on op.z_tum_id = tum.z_tum_id",
    filters=_filters,
    distinct_metric="OPId",
    first_n_filter_apply_to_rows=0,
)

_op = (OP
    .join(Tumor
        .set_alias("t")
        .project("*, left(Diagnose_ICD10_Code,3) as icd10_3d"), 
        "z_tum_id")
    .filter(_filter)
    .aggregate("icd10_3d, t.z_kkr, count(*) as cnt")
    .join(dim_lieferregister, "z_kkr::int = code::int")
    .project("kkr, icd10_3d, cnt")
    .to_df()
    )
_=pls.plot_stacked_bars(_op.export_plot_data(), orientation="h", height=700, top_n_color=10, relative=True, sort_values_color=True, show_other=True, show_total=True, show_pct_bar=True, title="OP-Meldungen nach ICD10",)
# Out:
# <!-- START_TOKEN -->
# count: distinct OPId
# ---
# n = 2_121_378                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 2_085_372  (98.3%) ░█████████████████████████████
# └ [keine DCO]:     n = 2_085_319  (98.3%) ░█████████████████████████████
# └ [keine C44,D04]: n = 1_919_103  (90.5%) ░░░███████████████████████████
# └ [nur erste OP]:  n = 1_532_530  (72.2%) ░░░░░░░░░█████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# and z_op_order = 1
# ```
#
# </details>
# <!-- ALT_TEXT:OP-Meldungen nach ICD10-->

# %% [markdown]
# <br>
#
# #### <a id='toc1_10_1_2_'></a>[nach Intention](#toc0_)
# - Grundgesamtheit: alle **OP Meldungen**

# %%
_op = (OP
    .join(Tumor.set_alias("t"), "z_tum_id")
    .aggregate("Intention, t.z_kkr_label, count(*) as cnt")
    .join(dim_op_intention.set_alias("i"), "Intention=i.code")
    .project("z_kkr_label,concat(i.code, ' -  ', i.name) as label, cnt")
    .to_df()
    )
_=pls.plot_stacked_bars(_op.export_plot_data(), orientation="h", height=700, top_n_color=0, relative=True, show_total=True, show_pct_bar=True, title="OP-Meldungen nach Intention",)
# Out:
# <!-- ALT_TEXT:OP-Meldungen nach Intention-->

# %% [markdown]
# <br>
#
# ### <a id='toc1_10_2_'></a>[OPS](#toc0_)

# %% [markdown]
# #### <a id='toc1_10_2_1_'></a>[nach OPS ICD Kapitel (Top 10)](#toc0_)
# - Grundgesamtheit: **alle OPS Codes**
#
# > 💡 **ZfKD**: lediglich `02-HH` und `05-NW` übermitteln ausschliesslich Kapitel 5. Der Anteil von Meldungen <> Kapitel 5 sind wahrscheinlich diagnostische Massnahmen oder nicht-operative Therapien. Vorschlag: nur noch Kapitel 5 übermitteln

# %%
_ops = (OPS
    # .join(Tumor.set_alias("t"), "oBDS_RKIPatientTumorId")
    .aggregate("left(Code,1) as code_1d, z_kkr, count(*) as cnt")
    .join(dim_lieferregister, "z_kkr::int=code::int")
    .project("kkr, code_1d, cnt")
    .to_df()
    )
_=pls.plot_stacked_bars(_ops.export_plot_data(), orientation="h", height=700, top_n_color=10, relative=True, sort_values_color=False, show_total=True, title="OPS nach ICD-Kapitel (Top 10)",)
# Out:
# <!-- ALT_TEXT:OPS nach ICD-Kapitel (Top 10)-->

# %% [markdown]
# ### <a id='toc1_10_3_'></a>[SYST](#toc0_)

# %% [markdown]
# #### <a id='toc1_10_3_1_'></a>[nach Stellung_OP](#toc0_)
#
# - Grundgesamtheit: **alle SYST Elemente**

# %%
_syst = (SYST
    .join(Tumor.set_alias("t"), "z_tum_id")
    .aggregate("Stellung_OP, t.z_kkr_label, count(*) as cnt")
    .join(con.table("dim_syst_op_stellung").set_alias("s"), "Stellung_OP=s.code")
    .project("z_kkr_label,concat(s.code, ' -  ', s.name) as label, cnt")
    .to_df()
    )
_=pls.plot_stacked_bars(_syst.export_plot_data(), orientation="h", height=700, top_n_color=0, relative=True, show_total=True, title="SYST nach Stellung_OP",)
# Out:
# <!-- ALT_TEXT:SYST nach Stellung_OP-->

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_11_'></a>[Missings- und Unbekannt-Kodierungen](#toc0_)
# - in diesem Kapitel sind Ampelfarben zugeordnet, da Zielwerte klar identifizierbar sind
# - die Zuordnung zu Wertebereichen ist Diskussionsgrundlage
# - es sind folgende Schwellwerte verwendet:
#   - 🟩 0 bis <5%
#   - 🟨 **missings**: 5% bis <100% | **unbekannt**: 5% bis <35%>
#   - 🟥 **missings**: bei 100% | **unbekannt** >= 35%
# - dargestellt sind Variablen aus dem Schema in folgender Notation: `[Elementknoten]Variablenname`
# - die graumelierte `0` kennzeichnet einen leeren Wert (=keine missings), 0% entsteht durch Rundung von kleinen Werten
# - die Prozentwerte sind bei allen Darstellungen gerundet, "100%" bei einer gelben Ampel kann interpretiert werden als knapp unter 100%
# - - `Total`
#   - ist als Spalte neu eingefügt, und bildet den Anteil von missings bzw unbekannt deutschlandweit ab
#   - ⚠️ verliert an Aussagekraft, wenn aus KKR keine Daten vorliegen für diese Variable (100% missings), der Wert wirkt dann geschönt
#
# **unbekannt**
# - bei 100% missings wird auch unbekannt auf 100% gesetzt
# - Beispiele für gewertete Unbekannt-Kodierungen:
#   - `Diagnosesicherung` = 9
#   - `Seitenlokalisation` = U
#   - `Datumsgenauigkeit` in ('M','V')
# - der Quellcode zur Bestimmung von `Unbekannt` Kodierungen ist hier abrufbar: [sql](sql/check_if_unknown.sql)

# %%
with open("../sql/check_if_unknown.sql") as f:
    _macro_check_if_unknown = f.read()
_=con.execute(_macro_check_if_unknown)

# %%
def show_missings2(
    filter_col: str,
    filter_row: str = "true",
    use_unknown: bool = False,
    swap: bool = True,
    debug: bool = False,
    font_size_th: int = 12,
    font_size_td: int = 11,
    image_scale: str = None,
    use_short_names: bool = True,
):
    """
    filter_col: filter for columns  
    filter_row: filter for tablerows  
    use_unknown: show unknowns instead of missings  
    print_filter: print filter string  
    debug: show debug info  
    
    hint for filter_col:
    ```python
    regexp_matches(tablecolumn, 'atem|radio|geschl|inzidenz|Anzahl_Tage_Diagnose_OP','i')
    ```
    or
    ```python
    table = 'OPS'
    ```
    
    or

    ['sel3_TNM',
    'sel4_datum',
    'sel5_pflicht',
    'sel6_mamma',
    'sel7_prostata',
    'sel8_prio',
    'sel9_darm',
    'sel10_melanom',
    'sel11_fo',
    'sel12_free',
    'sel13_unknown']

    """
    # * get all columns and tables
    items = (dim_tree
        # .filter("regexp_matches(tablecolumn, 'atem|radio|geschl|inzidenz|Anzahl_Tage_Diagnose_OP','i')")
        .filter(filter_col)
        .project("""--sql
            tablecolumn,
            regexp_extract(tablecolumn, '\](.*)', 1) as col_name,
            tables,
        """)
        .to_df()
        .to_dict()
    )
    if debug:
        print(items)

    # * create empty df
    df_missings_all = pd.DataFrame()

    for col, tab, col_name in zip(items["tablecolumn"].values(), items["tables"].values(), items["col_name"].values()):

        # * create stub, care for the unclosed brackets (closing in query_1)
        query_0 = (f"""--sql
            with t1 as (
                select
                    (ifnull(t_1.{col_name}::text, '') = '') as is_missing,
                    mem.fx_check_if_unknown(t_1.{col_name}, '{col_name}') AS is_unknown,
                    t_1.z_kkr as z_kkr,
                from {tab} t_1
                
        """)

        # ! use extra query for patient oriented tables, join is different here
        if tab in ('Patient', 'Todesursache'):
            query_1 = (f"""--sql
                where oBDS_RKIPatientId in
                    -- avoid join to not have a table prefix like "tum.", to reuse the filter
                    (select z_pat_id from Tumor where {filter_row})
            ),
            """)
        else:
            query_1 = (f"""--sql
                where z_tum_id in (select z_tum_id from Tumor where {filter_row})
            ),
            """)
            
        # ! use extra metrics for unknown. missings / unknown -> invalid
        if not use_unknown:
            query_2 = ("""--sql
                t2 as (
                    select
                        is_missing as is_invalid,
                        z_kkr,
                        count(*)::int as cnt,
                    from t1
                    group by is_missing,z_kkr
                ),
            """)
        else:
            query_2 = ("""--sql
                t2 as (
                    select
                        is_unknown as is_invalid,
                        z_kkr,
                        case
                            -- check if there are any rows at all
                            -- if not, return 0, which makes nonexisting data also unknown
                            when count(*) filter (not is_missing) = 0 then 0
                            else count(*)::int
                        end as cnt,
                    from t1
                    group by is_unknown,z_kkr
                ),
            """)

        query_rest = (f"""--sql
            t3 as (
                select
                    *,
                    sum(cnt) over (partition by z_kkr) as cnt_all,
                from t2
                order by z_kkr
            ),
            t4 as (
                select
                    z_kkr,
                    cnt as cnt_valid,
                    cnt_all,
                from t3
                where not is_invalid
                -- filter for the **valid** rows
                -- these can be better distinguished from non existing data

                -- ! TOTALS can be activated here. problem is, non existing data bias the total
                -- when kkr dont have any data, total looks fine. this is not intuitive!

                -- now calc the total. must be on t2 since t3 is filtered
                union
                select
                    -- 0 = Total
                    0 as z_kkr,
                    -- sum all cnt but only for the valid
                    sum(cnt) filter (not is_invalid) as cnt_valid,
                    -- sum all cnt
                    sum(cnt) as cnt_all
                from t2
            ),
            t5 as (
                select
                    '{col_name if use_short_names else col}' as col,
                    kkr as z_kkr,
                    cnt_valid,
                    cnt_all,
                    case
                        -- no data at all -> 100% (red)
                        when ifnull(cnt_all,0) = 0 then 1
                        -- calculate diff to 100%. empty valids -> 0
                        else 1 - coalesce(cnt_valid/cnt_all::float,0)
                    end as pct_invalid
                from t4
                -- fill up non existing data
                right join dim_lieferregister on z_kkr = code
                --where kkr <> 'Total'
            )
            select * from t5
        """)

        query = query_0 + query_1 + query_2 + query_rest
        # print(query)
        db_missings = con.sql(query)
                
        df_missings = db_missings.to_df()

        if df_missings_all.empty:
            df_missings_all = df_missings
        else:
            df_missings_all = pd.concat([df_missings_all, df_missings], axis=0)

    # * debug
    # con.from_df(df_missings_all).filter("z_kkr <> 0").sum("cnt_all").show()
    # return df_missings_all.sort_values(["z_kkr"])#["cnt_invalid"].sum()

    if debug:
        print(query)
        display(df_missings_all.sort_values(["col","z_kkr"]))

    if use_unknown:
        print("🟠 unknowns")
    else:
        print("🟠 missings")

    _df = df_missings_all[["z_kkr","col","pct_invalid"]] if swap else df_missings_all[["col","z_kkr","pct_invalid"]]

    display(tbl.pivot_df(
        df=_df,
        total_axis="",
        precision=1,
        show_as_pct=True,
        pct_axis="",
        # kkr_col="z_kkr",
        # swap=True,
        kpi_mode="rag_abs",
        kpi_rag_list=[0.05,1] if not use_unknown else [0.05, 0.35],
        font_size_th=font_size_th,
        font_size_td=font_size_td,
        image_scale=image_scale,
        )
    )

# %% [markdown]
# <br>
#
# ### <a id='toc1_11_1_'></a>[Verpflichtende Tumorvariablen](#toc0_)
# - kein Filter
# - Pflichtangaben aus anderen Elementknoten (z.B. Datum aus dem OP Knoten) sind nicht aufgeführt, da diese selbst optional sind
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - Pflichtfelder sind nahezu komplett vorhanden, die wenigen Ausnahmen werden allerdings Stand heute nicht korrigiert
# > - `Gesamtbeurteilung_Tumorstatus`ist zwar vollständig geliefert (siehe vorherige Grafiken), aber häufig als Unbekannt kodiert. Viele Pflichtvariablen haben keine Unbekannt Kodes, etwas auffällig sind hier `Diagnosesicherung` und `Seitenlokalisation`. Ähnlich auch `Morphologie` (kein Pflichtfeld)

# %%
os.environ['IMAGE_SCALE'] = "100%"

_filters = [
    FILTERS_DY,
]
_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col="sel5_pflicht",
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    # swap=True,
    # image_scale="100%"
    use_short_names=True,
)

show_missings2(
    filter_col="sel5_pflicht",
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    # image_scale="100%"
)
# show_missings2(
#     filter_col="sel5_pflicht",
#     filter_row = _filter,
#     use_unknown=True,
#     # debug=True,
#     # image_scale="100%",
#     # swap = False,
# )
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_794_188  (93.4%) ░░████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_adf19 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_adf19 td {
#   text-align: right;
#   font-size: 11pt;
# }
# ...

# %% [markdown]
# ### <a id='toc1_11_2_'></a>[Weitere Tumorangaben](#toc0_)

# %%
_fil = """--sql
    tablecolumn in (
        --'[Tumor]Diagnosesicherung',
        --'[Tumor]T_p',
        --'[Tumor]UICC_Stadium_p',
        '[Tumor]Morphologie_Code',
        --'[Tumor]Diagnosedatum_Genauigkeit',
        '[Tumor]Topographie_Code',
        '[Tumor]Grading',
)"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    # font_size_th=12,
    # font_size_td=11,
    image_scale="50%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=True,
    # debug=True,
    # font_size_th=12,
    # font_size_td=11,
    image_scale="50%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_065_024  (75.4%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-50% -->
# <style type="text/css">
# #T_02a39 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_02a39 td {
#   text-align: right;
#   font-size: 11pt;
# }
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_11_3_'></a>[Tumorstadien](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - die Auflage ist in `05-NW` als Konstante im Datensatz hinterlegt
# > - für `07-RP` liegen keine pathologischen Angaben vor

# %%
    # sel3_TNM
_fil = """--sql
    tablecolumn in (
        '[Tumor]T_c',
        '[Tumor]T_p',
        '[Tumor]N_c',
        '[Tumor]N_p',
        '[Tumor]M_c',
        '[Tumor]M_p',
        '[Tumor]UICC_Stadium_c',
        '[Tumor]UICC_Stadium_p',
        '[Tumor]TNM_Auflage_c',
        '[Tumor]TNM_Auflage_p',
        --'[Tumor]c_p_u_Praefix_T_c',
        --'[Tumor]c_p_u_Praefix_T_p'
    )"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)


show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=True
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=True,
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_082_538  (51.3%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_11_4_'></a>[Therapieangaben](#toc0_)

# %% [markdown]
# #### <a id='toc1_11_4_1_'></a>[OP](#toc0_)
#
# > 💡 **ZfKD**: für überlieferte OP liegen `Datum_OP` und `Intention` komplett vollständig vor. Der Tagesabstand hat wenige Lücken, während `Lokale_Beurteilung_Residualstatus` auch ausserhalb der Tristan KKR erkennbar häufiger fehlt

# %%
_fil = """--sql
tables = 'OP' and tablecolumn not ilike '%genauigkeit'
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="80%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="80%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_065_024  (75.4%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-80% -->
# <style type="text/css">
# #T_41306 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_41306 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_41306_row0_col0, #T_41306_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 1.4%, transparent 1.4%);
#   font-family: Courier;
# }
# ...

# %% [markdown]
# #### <a id='toc1_11_4_2_'></a>[ST](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - `Datum_Beginn_Bestrahlung` und `Intention` sind nahezu komplett verfügbar in den dokumentierten ST / Bestrahlungen, mit Abstrichen auch `Anzahl_Tage_Diagnose_Bestrahlung`.
# > - `Anzahl_Tage_Bestrahlung_Dauer` und `Stellung_OP` fehlen bei Tristan
# > - `Applikationsart` wird nicht von allen kkr übermittelt, davon abgesehen ist `Seite_Zielgebiet` zuverlässig angegeben, die CodeVersionen ergänzen sich, wobei `2014` deutlich häufiger angewendet wird als `2021`

# %%
_fil = """--sql
        tablecolumn not ilike '%genauigkeit'
        and (
            tables in ('ST', 'Bestrahlung')
            or regexp_matches(tablecolumn,'codeversion|zielgebiet','i')
)"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=
    # debug=True,
    # use_short_names=False,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=
    # debug=True,
    # use_short_names=False,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_065_024  (75.4%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_cf1da th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_cf1da td {
#   text-align: right;
#   font-size: 11pt;
# }
# ...

# %% [markdown]
# #### <a id='toc1_11_4_3_'></a>[SYST](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**: die meisten Angaben im SYST Element liegen komplett vor. `Anzahl_Tage_SYST_Dauer` fehlt häufig, was auch an noch nicht abgeschlossenen Therapien liegen könnte

# %%
_fil = """--sql
tables in ('SYST') and tablecolumn not ilike '%genauigkeit'
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_065_024  (75.4%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_53e48 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_53e48 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_53e48_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 9.1%, transparent 9.1%);
#   font-family: Courier;
# }
# #T_53e48_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 59.7%, transparent 59.7%);
#   font-family: Courier;
# }
# ...

# %% [markdown]
# ### <a id='toc1_11_5_'></a>[Folgeereignisse](#toc0_)
# - die Variablen aus `Folgeereignis` und `Folgeereignis_TNM` sind hier zusammengefasst
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - `Datum_Folgeereignis` und `Gesamtbeurteilung_Tumorstatus` liegen komplett vor, die anderen Angaben zum Tumorstatus allerdings nicht
# > - die Erkennung von Rezidiven ist so deutlich erschwert
# > - Angaben für `Folgeereignis_TNM` fehlen ganz überwiegend, auch wenn Folgereignisse keine TNM enthalten müssen
# > - Folgeereignisse aus `07-RP` und `08-BW` enthalten keine Missings, dafür allerdings erhöhte Anteile an Unbekannt Kodierungen
# > - T-Stadien zu Folgeereignissen weisen in `02-HH` einen ungewöhnlich niedrigen Missing Anteil auf, bei gleichzeitig fast Unbekannt-freien Kodierungen. Die Fallzahlen dieser Folgeereignisse sind in etwa im erwarteten Rahmen

# %%
_fil = """--sql
tablecolumn not ilike '%genauigkeit' and sel11_fo
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_065_024  (75.4%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_55fc9 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_55fc9 td {
#   text-align: right;
#   font-size: 11pt;
# }
# ...

# %% [markdown]
# ### <a id='toc1_11_6_'></a>[Freitexte](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**:
# > - Protokolle und Substanzen werden nach und nach in den Datensatz eingebunden. Protokolle bislang ausschliesslich als Freitext
# > - bei Substanzen komplementieren sich Freitexte und Kodierungen, bei vielen GTDS Ländern überwiegen inzwischen die Kodierungen

# %%
_fil = """--sql
not regexp_matches(tablecolumn,'genauigkeit','i') and sel12_free
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_NO_C44,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=True,
    # debug=True,
    use_short_names=False,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=True,
    # debug=True,
    use_short_names=False,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                    (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:  n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:     n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [keine C44,D04]: n = 3_065_024  (75.4%) ░░░░░░░░██████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d not in ('C44','D04')
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_b1bbc th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_b1bbc td {
#   text-align: right;
#   font-size: 11pt;
# }
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_11_7_'></a>[Organspezifische Variablen](#toc0_)

# %% [markdown]
# <br>
#
# #### <a id='toc1_11_7_1_'></a>[Mamma](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - missing Anteile sind besonders niedrig aus `04-HB` und den GTDS Ländern bei gleichzeitig unauffälligem Unbekannt Anteil
# > - `HormonrezeptorStatus_Progesteron` ist in der Fläche erkennbar schlechter erfasst als z.B. `Her2neuStatus`

# %%
_fil = """--sql
sel6_mamma
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_C50,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)


show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # show_filter=
    # debug=True,
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # show_filter=
    # debug=True,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [ICD10 C50]:      n = 394_544   (9.7%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C50'
# ```
#
# </details>
# 🟠 missings
# <style type="text/css">
# #T_2f9d6 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_2f9d6 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_2f9d6_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 15.5%, transparent 15.5%);
#   font-family: Courier;
# }
# #T_2f9d6_row0_col1, #T_2f9d6_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 14.3%, transparent 14.3%);
#   font-family: Courier;
# }
# #T_2f9d6_row0_col3 {
# ...

# %% [markdown]
# <br>
#
# #### <a id='toc1_11_7_2_'></a>[Prostata](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**: auch innerhalb eines KKR gibt es deutliche Varianzen zwischen Variablen des organspezifischen Moduls, z.B. in den NBL

# %%
_fil = """--sql
sel7_prostata
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d = 'C61'", "ICD C61"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    # font_size_th=12,
    # font_size_td=11,
    image_scale="70%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    # font_size_th=12,
    # font_size_td=11,
    image_scale="70%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [ICD C61]:        n = 379_354   (9.3%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C61'
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-70% -->
# <style type="text/css">
# #T_7f374 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_7f374 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_7f374_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 17.5%, transparent 17.5%);
#   font-family: Courier;
# }
# #T_7f374_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 41.4%, transparent 41.4%);
#   font-family: Courier;
# }
# #T_7f374_row0_col2 {
# ...

# %% [markdown]
# <br>
#
# #### <a id='toc1_11_7_3_'></a>[Darm](#toc0_)

# %%
_fil = """--sql
sel9_darm
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d in ('C18','C19','C20')", "ICD C18-20"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)



show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="40%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="40%"
    )
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [ICD C18-20]:     n = 277_957   (6.8%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d in ('C18','C19','C20')
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-40% -->
# <style type="text/css">
# #T_69f0a th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_69f0a td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_69f0a_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 53.2%, transparent 53.2%);
#   font-family: Courier;
# }
# #T_69f0a_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 86.5%, transparent 86.5%);
#   font-family: Courier;
# }
# ...

# %% [markdown]
# <br>
#
# #### <a id='toc1_11_7_4_'></a>[Melanom](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**: insgesamt weist dieses Modul die höchsten Werte für Missings auf

# %%
_fil = """--sql
sel10_melanom
"""

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d = 'C43'", "ICD C43"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor",
    filters=_filters,
    # distinct_metric="z_tum_id",
)

show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    # use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="50%"
)
show_missings2(
    filter_col=_fil,
    filter_row = _filter,
    use_unknown=True,
    # debug=True,
    font_size_th=12,
    font_size_td=11,
    image_scale="50%"
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [ICD C43]:        n = 144_842   (3.6%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░█
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C43'
# ```
#
# </details>
# 🟠 missings
# <!-- SCALE-50% -->
# <style type="text/css">
# #T_77422 th {
#   text-align: right;
#   font-size: 12pt;
# }
# #T_77422 td {
#   text-align: right;
#   font-size: 11pt;
# }
# #T_77422_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 98.0%, transparent 98.0%);
#   font-family: Courier;
# }
# #T_77422_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #b3c8ec 52.2%, transparent 52.2%);
#   font-family: Courier;
# }
# #T_77422_row0_col2 {
# ...

# %%
# show_missings(
#     kpi.MISSINGS.value,
#     filter=f"{fil_pd_dco_dy} and sel10_melanom and icd10_3d in ('C43')",
#     group_table=grouper_table.TABLECOL.value,
# )

# %% [markdown]
# ## <a id='toc1_12_'></a>[Weitere Klassifikationen](#toc0_)
# - Kodierungen zu `Weitere Klassifikationen` können an verschiedenen Orten des Schemas übermittelt werden
#   - im Element `Primärdiagnose`
#   - im Element `Folgeereignisse`
# - darüber hinaus können diese Kodierungen Angaben darstellen, welche in dedizierten Feldern vorgesehen sind (z.B. UICC, PSA)
# - die Zuordnung der Freitexte zu von der Plattform 65c definierten Klassifikationen (internes Plattform Dokument)[https://plattform65c.atlassian.net/wiki/spaces/UMK/pages/15532511/Weitere+Klassifikationen] erfolgt per regex in diesem [sql script](../sql/check_if_class.sql)

# %% [markdown]
# ### <a id='toc1_12_1_'></a>[nach Quelle](#toc0_)
# - untersucht wird der Zusammenhang zwischen den Orten im Schema ("Quelle"), wo die Klassifikation übermittelt wird
# - gezeigt sind die 20 häufigsten Klassifikationen
# - Kategorie `source`
#   - `diag`: Klassifikation ist der Diagnose zugeordnet
#   - `fol`: Klassifikation ist einem Folgeereignis zugeordnet
#
# > [!NOTE]
# > **💡 ZfKD**
# > - die überwiegende Zahl der Kodierungen ist der Diagnose zugeordnet
# > - Ausnahme: für PSA gibt es viele Kodes aus Folgeereignissen, für Hormonrezeptoren sogar überwiegend

# %%
with open("../sql/check_if_class.sql") as f:
    _macro_check_if_class = f.read()
_=con.execute(_macro_check_if_class)

# %%
db_class = (con.sql("""--sql
        with dia_fol as (
            select Name, Stadium, z_tum_id,
            'diag' as source 
            from Diagnose_WeitereKlassifikation
            union
            select Name, Stadium, z_tum_id,
            'fol' as source 
            from Folgeereignis_WeitereKlassifikation
        )
        select
            tum.z_tum_id,
            Name,
            Stadium,
            z_kkr_label,
            source,
            z_dy,
            case when z_dy < 2020 then '(<2020)' else z_dy::text end as z_dy_str,
            mem.fx_check_if_class(Name) as class,
        from dia_fol
        join Tumor tum on dia_fol.z_tum_id = tum.z_tum_id
        --where Stadium is not null
    """)
)
# tbl.descr_db(db_class, "db_class")
con.register("db_class", db_class)

_filters = [
    ("Stadium is not null", "Stadium vorhanden"),
    # ("z_dy < 2025","")
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from db_class",
    filters=_filters,
)

db_class_filtered = db_class.filter(_filter)
# Out:
# <!-- START_TOKEN -->
# n = 873_871                        (100.0%) ██████████████████████████████
# └ [Stadium vorhanden]: n = 873_871 (100.0%) ██████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# Stadium is not null
# ```
#
# </details>

# %%
_df = (db_class_filtered
    .aggregate("class, source, count(*) as cnt")
    .to_df()
)

pls.plot_stacked_bars(
    _df.export_plot_data(),
    orientation="h",
    sort_values_index=True,
    height=600,
    normalize=True,
    show_pct_all=True,
    top_n_index=20,
    color_palette=const.PALETTE_RKI2,
    null_label="(no_match)",
    title="Weitere Klassifikationen nach Quelle",
)
# Out:
# <!-- ALT_TEXT:Weitere Klassifikationen nach Quelle-->

# %% [markdown]
# ### <a id='toc1_12_2_'></a>[nach KKR](#toc0_)
# - gezeigt sind die 20 häufigsten Klassifikationen
#
# > [!NOTE]
# > **💡 ZfKD**
# > - visuell erkennbare "hotspots":
# >   - die grösste Gruppe der Kodierungen stellt `PSA` dar aus `05-NW`
# >   - markante Anteile sind `KI67` und `UICC` aus `08-BW`
# >   - ebenfalls erwähnenswert: Anteile vor allem aus `05-NW` und `08-BH`, welche nicht zu den von der Plattform definierten Klassifikationen zugeordnet werden können (siehe Zeile `(NA)`)

# %%
_df = (db_class_filtered
    .aggregate("class, z_kkr_label, count(*) as cnt")
    .to_df()
)
tbl.pivot_df(
    _df,
    top_n_index=20,
    data_bar_axis="",
    heatmap_axis="xy",
    # total_exclude=True,
    pct_axis="",
    total_axis="",
    image_scale="100%",
    font_size_th=9,
    font_size_td=8,
)
# Out:
# <!-- SCALE-100% -->
# <style type="text/css">
# #T_7469c th {
#   text-align: right;
#   font-size: 9pt;
# }
# #T_7469c td {
#   text-align: right;
#   font-size: 8pt;
# }
# #T_7469c_row0_col0, #T_7469c_row0_col9, #T_7469c_row1_col1, #T_7469c_row1_col9, #T_7469c_row2_col2, #T_7469c_row2_col5, #T_7469c_row2_col11, #T_7469c_row2_col12, #T_7469c_row2_col14, #T_7469c_row3_col6, #T_7469c_row3_col9, #T_7469c_row4_col2, #T_7469c_row4_col3, #T_7469c_row4_col8, #T_7469c_row4_col9, #T_7469c_row4_col11, #T_7469c_row6_col1, #T_7469c_row6_col3, #T_7469c_row6_col15, #T_7469c_row8_col2, #T_7469c_row8_col6, #T_7469c_row8_col10, #T_7469c_row9_col1, #T_7469c_row11_col3, #T_7469c_row11_col5, #T_7469c_row11_col15, #T_7469c_row12_col5, #T_7469c_row12_col13, #T_7469c_row13_col8, #T_7469c_row13_col13, #T_7469c_row14_col5, #T_7469c_row14_col13, #T_7469c_row15_col12, #T_7469c_row18_col10, #T_7469c_row18_col11, #T_7469c_row19_col11, #T_7469c_row19_col15 {
#   font-family: Courier;
# ...

# %%
# # * nach Jahren

# _df = (db_class_filtered
#     .aggregate("class, z_dy_str as z_dy, count(*) as cnt")
#     .to_df()
# )

# pls.plot_stacked_bars(
#     _df.export_plot_data(),
#     orientation="h",
#     height=450,
#     # normalize=True,
#     # show_pct_all=True,
#     top_n_color=10,
#     first_col_grey=True,
#     relative=True,
#     swap=True,
#     show_other=True,
#     title="nach Jahren",
# )

# %%
# db_class_agg = (db_class_filtered
#     .aggregate("z_kkr_label, source, class, count(*) as cnt, count(distinct z_tum_id) as cnt_tum")
# )

# # db_class_top_n = db_class_agg.aggregate("class, sum(cnt) as cnt").order("cnt desc").project("class").limit(TOP_N)

# _df = (db_class_agg
#     .project("class, z_kkr_label, cnt")
#     .filter("class in (select class from db_class_top_n)")
#     .to_df()
#     .dropna()
# )
# tbl.pivot_df(
#     _df,
#     data_bar_axis="",
#     heatmap_axis="xy",
#     pct_axis="",
#     total_axis="xy",
#     total_exclude=True,
#     top_n_index=10,
# )

# %% [markdown]
# ### <a id='toc1_12_3_'></a>[PSA](#toc0_)

# %%
db_comb =con.sql("""--sql
    with t0 as (
        select
            PSA as psa,
            z_tum_id,
            z_kkr_label,
            z_dy,
            z_icd10_3d,
            z_is_dco,
        from Tumor
    ),
    t1_diag as (
        select z_tum_id, count(*) as cnt
        from Diagnose_WeitereKlassifikation 
        where Name ilike '%psa%'
        and Stadium is not null
        group by all
    ),
    t1_fol as (
        select z_tum_id, count(*) as cnt
        from Folgeereignis_WeitereKlassifikation
        where Name ilike '%psa%'
        and Stadium is not null
        group by all
    ),
    t2 as (
        select
            --t0.z_tum_id,
            z_kkr_label,
            z_dy,
            z_icd10_3d,
            z_is_dco,
            (psa is not null) as has_psa,
            (t1_diag.z_tum_id is not null) as has_diag,
            (t1_fol.z_tum_id is not null) as has_fol,
            (t1_fol.z_tum_id is not null or t1_diag.z_tum_id is not null) as has_class,
            --t1_diag.cnt as cnt_psa_diag,
            --t1_fol.cnt as cnt_psa_fol,
            t1_diag.cnt + t1_fol.cnt as cnt_class,
            case
                when not has_psa and not has_class then '1_all_null'
                when has_psa and not has_class then '2_tum_only'
                when not has_psa and has_class then '3_class_only'
                when has_psa and has_class then '4_tum_and_class'
                --when psa is null and t1_diag.z_tum_id is null and t1_fol.z_tum_id is null then '1_all_null'
                --when psa is not null and t1_diag.z_tum_id is null and t1_fol.z_tum_id is null then '2_tum_only'
                --when psa is null and (t1_diag.z_tum_id is not null or t1_fol.z_tum_id is null) then '3_class_only'
                --when psa is not null and t1_diag.z_tum_id is not null and t1_fol.z_tum_id is not null then '4_tum_and_class'
                --when coalesce(psa::text, t1_diag.z_tum_id, t1_fol.z_tum_id) is not null then '5_mixed'
            else 'U' end as categ_psa
        from t0
        left join t1_diag on t0.z_tum_id = t1_diag.z_tum_id
        left join t1_fol on t0.z_tum_id = t1_fol.z_tum_id
    )
    select * from t2
""")
con.register("db_comb", db_comb)

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    ("z_icd10_3d = 'C61'", "ICD C61"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from db_comb",
    filters=_filters,
)
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                   (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]: n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:    n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [ICD C61]:        n = 379_354   (9.3%) ░░░░░░░░░░░░░░░░░░░░░░░░░░░░██
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and z_icd10_3d = 'C61'
# ```
#
# </details>

# %% [markdown]
# #### <a id='toc1_12_3_1_'></a>[Angabe zu Diagnose vs Weitere Klassifikationen](#toc0_)
# - untersucht wird, ob PSA Angaben jeweils Diagnosen zugeordnet sind (erwartete Quelle der Angabe), oder Weiteren Klassifikationen (aus Freitext isoliert)
# - Kategorien für die Kombination von PSA Werten zu jedem Tumor
#   - `1_all_null`: keine PSA Werte zum Tumor
#   - `2_tum_only`: PSA Wert nur vom Organmodul
#   - `3_class_only`: PSA Wert nur aus Weitere Klassifikationen (Diagnose oder Folgeereignis)
#   - `4_tum_and_class`: PSA Werte aus Organmodul und Weitere Klassifikationen
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - Angaben aus `02-HH` sind fast komplett leer aufgrund der fehlenden Organmodule
# > - überwiegend stammen die PSA Werte aus dem Diagnose Element, mit bis zu 87% der C61 Fälle (`14-SN`)
# > - Besonderheit `05-NW`: hier stammen zum grossen Teil PSA Angaben sowohl aus Diagnosen als auch aus Weiteren Klassifikationen

# %%
db_comb_filtered = db_comb.filter(_filter)

# db_comb.filter("categ_psa = 'U'").show()
# tbl.descr_db(db_comb, "db_comb")


pls.plot_stacked_bars(
    db_comb_filtered.project("z_kkr_label, categ_psa").to_df().export_plot_data(),
    orientation="h",
    relative=True,
    show_total=True,
    show_pct_bar=True,
    first_col_grey=True,
    color_palette=const.PALETTE_RKI2,
    height=900,
    title="PSA: Angabe zu Diagnose vs Weitere Klassifikationen",
)
# Out:
# <!-- ALT_TEXT:PSA: Angabe zu Diagnose vs Weitere Klassifikationen-->

# %% [markdown]
# #### <a id='toc1_12_3_2_'></a>[Kombinationen der PSA Merkmale](#toc0_)
# - untersucht wird, in welchen Kombinationen folgende Merkmale auftreten (deutschlandweit):
#   - `has_psa` - Tumor hat einen PSA Wert aus dem Organmodul
#   - `has_diag` - Tumor hat einen PSA Wert aus Diagnose -> Weitere Klassifikationen
#   - `has_fol` - Tumor hat einen PSA Wert aus Folgeereignis -> Weitere Klassifikationen
# - Tumore ohne jegliche PSA Angabe sind ignoriert
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - von den 375k Tumore im Filter haben 245k mind. eine PSA Angabe
# >   - 98% der Tumore mit PSA haben eine Angabe im Organmodul
# >   - 75% der Tumore mit PSA haben ausschliesslich eine Angabe im Organmodul
# >   - 23% (addiert) der Tumore mit PSA haben Angaben sowohl im Organmodul als auch kodiert im Element Diagnose und sind somit potentiell widersprüchlich
# >   - 9% der Tumore mit PSA haben Angaben zum Verlauf (kodiert in Folgeereignissen)

# %%
pls.plot_upset(
    db_comb_filtered.project("columns('^has_')").project("* exclude (has_class)").to_df().export_plot_data(),
    include_false_subsets=False,
    alt_text="Kombinationen der PSA Merkmale",
)
# Out:
# n = 379_354 | n(true) = 248_236
# <!-- ALT_TEXT:Kombinationen der PSA Merkmale-->

# %% [markdown]
# #### <a id='toc1_12_3_3_'></a>[Weitere Klassifikationen: Diagnose vs Folgeereignis](#toc0_)
# - untersucht wird pro KKR, ob sich PSA Angaben aus `Weitere Klassifikationen` überlappen
# - um Verlaufsangaben zu erkennen ist es relevant, ob Angaben in `Weitere Klassifikationen` jeweils zur Diagnose oder Folgeereignis gemacht werden
# - Kategorien für die Kombination von PSA Werten zu jedem Tumor:
#   - `1_none`: kein PSA Wert in `Weitere Klassifikationen`
#   - `2_both`: PSA Wert sowohl für Diagnose als auch für Folgeereignis vorhanden
#   - `3_diag_only`: PSA Wert nur für Diagnose vorhanden
#   - `4_fol_only`: PSA Werte nur für Folgeereignis vorhanden
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - nur `05-NW`:
# >   - kodiert nennenswert in `Weitere Klassifikationen` (78% der Tumore im Filter)
# >   - für ~27% der Tumore (addiert) liegen Verlaufsangaben vor

# %%
db_comb =con.sql(f"""--sql
    with t0 as (
        select
            PSA as psa,
            z_tum_id,
            z_kkr_label,
            z_dy,
            z_icd10_3d,
            z_is_dco,
        from Tumor
        where {_filter}
    ),
    t1_diag as (
        select z_tum_id, count(*) as cnt
        from Diagnose_WeitereKlassifikation 
        where Name ilike '%psa%'
        and Stadium is not null
        group by all
    ),
    t1_fol as (
        select z_tum_id, count(*) as cnt
        from Folgeereignis_WeitereKlassifikation
        where Name ilike '%psa%'
        and Stadium is not null
        group by all
    ),
    t2 as (
        select
            --t0.z_tum_id,
            z_kkr_label,
            -- z_dy,
            --z_icd10_3d,
            --z_is_dco,
            (psa is not null) as has_psa,
            (t1_diag.z_tum_id is not null) as has_diag,
            (t1_fol.z_tum_id is not null) as has_fol,
            (t1_fol.z_tum_id is not null or t1_diag.z_tum_id is not null) as has_class,
            t1_diag.cnt + t1_fol.cnt as cnt_class,
            case
                when not has_class then '1_none'
                when has_diag and has_fol then '2_both'
                when has_diag and not has_fol then '3_diag_only'
                when not has_diag and has_fol then '4_fol_only'
            else 'U' end as categ_psa2
        from t0
        left join t1_diag on t0.z_tum_id = t1_diag.z_tum_id
        left join t1_fol on t0.z_tum_id = t1_fol.z_tum_id
    )
    select * from t2
""")

# db_comb.show()

pls.plot_stacked_bars(
    db_comb.project("z_kkr_label, categ_psa2").to_df().export_plot_data(),
    orientation="h",
    relative=True,
    show_total=True,
    show_pct_bar=True,
    first_col_grey=True,
    color_palette=const.PALETTE_RKI2,
    height=700,
    title="PSA: Weitere Klassifikationen - Diagnose vs Folgeereignis",
)
# Out:
# <!-- ALT_TEXT:PSA: Weitere Klassifikationen - Diagnose vs Folgeereignis-->

# %% [markdown]
# ### <a id='toc1_12_4_'></a>[UICC](#toc0_)

# %%
db_uicc =con.sql("""--sql
    with t0 as (
        select
            coalesce(UICC_Stadium_p, UICC_Stadium_c) as uicc,
            z_tum_id,
            z_kkr_label,
            z_dy,
            z_icd10,
            z_icd10_3d,
            z_is_dco,
            Morphologie_Code,
        from Tumor
    ),
    t1_diag as (
        select z_tum_id, count(*) as cnt
        from Diagnose_WeitereKlassifikation 
        where Name ilike '%uicc%'
        and Stadium is not null
        group by all
    ),
    t1_fol as (
        select z_tum_id, count(*) as cnt
        from Folgeereignis_WeitereKlassifikation
        where Name ilike '%uicc%'
        and Stadium is not null
        group by all
    ),
    t1_tnm as (
        select z_tum_id, count(*) as cnt
        from Folgeereignis_TNM
        where UICC_Stadium is not null
        group by all
    ),
    t2 as (
        select
            t0.*,
            (uicc is not null) as has_diag_uicc,
            (t1_diag.z_tum_id is not null) as has_diag_class,
            (t1_fol.z_tum_id is not null) as has_fol_class,
            (t1_tnm.z_tum_id is not null) as has_fol_tnm,
            (has_fol_tnm or has_fol_class) as has_fol,
            (has_fol_class or has_diag_class) as has_class,
            (has_diag_class or has_diag_uicc) as has_diag,
            case
                when not (has_diag_uicc or has_diag_class) then '1_no_diag'
                when has_diag_uicc and not has_diag_class then '2_diag_uicc_only'
                when has_diag_uicc and has_diag_class then '3_diag_both'
                when not has_diag_uicc and has_diag_class then '4_diag_class_only'
                --when has_diag_uicc and not has_class then '2_diag_only'
                --when not has_diag_uicc and has_class then '3_fol_only'
            else '4_mixed' end as categ_uicc
        from t0
        left join t1_diag on t0.z_tum_id = t1_diag.z_tum_id
        left join t1_fol on t0.z_tum_id = t1_fol.z_tum_id
        left join t1_tnm on t0.z_tum_id = t1_tnm.z_tum_id
    )
    select * from t2
""")
con.register("db_uicc", db_uicc)

_filters = [
    FILTERS_DY,
    FILTERS_NO_DCO,
    FILTERS_TNM,
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from db_uicc",
    filters=_filters,
)

db_uicc_filtered = db_uicc.filter(_filter)

# db_uicc_filtered.filter("categ_uicc = 'U'").show()
# tbl.descr_db(db_uicc, "db_uicc")
# Out:
# <!-- START_TOKEN -->
# n = 4_062_856                               (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:             n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine DCO]:                n = 3_672_629  (90.4%) ░░░███████████████████████████
# └ [nur tnm-relevante Tumore]: n = 2_082_538  (51.3%) ░░░░░░░░░░░░░░░███████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and not z_is_dco
# and
#     (
#         left(z_icd10_3d, 1) ='C' and
#         (
#             right(z_icd10_3d, 2)::int8 between 00 and 43
#             or right(z_icd10_3d, 2)::int8 between 45 and 69
#             or right(z_icd10_3d, 2)::int8 between 73 and 74
#         )
#         and left(Morphologie_Code,4)::int between 8010 and 8790
#         and z_icd10_3d not in ('C26', 'C39', 'C55')
#         and z_icd10 not in ('C14.0', 'C57.9', 'C63.9')
#     )
# ```
#
# </details>

# %% [markdown]
# #### <a id='toc1_12_4_1_'></a>[Kombinationen](#toc0_)
#
# - untersucht wird die Überlappung von UICC Angaben
# - UICC Angaben können an folgenden Orten im Schema überliefert sein:
#   - Element `Diagnose` im `TNM` Modul (hier sind `c` und `p` Angaben zusammengefasst) - `has_diag_uicc`
#   - Element `Diagnose` in `Weitere Klassifikationen` - `has_diag_class`
#   - Element `Folgeereignis` im `TNM` Modul - `has_fol`
#   - Element `Folgeereignis` in `Weitere Klassifikationen` - `has_fol`
# - Angaben in den Folgeereignissen sind hier nicht weiter differenziert (TNM Modul und Freitext zusammengefasst)
#
# > [!NOTE]
# > **💡 ZfKD**
# > - bei ~7% (addiert) der Tumore werden UICC zur Diagnose übermittelt sowohl im TNM Modul als auch als Freitext Klassifikation
# > - diese Angaben sind potentiell widersprüchlich

# %%
pls.plot_upset(
    (
        db_uicc_filtered
        # .project("columns('^has_')")
        # .project("* exclude (has_class)")
        # .project("has_diag_uicc, has_diag_class, has_fol_class, has_fol_tnm")
        .project("has_diag_uicc, has_diag_class,has_fol")
        # .project("has_diag, has_fol, has_class")
        .to_df()
        .export_plot_data()
    ),
    include_false_subsets=False,
    alt_text="UICC: Kombinationen",
)
# Out:
# n = 2_082_538 | n(true) = 1_056_708
# <!-- ALT_TEXT:UICC: Kombinationen-->

# %% [markdown]
# #### <a id='toc1_12_4_2_'></a>[nach KKR](#toc0_)
# - Folgeereignisse sind hier nicht betrachtet
# - Kategorien:
#   - `1_no_diag`: keine UICC Angabe im Diagnose Element
#   - `2_diag_uicc_only`: UICC Angabe nur im `TNM` Modul
#   - `3_diag_both`: UICC Angabe sowohl im `TNM` Modul als auch in `Weitere Klassifikationen`
#   - `4_diag_class_only`: UICC Angabe nur in `Weitere Klassifikationen`
# -
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - Anteil Tumore im Filter mit UICC Angabe ist sehr variabel, zwischen 0% in `05-NW` und 94% in `14-SN`
# > - überlappende Angaben (Kategorie `3_diag_both`) sind potentiell widersprüchlich, bis zu 15% der Tumore in `08-BW`
# > - `03-NI` liefert die UICC Angaben zur Diagnose ausschliesslich als Freitext, `10-SL` mit erheblichem Anteil. Diese Werte werden bei UICC Auswertungen üblicherweise nicht erfasst

# %%
pls.plot_stacked_bars(
    db_uicc_filtered.project("z_kkr_label, categ_uicc").to_df().export_plot_data(),
    orientation="h",
    relative=True,
    show_total=True,
    show_pct_bar=True,
    first_col_grey=True,
    title="UICC nach KKR",
)

# del db_uicc
# Out:
# <!-- ALT_TEXT:UICC nach KKR-->

# %% [markdown]
# ## <a id='toc1_13_'></a>[Freitextkodierung](#toc0_)
#
# ### <a id='toc1_13_1_'></a>[Substanzen](#toc0_)
# - untersucht wird die Abdeckung von kodierten Freitexten im `Substanz` Element
# - die Freitextkodierung (abrufbar in: `z_substance_prediction_name`) wird hier als erfolgreich angesehen, wenn der Score (abrufbar in: `z_substance_prediction_score`) über 85% liegt
# - Kategorien:
#   - `1_all_null` - weder ATC noch Freitext vorhanden
#   - `2_code_only` - nur ATC vorhanden, keine Kodierung möglich
#   - `3_text_unpredicted` - Freitext vorhanden, keine erfolgreiche Kodierung
#   - `4_text_predicted` - Freitext vorhanden, Kodierung erfolgreich
#
# > [!NOTE]
# > **💡 ZfKD**
# > - Substanz Informationen werden inzwischen überwiegend als Kodierung übermittelt
# > - wenn Freitexte vorhanden sind werden diese mit hohem Anteil von dem Algorithmus zur Kodierung erfasst
# > - Extreme: in `07-RP` / `13-MV` sind fast alle Freitexte kodiert, in `14-SN` fast keine. Ursache noch unklar

# %%
db_subst = con.sql("""--sql
    select
        sub.z_tum_id,
        z_kkr_label,
        --lpad(z_kkr::text, 2, '0') as z_kkr,
        (SYST_TypSubstanzATC_Code is not null) as has_code,
        (Bezeichnung is not null) as has_text,
        case when z_substance_prediction_score >= 0.85 then true else false end as has_pred,
        case
            when not has_code and not has_text and not has_pred then '1_all_null'
            when has_code and not has_text and not has_pred then '2_code_only'
            when not has_code and has_text and not has_pred then '3_text_unpredicted'
            when not has_code and has_text and has_pred then '4_text_predicted'
        else 'U' end as categ_subst
    from Substanz sub
    join Tumor tum on sub.z_tum_id = tum.z_tum_id
""")

pls.plot_stacked_bars(
    db_subst.project("z_kkr_label, categ_subst").to_df().export_plot_data(),
    orientation="h",
    # relative=True,
    # show_total=True,
    show_pct_bar=True,
    first_col_grey=True,
    color_palette=const.PALETTE_RKI2,
    # color_palette="Pastel",
    title="Freitextkodierung: Substanzen",
)
# Out:
# <!-- ALT_TEXT:Freitextkodierung: Substanzen-->

# %% [markdown]
# <br>
#
# ## <a id='toc1_14_'></a>[Datum Vitalstatus](#toc0_)

# %% [markdown]
# ### <a id='toc1_14_1_'></a>[Zeitpunkt der Erhebung](#toc0_)
#
# > [!NOTE]
# > 💡 **ZfKD**: angestrebt ist die Verwendung eines einzelnen Erhebungszeitpunkts (z.B. Dezember)

# %%
_filters = [
    FILTERS_DY,
    ("Verstorben = 'N'",""),
    ("year(Datum_Vitalstatus) >= 2020","Vitalstatus >= 2020"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum join Patient pat on tum.oBDS_RKIPatientId = pat.oBDS_RKIPatientId",
    filters=_filters,
    distinct_metric="z_pat_id",
)

_tu = (con.sql(f"""--sql
    with t1 as (
        select
            year(Datum_Vitalstatus::date)::text as Vitalstatus_YY,
            'M' || lpad(month(Datum_Vitalstatus)::text, 2, '0') as Vitalstatus_MM,
            z_kkr_label,
            --z_pat_id,
        from Patient pat
        join Tumor tum on pat.oBDS_RKIPatientId = tum.oBDS_RKIPatientId
        where {_filter}
    ),
    t2 as (
        select
            *,
            count(*) as cnt,
        from t1
        group by all
    ),
    t3 as (
        SELECT
            range::int16 AS Vitalstatus_YY,
            NULL AS Vitalstatus_MM,
            label AS z_kkr_label,
            0 AS cnt
        FROM range(2020, 2026)
        CROSS JOIN (SELECT unnest(['01-SH', '02-HH', '03-NI','04-HB','05-NW','06-HE','07-RP','08-BW','09-BY','10-SL','11-BE','12-BB','13-MV','14-SN','15-ST','16-TH']) AS label)
    ),
    t4 as (
        select
            Vitalstatus_YY,
            Vitalstatus_MM,
            z_kkr_label,
            cnt,
        from t2
        union
        select
            Vitalstatus_YY,
            Vitalstatus_MM,
            z_kkr_label,
            cnt,
        from t3
    )
    select * from t4
    """)
    .to_df()
)
# _tu
# Out:
# <!-- START_TOKEN -->
# count: distinct z_pat_id
# ---
# n = 3_452_844                          (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:        n = 3_444_458  (99.8%) ░█████████████████████████████
# └ [Verstorben = 'N']:    n = 2_452_511  (71.0%) ░░░░░░░░░█████████████████████
# └ [Vitalstatus >= 2020]: n = 2_447_358  (70.9%) ░░░░░░░░░█████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Verstorben = 'N'
# and year(Datum_Vitalstatus) >= 2020
# ```
#
# </details>

# %%
_=pls.plot_facet_stacked_bars(
    _tu.export_plot_data(),
    relative=True,
    subplot_size=400,
    # subplots_per_row=4,
    # top_n_color=5,
    # sort_values_index=True,
    # sort_values_facet=True,
    # show_other=False,
    annotations=True,
    title="Zeitpunkt der Erhebung",
)
# Out:
# <!-- ALT_TEXT:Zeitpunkt der Erhebung-->

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# ## <a id='toc1_15_'></a>[Numerische Variablen](#toc0_)

# %%
# _db = con.sql("""--sql
# select z_kkr_label, Diagnosedatum_Genauigkeit, count(*) as cnt from Tumor group by all
# """)

# pls.plot_stacked_bars(
#     _db.to_df(),#.export_plot_data(),
#     orientation="h",
#     relative=True,
#     # show_total=True,
#     show_pct_bar=True,
#     color_palette=const.PALETTE_RKI2,
#     # height=700,
#     # title="Diagnosedatum Genauigkeit",
#     )

# %% [markdown]
# <br>
#
# ### <a id='toc1_15_1_'></a>[Diagnosealter](#toc0_)
# - berechnet aus `Diagnosedatum` - `Geburtsdatum`
# - negative Werte entstehen aus falscher Datumsreihenfolge von Ereignissen
# - die Angaben sind
#   - in der Tabelle unbereinigt, um strukturelle Effekte sichtbar zu machen
#   - in den Boxplots gefiltert nach `z_age between 0 and 130` um die Verteilung besser darstellen zu können
#
# > [!NOTE]
# > 💡 **ZfKD**
# > - für die eingeschlossenen DJ liegen (nahezu) keine vollständig geschätzten Angaben vor
# > - wenige (aber extreme) Ausreisser in `13-MV`

# %%
_filters = [
    FILTERS_DY,
    ("Diagnosedatum_Genauigkeit <> 'V' and Geburtsdatum_Genauigkeit <> 'V'","keine geschätzten Datumsangaben"),
]

_filter=hlp.get_duckdb_filter_n(
    con=con,
    query="from Tumor tum join Patient pat on tum.oBDS_RKIPatientId = pat.oBDS_RKIPatientId",
    filters=_filters,
    distinct_metric="z_tum_id",
)

_db = con.sql(f"""--sql
    select
        z_tum_id,
        z_kkr_label,
        z_age,
        Tumordicke,
        Anzahl_Tage_Diagnose_Tod,
        PSA,
        LK_befallen,
        LK_untersucht,
        RektumAbstandAnokutanlinie,
        LDH,
    from Tumor tum
    join Patient pat on tum.oBDS_RKIPatientId = pat.oBDS_RKIPatientId 
    where {_filter}
    group by all
""")

_df = _db.to_df()
# Out:
# <!-- START_TOKEN -->
# count: distinct z_tum_id
# ---
# n = 4_062_856                                      (100.0%) ██████████████████████████████
# └ [DJ 2020-2024]:                    n = 3_794_188  (93.4%) ░░████████████████████████████
# └ [keine geschätzten Datumsangaben]: n = 3_793_405  (93.4%) ░░████████████████████████████
# <!-- END_TOKEN -->
# <details>
# <summary>filter-sql</summary>
#
# ```sql
# z_dy between 2020 and 2024
# and Diagnosedatum_Genauigkeit <> 'V' and Geburtsdatum_Genauigkeit <> 'V'
# ```
#
# </details>

# %%
_df_filter  = _db.filter("z_age between 0 and 130").to_df()

# plots
_=pls.plot_box_large(_df_filter["z_age"], height=150, width=2000, summary=False)
_ = pls.plot_boxes_large(_df_filter[["z_kkr_label", "z_age"]],height=400,width=2000, summary=False,)

# summary
_ = pls.plot_boxes_large(_df[["z_kkr_label", "z_age"]],plot=False,)
# Out:
# column (n = 3_793_405) |     notnull      |  min  | lower |  q25  | median | mean  |  q75  | upper  |  max   |  std  |  cv
# -----------------------+------------------+-------+-------+-------+--------+-------+-------+--------+--------+-------+-----
# z_age                  | 3_793_405 (100%) | -4.17 | 29.92 | 59.75 |  70.17 | 68.29 | 79.67 | 109.17 | 983.33 | 14.74 | 0.22
#
#
# item (n = 3_793_405) |   count   |  min  | lower |  q25  | median | mean  |  q75  | upper  |  max   |  std  |  cv
# ---------------------+-----------+-------+-------+-------+--------+-------+-------+--------+--------+-------+-----
# 01-SH                |   194_238 |  0.00 | 32.58 | 61.58 |  72.58 | 70.12 | 80.92 | 106.67 | 112.50 | 14.26 | 0.20
# 02-HH                |    69_555 |  0.00 | 22.83 | 56.42 |  68.58 | 66.16 | 78.83 | 104.83 | 104.83 | 16.21 | 0.25
# 03-NI                |   277_364 | 13.08 | 30.58 | 58.92 |  68.83 | 67.12 | 77.83 | 105.33 | 105.33 | 14.10 | 0.21
# ...

# %% [markdown]
# <br>
#
# ### <a id='toc1_15_2_'></a>[Anzahl Tage zwischen Diagnose und Tod](#toc0_)
# - die Angaben sind
#   - in der Tabelle unbereinigt, um strukturelle Effekte sichtbar zu machen
#   - in den Boxplots gefiltert nach `Anzahl_Tage_Diagnose_Tod > 0` um die Verteilung besser darstellen zu können

# %%
_df_filter =  _db.filter("Anzahl_Tage_Diagnose_Tod > 0").to_df()

_=pls.plot_box_large(_df_filter["Anzahl_Tage_Diagnose_Tod"], height=150, width=2000, use_log=False, summary=False)
_ = pls.plot_boxes_large(_df_filter[["z_kkr_label", "Anzahl_Tage_Diagnose_Tod"]],height=400,width=2000,summary=False,use_log=False,)

_ = pls.plot_boxes_large(_df[["z_kkr_label", "Anzahl_Tage_Diagnose_Tod"]],plot=False, summary=True,)
# Out:
# column (n = 3_793_405)   |     notnull     |  min   | lower |  q25  | median |  mean  |  q75   | upper |  max  |  std   |  cv
# -------------------------+-----------------+--------+-------+-------+--------+--------+--------+-------+-------+--------+-----
# Anzahl_Tage_Diagnose_Tod | 1_072_049 (28%) | -6_000 |  -212 | 45.00 | 217.00 | 372.15 | 567.00 | 1_350 | 2_210 | 418.21 | 1.12
#
#
# item (n = 3_793_405) |  count  |  min   | lower |  q25  | median |  mean  |  q75   | upper |  max  |  std   |  cv
# ---------------------+---------+--------+-------+-------+--------+--------+--------+-------+-------+--------+-----
# 01-SH                |  55_342 |      0 |     0 | 31.00 | 217.00 | 391.41 | 611.00 | 1_481 | 2_185 | 450.63 | 1.15
# 02-HH                |  23_311 |      0 |     0 | 37.00 | 184.00 | 348.89 | 520.00 | 1_244 | 2_159 | 414.58 | 1.19
# 03-NI                |  85_931 |      0 |     0 | 81.00 | 273.00 | 420.74 | 625.00 | 1_441 | 2_187 | 431.13 | 1.02
# ...

# %% [markdown]
# ### <a id='toc1_15_3_'></a>[PSA](#toc0_)

# %%
_=pls.plot_box_large(_df["PSA"], height=150, width=2000, use_log=True, violin=False, summary=False)
_=pls.plot_boxes_large(_df[["z_kkr_label", "PSA"]], height=400, width=2000, summary=False, use_log=True)

_ = pls.plot_boxes_large(_df[["z_kkr_label", "PSA"]],plot=False, summary=True,)
# Out:
# column (n = 3_793_405) |   notnull    | min  | lower | q25  | median | mean  |  q75  | upper |    max    |  std   |  cv
# -----------------------+--------------+------+-------+------+--------+-------+-------+-------+-----------+--------+-----
# PSA                    | 245_159 (6%) | 0.00 |  0.00 | 5.63 |   8.74 | 90.67 | 18.00 | 36.55 | 99_999.00 | 743.88 | 8.20
#
#
# item (n = 3_793_405) | count  | min  | lower | q25  | median |  mean  |  q75  | upper |    max    |   std    |  cv
# ---------------------+--------+------+-------+------+--------+--------+-------+-------+-----------+----------+------
# 01-SH                |  8_181 | 0.00 |  0.00 | 5.86 |   9.32 | 175.20 | 21.00 | 43.70 | 52_060.00 | 1_225.13 |  6.99
# 03-NI                | 20_601 | 0.00 |  0.00 | 5.56 |   8.44 |  75.94 | 16.80 | 33.66 | 28_485.00 |   477.38 |  6.29
# 04-HB                |  1_668 | 0.00 |  0.00 | 5.80 |   9.10 |  93.68 | 20.58 | 42.60 |  9_000.00 |   449.20 |  4.79
# ...

# %% [markdown]
# ### <a id='toc1_15_4_'></a>[LK_untersucht](#toc0_)

# %%
_=pls.plot_boxes_large(_df[["z_kkr_label", "LK_untersucht"]], height=400, width=2000,  summary=False, use_log=True)
_=pls.plot_box_large(_df["LK_untersucht"], height=150, width=2000,  use_log=False, violin=False, plot=False, summary=False)

_ = pls.plot_boxes_large(_df[["z_kkr_label", "LK_untersucht"]],plot=False, summary=True,)
# Out:
# column (n = 3_793_405) |    notnull    | min | lower | q25  | median | mean  |  q75  | upper |  max  |  std  |  cv
# -----------------------+---------------+-----+-------+------+--------+-------+-------+-------+-------+-------+-----
# LK_untersucht          | 947_076 (24%) |   0 |     0 | 1.00 |   5.00 | 10.50 | 17.00 |    41 | 2_319 | 13.58 | 1.29
#
#
# item (n = 3_793_405) |  count  | min | lower | q25  | median | mean  |  q75  | upper |  max  |  std  |  cv
# ---------------------+---------+-----+-------+------+--------+-------+-------+-------+-------+-------+-----
# 01-SH                |  28_058 |   0 |     0 | 2.00 |  11.00 | 13.24 | 20.00 |    47 |   121 | 13.14 | 0.99
# 02-HH                |  16_589 |   0 |     0 | 2.00 |   8.00 | 13.04 | 20.00 |    47 |   168 | 14.72 | 1.13
# 03-NI                |  84_781 |   0 |     0 | 3.00 |  10.00 | 12.38 | 18.00 |    40 | 2_021 | 13.68 | 1.10
# ...

# %% [markdown]
# ### <a id='toc1_15_5_'></a>[LK_befallen](#toc0_)

# %%
_=pls.plot_boxes_large(_df[["z_kkr_label", "LK_befallen"]], height=400, width=2000, summary=False, use_log=True)
_=pls.plot_box_large(_df["LK_befallen"], height=150, width=2000,  use_log=False, violin=False, plot=False, summary=False)

_ = pls.plot_boxes_large(_df[["z_kkr_label", "LK_befallen"]],plot=False, summary=True,)
# Out:
# column (n = 3_793_405) |    notnull    | min | lower | q25  | median | mean | q75  | upper | max | std  |  cv
# -----------------------+---------------+-----+-------+------+--------+------+------+-------+-----+------+-----
# LK_befallen            | 792_920 (20%) |   0 |     0 | 0.00 |   0.00 | 0.92 | 0.00 |     0 | 722 | 3.08 | 3.36
#
#
# item (n = 3_793_405) |  count  | min | lower | q25  | median | mean | q75  | upper | max | std  |  cv
# ---------------------+---------+-----+-------+------+--------+------+------+-------+-----+------+-----
# 01-SH                |  27_920 |   0 |     0 | 0.00 |   0.00 | 1.28 | 1.00 |     2 |  67 | 3.48 | 2.72
# 02-HH                |  16_587 |   0 |     0 | 0.00 |   0.00 | 1.15 | 1.00 |     2 |  63 | 3.10 | 2.68
# 03-NI                |  84_524 |   0 |     0 | 0.00 |   0.00 | 1.16 | 1.00 |     2 |  89 | 3.20 | 2.75
# 04-HB                |   8_014 |   0 |     0 | 0.00 |   0.00 | 1.25 | 1.00 |     2 |  43 | 3.20 | 2.56
# ...
